# %% [markdown]
# <h1 style="display:none;">Test</h1>
# <h1 style="line-height: 1.2">W4111 Introduction to Databases $-$ Lecture 2:<br>Begin Working with Data, Data Modeling, Databases and Applications</h1>

# %%
# %load_ext sql
# %sql mysql+pymysql://dbuser:dbuser@localhost/lahman2017
# %sql select * from people where playerid='willite01'
# Out:
# 1 rows affected.
# [('willite01', '1918', '8', '30', 'USA', 'CA', 'San Diego', '2002', '7', '5', 'USA', 'FL', 'Inverness', 'Ted', 'Williams', 'Theodore Samuel', '205', 75, 'L', 'R', '1939-04-20', '1960-09-28', 'willt103', 'willite01')]

# %% [markdown]
# ## Questions or Comments?

# %% [markdown]
# ### Open Q&A
#
# ### From Piazza
#
# #### Indexing in Memory
#
# |<img src="../images/piazza_1.jpeg">|
# | :---: |
# | __Good Piazza Question__ |

# %% [markdown]
# - This is an insightful question.
#
#
# - Python dictionaries implement a _hash index_ on elements based on the key. Pandas also supports indexes.
#
#
# - RDBs support hash indexes but also support a binary tree link index, which helps with queries using >, >=, ...
#
#
# - RDBs also handle the case in which the "dictionary" does not fit into memory, or the index data structure itself is too large to fit into memory.
#
#
# - We will cover these concepts latter.

# %% [markdown]
# #### Constructor vs Explicit ```load()``` Call
#
# |<img src="../images/piazza_2.jpeg">|
# | :---: |
# | __Good Piazza Question__ |

# %% [markdown]
# - Another good question.
#
#
# - Consider the test function below:
#
# ```
# def testC():
#     try:
#         # Create the DataTable and load it.
#         csvt = CSVTable.CSVTable("People", "People.csv", ["playerID"])
#         csvt.load()
#
#         # Print some information about the table.
#         print("Initial table is:")
#         print(csvt)
#
#         # Define the template and fields to select.
#         t2 = {"nameLast": "Williams", "throws": "R"}
#         fields2 = ['nameLast', 'nameFirst', 'birthCountry', 'throws', 'bats']
#         print("Testing template ", t2, " on table", "People")
#         print("With field list = ", fields2)
#
#         # Run and print query. Notice the result is also a Data Table
#         result = csvt.find_by_template(t2, fields2)
#         print("\n\nQuery result is ")
#         print(result)
#
#         print("\n\nNow querying the derived table.")
#         t3 = { "nameFirst": "Ted"}
#         result2 = result.find_by_template(t3, None)
#         print("\n\nQuery2 result is ")
#         print(result2)
#     except Exception as e:
#         print("Got exception = ", str(e))
# ```
#
# - The result of the first query is __a CSVTable.__ The relational algebra is closed under operators. Queries on table always produce table.
#
#
# - Subsequent code queries the result of the first query. The result of the first query is a __derived__ table.
#
#
# - The program output is below. I do not expect you to implement all of the complexity and nuances. My implementation is for teaching concepts.
#
# ```
# Initial table is:
# Name: People, File: People.csv, No of rows: 19370, Key: ['playerID']
# playerID       birthYear      birthMonth     birthDay       birthCountry   birthState     birthCity      deathYear      deathMonth     deathDay       deathCountry   deathState     deathCity      nameFirst      nameLast       nameGiven      weight         height         bats           throws         debut          finalGame      retroID        bbrefID
# aardsda01      1981           12             27             USA            CO             Denver                                                                                                   David          Aardsma        David Allan    215            75             R              R              2004-04-06     2015-08-23     aardd001       aardsda01
# aaronha01      1934           2              5              USA            AL             Mobile                                                                                                   Hank           Aaron          Henry Louis    180            72             R              R              1954-04-13     1976-10-03     aaroh101       aaronha01
# aaronto01      1939           8              5              USA            AL             Mobile         1984           8              16             USA            GA             Atlanta        Tommie         Aaron          Tommie Lee     190            75             R              R              1962-04-10     1971-09-26     aarot101       aaronto01
# aasedo01       1954           9              8              USA            CA             Orange                                                                                                   Don            Aase           Donald William 190            75             R              R              1977-07-26     1990-10-03     aased001       aasedo01
# abadan01       1972           8              25             USA            FL             Palm Beach                                                                                               Andy           Abad           Fausto Andres  184            73             L              L              2001-09-10     2006-04-13     abada001       abadan01
# ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...            ...
# zychto01       1990           8              7              USA            IL             Monee                                                                                                    Tony           Zych           Anthony Aaron  190            75             R              R              2015-09-04     2017-08-19     zycht001       zychto01
# zwilldu01      1888           11             2              USA            MO             St. Louis      1978           3              27             USA            CA             La Crescenta   Dutch          Zwilling       Edward Harrison160            66             L              L              1910-08-14     1916-07-12     zwild101       zwilldu01
# zuverge01      1924           8              20             USA            MI             Holland        2014           9              8              USA            AZ             Tempe          George         Zuverink       George         195            76             R              R              1951-04-21     1959-06-15     zuveg101       zuverge01
# zuvelpa01      1958           10             31             USA            CA             San Mateo                                                                                                Paul           Zuvella        Paul           173            72             R              R              1982-09-04     1991-05-02     zuvep001       zuvelpa01
# zupofr01       1939           8              29             USA            CA             San Francisco  2005           3              25             USA            CA             Burlingame     Frank          Zupo           Frank Joseph   182            71             L              R              1957-07-01     1961-05-09     zupof101       zupofr01
#
# Testing template  {'nameLast': 'Williams', 'throws': 'R'}  on table People
# With field list =  ['nameLast', 'nameFirst', 'birthCountry', 'throws', 'bats']
#
#
# Query result is
# Name: PROJECT_SELECTED_People.csv, File: DERIVED, No of rows: 61, Key: None
# nameLast       nameFirst      birthCountry   throws         bats
# Williams       Al             USA            R              R
# Williams       Albert         Nicaragua      R              R
# Williams       Art            USA            R              L
# Williams       Bernie         USA            R              R
# Williams       Bernie         P.R.           R              B
# ...            ...            ...            ...            ...
# Williams       Woody          USA            R              R
# Williams       Woody          USA            R              R
# Williams       Walt           USA            R              R
# Williams       Trevor         USA            R              R
# Williams       Todd           USA            R              R
#
#
#
# Now querying the derived table.
#
#
# Query2 result is
# Name: SELECTED_DERIVED, File: DERIVED, No of rows: 1, Key: None
# nameLast       nameFirst      birthCountry   throws         bats
# Williams       Ted            USA            R              L
# ```

# %% [markdown]
# #### Nothing Found by ```find_by_template()```
#
# | <img src="../images/piazza4.jpeg"> |
# | :---: |
# | __NULL Response__ |
#
# - But let's try this out.

# %%
import pymysql.cursors
import pandas as pd
import json

# The database server is running somewhere in the network.
# I must specify the IP address (HW server) and port number
# (connection that SW server is listening on)
# Also, I do not want to allow anyone to access the database
# and different people have different permissions. So, the
# client must log on.


# Connect to the database over the network. Use the connection
# to send commands to the DB.
cnx = pymysql.connect(host='localhost',
                             user='dbuser',
                             password='dbuser',
                             db='lahman2017',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)


def DBRunQuery(q):
    cursor=cnx.cursor()
    print ("Query = ", q)
    cursor.execute(q);
    r = cursor.fetchall()
    #print("Query result = ", r)
    return r

# %%
result = DBRunQuery("select * from people where playerid='cat'")
print("The result is of type: ", type(result))
print("OK. The answer is an instance of the class 'tuple.'")
# Out:
# Query =  select * from people where playerid='cat'
# The result is of type:  <class 'tuple'>
# OK. The answer is an instance of the class 'tuple.'

# %%
if result is None:
    print("Nothing there!")
else:
    print("There is SOMETHING THERE.")
    print("Tuple length is = ", len(result))
    for row in result:
        print("A row = ", row)
    else:
        print("Printed all the rows.")
    print("\nSeems clear to me that the answer is 'an empty set'")
# Out:
# There is SOMETHING THERE.
# Tuple length is =  0
# Printed all the rows.
#
# Seems clear to me that the answer is 'an empty set'

# %% [markdown]
# - We will see today that the _relational model_ is an _algebra_ and is closed under its operators.
#
#
# - A relational expression __always:__
#     - Operates on relations (tables)
#     - Produces a relation or table.
#
#
# - The empty table or relation is a table/relation.

# %% [markdown]
# #### ```save()``` vs. Write File on ```insert() or delete()```
#
# | <img src="../images/piazza5.jpeg"> |
# | :---: |
# | __Cache Write Models__ |

# %% [markdown]
# - We will see in __Module I__ on database management system architecture and implementation that this is an incredibly complex and profound question.
#
#
# - Always reading from the in-memory data makes sense.
#
#
# - Consider ```insert()``` and ```delete()```
# <br>
#     - Writing the file on every update has several benefits:
#         - Less likely to lose changes if there is a failure.
#         - Simple.
#         - Other programs can read file and see updates.
#     - The main disadvantage is performance overhead.
#         - A tuple may change several times during execution. Why write every change instead of the last one.
#         - File open and close on every update.
#         - Saving the entire file (or changed tuples) once is much more efficient.
#
#
# - Database management systems have very sophisticated algorithms and software to optimize behavior and performance for saving updates.
#
#
# - For the homework, either approach is fine.

# %% [markdown]
# ## Today's Lecture
#
# 1. Introduction to Relational Algebra/Model and SQL Realization
# <br>
# 1. Examples of
#     1. SELECT
#     1. PROJECT
#     1. WHERE

# %% [markdown]
# ## The Relational Model $-$ I
#
# ### Overview
#
# References: Ramakrishnan and Gehrke, section 3.1
#
# There are two perspectives on the relational model:
# - Formal language and algebra.
#
#
# - A standard implementation language, Structure Query Language [(SQL)](https://en.wikipedia.org/wiki/SQL)
#
#
# - The relational model and SQL language (and most DB engines) have two sub-languages/models:
#     - Data definition
#     - Data manipulation
#
#
# - SQL and other database engines also have an API/language for administration and security.
#
# | <img src="../images/db_engine_apis.jpeg"> |
# | :---: |
# | __DN Engine Interfaces__ |

# %% [markdown]
# ### Defining Data
#
# #### Relational Model
#
# - _Relational Schema_ defines and provides metadata describing what is/can be in "the file" (called a _relation_), e.g.<br>
#
#
# ```
# People(
#     playerID:string,
#     birthYear:string,
#     birthMonth:string,
#     birthDay:string,
#     birthCountry:string,
#     birthState:string,
#     birthCity:string,
#     deathYear:string,
#     deathMonth:string,
#     deathDay:string,
#     deathCountry:string,
#     deathState:string,
#     deathCity:string,
#     nameFirst:string,
#     nameLast:string,
#     nameGiven:string,
#     weight:string,
#     height:string,
#     bats:string,
#     throws:string,
#     debut:string,
#     finalGame:string,
#     retroID:string,
#     bbrefID!:string)
# ```
#
# __Note:__
# 1. A lot of these attributes are not really strings.
# 1. The data types are "confused" because we got the input via a CSV/text file.
# 1. We will have to clean up the data as we go forward.
# 1. Relational model is imprecise about allowed types, but there are obvious ones:
#     1. Integer
#     1. Real
#     1. String
#
# - A _Relational Instance_ is a "table" of data that conforms to a relation schema, e.g.<br><br>
#
# | <img src="../images/bbmaster.jpeg" width="90%"> |
# | :---: |
# | __People Relational Instance__ |

# %% [markdown]
# #### SQL
#
# - Structured Query Language (SQL) is a well-defined programming language that realizes a superset of the relation model.
#
#
# - There are two sub-languages
#     - Data Definition Language (DDL) corresponds to relational schema.
#     - Data Manipulation Language corresponds to relational algebra (covered later).
#
#
# - DML statements are how you create tables in SQL.
#
#
# - Defining a table in SQL: The default you get if you just import the People.CSV file is
# ```
# CREATE TABLE `people` (
#   `playerID` text,
#   `birthYear` text,
#   `birthMonth` text,
#   `birthDay` text,
#   `birthCountry` text,
#   `birthState` text,
#   `birthCity` text,
#   `deathYear` text,
#   `deathMonth` text,
#   `deathDay` text,
#   `deathCountry` text,
#   `deathState` text,
#   `deathCity` text,
#   `nameFirst` text,
#   `nameLast` text,
#   `nameGiven` text,
#   `weight` text,
#   `height` text,
#   `bats` text,
#   `throws` text,
#   `debut` text,
#   `finalGame` text,
#   `retroID` text,
#   `bbrefID` text
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
# ```
#
# - The back, single quotes are a sometimes useful/sometimes annoying aspect of MySQL's implementation of the SQL standard.
#     - Anything in between single back quotes is a schema element.
#     - Allows attributes and table names of the form \`My Table\` \`My-Table\` and makes clear that \`My-Table\` is a schema element and not an attempt to subtract the variable `Table` from the variable `My`
#
#
# - SQL has a superset of the relational model's schema definition capability. An improved table definition could be
#
# ```
# CREATE TABLE `people` (
#   `playerID` varchar(12) NOT NULL,
#   `birthYear` char(4) DEFAULT NULL,
#   `birthMonth` char(2) DEFAULT NULL,
#   `birthDay` char(2) DEFAULT NULL,
#   `birthCountry` varchar(64) DEFAULT NULL,
#   `birthState` varchar(32) DEFAULT NULL,
#   `birthCity` varchar(64) DEFAULT NULL,
#   `deathYear` char(4) DEFAULT NULL,
#   `deathMonth` char(2) DEFAULT NULL,
#   `deathDay` char(2) DEFAULT NULL,
#   `deathCountry` varchar(64) DEFAULT NULL,
#   `deathState` varchar(32) DEFAULT NULL,
#   `deathCity` varchar(64) DEFAULT NULL,
#   `nameFirst` varchar(64) NOT NULL,
#   `nameLast` varchar(64) NOT NULL,
#   `nameGiven` varchar(128) DEFAULT NULL,
#   `weight` char(3) DEFAULT NULL,
#   `height` char(3) DEFAULT NULL,
#   `bats` char(1) DEFAULT NULL,
#   `throws` char(1) DEFAULT NULL,
#   `debut` varchar(16) DEFAULT NULL,
#   `finalGame` varchar(16) DEFAULT NULL,
#   `retroID` varchar(12) DEFAULT NULL,
#   `bbrefID` varchar(12) DEFAULT NULL,
#   PRIMARY KEY (`playerID`)
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
# ```
#
# - This definition adds two benefits
#     1. More precise definition of attribute sizes
#         - Allows the database engine to more efficiently allocate disk/storage space and place records on disk.
#         - This is not important for a relation with a few thousand rows requiring a couple of MB.
#         - But, some scenarios have millions or billions of rows requiring GBs of storage.
#     1. Integrity Constraints: The database engine will not allow creates or updates that produce obviously invalid data, e.g.
#         - You cannot create a person that does not have a first and last name.
#         - ```throws``` can only be a single character: 'L', 'R', 'B'
#         - The various month attributes can only be things like '1', '11'.
#
#
# - There is a lot more cleanup and refinement we could have, should have and will do. For example,
#     - Many of these fields should be numbers, e.g. ```weight```
#     - Unfortunately, the data is "dirty" and some weights are unknown, and hence "".
#
#
# - Cleaning up the data will help us understand the benefits and semantics of the relational model and data modeling in general.
#
#
# - The SQL DML
#     - Has many other operations/statements.
#         - DROP
#         - ALTER
#     - Operates on more than just a table's attributes, e.g.
#         - Constraints
#         - Triggers
#         - Indexes
#
#
# - We will go into DML and defining data in much more detail.

# %% [markdown]
# ### Manipulating and Processing Information
#
# #### Computer Languages
#
# - A [declarative language's] (https://en.wikipedia.org/wiki/Declarative_programming) statements express what is supposed to happen/be output, but not how to do it. The opposite of a declarative language is an [imperative language.](https://en.wikipedia.org/wiki/Imperative_programming)
#
#
# - Most languages with which you are familiar are imperative languages.
#
#
# - The most distinguishing feature is that declarative languages do not have control-flow constructs, e.g.
#     - ```if {...} else {...}```
#     - ```for (...) {...}```
#
#
# - The relation model, SQL and many DB languages are (primarily) declarative languages.

# %% [markdown]
# #### Algebraic Query Language
#
# Reference: Ramkrishan and Gherke, section 2.4.
#
# Both the abstract relational model/theory and SQL are __algebras__.
#
# ##### Algebra
#
# "... abstract algebra (occasionally called modern algebra) is the study of algebraic structures." (https://en.wikipedia.org/wiki/Abstract_algebra)
#
# "In mathematics, and more specifically in abstract algebra, an algebraic structure is a set (called carrier set or underlying set) with one or more operations defined on it that satisfies a list of axioms." (https://en.wikipedia.org/wiki/Algebraic_structure)
#
# __Group is an Example__ (http://mathworld.wolfram.com/Group.html)
#
# "A group G is a finite or infinite set of elements together with a binary operation (called the group operation) that together satisfy the four fundamental properties of closure, associativity, the identity property, and the inverse property. The operation with respect to which a group is defined is often called the "group operation," and a set is said to be a group "under" this operation. Elements A, B, C, ... with binary operation between A and B denoted AB form a group if
#
# 1. Closure: If A and B are two elements in G, then the product AB is also in G.
# <br><br>
# 2. Associativity: The defined multiplication is associative, i.e., for all A,B,C in G, (AB)C=A(BC).
# <br><br>
# 3. Identity: There is an identity element I (a.k.a. 1, E, or e) such that IA=AI=A for every element A in G.
# <br><br>
# 4. Inverse: There must be an inverse (a.k.a. reciprocal) of each element. Therefore, for each element A of G, the set contains an element B=A<sup>-1</sup> such that <br>AA<sup>-1</sup>=A<sup>-1</sup>A=I.

# %% [markdown]
# ##### Why a Special Query Language? Why a Formal Language? Why an Algebra
#
# - Computing has a formal mathemetical model.
#
#
# - Programming languages derive from the model and have their own formal definition.
#
#
# - Almost every time someone publishes a new language, my reaction is, "What? Why another language? Can't we just pick one, use it and get it right?"
#
#
# - Relational algebra is less powerful and expressive than Java, C, ... and other programming languages.
#
#
# - __The simplicity and constrained capabilities is actually the core of the value,__ enabling
#     - Vastly simplified programming and supporting tools that yields increased productivity.
#     - Development of algorithms that process the data definitions and query statements to automatically produce optimal execution plans, which are better than what a programmer can directly code.
#
#
# - We will see these benefits in coming lectures.
#
#
# _Simple Tool Example_ that enables "citizen programmers" to maniuplate data.
#
# <img src="../images/ss_1.jpeg">
#
# <br><br>
# _Simple Tool Example_ for enabling business professionals to analyze and report on data.
# <img src="../images/quicksite.jpeg" width="85%">

# %% [markdown]
# #### Relational Algebra
#
# - There are two notations or representations of the algebra:
#     - The original, formal theory.
#     - SQL
#
# ##### Original, Formal Relational Notation
#
# Ramakrishnan and Gehrke, section 4.2
#
#
# - The "set" in the relational algebra is the set of _relations_.
#
#
# - The operations are:
#     - Common set operations:
#         - Union: $\cup$
#         - Intersection: $\cap$
#         - Difference: $-$
#     - Projection: $\pi$
#     - Selection: $\sigma$
#     - Cartesian Product: $\times$
#     - Join: $\bowtie$
#     - Rename/Alias
#
#
# - The formal notation does not support create, update or delete of tuples/rows in a relation. You could emulate the operations by
#     - Defining new relations containing the created, updated or delete tuples.
#     - Using $\cup$, $\cap$, $-$ on the original relation and created/deleted/updated tuple relation.
#
#
# - This is an algebra $\Rightarrow$ that $R_1\ OP\ R_2 \rightarrow R_3 ,$ where $R_1 , R_2 , $ and $R_3$ are relations ( aka tables). Relationa algebra is closed. Algebra statements operate on relations and produce relations.
#
#
# ##### SQL Notation
#
# Ramakrishnan and Gehrke, sections 5.1, 5.2
#
# - The "set" in the relational algebra is the catalog of _tables_.
#
#
# - The operations are:
#     - Common set operations:
#         - Union: UNION
#         - Intersection: INTERSECT
#         - Difference: EXCEPT
#     - Selection, Projection, Cartesian Product, Rename/Alias and Join are clauses within a SELECT statement.
#
#     ```SELECT <project clause> FROM <table> [JOIN <table> [ON <join condition]] WHERE <select condition>```
#
#
# - SQL supports additional operations, e.g
#     - GROUP BY
#     - ORDER BY
#     - INSERT, DELETE, UPDATE

# %% [markdown]
# ### Selection and Projection
#
# #### Relational Model

# %% [markdown]
#
# - <span style="color: red;">Projection</span> produces a new relation that
#     - Has the same rows as the original table
#     - But only contains the requested columns/fields
#
#
# - <span style="color: red;">Selection</span> produces a new relation that
#     - Has the same columns as the original relation
#     - But only contains rows with column values matching a predicate.
#
#
# - <span style="color: red;">Projection, Selection and Keys are required for HW 2. </span>
#
#
# - We will cover the other operations in the next few lectures.

# %% [markdown]
# ##### Selection
#
# - The selection operator is $\sigma$
#
#
# - The selection predicate operators are: $\lt, \gt, =, \ne, \ge, \le$
#
#
# - $\sigma(Players)$ selects all of the rows/tuples in the player relation.
#
#
# - The predicate/condition is a "subscript," e.g.
#     - $\sigma$<sub>playerID=napolmi01</sub>$(Players)$ selects all players with _playerID=napolmi01_
#     - $\sigma$<sub>((nameLast=Williams)$\land(throws=L))\lor(birthYear\ne1914)$</sub>$(Players)$ selects all players with
#         - Last name williams who threw lefthanded or
#         - Birth year not equal to 1914
#
#
# - This notation is a little clunky. You can think of the selection predicate being similar to what goes in an _if()_ statement if you were looping through an array testing for a match.

# %% [markdown]
# ###### Projection
#
# - The projection operator is $\pi$
#
#
# - The requested columns are subscripts on the operator, e.g. $\pi$<sub>$nameLast,nameFirst,throws$</sub>$(Players)$ returns a table
#     - Containing the $nameLast, nameFirst, throws$ column values, in that order
#     - For all tuples in the $Players$ table.

# %% [markdown]
# ##### An Algebra
#
# - Because the relational model is an algebra, composition is possible.
#
#
# - Like algebras, there are instances where composition support _commutativity,_ _associativity,_ _distribution_ and other algebra rules.
#
#
# - For example, $\pi$ and $\sigma$ are commutative.
# \begin{equation}
# \pi_{nameLast,nameFirst,birthYear}(\sigma_{birthYear=1960}(Players)) = \sigma_{birthYear=1960}(\pi_{nameLast,nameFirst,birthYear}(Players))
# \end{equation}
#
#
# - The fact that some algebra rules apply will become important in query optimization later in the course.

# %% [markdown]
# #### SQL: SELECT and Project
#
# - The core syntax of the SQL SELECT statement is
# ```
# SELECT [DISTINCT] column-list
#     FROM table-list
#     WHERE qualification
# ```
#
# - All RDB products implement the core syntax but with extensions.
#
#
# - The MYSQL syntax is
#
#
# | <img src="../images/sqlselect.jpeg"> |
# | :---: |
# | [MySQL SELECT Syntaxt](https://dev.mysql.com/doc/refman/5.7/en/select.html)|
# <br><br>
#
# - Examples are the easiest way to master the syntax and behavior.
#
#
# - A reminder of the ```People``` table.
#
# ```
# CREATE TABLE `people` (
#   `playerID` varchar(12) NOT NULL,
#   `birthYear` char(4) DEFAULT NULL,
#   `birthMonth` char(2) DEFAULT NULL,
#   `birthDay` char(2) DEFAULT NULL,
#   `birthCountry` varchar(64) DEFAULT NULL,
#   `birthState` varchar(32) DEFAULT NULL,
#   `birthCity` varchar(64) DEFAULT NULL,
#   `deathYear` char(4) DEFAULT NULL,
#   `deathMonth` char(2) DEFAULT NULL,
#   `deathDay` char(2) DEFAULT NULL,
#   `deathCountry` varchar(64) DEFAULT NULL,
#   `deathState` varchar(32) DEFAULT NULL,
#   `deathCity` varchar(64) DEFAULT NULL,
#   `nameFirst` varchar(64) NOT NULL,
#   `nameLast` varchar(64) NOT NULL,
#   `nameGiven` varchar(128) DEFAULT NULL,
#   `weight` char(3) DEFAULT NULL,
#   `height` char(3) DEFAULT NULL,
#   `bats` char(1) DEFAULT NULL,
#   `throws` char(1) DEFAULT NULL,
#   `debut` varchar(16) DEFAULT NULL,
#   `finalGame` varchar(16) DEFAULT NULL,
#   `retroID` varchar(12) DEFAULT NULL,
#   `bbrefID` varchar(12) DEFAULT NULL,
#   PRIMARY KEY (`playerID`)
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
# ```
#
# - __NOTE:__ All of the single back quotes are:
#     - MySQL specific
#     - Optional in most cases, and only required if a table or column name has a space or some other icky character, e.g. ``` `First Name` ```, ```First-Name```

# %% [markdown]
# ##### Select all People with last name 'Williams'

# %%
# %sql select * from People where nameLast='Williams';
# Out:
# 80 rows affected.
# [('williac01', '1917', '3', '18', 'USA', 'NJ', 'Montclair', '1999', '9', '16', 'USA', 'FL', 'Fort Myers', 'Ace', 'Williams', 'Robert Fulton', '174', 74, 'R', 'L', '1940-07-15', '1946-04-22', 'willa103', 'williac01'),
#  ('willial02', '1914', '5', '11', 'USA', 'AL', 'Valhermosa Springs', '1969', '7', '19', 'USA', 'TX', 'Groves', 'Al', 'Williams', 'Almon Edward', '200', 75, 'R', 'R', '1937-04-19', '1938-09-04', 'willa101', 'willial02'),
#  ('willial03', '1954', '5', '6', 'Nicaragua', 'Atlantico Sur', 'Pearl Lagoon', '', '', '', '', '', '', 'Albert', 'Williams', 'Albert Hamilton', '190', 76, 'R', 'R', '1980-05-07', '1984-09-26', 'willa001', 'willial03'),
#  ('williar01', '1877', '8', '24', 'USA', 'MA', 'Somerville', '1941', '5', '16', 'USA', 'VA', 'Arlington', 'Art', 'Williams', 'Arthur Frank', '', None, 'L', 'R', '1902-05-07', '1902-09-01', 'willa104', 'williar01'),
#  ('willibe01', '1948', '10', '8', 'USA', 'CA', 'Alameda', '', '', '', '', '', '', 'Bernie', 'Williams', 'Bernard', '175', 73, 'R', 'R', '1970-09-07', '1974-05-12', 'willb105', 'willibe01'),
#  ('willibe02', '1968', '9', '13', 'P.R.', '', 'San Juan', '', '', '', '', '', '', 'Bernie', 'Williams', 'Bernabe', '180', 74, 'B', 'R', '1991-07-07', '2006-10-01', 'willb002', 'willibe02'),
#  ('willibi01', '1938', '6', '15', 'USA', 'AL', 'Whistler', '', '', '', '', '', '', 'Billy', 'Williams', 'Billy Leo', '175', 73, 'L', 'R', '1959-08-06', '1976-10-02', 'willb104', 'willibi01'),
#  ('willibi02', '1932', '6', '13', 'USA', 'SC', 'Newberry', '2013', '6', '11', 'USA', 'CA', 'Berkeley', 'Billy', 'Williams', 'William', '195', 75, 'L', 'R', '1969-08-15', '1969-08-20', 'willb102', 'willibi02'),
#  ('willibo01', '1884', '4', '27', 'USA', 'OH', 'Monday', '1962', '8', '6', 'USA', 'OH', 'Nelsonville', 'Bob', 'Williams', 'Robert Elias', '190', 72, 'R', 'R', '1911-07-03', '1913-09-30', 'willb103', 'willibo01'),
#  ('willibr01', '1969', '2', '15', 'USA', 'SC', 'Lancaster', '', '', '', '', '', '', 'Brian', 'Williams', "Brian O'Neal", '205', 75, 'R', 'R', '1991-09-16', '2000-07-05', 'willb001', 'willibr01'),
#  ('willich01', '1947', '10', '11', 'USA', 'NY', 'Flushing', '2015', '1', '27', 'USA', 'FL', 'Port Orange', 'Charlie', 'Williams', 'Charles Prosek', '200', 74, 'R', 'R', '1971-04-23', '1978-09-11', 'willc101', 'willich01'),
#  ('willicy01', '1887', '12', '21', 'USA', 'IN', 'Wadena', '1974', '4', '23', 'USA', 'WI', 'Eagle River', 'Cy', 'Williams', 'Fred', '180', 74, 'L', 'L', '1912-07-18', '1930-09-22', 'willc103', 'willicy01'),
#  ('willida01', '1855', '10', '6', 'USA', 'KY', 'Ludlow', '1939', '10', '22', 'USA', 'KY', 'Covington', 'Dale', 'Williams', 'Elisha Alphonso', '175', 69, 'R', 'R', '1876-08-12', '1876-09-09', 'willd106', 'willida01'),
#  ('willida05', '1958', '2', '28', 'USA', 'NY', 'Brooklyn', '', '', '', '', '', '', 'Dallas', 'Williams', 'Dallas McKinley', '165', 71, 'L', 'L', '1981-09-19', '1983-10-02', 'willd101', 'willida05'),
#  ('willida06', '1963', '3', '20', 'USA', 'WV', 'Weirton', '', '', '', '', '', '', 'Dana', 'Williams', 'Dana Lamont', '170', 70, 'R', 'R', '1989-06-19', '1989-07-02', 'willd001', 'willida06'),
#  ('willida02', '1881', '2', '7', 'USA', 'PA', 'Scranton', '1918', '4', '25', 'USA', 'AR', 'Hot Springs', 'Dave', 'Williams', 'David Owen', '167', 71, 'R', 'L', '1902-07-02', '1902-08-03', 'willd103', 'willida02'),
#  ('willida03', '1927', '11', '2', 'USA', 'TX', 'Dallas', '2009', '8', '17', 'USA', 'TX', 'Farmers Branch', 'Davey', 'Williams', 'David Carlous', '160', 70, 'R', 'R', '1949-09-16', '1955-07-31', 'willd102', 'willida03'),
#  ('willida07', '1979', '3', '12', 'USA', 'AK', 'Anchorage', '', '', '', '', '', '', 'David', 'Williams', 'David Aaron', '215', 75, 'L', 'L', '2001-06-06', '2007-09-24', 'willd002', 'willida07'),
#  ('willide01', '1896', '12', '13', 'USA', 'OR', 'Portland', '1929', '3', '23', 'USA', 'CA', 'San Clemente', 'Denny', 'Williams', 'Evon Daniel', '150', 68, 'L', 'R', '1921-04-15', '1928-07-18', 'willd105', 'willide01'),
#  ('willide02', '1916', '2', '5', 'USA', 'NC', 'Durham', '2000', '3', '19', 'USA', 'ND', 'Williston', 'Dewey', 'Williams', 'Dewey Edgar', '160', 72, 'R', 'R', '1944-06-28', '1948-09-26', 'willd109', 'willide02'),
#  ('willidi01', '1910', '1', '19', 'USA', 'AR', 'Greenbrier', '1992', '4', '2', 'USA', 'AR', 'Searcy', 'Dib', 'Williams', 'Edwin Dibrell', '175', 71, 'R', 'R', '1930-04-27', '1935-09-29', 'willd107', 'willidi01'),
#  ('willidi02', '1929', '5', '7', 'USA', 'MO', 'St. Louis', '2011', '7', '7', 'USA', 'NV', 'Las Vegas', 'Dick', 'Williams', 'Richard Hirschfeld', '190', 72, 'R', 'R', '1951-06-10', '1964-10-01', 'willd104', 'willidi02'),
#  ('willido01', '1931', '9', '14', 'USA', 'VA', 'Floyd', '2011', '10', '16', 'USA', 'VA', 'Floyd', 'Don', 'Williams', 'Don Fred', '180', 74, 'R', 'R', '1958-09-12', '1962-08-23', 'willd108', 'willido01'),
#  ('willido02', '1935', '9', '2', 'USA', 'CA', 'Los Angeles', '1991', '12', '20', 'USA', 'CA', 'La Jolla', 'Don', 'Williams', 'Donald Reid', '218', 77, 'R', 'R', '1963-08-04', '1963-08-17', 'willd110', 'willido02'),
#  ('williea01', '1903', '1', '27', 'USA', 'TN', 'Cumberland Gap', '1958', '3', '10', 'USA', 'TN', 'Knoxville', 'Earl', 'Williams', 'Earl Baxter', '185', 72, 'R', 'R', '1928-05-27', '1928-06-02', 'wille102', 'williea01'),
#  ('williea02', '1948', '7', '14', 'USA', 'NJ', 'Newark', '2013', '1', '28', 'USA', 'NJ', 'Somerset', 'Earl', 'Williams', 'Earl Craig', '215', 75, 'R', 'R', '1970-09-13', '1977-09-25', 'wille101', 'williea02'),
#  ('willied01', '1964', '11', '1', 'USA', 'LA', 'Shreveport', '', '', '', '', '', '', 'Eddie', 'Williams', 'Edward Laquan', '175', 72, 'R', 'R', '1986-04-18', '1998-05-27', 'wille001', 'willied01'),
#  ('willifr01', '1958', '2', '13', 'USA', 'WA', 'Seattle', '2009', '1', '9', 'CAN', 'BC', 'Victoria', 'Frank', 'Williams', 'Frank Lee', '180', 73, 'R', 'R', '1984-04-05', '1989-09-27', 'willf001', 'willifr01'),
#  ('willige01', '1939', '10', '23', 'USA', 'MI', 'Detroit', '2009', '5', '14', 'USA', 'MI', 'Detroit', 'George', 'Williams', 'George', '165', 71, 'R', 'R', '1961-07-16', '1964-07-05', 'willg101', 'willige01'),
#  ('willige03', '1969', '4', '22', 'USA', 'WI', 'La Crosse', '', '', '', '', '', '', 'George', 'Williams', 'George Erik', '190', 70, 'B', 'R', '1995-07-14', '2000-09-13', 'willg002', 'willige03'),
#  ('willige02', '1966', '8', '10', 'USA', 'LA', 'New Orleans', '', '', '', '', '', '', 'Gerald', 'Williams', 'Gerald Floyd', '190', 74, 'R', 'R', '1992-09-15', '2005-10-02', 'willg001', 'willige02'),
#  ('willigl01', '1977', '7', '18', 'Australia', 'New South Wales', 'Gosford', '', '', '', '', '', '', 'Glenn', 'Williams', 'Glenn David', '195', 74, 'B', 'R', '2005-06-07', '2005-06-28', 'willg003', 'willigl01'),
#  ('willigu01', '1870', '', '', 'USA', 'NY', 'New York', '1890', '10', '14', 'USA', 'NY', 'New York', 'Gus', 'Williams', 'Augustine H.', '170', 71, '', None, '1890-04-18', '1890-04-22', 'willg102', 'willigu01'),
#  ('willigu02', '1888', '5', '7', 'USA', 'NE', 'Omaha', '1964', '4', '16', 'USA', 'IL', 'Sterling', 'Gus', 'Williams', 'August Joseph', '185', 72, 'L', 'L', '1911-04-12', '1915-06-18', 'willg103', 'willigu02'),
#  ('williha01', '1890', '6', '23', 'USA', 'NE', 'Omaha', '1963', '12', '21', 'USA', 'CA', 'Huntington Park', 'Harry', 'Williams', 'Harry Peter', '200', 73, 'R', 'R', '1913-08-07', '1914-06-30', 'willh103', 'williha01'),
#  ('willija01', '1986', '5', '14', 'USA', 'OK', 'Tulsa', '', '', '', '', '', '', 'Jackson', 'Williams', 'Jackson Thomas', '200', 70, 'R', 'R', '2014-08-27', '2015-10-04', 'willj005', 'willija01'),
#  ('willije01', '1972', '6', '6', 'Australia', 'Capital Territory', 'Canberra', '', '', '', '', '', '', 'Jeff', 'Williams', 'Jeffrey F.', '185', 72, 'R', 'L', '1999-09-12', '2002-09-28', 'willj002', 'willije02'),
#  ('willije02', '1981', '12', '4', 'USA', 'HI', 'Honolulu', '', '', '', '', '', '', 'Jerome', 'Williams', 'Jerome Lee', '260', 75, 'R', 'R', '2003-04-26', '2016-09-26', 'willj003', 'willije01'),
#  ('williji04', '1947', '4', '29', 'USA', 'LA', 'Zachary', '', '', '', '', '', '', 'Jim', 'Williams', 'James Alfred', '190', 74, 'R', 'R', '1969-09-08', '1970-09-30', 'willj108', 'williji04'),
#  ('williji01', '1876', '12', '20', 'USA', 'MO', 'St. Louis', '1965', '1', '16', 'USA', 'FL', 'St. Petersburg', 'Jimmy', 'Williams', 'James Thomas', '175', 69, 'R', 'R', '1899-04-15', '1909-10-03', 'willj106', 'williji01'),
#  ('williji99', '1847', '1', '4', 'USA', 'OH', 'Catawba', '1918', '10', '23', 'USA', 'NY', 'Westbury', 'Jimmy', 'Williams', 'James Andrew', '', None, '', None, '', '', 'willj801', 'williji99'),
#  ('williji03', '1943', '10', '4', 'USA', 'CA', 'Santa Maria', '', '', '', '', '', '', 'Jimy', 'Williams', 'James Francis', '170', 70, 'R', 'R', '1966-04-26', '1967-09-21', 'willj107', 'williji03'),
#  ('willijo02', '1889', '7', '16', 'USA', 'HI', 'Honolulu', '1963', '9', '8', 'USA', 'CA', 'Long Beach', 'Johnnie', 'Williams', 'John Brodie', '180', 72, 'R', 'R', '1914-04-21', '1914-08-19', 'willj101', 'willijo02'),
#  ('willike03', '1972', '4', '21', 'USA', 'PA', 'Bedford', '', '', '', '', '', '', 'Keith', 'Williams', 'David Keith', '190', 72, 'R', 'R', '1996-06-07', '1996-06-23', 'willk002', 'willike03'),
#  ('willike01', '1890', '6', '28', 'USA', 'OR', 'Grants Pass', '1959', '1', '22', 'USA', 'OR', 'Grants Pass', 'Ken', 'Williams', 'Kenneth Roy', '170', 72, 'L', 'R', '1915-07-14', '1929-08-10', 'willk101', 'willike01'),
#  ('willike02', '1964', '4', '6', 'USA', 'CA', 'Berkeley', '', '', '', '', '', '', 'Ken', 'Williams', 'Kenneth Royal', '187', 74, 'R', 'R', '1986-09-02', '1991-10-04', 'willk001', 'willike02'),
#  ('willile01', '1893', '3', '9', 'USA', 'MO', 'Aurora', '1959', '11', '4', 'USA', 'CA', 'Laguna Beach', 'Lefty', 'Williams', 'Claude Preston', '160', 69, 'R', 'L', '1913-09-17', '1920-09-25', 'willl104', 'willile01'),
#  ('willile03', '1905', '12', '2', 'USA', 'GA', 'Macon', '1984', '11', '20', 'USA', 'GA', 'Atlanta', 'Leon', 'Williams', 'Leon Theo', '154', 70, 'L', 'L', '1926-05-26', '1926-09-06', 'willl101', 'willile03'),
#  ('willima02', '1953', '7', '28', 'USA', 'NY', 'Elmira', '', '', '', '', '', '', 'Mark', 'Williams', 'Mark Westley', '180', 72, 'L', 'L', '1977-05-20', '1977-05-22', 'willm105', 'willima02'),
#  ('willima01', '1893', '2', '21', 'USA', 'NC', 'Faison', '1935', '2', '22', 'USA', 'AZ', 'Tucson', 'Marsh', 'Williams', 'Marshall McDiarmid', '180', 72, 'R', 'R', '1916-07-07', '1916-08-25', 'willm104', 'willima01'),
#  ('willima07', '1991', '8', '21', 'USA', 'RI', 'Pawtucket', '', '', '', '', '', '', 'Mason', 'Williams', 'Mason', '195', 73, 'L', 'R', '2015-06-12', '2017-06-25', 'willm007', 'willima10'),
#  ('willima03', '1959', '7', '25', 'USA', 'TX', 'Houston', '', '', '', '', '', '', 'Matt', 'Williams', 'Matthew Evan', '200', 73, 'R', 'R', '1983-08-02', '1985-10-05', 'willm001', 'willima03'),
#  ('willima04', '1965', '11', '28', 'USA', 'CA', 'Bishop', '', '', '', '', '', '', 'Matt', 'Williams', 'Matthew Derrick', '205', 74, 'R', 'R', '1987-04-11', '2003-05-31', 'willm003', 'willima04'),
#  ('willima06', '1971', '4', '12', 'USA', 'VA', 'Virginia Beach', '', '', '', '', '', '', 'Matt', 'Williams', 'Matt Taylor', '185', 72, 'B', 'L', '2000-04-05', '2000-04-29', 'willm006', 'willima09'),
#  ('willimi03', '1968', '7', '29', 'USA', 'VA', 'Radford', '', '', '', '', '', '', 'Mike', 'Williams', 'Michael Darren', '190', 74, 'R', 'R', '1992-06-30', '2003-09-28', 'willm005', 'willimi03'),
#  ('willimi02', '1964', '11', '17', 'USA', 'CA', 'Santa Ana', '', '', '', '', '', '', 'Mitch', 'Williams', 'Mitchell Steven', '180', 75, 'L', 'L', '1986-04-09', '1997-05-10', 'willm002', 'willimi02'),
#  ('willimu01', '1892', '7', '31', 'USA', 'AR', 'Ozark', '1962', '3', '30', 'USA', 'AR', 'Fayetteville', 'Mutt', 'Williams', 'David Carter', '195', 75, 'R', 'R', '1913-10-04', '1914-10-01', 'willm103', 'willimu01'),
#  ('willini01', '1993', '9', '8', 'USA', 'TX', 'Galveston', '', '', '', '', '', '', 'Nick', 'Williams', 'Billy Nicholas', '195', 75, 'L', 'L', '2017-06-30', '2017-10-01', 'willn001', 'willini01'),
#  ('williot01', '1877', '11', '2', 'USA', 'NJ', 'Newark', '1937', '3', '19', 'USA', 'NE', 'Omaha', 'Otto', 'Williams', 'Otto George', '165', 68, 'R', 'R', '1902-10-05', '1906-06-09', 'willo101', 'williot01'),
#  ('willipa01', '1913', '7', '17', 'USA', 'MS', 'Meridian', '1993', '11', '2', 'USA', 'MS', 'Meridian', 'Papa', 'Williams', 'Fred', '200', 73, 'R', 'R', '1945-04-19', '1945-07-08', 'willp102', 'willipa01'),
#  ('willipo01', '1874', '5', '19', 'USA', 'ME', 'Bowdoinham', '1959', '8', '4', 'USA', 'ME', 'Topsham', 'Pop', 'Williams', 'Walter Merrill', '190', 71, 'R', 'L', '1898-09-14', '1903-09-15', 'willp101', 'willipo01'),
#  ('willira01', '1975', '9', '18', 'USA', 'TX', 'Harlingen', '', '', '', '', '', '', 'Randy', 'Williams', 'Randall Duane', '200', 75, 'L', 'L', '2004-09-11', '2011-08-05', 'willr003', 'willira01'),
#  ('willire01', '1960', '8', '29', 'USA', 'TN', 'Memphis', '', '', '', '', '', '', 'Reggie', 'Williams', 'Reginald Dewayne', '185', 71, 'R', 'R', '1985-09-02', '1988-10-02', 'willr001', 'willire01'),
#  ('willire02', '1966', '5', '5', 'USA', 'SC', 'Laurens', '', '', '', '', '', '', 'Reggie', 'Williams', 'Reginald Bernard', '180', 73, 'B', 'R', '1992-09-08', '1999-07-25', 'willr002', 'willire02'),
#  ('williri03', '1952', '11', '9', 'USA', 'CA', 'Merced', '', '', '', '', '', '', 'Rick', 'Williams', 'Richard Allen', '180', 73, 'R', 'R', '1978-06-12', '1979-09-26', 'willr101', 'williri03'),
#  ('williri02', '1893', '12', '18', 'USA', 'CA', 'Santa Cruz', '1966', '4', '24', 'USA', 'AZ', 'Cottonwood', 'Rinaldo', 'Williams', 'Rinaldo Louis', '', None, 'L', 'R', '1914-10-08', '1914-10-10', 'willr103', 'williri02'),
#  ('williri01', '1882', '1', '31', 'USA', 'IL', 'Carthage', '1933', '7', '23', 'USA', 'IA', 'Keokuk', 'Rip', 'Williams', 'Alva Mitchell', '187', 71, 'R', 'R', '1911-04-12', '1918-06-09', 'willr104', 'williri01'),
#  ('willish01', '1971', '3', '10', 'USA', 'CA', 'Fresno', '', '', '', '', '', '', 'Shad', 'Williams', 'Shad Clayton', '185', 72, 'R', 'R', '1996-05-18', '1997-07-22', 'wills001', 'willish01'),
#  ('willijo99', '1885', '4', '6', 'USA', 'TX', 'Seguin', '1951', '2', '25', 'USA', 'NY', 'New York', 'Smokey Joe', 'Williams', 'Joseph', '190', 76, 'R', 'R', '', '', '', 'willijo99'),
#  ('willist02', '1936', '9', '14', 'USA', 'NH', 'Enfield', '', '', '', '', '', '', 'Stan', 'Williams', 'Stanley Wilson', '230', 77, 'R', 'R', '1958-05-17', '1972-08-01', 'wills102', 'willist02'),
#  ('willist01', '1892', '1', '31', 'USA', 'MT', 'Cascade', '1979', '6', '29', 'USA', 'MN', 'Deer River', 'Steamboat', 'Williams', 'Rees Gephardt', '170', 71, 'L', 'R', '1914-07-12', '1916-10-01', 'wills101', 'willist01'),
#  ('willita01', '1991', '7', '21', 'USA', 'WA', 'Vancouver', '', '', '', '', '', '', 'Taylor', 'Williams', 'Taylor Grant', '195', 71, 'B', 'R', '2017-09-06', '2017-10-01', 'willt003', 'willita01'),
#  ('willite01', '1918', '8', '30', 'USA', 'CA', 'San Diego', '2002', '7', '5', 'USA', 'FL', 'Inverness', 'Ted', 'Williams', 'Theodore Samuel', '205', 75, 'L', 'R', '1939-04-20', '1960-09-28', 'willt103', 'willite01'),
#  ('willito02', '1971', '2', '13', 'USA', 'NY', 'Syracuse', '', '', '', '', '', '', 'Todd', 'Williams', 'Todd Michael', '185', 75, 'R', 'R', '1995-04-29', '2007-06-15', 'willt001', 'willito02'),
#  ('willito01', '1870', '8', '19', 'USA', 'OH', 'Minersville', '1940', '7', '27', 'USA', 'OH', 'Columbus', 'Tom', 'Williams', 'Thomas C.', '', None, '', None, '1892-05-01', '1893-09-14', 'willt101', 'willito01'),
#  ('willitr01', '1992', '4', '25', 'USA', 'CA', 'San Diego', '', '', '', '', '', '', 'Trevor', 'Williams', 'Trevor Anthony', '230', 75, 'R', 'R', '2016-09-07', '2017-09-26', 'willt002', 'willitr01'),
#  ('williwa02', '1943', '12', '19', 'USA', 'TX', 'Brownwood', '2016', '1', '23', 'USA', 'TX', 'Abilene', 'Walt', 'Williams', 'Walter Allen', '165', 66, 'R', 'R', '1964-04-21', '1975-09-22', 'willw103', 'williwa02'),
#  ('williwa01', '', '', '', 'USA', 'PA', 'Philadelphia', '', '', '', '', '', '', 'Wash', 'Williams', 'Washington J.', '180', 71, '', None, '1884-08-05', '1885-06-08', 'willw102', 'williwa01'),
#  ('williwo01', '1912', '8', '21', 'USA', 'VA', 'Pamplin', '1995', '2', '24', 'USA', 'VA', 'Appomattox', 'Woody', 'Williams', 'Woodrow Wilson', '175', 71, 'R', 'R', '1938-09-05', '1945-09-30', 'willw101', 'williwo01'),
#  ('williwo02', '1966', '8', '19', 'USA', 'TX', 'Houston', '', '', '', '', '', '', 'Woody', 'Williams', 'Gregory Scott', '180', 72, 'R', 'R', '1993-05-14', '2007-09-22', 'willw001', 'williwo02')]

# %% [markdown]
# - I am using a special plug-in [ipython-sql](https://pypi.org/project/ipython-sql/) for running SQL directly from a code cell in the Jupyter notebook.
#
#
# - I can use the SQL command from many database clients.

# %% [markdown]
# | <img src="../images/sql_query_1.jpeg"> |
# | :---: |
# | __Query MySQL Workbench__ |

# %% [markdown]
# | <img src="../images/sql_select_terminal_1.jpeg"> |
# | :---: |
# | __Query MySQL Terminal Client__ |

# %% [markdown]
# - From Python code

# %%
import pymysql.cursors
import pandas as pd
import json

# The database server is running somewhere in the network.
# I must specify the IP address (HW server) and port number
# (connection that SW server is listening on)
# Also, I do not want to allow anyone to access the database
# and different people have different permissions. So, the
# client must log on.


# Connect to the database over the network. Use the connection
# to send commands to the DB.
cnx = pymysql.connect(host='localhost',
                             user='dbuser',
                             password='dbuser',
                             db='lahman2017',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)


def DBRunQuery(q):
    cursor=cnx.cursor()
    print ("Query = ", q)
    cursor.execute(q);
    r = cursor.fetchall()
    #print("Query result = ", r)
    return r

result = DBRunQuery("select * from people where nameLast='Williams';")
print("Result = ")
print(result)
# Out:
# Query =  select * from people where nameLast='Williams';
# Result =
# [{'playerID': 'williac01', 'birthYear': '1917', 'birthMonth': '3', 'birthDay': '18', 'birthCountry': 'USA', 'birthState': 'NJ', 'birthCity': 'Montclair', 'deathYear': '1999', 'deathMonth': '9', 'deathDay': '16', 'deathCountry': 'USA', 'deathState': 'FL', 'deathCity': 'Fort Myers', 'nameFirst': 'Ace', 'nameLast': 'Williams', 'nameGiven': 'Robert Fulton', 'weight': '174', 'height': '74', 'bats': 'R', 'throws': 'L', 'debut': '1940-07-15', 'finalGame': '1946-04-22', 'retroID': 'willa103', 'bbrefID': 'williac01'}, {'playerID': 'willial02', 'birthYear': '1914', 'birthMonth': '5', 'birthDay': '11', 'birthCountry': 'USA', 'birthState': 'AL', 'birthCity': 'Valhermosa Springs', 'deathYear': '1969', 'deathMonth': '7', 'deathDay': '19', 'deathCountry': 'USA', 'deathState': 'TX', 'deathCity': 'Groves', 'nameFirst': 'Al', 'nameLast': 'Williams', 'nameGiven': 'Almon Edward', 'weight': '200', 'height': '75', 'bats': 'R', 'throws': 'R', 'debut': '1937-04-19', 'finalGame': '1938-09-04', 'retroID': 'willa101', 'bbrefID': 'willial02'}, {'playerID': 'willial03', 'birthYear': '1954', 'birthMonth': '5', 'birthDay': '6', 'birthCountry': 'Nicaragua', 'birthState': 'Atlantico Sur', 'birthCity': 'Pearl Lagoon', 'deathYear': '', 'deathMonth': '', 'deathDay': '', 'deathCountry': '', 'deathState': '', 'deathCity': '', 'nameFirst': 'Albert', 'nameLast': 'Williams', 'nameGiven': 'Albert Hamilton', 'weight': '190', 'height': '76', 'bats': 'R', 'throws': 'R', 'debut': '1980-05-07', 'finalGame': '1984-09-26', 'retroID': 'willa001', 'bbrefID': 'willial03'}, {'playerID': 'williar01', 'birthYear': '1877', 'birthMonth': '8', 'birthDay': '24', 'birthCountry': 'USA', 'birthState': 'MA', 'birthCity': 'Somerville', 'deathYear': '1941', 'deathMonth': '5', 'deathDay': '16', 'deathCountry': 'USA', 'deathState': 'VA', 'deathCity': 'Arlington', 'nameFirst': 'Art', 'nameLast': 'Williams', 'nameGiven': 'Arthur Frank', 'weight': '', 'height': '', 'bats': 'L', 'throws': 'R', 'debut': '1902-05-07', 'finalGame': '1902-09-01', 'retroID': 'willa104', 'bbrefID': 'williar01'}, {'playerID': 'willibe01', 'birthYear': '1948', 'birthMonth': '10', 'birthDay': '8', 'birthCountry': 'USA', 'birthState': 'CA', 'birthCity': 'Alameda', 'deathYear': '', 'deathMonth': '', 'deathDay': '', 'deathCountry': '', 'deathState': '', 'deathCity': '', 'nameFirst': 'Bernie', 'nameLast': 'Williams', 'nameGiven': 'Bernard', 'weight': '175', 'height': '73', 'bats': 'R', 'throws': 'R', 'debut': '1970-09-07', 'finalGame': '1974-05-12', 'retroID': 'willb105', 'bbrefID': 'willibe01'}, {'playerID': 'willibe02', 'birthYear': '1968', 'birthMonth': '9', 'birthDay': '13', 'birthCountry': 'P.R.', 'birthState': '', 'birthCity': 'San Juan', 'deathYear': '', 'deathMonth': '', 'deathDay': '', 'deathCountry': '', 'deathState': '', 'deathCity': '', 'nameFirst': 'Bernie', 'nameLast': 'Williams', 'nameGiven': 'Bernabe', 'weight': '180', 'height': '74', 'bats': 'B', 'throws': 'R', 'debut': '1991-07-07', 'finalGame': '2006-10-01', 'retroID': 'willb002', 'bbrefID': 'willibe02'}, {'playerID': 'willibi01', 'birthYear': '1938', 'birthMonth': '6', 'birthDay': '15', 'birthCountry': 'USA', 'birthState': 'AL', 'birthCity': 'Whistler', 'deathYear': '', 'deathMonth': '', 'deathDay': '', 'deathCountry': '', 'deathState': '', 'deathCity': '', 'nameFirst': 'Billy', 'nameLast': 'Williams', 'nameGiven': 'Billy Leo', 'weight': '175', 'height': '73', 'bats': 'L', 'throws': 'R', 'debut': '1959-08-06', 'finalGame': '1976-10-02', 'retroID': 'willb104', 'bbrefID': 'willibi01'}, {'playerID': 'willibi02', 'birthYear': '1932', 'birthMonth': '6', 'birthDay': '13', 'birthCountry': 'USA', 'birthState': 'SC', 'birthCity': 'Newberry', 'deathYear': '2013', 'deathMonth': '6', 'deathDay': '11', 'deathCountry': 'USA', 'deathState': 'CA', 'deathCity': 'Berkeley', 'nameFirst': 'Billy', 'nameLast': 'Williams', 'nameGiven': 'William', 'weight': '195', 'height': '75', 'bats': 'L', 'throws': 'R', 'debut': '1969-08-15', 'finalGame': '1969-08-20', 'retroID': 'willb102', ...

# %% [markdown]
# - OK. That output is kind of icky.
#
#
# - The Python function json.dumps() makes the output a little cleaner.

# %% [markdown]
# ##### A more complex example that includes PROJECT

# %%
q ='''SELECT nameLast as last_name, nameFirst as firstName, birthYear as birth_year  
    from people where 
    nameLast='Williams' and birthYear > '1920';'''
result = DBRunQuery(q)
print("Result = ")
print(json.dumps(result, indent=2))
# Out:
# Query =  SELECT nameLast as last_name, nameFirst as firstName, birthYear as birth_year
#     from people where
#     nameLast='Williams' and birthYear > '1920';
# Result =
# [
#   {
#     "last_name": "Williams",
#     "firstName": "Albert",
#     "birth_year": "1954"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Bernie",
#     "birth_year": "1948"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Bernie",
#     "birth_year": "1968"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Billy",
#     "birth_year": "1938"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Billy",
#     "birth_year": "1932"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Brian",
#     "birth_year": "1969"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Charlie",
#     "birth_year": "1947"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Davey",
#     "birth_year": "1927"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Dallas",
#     "birth_year": "1958"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Dana",
#     "birth_year": "1963"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "David",
#     "birth_year": "1979"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Dick",
#     "birth_year": "1929"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Don",
#     "birth_year": "1931"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Don",
#     "birth_year": "1935"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Earl",
#     "birth_year": "1948"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Eddie",
#     "birth_year": "1964"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Frank",
#     "birth_year": "1958"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "George",
#     "birth_year": "1939"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Gerald",
#     "birth_year": "1966"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "George",
#     "birth_year": "1969"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Glenn",
#     "birth_year": "1977"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Jackson",
#     "birth_year": "1986"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Jeff",
#     "birth_year": "1972"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Jerome",
#     "birth_year": "1981"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Jimy",
#     "birth_year": "1943"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Jim",
#     "birth_year": "1947"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Ken",
#     "birth_year": "1964"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Keith",
#     "birth_year": "1972"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Mark",
#     "birth_year": "1953"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Matt",
#     "birth_year": "1959"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Matt",
#     "birth_year": "1965"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Matt",
#     "birth_year": "1971"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Mason",
#     "birth_year": "1991"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Mitch",
#     "birth_year": "1964"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Mike",
#     "birth_year": "1968"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Nick",
#     "birth_year": "1993"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Randy",
#     "birth_year": "1975"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Reggie",
#     "birth_year": "1960"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Reggie",
#     "birth_year": "1966"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Rick",
#     "birth_year": "1952"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Shad",
#     "birth_year": "1971"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Stan",
#     "birth_year": "1936"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Taylor",
#     "birth_year": "1991"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Todd",
#     "birth_year": "1971"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Trevor",
#     "birth_year": "1992"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Walt",
#     "birth_year": "1943"
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Woody",
#     "birth_year": "1966"
#   }
# ]

# %% [markdown]
# ##### Complex WHERE Clause

# %%
# %sql SELECT playerID, nameLast, nameFirst, birthCountry, birthCity from people where \
    (birthCountry in ('USA', 'Mexico') and nameLast <= "ab") or \
    (nameLast = "Williams" and birthCity = "San Diego")
# Out:
# 6 rows affected.
# [('aardsda01', 'Aardsma', 'David', 'USA', 'Denver'),
#  ('aaronha01', 'Aaron', 'Hank', 'USA', 'Mobile'),
#  ('aaronto01', 'Aaron', 'Tommie', 'USA', 'Mobile'),
#  ('aasedo01', 'Aase', 'Don', 'USA', 'Orange'),
#  ('willite01', 'Williams', 'Ted', 'USA', 'San Diego'),
#  ('willitr01', 'Williams', 'Trevor', 'USA', 'San Diego')]

# %%
# %sql SELECT playerID, nameLast, nameFirst, birthCountry, birthCity, birthYear from people where \
    ((birthCountry > nameLast and birthCountry > nameFirst) and (birthCountry != "USA")) or \
    (birthYear >= 1960 and birthYear <= 1961)
# Out:
# 1053 rows affected.
# [('abreubo01', 'Abreu', 'Bobby', 'Venezuela', 'Maracay', '1974'),
#  ('aceveal01', 'Aceves', 'Alfredo', 'Mexico', 'San Luis Rio Colorado', '1982'),
#  ('aceveju01', 'Acevedo', 'Juan', 'Mexico', 'Ciudad Juarez', '1970'),
#  ('acostcy01', 'Acosta', 'Cy', 'Mexico', 'El Sabino', '1946'),
#  ('acosted01', 'Acosta', 'Ed', 'Panama', 'Boquete', '1944'),
#  ('acostma01', 'Acosta', 'Manny', 'Panama', 'Colon', '1981'),
#  ('adamecr01', 'Adames', 'Cristhian', 'D.R.', 'Santo Domingo', '1991'),
#  ('addybo01', 'Addy', 'Bob', 'CAN', 'Port Hope', '1842'),
#  ('adriaeh01', 'Adrianza', 'Ehire', 'Venezuela', 'Guarenas', '1989'),
#  ('agostju01', 'Agosto', 'Juan', 'P.R.', 'Rio Piedras', '1958'),
#  ('aguaylu01', 'Aguayo', 'Luis', 'P.R.', 'Vega Baja', '1959'),
#  ('aguilje01', 'Aguilar', 'Jesus', 'Venezuela', 'Maracay', '1990'),
#  ('aguilri01', 'Aguilera', 'Rick', 'USA', 'San Gabriel', '1961'),
#  ('ainsmed01', 'Ainsmith', 'Eddie', 'Russia', '', '1890'),
#  ('albagi01', 'Alba', 'Gibson', 'D.R.', 'Santiago', '1960'),
#  ('albaljo01', 'Albaladejo', 'Jonathan', 'P.R.', 'San Juan', '1982'),
#  ('alberan01', 'Albers', 'Andrew', 'CAN', 'North Battleford', '1985'),
#  ('alberjo01', 'Alberro', 'Jose', 'P.R.', 'San Juan', '1969'),
#  ('albural01', 'Alburquerque', 'Al', 'D.R.', 'San Pedro de Macoris', '1986'),
#  ('alcanar01', 'Alcantara', 'Arismendy', 'D.R.', 'Santo Domingo', '1991'),
#  ('alcarlu01', 'Alcaraz', 'Luis', 'P.R.', 'Humacao', '1941'),
#  ('aldremi01', 'Aldrete', 'Mike', 'USA', 'Carmel', '1961'),
#  ('aldrija01', 'Aldrich', 'Jay', 'USA', 'Alexandria', '1961'),
#  ('alexabo01', 'Alexander', 'Bob', 'CAN', 'Vancouver', '1922'),
#  ('alfonan01', 'Alfonseca', 'Antonio', 'D.R.', 'La Romana', '1972'),
#  ('alfoned01', 'Alfonzo', 'Edgardo', 'Venezuela', 'Santa Teresa del Tuy', '1973'),
#  ('alfonel01', 'Alfonzo', 'Eliezer', 'Venezuela', 'Puerto La Cruz', '1979'),
#  ('alicelu01', 'Alicea', 'Luis', 'P.R.', 'Santurce', '1965'),
#  ('allanan01', 'Allanson', 'Andy', 'USA', 'Richmond', '1961'),
#  ('almadme01', 'Almada', 'Mel', 'Mexico', 'Huatabampo', '1913'),
#  ('almanca01', 'Almanzar', 'Carlos', 'D.R.', 'Santiago', '1973'),
#  ('almonab01', 'Almonte', 'Abraham', 'D.R.', 'Santo Domingo', '1989'),
#  ('altheaa01', 'Altherr', 'Aaron', 'Germany', 'Landstuhl', '1991'),
#  ('altuvjo01', 'Altuve', 'Jose', 'Venezuela', 'Puerto Cabello', '1990'),
#  ('alvarcl01', 'Alvarez', 'Clemente', 'Venezuela', 'Guanta', '1968'),
#  ('alvarga01', 'Alvarez', 'Gabe', 'Mexico', 'Navojoa', '1974'),
#  ('alvarhe01', 'Alvarez', 'Henderson', 'Venezuela', 'Valencia', '1990'),
#  ('alvarjo02', 'Alvarez', 'Jose', 'Venezuela', 'Barcelona', '1989'),
#  ('alvarjo03', 'Alvarado', 'Jose', 'Venezuela', 'Maracaibo', '1995'),
#  ('alvarlu01', 'Alvarado', 'Luis', 'P.R.', 'Lajas', '1949'),
#  ('alvaror01', 'Alvarez', 'Orlando', 'P.R.', 'Rio Grande', '1952'),
#  ('alvarto01', 'Alvarez', 'Tony', 'Venezuela', 'Caracas', '1979'),
#  ('amarial01', 'Amarista', 'Alexi', 'Venezuela', 'Barcelona', '1989'),
#  ('amezaal01', 'Amezaga', 'Alfredo', 'Mexico', 'Ciudad Obregon', '1978'),
#  ('anderda02', 'Anderson', 'Dave', 'USA', 'Louisville', '1960'),
#  ('anderjo01', 'Anderson', 'John', 'Norway', 'Sarpsborg', '1873'),
#  ('andruel01', 'Andrus', 'Elvis', 'Venezuela', 'Maracay', '1988'),
#  ('aparilu01', 'Aparicio', 'Luis', 'Venezuela', 'Maracaibo', '1934'),
#  ('apontlu01', 'Aponte', 'Luis', 'Venezuela', 'El Tigre', '1953'),
#  ('aquinlu01', 'Aquino', 'Luis', 'P.R.', 'Santurce', '1964'),
#  ('aragoan01', 'Aragon', 'Angel', 'Cuba', 'La Habana', '1890'),
#  ('araujel01', 'Araujo', 'Elvis', 'Venezuela', 'Maracaibo', '1991'),
#  ('arciaor01', 'Arcia', 'Orlando', 'Venezuela', 'Anaco', '1994'),
#  ('arciaos01', 'Arcia', 'Oswaldo', 'Venezuela', 'Anaco', '1991'),
#  ('ariasal02', 'Arias', 'Alberto', 'D.R.', 'Santo Domingo', '1983'),
#  ('armasma01', 'Armas', 'Marcos', 'Venezuela', 'Puerto Piritu', '1969'),
#  ('armasto01', 'Armas', 'Tony', 'Venezuela', 'Puerto Piritu', '1953'),
#  ('armasto02', 'Armas', 'Tony', 'Venezuela', 'Puerto Piritu', '1978'),
#  ('arroylu01', 'Arroyo', 'Luis', 'P.R.', 'Penuelas', '1927'),
#  ('ascanjo01', 'Ascanio', 'Jose', 'Venezuela', 'Maracay', '1985'),
#  ('assenpa01', 'Assenmacher', 'Paul', 'USA', 'Detroit', '1960'),
#  ('asuajca01', 'Asuaje', 'Carlos', 'Venezuela', 'Barquisimeto', '1991'),
#  ('atilalu01', 'Atilano', 'Luis', 'P.R.', 'Santurce', '1985'),
#  ('atkinbi01', 'Atkinson', 'Bill', 'CAN', 'Chatham', '1954'),
#  ('austiji01', 'Austin', 'Jimmy', 'United Kingdom', 'Swansea', '1879'),
#  ('avilabo01', 'Avila', 'Bobby', 'Mexico', 'Veracruz', '1924'),
#  ('avilalu01', 'Avilan', 'Luis', 'Venezuela', 'Caracas', '1989'),
#  ('ayalabe01', 'Ayala', 'Benny', 'P.R.', 'Yauco', '1951'),
#  ('ayalalu01', 'Ayala', 'Luis', 'Mexico', 'Los Mochis', '1978'),
#  ('azocaos01', 'Azocar', 'Oscar', 'Venezuela', 'Soro', '1965'),
#  ('baekch01', 'Baek', 'Cha-Seung', 'South Korea', 'Busan', '1980'),
#  ('baergca01', 'Baerga', 'Carlos', 'P.R.', 'Santurce', '1968'),
#  ('baezbe01', 'Baez', 'Benito', 'D.R.', 'Bonao', '1977'),
#  ('baezja01', 'Baez', 'Javier', 'P.R.', 'Bayamon', '1992'),
#  ('bailema01', 'Bailey', 'Mark', 'USA', 'Springfield', '1961'),
#  ('bailesc01', 'Bailes', 'Scott', 'USA', 'Chillicothe', '1961'),
#  ('bakerdo01', 'Baker', 'Doug', 'USA', 'Fullerton', '1961'),
#  ('balleja01', 'Baller', 'Jay', 'USA', 'Stayton', '1960'),
#  ('banuema01', 'Banuelos', 'Manny', 'Mexico', 'Gomez Palacio', '1991'),
#  ('barfijo02', 'Barfield', 'Josh', 'Venezuela', 'Barquisimeto', '1982'),
#  ('barrage01', 'Barranca', 'German', 'Mexico', 'Veracruz', '1956'),
#  ('barrefr02', 'Barreto', 'Franklin', 'Venezuela', 'Caracas', '1996'),
#  ('barreti01', 'Barrett', 'Tim', 'USA', 'Huntingburg', '1961'),
#  ('barreto01', 'Barrett', 'Tom', 'USA', 'San Fernando', '1960'),
#  ('barrifr01', 'Barrios', 'Francisco', 'Mexico', 'Hermosillo', '1953'),
#  ('barrima01', 'Barrios', 'Manuel', 'Panama', 'Cabecera', '1974'),
#  ('bastaan01', 'Bastardo', 'Antonio', 'D.R.', 'Hato Mayor del Rey', '1985'),
#  ('bathebi01', 'Bathe', 'Bill', 'USA', 'Downey', '1960'),
#  ('behenri01', 'Behenna', 'Rick', 'USA', 'Miami', '1960'),
#  ('belchti01', 'Belcher', 'Tim', 'USA', 'Mount Gilead', '1961'),
#  ('belisro01', 'Belisario', 'Ronald', 'Venezuela', 'Maracay', '1982'),
#  ('bellira01', 'Belliard', 'Rafael', 'D.R.', 'Pueblo Nuevo', '1961'),
#  ('belloed01', 'Bellorin', 'Edwin', 'Venezuela', 'San Felix', '1982'),
#  ('beltrad01', 'Beltre', 'Adrian', 'D.R.', 'Santo Domingo', '1979'),
#  ('beltrca01', 'Beltran', 'Carlos', 'P.R.', 'Manati', '1977'),
#  ('benarma01', 'Benard', 'Marvin', 'Nicaragua', 'Bluefields', '1971'),
#  ('beniqju01', 'Beniquez', 'Juan', 'P.R.', 'San Sebastian', '1950'),
#  ('benitar01', 'Benitez', 'Armando', 'D.R.', 'Ramon Santana', '1972'),
#  ('berenju01', 'Berenguer', 'Juan', 'Panama', 'Aguadulce', '1954'),
#  ('bernica01', 'Bernier', 'Carlos', 'P.R.', 'Juana Diaz', '1927'),
#  ('berrijo01', 'Berrios', 'Jose', 'P.R.', 'Bayamon', '1994'),
#  ('berroan01', 'Berroa', 'Angel', 'D.R.', 'Santo Domingo', '1978'),
#  ('beruman01', 'Berumen', 'Andres', 'Mexico', 'Tijuana', '1971'),
#  ('betanra01', 'Betancourt', 'Rafael', 'Venezuela', 'Cumana', '1975'),
#  ('bethach01', 'Bethancourt', 'Christian', 'Panama', 'Panama', '1991'),
#  ('betteje01', 'Bettendorf', 'Jeff', 'USA', 'Lompoc', '1960'),
#  ('biancbu01', 'Biancalana', 'Buddy', 'USA', 'Greenbrae', '1960'),
#  ('biasaha01', 'Biasatti', 'Hank', 'Italy', 'Beano', '1922'),
#  ('birkbmi01', 'Birkbeck', 'Mike', 'USA', 'Orrville', '1961'),
#  ('birtsti01', 'Birtsas', 'Tim', 'USA', 'Pontiac', '1960'),
#  ('bithohi01', 'Bithorn', 'Hi', 'P.R.', 'Santurce', '1916'),
#  ('blancan01', 'Blanco', 'Andres', 'Venezuela', 'Urama', '1984'),
#  ('blancda01', 'Blanco', 'Damaso', 'Venezuela', 'Curiepe', '1941'),
#  ('blancgr01', 'Blanco', 'Gregor', 'Venezuela', 'Caracas', '1983'),
#  ('blanche01', 'Blanco', 'Henry', 'Venezuela', 'Caracas', '1971'),
#  ('blancos01', 'Blanco', 'Ossie', 'Venezuela', 'Caracas', '1945'),
#  ('blashja01', 'Blash', 'Jabari', 'V.I.', 'St. Thomas', '1989'),
#  ('blylebe01', 'Blyleven', 'Bert', 'Netherlands', 'Zeist', '1951'),
#  ('bocachi01', 'Bocachica', 'Hiram', 'P.R.', 'Ponce', '1976'),
#  ('bochybr01', 'Bochy', 'Bruce', 'France', 'Landes de Bussac', '1955'),
#  ('bockura01', 'Bockus', 'Randy', 'USA', 'Canton', '1960'),
#  ('boevejo01', 'Boever', 'Joe', 'USA', 'Kirkwood', '1960'),
#  ('bohnejo01', 'Bohnet', 'John', 'USA', 'Pasadena', '1961'),
#  ('boldch01', 'Bold', 'Charlie', 'Sweden', 'Karlskrona', '1894'),
#  ('bongju01', 'Bong', 'Jung', 'South Korea', 'Seoul', '1980'),
#  ('bonilju01', 'Bonilla', 'Juan', 'P.R.', 'Santurce', '1956'),
#  ('bookegr01', 'Booker', 'Greg', 'USA', 'Lynchburg', '1960'),
#  ('boscajc01', 'Boscan', 'J. C.', 'Venezuela', 'Maracaibo', '1979'),
#  ('brachsi01', 'Bracho', 'Silvino', 'Venezuela', 'Maracaibo', '1992'),
#  ('bradlsc01', 'Bradley', 'Scott', 'USA', 'Glen Ridge', '1960'),
#  ('brainda01', 'Brain', 'Dave', 'United Kingdom', 'Hereford', '1879'),
#  ('brantmi01', 'Brantley', 'Mickey', 'USA', 'Catskill', '1961'),
#  ('bravoan01', 'Bravo', 'Angel', 'Venezuela', 'Maracaibo', '1942'),
#  ('breamsi01', 'Bream', 'Sid', 'USA', 'Carlisle', '1960'),
#  ('briceau01', 'Brice', 'Austin', 'Hong Kong', 'Hong Kong', '1992'),
#  ('britobe01', 'Brito', 'Bernardo', 'D.R.', 'San Cristobal', '1963'),
#  ('browebo01', 'Brower', 'Bob', 'USA', 'Jamaica', '1960'),
#  ('brownch02', 'Brown', 'Chris', 'USA', 'Jackson', '1961'),
#  ('browncu03', 'Brown', 'Curt', 'USA', 'Fort Lauderdale', '1960'),
#  ('brownje01', 'Browne', 'Jerry', 'V.I.', 'Christiansted', '1966'),
#  ('brownto01', 'Brown', 'Tom', 'United Kingdom', 'Liverpool', '1860'),
#  ('brownto05', 'Browning', 'Tom', 'USA', 'Casper', '1960'),
#  ('brunato01', 'Brunansky', 'Tom', 'USA', 'Covina', '1960'),
#  ('bryanra01', 'Bryant', 'Ralph', 'USA', 'Fort Gaines', '1961'),
#  ('buchabo01', 'Buchanan', 'Bob', 'USA', 'Ridley Park', '1961'),
#  ('buechst01', 'Buechele', 'Steve', 'USA', 'Lancaster', '1961'),
#  ('buelofr01', 'Buelow', 'Fritz', 'Germany', 'Berlin', '1876'),
#  ('bullasi01', 'Bullas', 'Sim', 'United Kingdom', '', '1863'),
#  ('bulloer01', 'Bullock', 'Eric', 'USA', 'Los Angeles', '1960'),
#  ('burgoam01', 'Burgos', 'Ambiorix', 'D.R.', 'Nagua', '1984'),
#  ('burgoen01', 'Burgos', 'Enrique', 'Panama', 'Chorrera', '1965'),
#  ('burgoen02', 'Burgos', 'Enrique', 'Panama', 'Panama', '1990'),
#  ('burgohi01', 'Burgos', 'Hiram', 'P.R.', 'Cayey', '1987'),
#  ('burnsja01', 'Burns', 'Jack', 'United Kingdom', 'Salford', '1878'),
#  ('cabrace01', 'Cabral', 'Cesar', 'D.R.', 'Sabana Grande de Palenque', '1989'),
#  ('cabreal01', 'Cabrera', 'Al', 'Spain', '', '1881'),
#  ('cabreal02', 'Cabrera', 'Alex', 'Venezuela', 'Caripito', '1971'),
#  ('cabreal03', 'Cabrera', 'Alberto', 'D.R.', 'Las Matas de Farfan', '1988'),
#  ('cabreas01', 'Cabrera', 'Asdrubal', 'Venezuela', 'Puerto La Cruz', '1985'),
#  ('cabreev01', 'Cabrera', 'Everth', 'Nicaragua', 'Nandaime', '1986'),
#  ('cabrefe01', 'Cabrera', 'Fernando', 'P.R.', 'Toa Baja', '1981'),
#  ('cabremi01', 'Cabrera', 'Miguel', 'Venezuela', 'Maracay', '1983'),
#  ('cabrera01', 'Cabrera', 'Ramon', 'Venezuela', 'Caracas', '1989'),
#  ('cacered01', 'Caceres', 'Edgar', 'Venezuela', 'Barquisimeto', '1964'),
#  ('cairomi01', 'Cairo', 'Miguel', 'Venezuela', 'Anaco', '1974'),
#  ('caldeiv01', 'Calderon', 'Ivan', 'P.R.', 'Fajardo', '1962'),
#  ('calerki01', 'Calero', 'Kiko', 'P.R.', 'Santurce', '1975'),
#  ('callaal01', 'Callaspo', 'Alberto', 'Venezuela', 'Maracay', '1983'),
#  ('camarjo01', 'Camargo', 'Johan', 'Panama', 'Panama', '1993'),
#  ('caminar01', 'Caminero', 'Arquimedes', 'D.R.', 'Santo Domingo', '1987'),
#  ('campaal01', 'Campanis', 'Al', 'Greece', 'Kos', '1916'),
#  ('campabe01', 'Campaneris', 'Bert', 'Cuba', 'Pueblo Nuevo', '1942'),
#  ('campbhu01', 'Campbell', 'Hugh', 'Ireland', '', '1846'),
#  ('campijo01', 'Campillo', 'Jorge', 'Mexico', 'Tijuana', '1978'),
#  ('campole01', 'Campos', 'Leonel', 'Venezuela', 'Valera', '1987'),
#  ('candaca01', 'Candaele', 'Casey', 'USA', 'Lompoc', '1961'),
#  ('canizba01', 'Canizares', 'Barbaro', 'Cuba', 'La Habana', '1979'),
#  ('capelmi01', 'Capel', 'Mike', 'USA', 'Marshall', '1961'),
#  ('cardoja01', 'Cardona', 'Javier', 'P.R.', 'Santurce', '1975'),
#  ('carraal01', 'Carrasquel', 'Alex', 'Venezuela', 'Caracas', '1912'),
#  ('carraca01', 'Carrasco', 'Carlos', 'Venezuela', 'Barquisimeto', '1987'),
#  ('carrach01', 'Carrasquel', 'Chico', 'Venezuela', 'Caracas', '1926'),
#  ('carragi01', 'Carrara', 'Giovanni', 'Venezuela', 'El Tigre', '1968'),
#  ('carream01', 'Carreno', 'Amalio', 'Venezuela', 'Chacachacare', '1964'),
#  ('carreez01', 'Carrera', 'Ezequiel', 'Venezuela', 'Guiria', '1987'),
#  ('carrima01', 'Carrillo', 'Matias', 'Mexico', 'Los Mochis', '1963'),
#  ('cartejo01', 'Carter', 'Joe', 'USA', 'Oklahoma City', '1960'),
#  ('carvama01', 'Carvajal', 'Marcos', 'Venezuela', 'Ciudad Bolivar', '1984'),
#  ('carych01', 'Cary', 'Chuck', 'USA', 'Whittier', '1960'),
#  ('casilal01', 'Casilla', 'Alexi', 'D.R.', 'San Cristobal', '1984'),
#  ('casimca01', 'Casimiro', 'Carlos', 'D.R.', 'San Pedro de Macoris', '1976'),
#  ('castepe01', 'Castellano', 'Pedro', 'Venezuela', 'Barquisimeto', '1970'),
#  ('castial01', 'Castillo', 'Alberto', 'D.R.', 'San Juan de la Maguana', '1970'),
#  ('castial02', 'Castillo', 'Alberto', 'Cuba', 'La Habana', '1975'),
#  ('castibr01', 'Castillo', 'Braulio', 'D.R.', 'Elias Pina', '1968'),
#  ('castica01', 'Castillo', 'Carmelo', 'D.R.', 'San Pedro de Macoris', '1958'),
#  ('castijo02', 'Castillo', 'Jose', 'Venezuela', 'Las Mercedes', '1981'),
#  ('castiju02', 'Castillo', 'Juan', 'Venezuela', 'Caracas', '1970'),
#  ('castito02', 'Castillo', 'Tony', 'Venezuela', 'Quibor', '1963'),
#  ('castran01', 'Castro', 'Angel', 'D.R.', 'Pimentel', '1982'),
#  ('castrbe01', 'Castro', 'Bernie', 'D.R.', 'Santo Domingo', '1979'),
#  ('castrbi01', 'Castro', 'Bill', 'D.R.', 'Santiago', '1952'),
#  ('castrda01', 'Castro', 'Daniel', 'Mexico', 'Guaymas', '1992'),
#  ('castrju01', 'Castro', 'Juan', 'Mexico', 'Los Mochis', '1972'),
#  ('castrra02', 'Castro', 'Ramon', 'Venezuela', 'Valencia', '1979'),
#  ('cecenjo01', 'Cecena', 'Jose', 'Mexico', 'Ciudad Obregon', '1963'),
#  ('cedenan01', 'Cedeno', 'Andujar', 'D.R.', 'La Romana', '1969'),
#  ('cedence01', 'Cedeno', 'Cesar', 'D.R.', 'Santo Domingo', '1951'),
#  ('cedenro01', 'Cedeno', 'Roger', 'Venezuela', 'Valencia', '1974'),
#  ('cedenro02', 'Cedeno', 'Ronny', 'Venezuela', 'Puerto Cabello', '1983'),
#  ('centeju01', 'Centeno', 'Juan', 'P.R.', 'Arecibo', '1989'),
#  ('cepedor01', 'Cepeda', 'Orlando', 'P.R.', 'Ponce', '1937'),
#  ('cerroju01', 'Cerros', 'Juan', 'Mexico', 'Monterrey', '1976'),
#  ('cerutjo01', 'Cerutti', 'John', 'USA', 'Albany', '1960'),
#  ('cervefr01', 'Cervelli', 'Francisco', 'Venezuela', 'Valencia', '1986'),
#  ('cessalu01', 'Cessa', 'Luis', 'Mexico', 'Cordoba', '1992'),
#  ('chacial01', 'Chacin', 'Alejandro', 'Venezuela', 'Maracay', '1993'),
#  ('chacigu01', 'Chacin', 'Gustavo', 'Venezuela', 'Maracaibo', '1980'),
#  ('chacijh01', 'Chacin', 'Jhoulys', 'Venezuela', 'Maracaibo', '1988'),
#  ('chacoel01', 'Chacon', 'Elio', 'Venezuela', 'Caracas', '1936'),
#  ('chadwhe99', 'Chadwick', 'Henry', 'United Kingdom', 'Exeter', '1824'),
#  ('chalmge01', 'Chalmers', 'George', 'United Kingdom', 'Aberdeen', '1888'),
#  ('chambal01', 'Chambers', 'Al', 'USA', 'Harrisburg', '1961'),
#  ('chapmar01', 'Chapman', 'Aroldis', 'Cuba', 'Holguin', '1988'),
#  ('chavaos01', 'Chavarria', 'Ossie', 'Panama', 'Colon', '1940'),
#  ('chavean02', 'Chavez', 'Angel', 'Panama', 'David', '1981'),
#  ('chaveen01', 'Chavez', 'Endy', 'Venezuela', 'Valencia', '1978'),
#  ('chavene01', 'Chavez', 'Nestor', 'Venezuela', 'Chacao', '1947'),
#  ('chavera01', 'Chavez', 'Raul', 'Venezuela', 'Valencia', '1973'),
#  ('chenbr01', 'Chen', 'Bruce', 'Panama', 'Panama', '1977'),
#  ('chench01', 'Chen', 'Chin-Feng', 'Taiwan', 'Tainan City', '1977'),
#  ('chiriro01', 'Chirinos', 'Robinson', 'Venezuela', 'Punto Fijo', '1984'),
#  ('choihe01', 'Choi', 'Hee-Seop', 'South Korea', 'Hwasun', '1979'),
#  ('choiji01', 'Choi', 'Ji-Man', 'South Korea', 'Incheon', '1991'),
#  ('choji01', 'Cho', 'Jin Ho', 'South Korea', 'Jeonju', '1975'),
#  ('choosh01', 'Choo', 'Shin-Soo', 'South Korea', 'Busan', '1982'),
#  ('chouibo01', 'Chouinard', 'Bobby', 'Philippines', 'Manila', '1972'),
#  ('chrisjo01', 'Christopher', 'Joe', 'V.I.', 'Frederiksted', '1935'),
#  ('chrisjo02', 'Christensen', 'John', 'USA', 'Downey', '1960'),
#  ('ciardma01', 'Ciardi', 'Mark', 'USA', 'New Brunswick', '1961'),
#  ('cintral01', 'Cintron', 'Alex', 'P.R.', 'Humacao', '1978'),
#  ('clackbo01', 'Clack', 'Bobby', 'United Kingdom', '', '1850'),
#  ('clarkho01', 'Clarke', 'Horace', 'V.I.', 'Frederiksted', '1940'),
#  ('clarkst02', 'Clarke', 'Stan', 'USA', 'Toledo', '1960'),
#  ('clarkte01', 'Clark', 'Terry', 'USA', 'Los Angeles', '1960'),
#  ('claudal01', 'Claudio', 'Alex', 'P.R.', 'San Juan', '1992'),
#  ('clayda02', 'Clay', 'Danny', 'USA', 'Sun Valley', '1961'),
#  ('clemeed02', 'Clemente', 'Edgard', 'P.R.', 'Santurce', '1975'),
#  ('coachpe01', 'Coachman', 'Pete', 'USA', 'Cottonwood', '1961'),
#  ('cocanja01', 'Cocanower', 'Jaime', 'P.R.', 'San Juan', '1957'),
#  ('cogswed01', 'Cogswell', 'Ed', 'United Kingdom', '', '1854'),
#  ('colemvi01', 'Coleman', 'Vince', 'USA', 'Jacksonville', '1961'),
#  ('colinal01', 'Colina', 'Alvin', 'Venezuela', 'Puerto Cabello', '1981'),
#  ('collibi01', 'Collins', 'Bill', 'Ireland', 'Dublin', '1863'),
#  ('colomal01', 'Colome', 'Alex', 'D.R.', 'Santo Domingo', '1988'),
#  ('colonba01', 'Colon', 'Bartolo', 'D.R.', 'Altamira', '1973'),
#  ('colonch01', 'Colon', 'Christian', 'P.R.', 'Cayey', '1989'),
#  ('coloncr01', 'Colon', 'Cris', 'Venezuela', 'La Guaira', '1969'),
#  ('colonjo01', 'Colon', 'Joe', 'P.R.', 'Caguas', '1990'),
#  ('conceda01', 'Concepcion', 'Dave', 'Venezuela', 'Ocumare de la Costa', '1948'),
#  ('conceon01', 'Concepcion', 'Onix', 'P.R.', 'Dorado', '1957'),
#  ('connoto99', 'Connolly', 'Tommy', 'United Kingdom', 'Manchester', '1870'),
#  ('conroti01', 'Conroy', 'Tim', 'USA', 'McKeesport', '1960'),
#  ('contrca01', 'Contreras', 'Carlos', 'D.R.', 'Santo Domingo', '1991'),
#  ('coraal01', 'Cora', 'Alex', 'P.R.', 'Caguas', '1975'),
#  ('corajo01', 'Cora', 'Joey', 'P.R.', 'Caguas', '1965'),
#  ('cordoal01', 'Cordoba', 'Allen', 'Panama', 'Changuinola', '1995'),
#  ('cordofr01', 'Cordova', 'Francisco', 'Mexico', 'Cerro Azul', '1972'),
#  ('corpama01', 'Corpas', 'Manny', 'Panama', 'Panama', '1982'),
#  ('corpoca01', 'Corporan', 'Carlos', 'P.R.', 'Hato Rey', '1984'),
#  ('correca01', 'Correa', 'Carlos', 'P.R.', 'Ponce', '1994'),
#  ('correed01', 'Correa', 'Ed', 'P.R.', 'Hato Rey', '1966'),
#  ('corsiji01', 'Corsi', 'Jim', 'USA', 'Newton', '1961'),
#  ('corteda01', 'Cortes', 'David', 'Mexico', 'Mexicali', '1973'),
#  ('costejo01', 'Costello', 'John', 'USA', 'Bronx', '1960'),
#  ('cotahu01', 'Cota', 'Humberto', 'Mexico', 'San Luis Rio Colorado', '1979'),
#  ('cottohe01', 'Cotto', 'Henry', 'USA', 'New York', '1961'),
#  ('cottojh01', 'Cotton', 'Jharel', 'V.I.', '', '1992'),
#  ('coxda01', 'Cox', 'Danny', 'United Kingdom', 'Northampton', '1959'),
#  ('crabbca01', 'Crabbe', 'Callix', 'V.I.', '', '1983'),
#  ('crespce01', 'Crespo', 'Cesar', 'P.R.', 'Rio Piedras', '1979'),
#  ('crespfe01', 'Crespo', 'Felipe', 'P.R.', 'Rio Piedras', '1973'),
#  ('crewsti01', 'Crews', 'Tim', 'USA', 'Tampa', '1961'),
#  ('crimch01', 'Crim', 'Chuck', 'USA', 'Van Nuys', '1961'),
#  ('cristbi01', 'Cristall', 'Bill', 'Russia', 'Odessa', '1875'),
#  ('crompne01', 'Crompton', 'Ned', 'United Kingdom', 'Liverpool', '1889'),
#  ('cruzhe01', 'Cruz', 'Hector', 'P.R.', 'Arroyo', '1953'),
#  ('cruzhe02', 'Cruz', 'Henry', 'V.I.', 'Christiansted', '1952'),
#  ('cruziv01', 'Cruz', 'Ivan', 'P.R.', 'Fajardo', '1968'),
#  ('cruzjo01', 'Cruz', 'Jose', 'P.R.', 'Arroyo', '1947'),
#  ('cruzjo02', 'Cruz', 'Jose', 'P.R.', 'Arroyo', '1974'),
#  ('cruzlu01', 'Cruz', 'Luis', 'Mexico', 'Navojoa', '1984'),
#  ('cubilda01', 'Cubillan', 'Darwin', 'Venezuela', 'Bobures', '1972'),
#  ('cummimi01', 'Cummings', 'Midre', 'V.I.', 'Christiansted', '1971'),
#  ('cusicto01', 'Cusick', 'Andy', 'Ireland', 'Limerick', '1857'),
#  ('cuthbch01', 'Cuthbert', 'Cheslor', 'Nicaragua', 'Corn Island', '1992'),
#  ('daalom01', 'Daal', 'Omar', 'Venezuela', 'Maracaibo', '1972'),
#  ('dailyhu01', 'Daily', 'Hugh', 'Ireland', '', '1847'),
#  ('dalenpe01', 'Dalena', 'Pete', 'USA', 'Fresno', '1960'),
#  ('darliro01', 'Darling', 'Ron', 'USA', 'Honolulu', '1960'),
#  ('daughja01', 'Daugherty', 'Jack', 'USA', 'Hialeah', '1960'),
#  ('davidbo01', 'Davidson', 'Bob', 'Germany', 'Bad Kreuznach', '1963'),
#  ('davidma01', 'Davidson', 'Mark', 'USA', 'Knoxville', '1961'),
#  ('davisal01', 'Davis', 'Alvin', 'USA', 'Riverside', '1960'),
#  ('davisch01', 'Davis', 'Chili', 'Jamaica', 'Kingston', '1960'),
#  ('davisgl01', 'Davis', 'Glenn', 'USA', 'Jacksonville', '1961'),
#  ('davisma01', 'Davis', 'Mark', 'USA', 'Livermore', '1960'),
#  ('davisst02', 'Davis', 'Storm', 'USA', 'Dallas', '1961'),
#  ('davisst03', 'Davis', 'Steve', 'USA', 'San Antonio', '1960'),
#  ('davistr01', 'Davis', 'Trench', 'USA', 'Baltimore', '1960'),
#  ('dedmoje01', 'Dedmon', 'Jeff', 'USA', 'Torrance', '1960'),
#  ('deerro01', 'Deer', 'Rob', 'USA', 'Orange', '1960'),
#  ('dejesiv01', 'de Jesus', 'Ivan', 'P.R.', 'Santurce', '1953'),
#  ('dejesiv02', 'De Jesus', 'Ivan', 'P.R.', 'Guaynabo', '1987'),
#  ('delarjo01', 'De La Rosa', 'Jorge', 'Mexico', 'Monterrey', '1981'),
#  ('delatjo01', 'De La Torre', 'Jose', 'P.R.', 'San Juan', '1985'),
#  ('deleojo01', 'DeLeon', 'Jose', 'D.R.', 'Rancho Viejo', '1960'),
#  ('deleojo03', 'De Leon', 'Jose', 'P.R.', 'Isabela', '1992'),
#  ('deleolu01', 'DeLeon', 'Luis', 'P.R.', 'Ponce', '1958'),
#  ('delgaal01', 'Delgado', 'Alex', 'Venezuela', 'Palmarejo', '1971'),
#  ('delgaca01', 'Delgado', 'Carlos', 'P.R.', 'Aguadilla', '1972'),
#  ('delgaje01', 'Delgado', 'Jesus', 'Venezuela', 'Maracay', '1984'),
#  ('deshaji01', 'Deshaies', 'Jim', 'USA', 'Massena', '1960'),
#  ('desseel01', 'Dessens', 'Elmer', 'Mexico', 'Hermosillo', '1971'),
#  ('diazar01', 'Diaz', 'Argenis', 'Venezuela', 'Guatire', '1987'),
#  ('diazbo01', 'Diaz', 'Bo', 'Venezuela', 'Cua', '1953'),
#  ('diazed01', 'Diaz', 'Edgar', 'P.R.', 'Santurce', '1964'),
#  ('diazed02', 'Diaz', 'Eddy', 'Venezuela', 'Barquisimeto', '1971'),
#  ('diazed03', 'Diaz', 'Edwin', 'P.R.', 'Bayamon', '1975'),
#  ('diazed04', 'Diaz', 'Edwin', 'P.R.', 'Naguabo', '1994'),
#  ('diazei01', 'Diaz', 'Einar', 'Panama', 'Chiriqui', '1972'),
#  ('diazel01', 'Diaz', 'Elias', 'Venezuela', 'Maracaibo', '1990'),
#  ('diazja01', 'Diaz', 'Jairo', 'Venezuela', 'Puerto La Cruz', '1991'),
#  ('diazma01', 'Diaz', 'Mario', 'P.R.', 'Humacao', '1962'),
#  ('diazmi01', 'Diaz', 'Mike', 'USA', 'San Francisco', '1960'),
#  ('dixonke01', 'Dixon', 'Ken', 'USA', 'Monroe', '1960'),
#  ('dorsebr01', 'Dorsett', 'Brian', 'USA', 'Terre Haute', '1961'),
#  ('dortame01', 'Dorta', 'Melvin', 'Venezuela', 'Valencia', '1982'),
#  ('doubrfe01', 'Doubront', 'Felix', 'Venezuela', 'Puerto Cabello', '1987'),
#  ('dowelke01', 'Dowell', 'Ken', 'USA', 'Sacramento', '1961'),
#  ('downske01', 'Downs', 'Kelly', 'USA', 'Ogden', '1960'),
#  ('doyleco01', 'Doyle', 'Conny', 'Ireland', '', '1862'),
#  ('dozieto01', 'Dozier', 'Tom', 'USA', 'San Pablo', '1961'),
#  ('drabomo01', 'Drabowsky', 'Moe', 'Poland', 'Ozanna', '1935'),
#  ('dreyfba99', 'Dreyfuss', 'Barney', 'Germany', 'Freiburg', '1865'),
#  ('duffyed01', 'Duffy', 'Ed', 'Ireland', '', '1844'),
#  ('durange01', 'Duran', 'German', 'Mexico', 'Zacatecas', '1984'),
#  ('duranlu01', 'Durango', 'Luis', 'Panama', 'Panama', '1986'),
#  ('durazer01', 'Durazo', 'Erubiel', 'Mexico', 'Hermosillo', '1974'),
#  ('earlsc01', 'Earl', 'Scott', 'USA', 'Seymour', '1960'),
#  ('easlelo01', 'Easley', 'Logan', 'USA', 'Salt Lake City', '1961'),
#  ('edenmi01', 'Eden', 'Mike', 'Panama', 'Fort Clayton', '1949'),
#  ('edensto01', 'Edens', 'Tom', 'USA', 'Ontario', '1961'),
#  ('eichhma01', 'Eichhorn', 'Mark', 'USA', 'San Jose', '1960'),
#  ('eiteled01', 'Eiteljorge', 'Ed', 'Germany', 'Berlin', '1871'),
#  ('ellswst01', 'Ellsworth', 'Steve', 'USA', 'Chicago', '1960'),
#  ('engelst01', 'Engel', 'Steve', 'USA', 'Cincinnati', '1961'),
#  ('epparji01', 'Eppard', 'Jim', 'USA', 'South Bend', '1960'),
#  ('ericker01', 'Erickson', 'Eric', 'Sweden', 'Vargarda', '1892'),
#  ('esaskni01', 'Esasky', 'Nick', 'USA', 'Hialeah', '1960'),
#  ('escaled01', 'Escalona', 'Edgmer', 'Venezuela', 'La Guaira', '1986'),
#  ('escalfe01', 'Escalona', 'Felix', 'Venezuela', 'Puerto Cabello', '1979'),
#  ('escalni01', 'Escalera', 'Nino', 'P.R.', 'Santurce', '1929'),
#  ('escalse01', 'Escalona', 'Sergio', 'Venezuela', 'El Tocuyo', '1984'),
#  ('escarch01', 'Escarrega', 'Chico', 'Mexico', 'Los Mochis', '1949'),
#  ('escobal01', 'Escobar', 'Alex', 'Venezuela', 'Valencia', '1978'),
#  ('escobal02', 'Escobar', 'Alcides', 'Venezuela', 'La Sabana', '1986'),
#  ('escoban01', 'Escobar', 'Angel', 'Venezuela', 'La Sabana', '1965'),
#  ('escobed01', 'Escobar', 'Eduardo', 'Venezuela', 'Villa de Cura', '1989'),
#  ('escobed02', 'Escobar', 'Edwin', 'Venezuela', 'La Boyera', '1992'),
#  ('escobjo01', 'Escobar', 'Jose', 'Venezuela', 'La Sabana', '1960'),
#  ('escobke01', 'Escobar', 'Kelvim', 'Venezuela', 'La Guaira', '1976'),
#  ('espinal01', 'Espinoza', 'Alvaro', 'Venezuela', 'Valencia', '1962'),
#  ('estrafr01', 'Estrada', 'Frank', 'Mexico', 'Navojoa', '1948'),
#  ('estraho01', 'Estrada', 'Horacio', 'Venezuela', 'San Joaquin', '1975'),
#  ('estrama01', 'Estrada', 'Marco', 'Mexico', 'Sonora', '1983'),
#  ('ewingre01', 'Ewing', 'Reuben', 'Russia', 'Odessa', '1899'),
#  ('faedole01', 'Faedo', 'Lenny', 'USA', 'Tampa', '1960'),
#  ('fajarhe01', 'Fajardo', 'Hector', 'Mexico', 'Sahuayo', '1970'),
#  ('fallobo01', 'Fallon', 'Bob', 'USA', 'Bronx', '1960'),
#  ('faluir01', 'Falu', 'Irving', 'P.R.', 'Hato Rey', '1983'),
#  ('farmebi01', 'Farmer', 'Bill', 'Ireland', 'Dublin', '1864'),
#  ('feldemi01', 'Felder', 'Mike', 'USA', 'Vallejo', '1961'),
#  ('felicje01', 'Feliciano', 'Jesus', 'P.R.', 'Bayamon', '1979'),
#  ('fenwibo01', 'Fenwick', 'Bobby', 'Japan', 'Naha', '1946'),
#  ('ferriho01', 'Ferris', 'Hobe', 'United Kingdom', 'Trowbridge', '1874'),
#  ('fieldbr01', 'Fields', 'Bruce', 'USA', 'Cleveland', '1960'),
#  ('figueed01', 'Figueroa', 'Ed', 'P.R.', 'Ciales', '1948'),
#  ('figuelu01', 'Figueroa', 'Luis', 'P.R.', 'Bayamon', '1974'),
#  ('fischto01', 'Fischer', 'Todd', 'USA', 'Columbus', '1960'),
#  ('fitzgde01', 'Fitzgerald', 'Dennis', 'United Kingdom', '', '1865'),
#  ('fitzgmi02', 'Fitzgerald', 'Mike', 'USA', 'Long Beach', '1960'),
#  ('floregi01', 'Flores', 'Gil', 'P.R.', 'Ponce', '1952'),
#  ('floreje01', 'Flores', 'Jesse', 'Mexico', 'Guadalajara', '1914'),
#  ('floreje02', 'Flores', 'Jesus', 'Venezuela', 'Carupano', '1984'),
#  ('florera02', 'Flores', 'Ramon', 'Venezuela', 'Barinas', '1992'),
#  ('foleycu01', 'Foley', 'Curry', 'Ireland', 'Milltown', '1856'),
#  ('fordcu01', 'Ford', 'Curt', 'USA', 'Jackson', '1960'),
#  ('francjo01', 'Franco', 'John', 'USA', 'Brooklyn', '1960'),
#  ('freiral01', 'Freire', 'Alejandro', 'Venezuela', 'Caracas', '1974'),
#  ('fuentmi01', 'Fuentes', 'Miguel', 'P.R.', 'Loiza Aldea', '1946'),
#  ('gagnegr01', 'Gagne', 'Greg', 'USA', 'Fall River', '1961'),
#  ('gainety01', 'Gainey', 'Ty', 'USA', 'Cheraw', '1960'),
#  ('gaisefr01', 'Gaiser', 'Fred', 'Germany', 'Stuttgart', '1885'),
#  ('galaran01', 'Galarraga', 'Andres', 'Venezuela', 'Caracas', '1961'),
#  ('galarar01', 'Galarraga', 'Armando', 'Venezuela', 'Cumana', '1982'),
#  ('gallada01', 'Gallagher', 'Dave', 'USA', 'Trenton', '1960'),
#  ('gallegi01', 'Gallegos', 'Giovanny', 'Mexico', 'Obregon', '1991'),
#  ('gallemi01', 'Gallego', 'Mike', 'USA', 'Whittier', '1960'),
#  ('galvifr01', 'Galvis', 'Freddy', 'Venezuela', 'Punto Fijo', '1989'),
#  ('garceri01', 'Garces', 'Rich', 'Venezuela', 'Maracay', '1971'),
#  ('garciav01', 'Garcia', 'Avisail', 'Venezuela', 'Anaco', '1991'),
#  ('garcica01', 'Garcia', 'Carlos', 'Venezuela', 'Tachira', '1967'),
#  ('garcich01', 'Garcia', 'Chico', 'Mexico', 'Veracruz', '1924'),
#  ('garcifr02', 'Garcia', 'Freddy', 'Venezuela', 'Caracas', '1976'),
#  ('garciha01', 'Garcia', 'Harvey', 'Venezuela', 'Caracas', '1984'),
#  ('garcija02', 'Garcia', 'Jaime', 'Mexico', 'Reynosa', '1986'),
#  ('garcika01', 'Garcia', 'Karim', 'Mexico', 'Ciudad Obregon', '1975'),
#  ('garcilu02', 'Garcia', 'Luis', 'Mexico', 'Hermosillo', '1975'),
#  ('garcimi02', 'Garcia', 'Miguel', 'Venezuela', 'Caracas', '1967'),
#  ('garcira03', 'Garcia', 'Ramon', 'Venezuela', 'Guanare', '1969'),
#  ('garciro01', 'Garcia', 'Rosman', 'Venezuela', 'Maracay', '1979'),
#  ('gardnwe01', 'Gardner', 'Wes', 'USA', 'Benton', '1961'),
#  ('garibda01', 'Garibay', 'Daniel', 'Mexico', 'Maneadero', '1973'),
#  ('garresc01', 'Garrelts', 'Scott', 'USA', 'Champaign', '1961'),
#  ('garrigi01', 'Garrido', 'Gil', 'Panama', 'Panama', '1941'),
#  ('gerenbo01', 'Geren', 'Bob', 'USA', 'San Diego', '1961'),
#  ('gerhake01', 'Gerhart', 'Ken', 'USA', 'Charleston', '1961'),
#  ('gettmja01', 'Gettman', 'Jake', 'Russia', 'Frank', '1875'),
#  ('ghelfto01', 'Ghelfi', 'Tony', 'USA', 'La Crosse', '1961'),
#  ('gibsopa01', 'Gibson', 'Paul', 'USA', 'Southampton', '1960'),
#  ('gilbe01', 'Gil', 'Benji', 'Mexico', 'Tijuana', '1972'),
#  ('gilesbr01', 'Giles', 'Brian', 'USA', 'Manhattan', '1960'),
#  ('gilgahu01', 'Gilgan', 'Hugh', 'Ireland', '', '1852'),
#  ('gilge01', 'Gil', 'Geronimo', 'Mexico', 'Estacion Lagunas', '1975'),
#  ('gilgu01', 'Gil', 'Gus', 'Venezuela', 'Caracas', '1939'),
#  ('gimenhe01', 'Gimenez', 'Hector', 'Venezuela', 'San Felipe', '1982'),
#  ('goldsiz01', 'Goldstein', 'Izzy', 'Russia', 'Odessa', '1908'),
#  ('gomezch01', 'Gomez', 'Chile', 'Mexico', 'Mazatlan', '1909'),
#  ('gomezje01', 'Gomez', 'Jeanmar', 'Venezuela', 'Caracas', '1988'),
#  ('gomezle02', 'Gomez', 'Leo', 'P.R.', 'Canovanas', '1966'),
#  ('gomezlu01', 'Gomez', 'Luis', 'Mexico', 'Guadalajara', '1951'),
#  ('gonzaal02', 'Gonzalez', 'Alex', 'Venezuela', 'Cagua', '1977'),
#  ('gonzaal03', 'Gonzalez', 'Alberto', 'Venezuela', 'Maracaibo', '1983'),
#  ('gonzaan01', 'Gonzalez', 'Andy', 'P.R.', 'Rio Piedras', '1981'),
#  ('gonzaca01', 'Gonzalez', 'Carlos', 'Venezuela', 'Maracaibo', '1985'),
#  ('gonzadi01', 'Gonzalez', 'Dicky', 'P.R.', 'Bayamon', '1978'),
#  ('gonzaed01', 'Gonzalez', 'Edgar', 'Mexico', 'San Nicolas de los Garza', '1983'),
#  ('gonzaen01', 'Gonzalez', 'Enrique', 'Venezuela', 'Ciudad Bolivar', '1982'),
#  ('gonzafe01', 'Gonzalez', 'Fernando', 'P.R.', 'Arecibo', '1950'),
#  ('gonzage01', 'Gonzalez', 'German', 'Venezuela', 'Rio Caribe', '1962'),
#  ('gonzaje01', 'Gonzalez', 'Geremi', 'Venezuela', 'Maracaibo', '1975'),
#  ('gonzaju02', 'Gonzalez', 'Julio', 'P.R.', 'Caguas', '1952'),
#  ('gonzaju03', 'Gonzalez', 'Juan', 'P.R.', 'Arecibo', '1969'),
#  ('gonzalu02', 'Gonzalez', 'Luis', 'Venezuela', 'Maracay', '1979'),
#  ('gonzama01', 'Gonzalez', 'Marwin', 'Venezuela', 'Puerto Ordaz', '1989'),
#  ('gonzami04', 'Gonzalez', 'Miguel', 'Venezuela', 'Porlamar', '1990'),
#  ('gonzare01', 'Gonzales', 'Rene', 'USA', 'Austin', '1960'),
#  ('gotayju01', 'Gotay', 'Julio', 'P.R.', 'Fajardo', '1939'),
#  ('gratebe01', 'Graterol', 'Beiker', 'Venezuela', 'Barquisimeto', '1974'),
#  ('grateju01', 'Graterol', 'Juan', 'Venezuela', 'Maracay', '1989'),
#  ('graveda01', 'Graves', 'Danny', 'Viet Nam', 'Saigon', '1973'),
#  ('greenbo01', 'Greenwood', 'Bob', 'Mexico', 'Cananea', '1928'),
#  ('greench01', 'Green', 'Chris', 'USA', 'Los Angeles', '1960'),
#  ('greenda03', 'Green', 'David', 'Nicaragua', 'Managua', '1960'),
#  ('gregodi01', 'Gregorius', 'Didi', 'Netherlands', 'Amsterdam', '1990'),
#  ('grosske01', 'Gross', 'Kevin', 'USA', 'Downey', '1961'),
#  ('guaipma01', 'Guaipe', 'Mayckol', 'Venezuela', 'Barcelona', '1990'),
#  ('guantce01', 'Guante', 'Cecilio', 'D.R.', 'Villa Mella', '1960'),
#  ('guerrde01', 'Guerra', 'Deolis', 'Venezuela', 'San Felix', '1989'),
#  ('guerrju02', 'Guerra', 'Junior', 'Venezuela', 'San Felix', '1985'),
#  ('guevagi01', 'Guevara', 'Giomar', 'Venezuela', 'Guarenas', '1972'),
#  ('guillca01', 'Guillen', 'Carlos', 'Venezuela', 'Maracay', '1975'),
#  ('guilloz01', 'Guillen', 'Ozzie', 'Venezuela', 'Ocumare del Tuy', '1964'),
#  ('gutiece01', 'Gutierrez', 'Cesar', 'Venezuela', 'Coro', '1943'),
#  ('gutiefr01', 'Gutierrez', 'Franklin', 'Venezuela', 'Caracas', '1983'),
#  ('gutieja01', 'Gutierrez', 'Jackie', 'Colombia', 'Cartagena', '1960'),
#  ('gutieju01', 'Gutierrez', 'J. C.', 'Venezuela', 'Puerto La Cruz', '1983'),
#  ('guzmaan01', 'Guzman', 'Angel', 'Venezuela', 'Caracas', '1981'),
#  ('guzmaed01', 'Guzman', 'Edwards', 'P.R.', 'Bayamon', '1976'),
#  ('guzmaje01', 'Guzman', 'Jesus', 'Venezuela', 'Cumana', '1984'),
#  ('guzmajo01', 'Guzman', 'Jose', 'P.R.', 'Santa Isabel', '1963'),
#  ('gwosddo01', 'Gwosdz', 'Doug', 'USA', 'Houston', '1960'),
#  ('gwynnto01', 'Gwynn', 'Tony', 'USA', 'Los Angeles', '1960'),
#  ('hagenke01', 'Hagen', 'Kevin', 'USA', 'Renton', '1960'),
#  ('hallge01', 'Hall', 'George', 'United Kingdom', 'Stepney', '1849'),
#  ('hallme01', 'Hall', 'Mel', 'USA', 'Lyons', '1960'),
#  ('hallsch01', 'Hallstrom', 'Charlie', 'Sweden', 'Jonkoping', '1863'),
#  ('halmagr01', 'Halman', 'Greg', 'Netherlands', 'Haarlem', '1987'),
#  ('halpiji01', 'Halpin', 'Jim', 'United Kingdom', '', '1863'),
#  ('hanfoch01', 'Hanford', 'Charlie', 'United Kingdom', 'Tunstall', '1882'),
#  ('hansade01', 'Hansack', 'Devern', 'Nicaragua', 'Pearl Lagoon', '1978'),
#  ('hartlmi01', 'Hartley', 'Mike', 'USA', 'Hawthorne', '1961'),
#  ('hasnepe01', 'Hasney', 'Pete', 'United Kingdom', '', '1865'),
#  ('hatchbi01', 'Hatcher', 'Billy', 'USA', 'Williams', '1960'),
#  ('hawkian01', 'Hawkins', 'Andy', 'USA', 'Waco', '1960'),
#  ('haywara01', 'Hayward', 'Ray', 'USA', 'Enid', '1961'),
#  ('haywobi01', 'Haywood', 'Bill', 'Panama', 'Colon', '1937'),
#  ('hearned02', 'Hearn', 'Ed', 'USA', 'Stuart', '1960'),
#  ('hearrje01', 'Hearron', 'Jeff', 'USA', 'Long Beach', '1961'),
#  ('heatone01', 'Heaton', 'Neal', 'USA', 'South Ozone Park', '1960'),
#  ('hendrel01', 'Hendricks', 'Elrod', 'V.I.', 'Charlotte Amalie', '1940'),
#  ('hengeda01', 'Hengel', 'Dave', 'USA', 'Oakland', '1961'),
#  ('hennemi01', 'Henneman', 'Mike', 'USA', 'St. Charles', '1961'),
#  ('henrios01', 'Henriquez', 'Oscar', 'Venezuela', 'La Guaira', '1974'),
#  ('heredub01', 'Heredia', 'Ubaldo', 'Venezuela', 'Ciudad Bolivar', '1956'),
#  ('hermore01', 'Hermoso', 'Remy', 'Venezuela', 'Carabobo', '1947'),
#  ('hernaal01', 'Hernandez', 'Alex', 'P.R.', 'San Juan', '1977'),
#  ('hernaca01', 'Hernandez', 'Carlos', 'Venezuela', 'San Felix', '1967'),
#  ('hernaca02', 'Hernandez', 'Carlos', 'Venezuela', 'Caracas', '1975'),
#  ('hernaca03', 'Hernandez', 'Carlos', 'Venezuela', 'Guacara', '1980'),
#  ('hernace02', 'Hernandez', 'Cesar', 'Venezuela', 'Valencia', '1990'),
#  ('hernaen01', 'Hernandez', 'Enzo', 'Venezuela', 'Valle de Guanape', '1949'),
#  ('hernaen02', 'Hernandez', 'Enrique', 'P.R.', 'San Juan', '1991'),
#  ('hernafe02', 'Hernandez', 'Felix', 'Venezuela', 'Valencia', '1986'),
#  ('hernago01', 'Hernandez', 'Gorkys', 'Venezuela', 'Guiria', '1987'),
#  ('hernaje01', 'Hernaiz', 'Jesus', 'P.R.', 'Santurce', '1945'),
#  ('hernajo01', 'Hernandez', 'Jose', 'P.R.', 'Rio Piedras', '1969'),
#  ('hernale01', 'Hernandez', 'Leo', 'Venezuela', 'Santa Lucia', '1959'),
#  ('hernalu01', 'Hernandez', 'Luis', 'Venezuela', 'Quibor', '1984'),
#  ('hernama01', 'Hernandez', 'Manny', 'D.R.', 'La Romana', '1961'),
#  ('hernaos01', 'Hernandez', 'Oscar', 'Venezuela', 'Punto Fijo', '1993'),
#  ('hernape02', 'Hernandez', 'Pedro', 'Venezuela', 'Barquisimeto', '1989'),
#  ('hernara02', 'Hernandez', 'Ramon', 'Venezuela', 'Caracas', '1976'),
#  ('hernato01', 'Hernandez', 'Toby', 'Venezuela', 'Calabozo', '1958'),
#  ('herreal01', 'Herrera', 'Alex', 'Venezuela', 'Maracaibo', '1979'),
#  ('herrebo01', 'Herrera', 'Bobby', 'Mexico', 'Nuevo Laredo', '1926'),
#  ('herrejo01', 'Herrera', 'Jose', 'Venezuela', 'San Lorenzo', '1942'),
#  ('herrejo03', 'Herrera', 'Jonathan', 'Venezuela', 'Maracaibo', '1984'),
#  ('herreod01', 'Herrera', 'Odubel', 'Venezuela', 'San Jose', '1991'),
#  ('herrero01', 'Herrera', 'Ronald', 'Venezuela', 'Maracay', '1995'),
#  ('hessot01', 'Hess', 'Otto', 'Switzerland', 'Berne', '1878'),
#  ('hidalri01', 'Hidalgo', 'Richard', 'Venezuela', 'Caracas', '1975'),
#  ('highadi01', 'Higham', 'Dick', 'United Kingdom', 'Ipswich', '1851'),
#  ('hilldo01', 'Hill', 'Donnie', 'USA', 'Pomona', '1960'),
#  ('hodgspa01', 'Hodgson', 'Paul', 'CAN', 'Montreal', '1960'),
#  ('hoganma01', 'Hogan', 'Marty', 'United Kingdom', 'Wednesbury', '1869'),
#  ('hopkimi01', 'Hopkins', 'Mike', 'United Kingdom', 'Glasgow', '1872'),
#  ('housecr01', 'House', 'Craig', 'Japan', 'Naha AFB', '1977'),
#  ('housejo01', 'Houseman', 'John', 'Netherlands', '', '1870'),
#  ('howelja02', 'Howell', 'Jack', 'USA', 'Tucson', '1961'),
#  ('howelke01', 'Howell', 'Ken', 'USA', 'Detroit', '1960'),
#  ('hrbekke01', 'Hrbek', 'Kent', 'USA', 'Minneapolis', '1960'),
#  ('huch01', 'Hu', 'Chin-lung', 'Taiwan', 'Tainan City', '1984'),
#  ('huch02', 'Hu', 'Chih-Wei', 'Taiwan', 'Taichung', '1993'),
#  ('hudlere01', 'Hudler', 'Rex', 'USA', 'Tempe', '1960'),
#  ('huletti01', 'Hulett', 'Tim', 'USA', 'Springfield', '1960'),
#  ('huntra01', 'Hunt', 'Randy', 'USA', 'Prattville', '1960'),
#  ('hurtaed01', 'Hurtado', 'Edwin', 'Venezuela', 'Barquisimeto', '1970'),
#  ('hwangja01', 'Hwang', 'Jae-gyun', 'South Korea', 'Seoul', '1987'),
#  ('ibarred01', 'Ibarra', 'Edgar', 'Venezuela', 'Valencia', '1989'),
#  ('inciaen01', 'Inciarte', 'Ender', 'Venezuela', 'Maracaibo', '1990'),
#  ('infanal01', 'Infante', 'Alexis', 'Venezuela', 'Barquisimeto', '1961'),
#  ('infangr01', 'Infante', 'Greg', 'Venezuela', 'Caracas', '1987'),
#  ('infanom01', 'Infante', 'Omar', 'Venezuela', 'Puerto La Cruz', '1981'),
#  ('irabuhi01', 'Irabu', 'Hideki', 'Japan', 'Hirara', '1969'),
#  ('iribahe01', 'Iribarren', 'Hernan', 'Venezuela', 'Barquisimeto', '1984'),
#  ('isaleor01', 'Isales', 'Orlando', 'P.R.', 'Santurce', '1959'),
#  ('iwakuhi01', 'Iwakuma', 'Hisashi', 'Japan', 'Higashi Yamato', '1981'),
#  ('iwamuak01', 'Iwamura', 'Akinori', 'Japan', 'Uwajima', '1979'),
#  ('izturce01', 'Izturis', 'Cesar', 'Venezuela', 'Barquisimeto', '1980'),
#  ('izturma01', 'Izturis', 'Maicer', 'Venezuela', 'Barquisimeto', '1980'),
#  ('jackssa01', 'Jackson', 'Sam', 'United Kingdom', 'Ripon', '1849'),
#  ('jelksgr01', 'Jelks', 'Greg', 'USA', 'Centre', '1961'),
#  ('jennida99', 'Jennings', 'Dan', 'USA', 'Daphne', '1960'),
#  ('jenniro01', 'Jennings', 'Robin', 'Singapore', 'Singapore', '1972'),
#  ('jimenaj01', 'Jimenez', 'A. J.', 'P.R.', 'San Juan', '1990'),
#  ('jimence01', 'Jimenez', 'Cesar', 'Venezuela', 'Cumana', '1984'),
#  ('jimenge01', 'Jimenez', 'German', 'Mexico', 'Santiago Ixcuintla', '1962'),
#  ('jimenho01', 'Jimenez', 'Houston', 'Mexico', 'Mexico', '1957'),
#  ('jimenjo02', 'Jimenez', 'Joe', 'P.R.', 'San Juan', '1995'),
#  ('jimenlu01', 'Jimenez', 'Luis', 'Venezuela', 'Bobare', '1982'),
#  ('johnsbi04', 'Johnson', 'Bill', 'USA', 'Wilmington', '1960'),
#  ('johnsho01', 'Johnson', 'Howard', 'USA', 'Clearwater', '1960'),
#  ('johnsjo05', 'Johnson', 'Joe', 'USA', 'Brookline', '1961'),
#  ('jonesro01', 'Jones', 'Ross', 'USA', 'Miami', '1960'),
#  ('jonestr01', 'Jones', 'Tracy', 'USA', 'Hawthorne', '1961'),
#  ('jorgear01', 'Jorgens', 'Arndt', 'Norway', 'Modum', '1905'),
#  ('juliojo01', 'Julio', 'Jorge', 'Venezuela', 'Caracas', '1979'),
#  ('kaiseje01', 'Kaiser', 'Jeff', 'USA', 'Wyandotte', '1960'),
#  ('kangju01', 'Kang', 'Jung Ho', 'South Korea', 'Gwangju', '1987'),
#  ('keyji01', 'Key', 'Jimmy', 'USA', 'Huntsville', '1961'),
#  ('kieckda01', 'Kiecker', 'Dana', 'USA', 'Sleepy Eye', '1961'),
#  ('kiefest01', 'Kiefer', 'Steve', 'USA', 'Chicago', '1960'),
#  ('kimby01', 'Kim', 'Byung-Hyun', 'South Korea', 'Gwangju', '1979'),
#  ('kimhy01', 'Kim', 'Hyun Soo', 'South Korea', 'Seoul', '1988'),
#  ('kingemi01', 'Kingery', 'Mike', 'USA', 'St. James', '1961'),
#  ('klozana01', 'Kloza', 'Nap', 'Poland', '', '1903'),
#  ('knudsma01', 'Knudson', 'Mark', 'USA', 'Denver', '1960'),
#  ('kommibr01', 'Komminsk', 'Brad', 'USA', 'Lima', '1961'),
#  ('kooda01', 'Koo', 'Dae-Sung', 'South Korea', 'Daejeon', '1969'),
#  ('kramera01', 'Kramer', 'Randy', 'USA', 'Palo Alto', '1960'),
#  ('krukjo01', 'Kruk', 'John', 'USA', 'Charleston', '1961'),
#  ('kuoho01', 'Kuo', 'Hung-Chih', 'Taiwan', 'Tainan City', '1981'),
#  ('kutchra01', 'Kutcher', 'Randy', 'USA', 'Anchorage', '1960'),
#  ('laboyco01', 'Laboy', 'Coco', 'P.R.', 'Ponce', '1940'),
#  ('lachoal01', 'Lachowicz', 'Al', 'USA', 'Pittsburgh', '1960'),
#  ('lagami01', 'Laga', 'Mike', 'USA', 'Ridgewood', '1960'),
#  ('lampake01', 'Lampard', 'Keith', 'United Kingdom', 'Warrington', '1945'),
#  ('langsma01', 'Langston', 'Mark', 'USA', 'San Diego', '1960'),
#  ('lansfjo01', 'Lansford', 'Joe', 'USA', 'Santa Clara', '1961'),
#  ('larkipa01', 'Larkin', 'Pat', 'USA', 'Arcadia', '1960'),
#  ('lathabi01', 'Latham', 'Bill', 'USA', 'Birmingham', '1960'),
#  ('lavalmi01', 'LaValliere', 'Mike', 'USA', 'Charlotte', '1960'),
#  ('lawsoal01', 'Lawson', 'Al', 'United Kingdom', 'London', '1869'),
#  ('leallu01', 'Leal', 'Luis', 'Venezuela', 'Barquisimeto', '1957'),
#  ('leeca01', 'Lee', 'Carlos', 'Panama', 'Aguadulce', '1976'),
#  ('leech01', 'Lee', 'C. C.', 'Taiwan', 'Peng-Hu County', '1986'),
#  ('leeda02', 'Lee', 'Dae-ho', 'South Korea', 'Busan', '1982'),
#  ('leesa01', 'Lee', 'Sang-Hoon', 'South Korea', 'Seoul', '1971'),
#  ('legggr01', 'Legg', 'Greg', 'USA', 'San Jose', '1960'),
#  ('leistjo01', 'Leister', 'John', 'USA', 'San Antonio', '1961'),
#  ('lelivbi01', 'Lelivelt', 'Bill', 'Netherlands', '', '1884'),
#  ('lelivja01', 'Lelivelt', 'Jack', 'Netherlands', '', '1885'),
#  ('leonar01', 'Leon', 'Arnold', 'Mexico', 'Culiacan', '1988'),
#  ('leonar02', 'Leon', 'Arcenio', 'Venezuela', 'Maracaibo', '1986'),
#  ('leonda01', 'Leon', 'Danny', 'Venezuela', 'La Concepcion', '1967'),
#  ('leonjo01', 'Leon', 'Jose', 'P.R.', 'Cayey', '1976'),
#  ('leonma01', 'Leon', 'Max', 'Mexico', 'Acula', '1950'),
#  ('leonsa01', 'Leon', 'Sandy', 'Venezuela', 'Maracaibo', '1989'),
#  ('lewisal01', 'Lewis', 'Allan', 'Panama', 'Colon', '1941'),
#  ('lewiste01', 'Lewis', 'Ted', 'United Kingdom', 'Machynlleth', '1872'),
#  ('lezcaca01', 'Lezcano', 'Carlos', 'P.R.', 'Arecibo', '1955'),
#  ('librafr01', 'Libran', 'Frankie', 'P.R.', 'Mayaguez', '1948'),
#  ('lickejo01', 'Lickert', 'John', 'USA', 'Pittsburgh', '1960'),
#  ('limch01', 'Lim', 'Chang-Yong', 'South Korea', 'Gwangju', '1976'),
#  ('linch01', 'Lin', 'Che-Hsuan', 'Taiwan', 'Hwa-Lian', '1988'),
#  ('lindjo01', 'Lind', 'Jose', 'P.R.', 'Toabaja', '1964'),
#  ('lindofr01', 'Lindor', 'Francisco', 'P.R.', 'Caguas', '1993'),
#  ('lindsax01', 'Lindstrom', 'Axel', 'Sweden', 'Gustavsberg', '1895'),
#  ('lindsbi02', 'Lindsey', 'Bill', 'USA', 'Staten Island', '1960'),
#  ('lirafe01', 'Lira', 'Felipe', 'Venezuela', 'Santa Teresa del Tuy', '1972'),
#  ('livinja01', 'Livingstone', 'Jake', 'Russia', 'St. Petersburg', '1875'),
#  ('loaizes01', 'Loaiza', 'Esteban', 'Mexico', 'Tijuana', '1971'),
#  ('lobatjo01', 'Lobaton', 'Jose', 'Venezuela', 'Acarigua', '1984'),
#  ('loch02', 'Lo', 'Chia-Jen', 'Taiwan', 'Pingtung County', '1986'),
#  ('lombast01', 'Lombardozzi', 'Steve', 'USA', 'Malden', '1960'),
#  ('longbi01', 'Long', 'Bill', 'USA', 'Cincinnati', '1960'),
#  ('lopezar01', 'Lopez', 'Art', 'P.R.', 'Mayaguez', '1937'),
#  ('lopezar02', 'Lopez', 'Arturo', 'Mexico', 'Culiacan', '1983'),
#  ('lopezau01', 'Lopez', 'Aurelio', 'Mexico', 'Tecamachalco', '1948'),
#  ('lopezca01', 'Lopez', 'Carlos', 'Mexico', 'Mazatlan', '1948'),
#  ('lopezfe01', 'Lopez', 'Felipe', 'P.R.', 'Bayamon', '1980'),
#  ('lopezhe01', 'Lopez', 'Hector', 'Panama', 'Colon', '1929'),
#  ('lopezja01', 'Lopez', 'Javy', 'P.R.', 'Ponce', '1970'),
#  ('lopezja02', 'Lopez', 'Javier', 'P.R.', 'San Juan', '1977'),
#  ('lopezjo01', 'Lopez', 'Jose', 'Venezuela', 'Barcelona', '1983'),
#  ('lopezjo02', 'Lopez', 'Jorge', 'P.R.', 'Cayey', '1993'),
#  ('lopezlu02', 'Lopez', 'Luis', 'P.R.', 'Cidra', '1970'),
#  ('lowelmi01', 'Lowell', 'Mike', 'P.R.', 'San Juan', '1974'),
#  ('lueckri01', 'Luecken', 'Rick', 'USA', 'McAllen', '1960'),
#  ('lugour01', 'Lugo', 'Urbano', 'Venezuela', 'Punto Fijo', '1962'),
#  ('luname01', 'Luna', 'Memo', 'Mexico', 'Mexico', '1930'),
#  ('lunarfe01', 'Lunar', 'Fernando', 'Venezuela', 'Cantaura', '1977'),
#  ('lyonsba01', 'Lyons', 'Barry', 'USA', 'Biloxi', '1960'),
#  ('lyonsst01', 'Lyons', 'Steve', 'USA', 'Tacoma', '1960'),
#  ('macarma01', 'MacArthur', 'Mac', 'United Kingdom', 'Glasgow', '1862'),
#  ('machaal01', 'Machado', 'Alejandro', 'Venezuela', 'Caracas', '1982'),
#  ('machaan01', 'Machado', 'Anderson', 'Venezuela', 'Caracas', '1981'),
#  ('machaan02', 'Machado', 'Andres', 'Venezuela', 'Carabobo', '1993'),
#  ('machadi01', 'Machado', 'Dixon', 'Venezuela', 'San Cristobal', '1992'),
#  ('machaju01', 'Machado', 'Julio', 'Venezuela', 'San Carlos del Zulia', '1965'),
#  ('macharo01', 'Machado', 'Robert', 'Venezuela', 'Puerto Cabello', '1973'),
#  ('machije01', 'Machi', 'Jean', 'Venezuela', 'El Tigre', '1982'),
#  ('maciajo01', 'Macias', 'Jose', 'Panama', 'Panama', '1972'),
#  ('mackto01', 'Mack', 'Tony', 'USA', 'Lexington', '1961'),
#  ('maddemo01', 'Madden', 'Morris', 'USA', 'Laurens', '1960'),
#  ('maddumi01', 'Maddux', 'Mike', 'USA', 'Dayton', '1961'),
#  ('magalev01', 'Magallanes', 'Ever', 'Mexico', 'El Sauz', '1965'),
#  ('malavjo01', 'Malave', 'Jose', 'Venezuela', 'Cumana', '1971'),
#  ('maldoca01', 'Maldonado', 'Candy', 'P.R.', 'Humacao', '1960'),
#  ('maldoca02', 'Maldonado', 'Carlos', 'Panama', 'Chepo', '1966'),
#  ('maldoca03', 'Maldonado', 'Carlos', 'Venezuela', 'Maracaibo', '1979'),
#  ('maldoma01', 'Maldonado', 'Martin', 'P.R.', 'Naguabo', '1986'),
#  ('manguan01', 'Mangual', 'Angel', 'P.R.', 'Juana Diaz', '1947'),
#  ('manniti01', 'Manning', 'Tim', 'United Kingdom', 'Henley-on-Thames', '1853'),
#  ('manrifr01', 'Manrique', 'Fred', 'Venezuela', 'Ciudad Bolivar', '1961'),
#  ('mantife01', 'Mantilla', 'Felix', 'P.R.', 'Isabella', '1934'),
#  ('marakpa01', 'Marak', 'Paul', 'United Kingdom', 'Lakenheath', '1965'),
#  ('marquge01', 'Marquez', 'German', 'Venezuela', 'San Felix', '1995'),
#  ('marqugo01', 'Marquez', 'Gonzalo', 'Venezuela', 'Carupano', '1940'),
#  ('marquis01', 'Marquez', 'Isidro', 'Mexico', 'Navojoa', '1965'),
#  ('marqulu01', 'Marquez', 'Luis', 'P.R.', 'Aguadilla', '1925'),
#  ('marreor01', 'Marrero', 'Oreste', 'P.R.', 'Bayamon', '1969'),
#  ('marshmi02', 'Marshall', 'Mike', 'USA', 'Libertyville', '1960'),
#  ('martica01', 'Martinez', 'Carmelo', 'P.R.', 'Dorado', '1960'),
#  ('martica02', 'Martinez', 'Carlos', 'Venezuela', 'La Guaira', '1965'),
#  ('martida02', 'Martinez', 'David', 'Venezuela', 'Cumana', '1987'),
#  ('martide01', 'Martinez', 'Dennis', 'Nicaragua', 'Granada', '1954'),
#  ('martija02', 'Martinez', 'Javier', 'P.R.', 'Bayamon', '1977'),
#  ('martijo08', 'Martinez', 'Jose', 'Venezuela', 'La Guaira', '1988'),
#  ('martios01', 'Martinez', 'Osvaldo', 'P.R.', 'Carolina', '1988'),
#  ('mashoda01', 'Mashore', 'Damon', 'P.R.', 'Ponce', '1969'),
#  ('matafr01', 'Mata', 'Frank', 'Venezuela', 'Barcelona', '1984'),
#  ('matavi01', 'Mata', 'Victor', 'D.R.', 'Santiago', '1961'),
#  ('matoslu01', 'Matos', 'Luis', 'P.R.', 'Bayamon', '1978'),
#  ('mattido01', 'Mattingly', 'Don', 'USA', 'Evansville', '1961'),
#  ('maysc01', 'May', 'Scott', 'USA', 'West Bend', '1961'),
#  ('maysoed01', 'Maysonet', 'Edwin', 'P.R.', 'Arecibo', '1981'),
#  ('mazalu01', 'Maza', 'Luis', 'Venezuela', 'Cumana', '1980'),
#  ('mcbeaal01', 'McBean', 'Al', 'V.I.', 'Charlotte Amalie', '1938'),
#  ('mccarto03', 'McCarthy', 'Tom', 'Germany', 'Landstuhl', '1961'),
#  ('mccaski01', 'McCaskill', 'Kirk', 'CAN', 'Kapuskasing', '1961'),
#  ('mccorji01', 'McCormick', 'Jim', 'United Kingdom', 'Glasgow', '1856'),
#  ('mcdowro01', 'McDowell', 'Roger', 'USA', 'Cincinnati', '1960'),
#  ('mcilvir01', 'McIlveen', 'Irish', 'United Kingdom', 'Belfast', '1880'),
#  ('meachbo01', 'Meacham', 'Bob', 'USA', 'Los Angeles', '1960'),
#  ('meadolo01', 'Meadows', 'Louie', 'USA', 'Maysville', '1961'),
#  ('medvisc01', 'Medvin', 'Scott', 'USA', 'North Olmsted', '1961'),
#  ('melenfr01', 'Melendez', 'Francisco', 'P.R.', 'Rio Piedras', '1964'),
#  ('melenjo01', 'Melendez', 'Jose', 'P.R.', 'Naguabo', '1965'),
#  ('melenlu01', 'Melendez', 'Luis', 'P.R.', 'Aibonito', '1949'),
#  ('melvibo01', 'Melvin', 'Bob', 'USA', 'Palo Alto', '1961'),
#  ('mendeca01', 'Mendez', 'Carlos', 'Venezuela', 'Caracas', '1974'),
#  ('mendedo01', 'Mendez', 'Donaldo', 'Venezuela', 'Barquisimeto', '1978'),
#  ('mendoca01', 'Mendoza', 'Carlos', 'Venezuela', 'Ciudad Bolivar', '1974'),
#  ('mendolu01', 'Mendoza', 'Luis', 'Mexico', 'Veracruz', '1983'),
#  ('mendoma01', 'Mendoza', 'Mario', 'Mexico', 'Chihuahua', '1950'),
#  ('mercahe01', 'Mercado', 'Hector', 'P.R.', 'Catano', '1974'),
#  ('mercaor01', 'Mercado', 'Orlando', 'P.R.', 'Arecibo', '1961'),
#  ('merceor01', 'Merced', 'Orlando', 'P.R.', 'Hato Rey', '1966'),
#  ('mijarjo01', 'Mijares', 'Jose', 'Venezuela', 'Caracas', '1984'),
#  ('millafe01', 'Millan', 'Felix', 'P.R.', 'Yabucoa', '1943'),
#  ('millele01', 'Miller', 'Lemmie', 'USA', 'Dallas', '1960'),
#  ('milleor01', 'Miller', 'Orlando', 'Panama', 'Changuinola', '1969'),
# ...
#  ('murreiv01', 'Murrell', 'Ivan', 'Panama', 'Almirante', '1943'),
#  ('narvaom01', 'Narvaez', 'Omar', 'Venezuela', 'Maracay', '1992'),
#  ('navardi01', 'Navarro', 'Dioner', 'Venezuela', 'Caracas', '1984'),
#  ('navarja01', 'Navarro', 'Jaime', 'P.R.', 'Bayamon', '1967'),
#  ('navarju01', 'Navarro', 'Julio', 'P.R.', 'Vieques', '1936'),
#  ('navaros01', 'Navarro', 'Oswaldo', 'Venezuela', 'Villa de Cura', '1984'),
#  ('nelsoge01', 'Nelson', 'Gene', 'USA', 'Tampa', '1960'),
#  ('nesbian01', 'Nesbitt', 'Angel', 'Venezuela', 'Maracay', '1990'),
#  ('newmaal01', 'Newman', 'Al', 'USA', 'Kansas City', '1960'),
#  ('ngoepgi01', 'Ngoepe', 'Gift', 'South Africa', 'Pietersburg', '1990'),
#  ('nichoal01', 'Nichols', 'Al', 'United Kingdom', 'Worcester', '1852'),
#  ('nicolhu01', 'Nicol', 'Hugh', 'United Kingdom', 'Campsie', '1858'),
#  ('nietoto01', 'Nieto', 'Tom', 'USA', 'Downey', '1960'),
#  ('nievefe01', 'Nieve', 'Fernando', 'Venezuela', 'Puerto Cabello', '1982'),
#  ('nievejo01', 'Nieves', 'Jose', 'Venezuela', 'Guacara', '1975'),
#  ('nieveju01', 'Nieves', 'Juan', 'P.R.', 'Santurce', '1965'),
#  ('nieveme01', 'Nieves', 'Melvin', 'P.R.', 'San Juan', '1971'),
#  ('nifu01', 'Ni', 'Fu-Te', 'Taiwan', 'Pingtung County', '1982'),
#  ('nixondo01', 'Nixon', 'Donell', 'USA', 'Evergreen', '1961'),
#  ('nunezed01', 'Nunez', 'Ed', 'P.R.', 'Humacao', '1963'),
#  ('nunezre01', 'Nunez', 'Renato', 'Venezuela', 'Valencia', '1994'),
#  ('obriech01', "O'Brien", 'Charlie', 'USA', 'Tulsa', '1960'),
#  ('ochoaiv01', 'Ochoa', 'Ivan', 'Venezuela', 'Guacara', '1982'),
#  ('odorro01', 'Odor', 'Rougned', 'Venezuela', 'Maracaibo', '1994'),
#  ('oelkebr01', 'Oelkers', 'Bryan', 'Spain', 'Zaragoza', '1961'),
#  ('oglivbe01', 'Oglivie', 'Ben', 'Panama', 'Colon', '1949'),
#  ('ohse01', 'Oh', 'Seung-hwan', 'South Korea', 'Jeongeup', '1982'),
#  ('olivaed01', 'Olivares', 'Ed', 'P.R.', 'Mayaguez', '1938'),
#  ('olivaom01', 'Olivares', 'Omar', 'P.R.', 'Mayaguez', '1967'),
#  ('olivefr01', 'Oliveras', 'Francisco', 'P.R.', 'Santurce', '1963'),
#  ('olivele01', 'Oliveros', 'Lester', 'Venezuela', 'Maracay', '1988'),
#  ('olmedra01', 'Olmedo', 'Ray', 'Venezuela', 'Maracay', '1981'),
#  ('olmolu01', 'Olmo', 'Luis', 'P.R.', 'Arecibo', '1919'),
#  ('olsongr02', 'Olson', 'Greg', 'USA', 'Marshall', '1960'),
#  ('omallto01', "O'Malley", 'Tom', 'USA', 'Orange', '1960'),
#  ('onealra01', "O'Neal", 'Randy', 'USA', 'Ashland', '1960'),
#  ('ontivst02', 'Ontiveros', 'Steve', 'USA', 'Tularosa', '1961'),
#  ('oquenjo01', 'Oquendo', 'Jose', 'P.R.', 'Rio Piedras', '1963'),
#  ('ordazlu01', 'Ordaz', 'Luis', 'Venezuela', 'Maracaibo', '1975'),
#  ('ordonma01', 'Ordonez', 'Magglio', 'Venezuela', 'Caracas', '1974'),
#  ('ortegan01', 'Ortega', 'Anthony', 'Venezuela', 'Ocumare del Tuy', '1985'),
#  ('ortegjo01', 'Ortega', 'Jose', 'Venezuela', 'Caja Seca', '1988'),
#  ('ortegra01', 'Ortega', 'Rafael', 'Venezuela', 'El Tigre', '1991'),
#  ('ortizda02', 'Ortiz', 'Danny', 'P.R.', 'Caguas', '1990'),
#  ('ortizhe01', 'Ortiz', 'Hector', 'P.R.', 'Rio Piedras', '1969'),
#  ('ortizjo01', 'Ortiz', 'Jose', 'P.R.', 'Ponce', '1947'),
#  ('ortizjo05', 'Ortiz', 'Joe', 'Venezuela', 'Caracas', '1990'),
#  ('ortizju01', 'Ortiz', 'Junior', 'P.R.', 'Humacao', '1959'),
#  ('osunajo01', 'Osuna', 'Jose', 'Venezuela', 'Trujillo', '1992'),
#  ('ouellph01', 'Ouellette', 'Phil', 'USA', 'Salem', '1961'),
#  ('owensp01', 'Owen', 'Spike', 'USA', 'Cleburne', '1961'),
#  ('pacheal01', 'Pacheco', 'Alex', 'Venezuela', 'Caracas', '1973'),
#  ('pacioji01', 'Paciorek', 'Jim', 'USA', 'Detroit', '1960'),
#  ('paglimi01', 'Pagliarulo', 'Mike', 'USA', 'Medford', '1960'),
#  ('paintla01', 'Painter', 'Lance', 'United Kingdom', 'Bedford', '1967'),
#  ('pardoal01', 'Pardo', 'Al', 'Spain', 'Oviedo', '1962'),
#  ('pareded01', 'Paredes', 'Eduardo', 'Venezuela', 'Valera', '1995'),
#  ('paredjo01', 'Paredes', 'Johnny', 'Venezuela', 'Maracaibo', '1962'),
#  ('parenma01', 'Parent', 'Mark', 'USA', 'Ashland', '1961'),
#  ('parkby01', 'Park', 'Byung Ho', 'South Korea', 'Seoul', '1986'),
#  ('parkch01', 'Park', 'Chan Ho', 'South Korea', 'Gongju', '1973'),
#  ('parrage01', 'Parra', 'Gerardo', 'Venezuela', 'Santa Barbara', '1987'),
#  ('parreje01', 'Parrett', 'Jeff', 'USA', 'Indianapolis', '1961'),
#  ('pasquda01', 'Pasqua', 'Dan', 'USA', 'Yonkers', '1961'),
#  ('paynemi01', 'Payne', 'Mike', 'USA', 'Woonsocket', '1961'),
#  ('pecotbi01', 'Pecota', 'Bill', 'USA', 'Redwood City', '1960'),
#  ('pederst01', 'Pederson', 'Stu', 'USA', 'Palo Alto', '1960'),
#  ('pedrial01', 'Pedrique', 'Al', 'Venezuela', 'Valencia', '1960'),
#  ('pendlte01', 'Pendleton', 'Terry', 'USA', 'Los Angeles', '1960'),
#  ('peplohe01', 'Peploski', 'Henry', 'Poland', 'Garlin', '1905'),
#  ('peralda01', 'Peralta', 'David', 'Venezuela', 'Valencia', '1987'),
#  ('perazjo01', 'Peraza', 'Jose', 'Venezuela', 'Barinas', '1994'),
#  ('perazos01', 'Peraza', 'Oswaldo', 'Venezuela', 'Puerto Cabello', '1962'),
#  ('perezca02', 'Perez', 'Carlos', 'Venezuela', 'Valencia', '1990'),
#  ('perezed02', 'Perez', 'Eddie', 'Venezuela', 'Ciudad Ojeda', '1968'),
#  ('perezhe01', 'Perez', 'Hernan', 'Venezuela', 'Villa de Cura', '1991'),
#  ('perezma02', 'Perez', 'Martin', 'Venezuela', 'Guanare', '1991'),
#  ('perezmi02', 'Perez', 'Miguel', 'Venezuela', 'Caracas', '1983'),
#  ('perezro01', 'Perez', 'Robert', 'Venezuela', 'Ciudad Bolivar', '1969'),
#  ('perezsa02', 'Perez', 'Salvador', 'Venezuela', 'Valencia', '1990'),
#  ('perezto03', 'Perez', 'Tomas', 'Venezuela', 'Barquisimeto', '1973'),
#  ('perryge01', 'Perry', 'Gerald', 'USA', 'Savannah', '1960'),
#  ('petagro01', 'Petagine', 'Roberto', 'Venezuela', 'Porlamar', '1971'),
#  ('petitgr01', 'Petit', 'Gregorio', 'Venezuela', 'Ocumare del Tuy', '1984'),
#  ('pickeca01', 'Pickering', 'Calvin', 'V.I.', '', '1976'),
#  ('pinama01', 'Pina', 'Manny', 'Venezuela', 'Barquisimeto', '1987'),
#  ('pintojo01', 'Pinto', 'Josmil', 'Venezuela', 'Valencia', '1989'),
#  ('pintore01', 'Pinto', 'Renyel', 'Venezuela', 'Cupira', '1982'),
#  ('pintori01', 'Pinto', 'Ricardo', 'Venezuela', 'Guacara', '1994'),
#  ('pireljo01', 'Pirela', 'Jose', 'Venezuela', 'Valera', '1989'),
#  ('pittach01', 'Pittaro', 'Chris', 'USA', 'Trenton', '1961'),
#  ('plaskel01', 'Plaskett', 'Elmo', 'V.I.', 'Frederiksted', '1938'),
#  ('polidgu01', 'Polidor', 'Gus', 'Venezuela', 'Caracas', '1961'),
#  ('pradoma01', 'Prado', 'Martin', 'Venezuela', 'Maracay', '1983'),
#  ('preslji01', 'Presley', 'Jim', 'USA', 'Pensacola', '1961'),
#  ('prietal01', 'Prieto', 'Alex', 'Venezuela', 'Caracas', '1976'),
#  ('puckeki01', 'Puckett', 'Kirby', 'USA', 'Chicago', '1960'),
#  ('pulidca01', 'Pulido', 'Carlos', 'Venezuela', 'Caracas', '1971'),
#  ('pyznati01', 'Pyznarski', 'Tim', 'USA', 'Chicago', '1960'),
#  ('quereju01', 'Querecuto', 'Juniel', 'Venezuela', 'Barquisimeto', '1992'),
#  ('queveru01', 'Quevedo', 'Ruben', 'Venezuela', 'Valencia', '1979'),
#  ('quinnja01', 'Quinn', 'Jack', 'Slovakia', 'Stefurov', '1883'),
#  ('quintca01', 'Quintana', 'Carlos', 'Venezuela', 'Mamporal', '1965'),
#  ('quinthu01', 'Quintero', 'Humberto', 'Venezuela', 'Maracaibo', '1979'),
#  ('quirogu01', 'Quiroz', 'Guillermo', 'Venezuela', 'Maracaibo', '1981'),
#  ('rabbjo01', 'Rabb', 'John', 'USA', 'Los Angeles', '1960'),
#  ('ramiral02', 'Ramirez', 'Alex', 'Venezuela', 'Caracas', '1974'),
#  ('ramirma03', 'Ramirez', 'Max', 'Venezuela', 'Barquisimeto', '1984'),
#  ('ramirra03', 'Ramirez', 'Ramon', 'Venezuela', 'Cagua', '1982'),
#  ('ramosch01', 'Ramos', 'Chucho', 'Venezuela', 'Maturin', '1918'),
#  ('ramosed01', 'Ramos', 'Edgar', 'Venezuela', 'Cumana', '1975'),
#  ('ramosed02', 'Ramos', 'Edubray', 'Venezuela', 'Caracas', '1992'),
#  ('ramsemi02', 'Ramsey', 'Mike', 'USA', 'Thomson', '1960'),
#  ('randasa01', 'Randall', 'Sap', 'USA', 'Mobile', '1960'),
#  ('ransoje01', 'Ransom', 'Jeff', 'USA', 'Fresno', '1960'),
#  ('reachal01', 'Reach', 'Al', 'United Kingdom', 'London', '1840'),
#  ('readyra01', 'Ready', 'Randy', 'USA', 'San Mateo', '1960'),
#  ('redfijo01', 'Redfield', 'Joe', 'USA', 'Doylestown', '1961'),
#  ('reedch01', 'Reed', 'Chris', 'United Kingdom', 'London', '1990'),
#  ('refsnro01', 'Refsnyder', 'Rob', 'South Korea', 'Seoul', '1991'),
#  ('renteri01', 'Renteria', 'Rich', 'USA', 'Harbor City', '1961'),
#  ('reyesre01', 'Reyes', 'Rene', 'Venezuela', 'Margarita', '1978'),
#  ('reynoha01', 'Reynolds', 'Harold', 'USA', 'Eugene', '1960'),
#  ('rileser01', 'Riles', 'Ernie', 'USA', 'Cairo', '1960'),
#  ('rincoju01', 'Rincon', 'Juan', 'Venezuela', 'Maracaibo', '1979'),
#  ('riosda01', 'Rios', 'Danny', 'Spain', 'Madrid', '1972'),
#  ('ripkeca01', 'Ripken', 'Cal', 'USA', 'Havre de Grace', '1960'),
#  ('rittere01', 'Ritter', 'Reggie', 'USA', 'Malvern', '1960'),
#  ('rivaslu01', 'Rivas', 'Luis', 'Venezuela', 'La Guaira', '1979'),
#  ('riverca02', 'Rivero', 'Carlos', 'Venezuela', 'Barquisimeto', '1988'),
#  ('riverfe01', 'Rivero', 'Felipe', 'Venezuela', 'San Felipe', '1991'),
#  ('riverge01', 'Rivera', 'German', 'P.R.', 'Santurce', '1960'),
#  ('riverju01', 'Rivera', 'Juan', 'Venezuela', 'Guarenas', '1978'),
#  ('robinje01', 'Robinson', 'Jeff', 'USA', 'Santa Ana', '1960'),
#  ('robinje02', 'Robinson', 'Jeff', 'USA', 'Ventura', '1961'),
#  ('roblema01', 'Robles', 'Mauricio', 'Venezuela', 'Valencia', '1989'),
#  ('rodried02', 'Rodriguez', 'Edwin', 'P.R.', 'Ponce', '1960'),
#  ('rodried05', 'Rodriguez', 'Eduardo', 'Venezuela', 'Valencia', '1993'),
#  ('rodrifr03', 'Rodriguez', 'Francisco', 'Venezuela', 'Caracas', '1982'),
#  ('rodrigu01', 'Rodriguez', 'Guillermo', 'Venezuela', 'Barquisimeto', '1978'),
#  ('rodrigu02', 'Rodriguez', 'Guilder', 'Venezuela', 'Barquisimeto', '1983'),
#  ('rodrihe03', 'Rodriguez', 'Henry', 'Venezuela', 'Santa Barbara', '1987'),
#  ('rodrihe04', 'Rodriguez', 'Henry', 'Venezuela', 'Maracay', '1990'),
#  ('rodrili01', 'Rodriguez', 'Liu', 'Venezuela', 'Caracas', '1976'),
#  ('rodrilu01', 'Rodriguez', 'Luis', 'Venezuela', 'San Carlos', '1980'),
#  ('rodriri01', 'Rodriguez', 'Rick', 'USA', 'Oakland', '1960'),
#  ('rodriri04', 'Rodriguez', 'Ricardo', 'Venezuela', 'Maracay', '1992'),
#  ('rodriro01', 'Rodriguez', 'Roberto', 'Venezuela', 'Caracas', '1941'),
#  ('rodrivi01', 'Rodriguez', 'Vic', 'USA', 'New York', '1961'),
#  ('rohrle01', 'Rohr', 'Les', 'United Kingdom', 'Lowestoft', '1946'),
#  ('rojasmi02', 'Rojas', 'Miguel', 'Venezuela', 'Los Teques', '1989'),
#  ('romanro01', 'Romanick', 'Ron', 'USA', 'Burley', '1960'),
#  ('romeral01', 'Romero', 'Alex', 'Venezuela', 'Maracaibo', '1983'),
#  ('romerni01', 'Romero', 'Niuman', 'Venezuela', 'Barcelona', '1985'),
#  ('rominke01', 'Romine', 'Kevin', 'USA', 'Exeter', '1961'),
#  ('rondobr01', 'Rondon', 'Bruce', 'Venezuela', 'Valencia', '1990'),
#  ('rondohe01', 'Rondon', 'Hector', 'Venezuela', 'Guatire', '1988'),
#  ('rondojo01', 'Rondon', 'Jorge', 'Venezuela', 'Calabozo', '1988'),
#  ('rondojo02', 'Rondon', 'Jose', 'Venezuela', 'Villa de Cura', '1994'),
#  ('rowdowa01', 'Rowdon', 'Wade', 'USA', 'Riverhead', '1960'),
#  ('ruizjo01', 'Ruiz', 'Jose', 'Venezuela', 'Guacara', '1994'),
#  ('russeje01', 'Russell', 'Jeff', 'USA', 'Cincinnati', '1961'),
#  ('russejo02', 'Russell', 'John', 'USA', 'Oklahoma City', '1961'),
#  ('ryalma01', 'Ryal', 'Mark', 'USA', 'Henryetta', '1960'),
#  ('ryuhy01', 'Ryu', 'Hyun-Jin', 'South Korea', 'Incheon', '1987'),
#  ('ryuja01', 'Ryu', 'Jae Kuk', 'South Korea', 'Choon Chung Do', '1983'),
#  ('salasma01', 'Salas', 'Mark', 'USA', 'Montebello', '1961'),
#  ('salazan01', 'Salazar', 'Angel', 'Venezuela', 'Anaco', '1961'),
#  ('salazlu01', 'Salazar', 'Luis', 'Venezuela', 'Barcelona', '1956'),
#  ('salazos01', 'Salazar', 'Oscar', 'Venezuela', 'Maracay', '1978'),
#  ('samueju01', 'Samuel', 'Juan', 'D.R.', 'San Pedro de Macoris', '1960'),
#  ('samuero01', 'Samuels', 'Roger', 'USA', 'San Jose', '1961'),
#  ('sanchad01', 'Sanchez', 'Adrian', 'Venezuela', 'Maracaibo', '1990'),
#  ('sanchan01', 'Sanchez', 'Anibal', 'Venezuela', 'Maracay', '1984'),
#  ('sanchca01', 'Sanchez', 'Carlos', 'Venezuela', 'Maracay', '1992'),
#  ('sanched01', 'Sanchez', 'Eduardo', 'Venezuela', 'Maracay', '1989'),
#  ('sanchhe01', 'Sanchez', 'Hector', 'Venezuela', 'Maracay', '1989'),
#  ('sanchlu01', 'Sanchez', 'Luis', 'Venezuela', 'Cariaco', '1953'),
#  ('sanchro01', 'Sanchez', 'Romulo', 'Venezuela', 'Carora', '1984'),
#  ('sandoda01', 'Sandoval', 'Danny', 'Venezuela', 'Barquisimeto', '1979'),
#  ('sandopa01', 'Sandoval', 'Pablo', 'Venezuela', 'Puerto Cabello', '1986'),
#  ('santaan02', 'Santander', 'Anthony', 'Venezuela', 'Margarita', '1994'),
#  ('santajo01', 'Santana', 'Johan', 'Venezuela', 'Tovar', '1979'),
#  ('santone01', 'Santovenia', 'Nelson', 'Cuba', 'Pinar del Rio', '1961'),
#  ('sardilu01', 'Sardinas', 'Luis', 'Venezuela', 'Upata', '1993'),
#  ('sarmima01', 'Sarmiento', 'Manny', 'Venezuela', 'Cagua', '1956'),
#  ('saxst01', 'Sax', 'Steve', 'USA', 'Sacramento', '1960'),
#  ('schaeje01', 'Schaefer', 'Jeff', 'USA', 'Patchogue', '1960'),
#  ('schulje01', 'Schulz', 'Jeff', 'USA', 'Evansville', '1961'),
#  ('scottdo01', 'Scott', 'Donnie', 'USA', 'Dunedin', '1961'),
#  ('scranji01', 'Scranton', 'Jim', 'USA', 'Torrance', '1960'),
#  ('scutama01', 'Scutaro', 'Marco', 'Venezuela', 'San Felipe', '1975'),
#  ('sebrabo01', 'Sebra', 'Bob', 'USA', 'Ridgewood', '1961'),
#  ('seela01', 'See', 'Larry', 'USA', 'Norwalk', '1960'),
#  ('seilhri01', 'Seilheimer', 'Ricky', 'USA', 'Brenham', '1960'),
#  ('senzaan01', 'Senzatela', 'Antonio', 'Venezuela', 'Valencia', '1995'),
#  ('seoja01', 'Seo', 'Jae Weong', 'South Korea', 'Gwangju', '1977'),
#  ('serraal01', 'Serrano', 'Alex', 'Venezuela', 'Barcelona', '1981'),
#  ('sharpmi01', 'Sharperson', 'Mike', 'USA', 'Orangeburg', '1961'),
#  ('shawal01', 'Shaw', 'Al', 'United Kingdom', 'Burslem', '1873'),
#  ('sheafda01', 'Sheaffer', 'Danny', 'USA', 'Jacksonville', '1961'),
#  ('shephro01', 'Shepherd', 'Ron', 'USA', 'Longview', '1960'),
#  ('silvaca01', 'Silva', 'Carlos', 'Venezuela', 'Bolivar', '1979'),
#  ('sinatma01', 'Sinatro', 'Matt', 'USA', 'Hartford', '1960'),
#  ('skinnjo01', 'Skinner', 'Joel', 'USA', 'La Jolla', '1961'),
#  ('smithda04', 'Smith', 'Dar', 'USA', 'Baltimore', '1960'),
#  ('smithha03', 'Smith', 'Harry', 'United Kingdom', '', '1874'),
#  ('smithke03', 'Smith', 'Keith', 'USA', 'Los Angeles', '1961'),
#  ('smithkl01', 'Smith', 'Klondike', 'United Kingdom', 'London', '1887'),
#  ('smithmi04', 'Smith', 'Mike', 'USA', 'Jackson', '1961'),
#  ('smithro01', 'Smith', 'Roy', 'USA', 'Mount Vernon', '1961'),
#  ('smithza01', 'Smith', 'Zane', 'USA', 'Madison', '1960'),
#  ('socolmi01', 'Socolovich', 'Miguel', 'Venezuela', 'Caracas', '1986'),
#  ('sojolu01', 'Sojo', 'Luis', 'Venezuela', 'Caracas', '1965'),
#  ('solanju01', 'Solano', 'Julio', 'D.R.', 'Agua Blanca', '1960'),
#  ('sprinst01', 'Springer', 'Steve', 'USA', 'Long Beach', '1961'),
#  ('stanist01', 'Stanicek', 'Steve', 'USA', 'Lake Forest', '1961'),
#  ('staplda02', 'Stapleton', 'Dave', 'USA', 'Miami', '1961'),
#  ('stclara01', 'St. Claire', 'Randy', 'USA', 'Glens Falls', '1960'),
#  ('steelji01', 'Steels', 'Jim', 'USA', 'Jackson', '1961'),
#  ('stephph01', 'Stephenson', 'Phil', 'USA', 'Guthrie', '1960'),
#  ('stockph01', 'Stockman', 'Phil', 'United Kingdom', 'Oldham', '1980'),
#  ('stoneje01', 'Stone', 'Jeff', 'USA', 'Kennett', '1960'),
#  ('strakle01', 'Straker', 'Les', 'Venezuela', 'Ciudad Bolivar', '1959'),
#  ('stubbfr01', 'Stubbs', 'Franklin', 'USA', 'Laurinburg', '1960'),
#  ('suareal01', 'Suarez', 'Albert', 'Venezuela', 'San Felix', '1989'),
#  ('suareeu01', 'Suarez', 'Eugenio', 'Venezuela', 'Puerto Ordaz', '1991'),
#  ('sucreje01', 'Sucre', 'Jesus', 'Venezuela', 'Cumana', '1988'),
#  ('swiftbi02', 'Swift', 'Bill', 'USA', 'Portland', '1961'),
#  ('tabatjo01', 'Tabata', 'Jose', 'Venezuela', 'El Tigre', '1988'),
#  ('taborgr01', 'Tabor', 'Greg', 'USA', 'Castro Valley', '1961'),
#  ('tannebr01', 'Tanner', 'Bruce', 'USA', 'New Castle', '1961'),
#  ('taylobi04', 'Taylor', 'Billy', 'USA', 'Monticello', '1961'),
#  ('taylodw01', 'Taylor', 'Dwight', 'USA', 'Los Angeles', '1960'),
#  ('telisto01', 'Telis', 'Tomas', 'Venezuela', 'El Tigre', '1991'),
#  ('tettlmi01', 'Tettleton', 'Mickey', 'USA', 'Oklahoma City', '1960'),
#  ('tewksbo01', 'Tewksbury', 'Bob', 'USA', 'Concord', '1960'),
#  ('thakeal01', 'Thake', 'Al', 'United Kingdom', 'Wymondham', '1849'),
#  ('thomsbo01', 'Thomson', 'Bobby', 'United Kingdom', 'Glasgow', '1923'),
#  ('tillmru01', 'Tillman', 'Rusty', 'USA', 'Jacksonville', '1960'),
#  ...]

# %% [markdown]
# - WHERE clause is similar to ```if (...)``` statement conditions with a different syntax and some different capabilities.
#
#
# - My going through the details will be boring. You can just look up answers, practice and we will learn by doing in various homeworks and questions.

# %% [markdown]
# ## A Note on Connections

# %% [markdown]
# - You may have noticed to segments of code in my examples:
#
#     ```%sql mysql+pymysql://dbuser:dbuser@localhost/lahman2017```
#
#
# - or
#
#
# ```
#     # Connect to the database over the network. Use the connection
#     # to send commands to the DB.
#     cnx = pymysql.connect(host='localhost',
#                              user='dbuser',
#                              password='dbuser',
#                              db='lahman2017',
#                              charset='utf8mb4',
#                              cursorclass=pymysql.cursors.DictCursor)
# ```

# %% [markdown]
# | <img src="../images/db-connection.jpg" width="900px;" >|
# | :---: |
# | __DB Connections__ |

# %% [markdown]
# "In computer science, a database connection is the means by which a database server and its client software communicate with each other. The term is used whether or not the client and the server are on different machines." (https://en.wikipedia.org/wiki/Database_connection)
#
#
# - Database systems and products provide client libraries and [software development kits](https://en.wikipedia.org/wiki/Software_development_kit) that simplify using the database APIs. Database SDKs are also called connectors.
#
#
# - [PyMySQL](https://github.com/PyMySQL/PyMySQL) is a Python connector/SDK for MySQL.
#
# ```
# cnx = pymysql.connect(host='localhost',
#                             port='3306',
#                              user='dbuser',
#                              password='dbuser',
#                              db='lahman2017',
#                              charset='utf8mb4',
#                              cursorclass=pymysql.cursors.DictCursor)
# ```
#
# In this simple example, the connection information is:
# - Host (Internet location of the database server) is "the local computer."
#
#
# - The port ```https://en.wikipedia.org/wiki/Port_(computer_networking)``` identifies a specific application's network endpoint on a host.
#
#
# - User and password to associate with requests on this connection (authentication, authorization)
#
#
# - There are many other "command and control" properties associated with a connection.
#
#
# - Most of our work and examples will use ```localhost.```
#     - This is common during initial solution development.
#     - But is not the general model for more advanced tested or deployment.
#
#
# - I will provide a "cloud" accessible version of MySQL for you to play with sometime during the semester.

# %% [markdown]
# - On your localhost, there are at least two programs executing:
#     - MySQL Workbench
#     - mysqld: The MySQL server.

# %% [markdown]
# | <img src="../images/db_processes.jpg"> |
# | :---: |
# | __DB Processes__ |
