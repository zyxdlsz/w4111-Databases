# %% [markdown]
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
#
# # Introduction to Databases: Decision Support, Final Exam Preparation

# %% [markdown]
# ## Some Helper Code

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# - Test helper code.

# %%
# %sql mysql+pymysql://dbuser:dbuser@localhost/classiccars

# %sql select * from customers where customerNumber=103
# Out:
# 1 rows affected.
# [(103, 'Atelier graphique', 'Schmitt', 'Carine ', '40.32.2555', '54, rue Royale', None, 'Nantes', None, '44000', 'France', 1370, Decimal('21000.00'))]

# %% [markdown]
# ## Lecture Objectives
#
# ### Topics
#
# We will cover
# - A quick overview of decision support/data analysis
# - Preparation for th final exam.
#
# ### Decision Support
#
# #### Course Overview Reminder
#
# - Module I: Foundational Concepts
#     - Introduction to databases, role in applications, type of DB applications and overall system software architecture.
#     - Information and data modeling and best practices, focusing on supporting application scenarios.
#     - Relational data model (theory), Relational Database Management Systems, Structured Query Language, data query and update scenarios.
#     - Extended topics in SQL and RDBMS (performance, security, constraints, triggers, connection management, etc).
#
#
# - Module II: Database Management System Implementation/Architecture
#     - Storage management, disk management, buffer management, indexes.
#     - Query processing and optimization:  Query evaluation, query parsing and parse trees, operator implementation algorithms, query rewrite, query optimization techniques.
#     - Concurrency control and transaction management.
#
#
# - Module III: NoSQL Database Overview
#     - Overview, graph databases, Redis.
#     - Amazon S3, Amazon DynamoDB, Google Firebase/Cloud Firestore.
#
#
# - Module IV: Decision Support, Data Analysis
#     - Overview of schema denormalization, OLAP cubes, data analytics, machine learning.
#
#
# #### Data Driven Decision Support
#
# - There is one major area of databases and database systems we have not covered. Various terms are:
#     - Data driven decision support.
#     - Business intelligence.
#     - Data warehouse.
#     - Big data.
#
#
# - There are several (too many) ways to classify applications and scenarios that use databases. Some examples
#     - One classification approach
#         - <span style="color: red;">_Batch processing systems,_ where you submit a a bunch of files, a "job" containing multiple subprograms, and later receive output in the form of a file.</span>
#         - <span style="color: green;"> _Real-time (online) systems,_ where you submit requests to do a small amount of work that has to be done before some very early deadline, or interactively why the user waits.</span>
#         - <span style="color: red;">_Data warehouse systems,_ where reporting programs and ad hoc queries access data that is integrated from multiple data sources.</span>
#     - Annother classification approach: A data processing system may involve some combination of
#         - Conversion converting data to another format.
#         - Validation – Ensuring that supplied data is "clean, correct and useful."
#         - Sorting – "arranging items in some sequence and/or in different sets."
#         - Summarization – reducing detail data to its main points.
#         - Aggregation – combining multiple pieces of data.
#         - <span style="color: red;">Analysis – the "collection, organization, analysis, interpretation and presentation of data."</span>
#         - <span style="color: red;">Reporting – list detail or summary data or computed information.</span>
#     - A third classification approach
#         - Operational Database
#         - External Database
#         - End User Database
#         - Distributed Database
#         - <span style="color: red;">Data Warehouse Database</span>
#         - <span style="color: red;">Analytical Database</span>
#         - Hypermedia Database
#
#
# - Unfortunately, we will spend less time on the <span style="color: red;">topics</span> than I had hoped.<br> But the foundation concepts we covered are necessary and crucial.
#
#
# - We spend the 1st half of the lecture on the topic.

# %% [markdown]
# ### Final Exam Preparation
#
# - There will be 20 questions:
#     - 10 "simple" programming questions, which are two points each.
#     - 10 questions with written answers.
#
#
# - There will be one extra-credit question worth 1 point if you get it correct, and -50 if you get it wrong.
#     - "Who is the greatest hockey player of all time?"
#     - Here is a hint.
#
#
# | <img src="../images/legends.jpeg"> |
# | :---: |
# | __Greatest Players__ |
#
# - I will go through the questions today and hold several recitations.

# %% [markdown]
# ## Data Driven Decision Support $-$ Concepts
#
# ### Batch Processing
#
# - Big data/Batch processing:
#     - These applications are usually in the back-end and not directly seen by users.
#     - The applications process and produce information used by other applications.
#     - Examples: recommendation engines for commerce web sites, Google Analytics.
#
# | <img src="../images/batch_1.jpeg"> |
# | :---: |
# | [Batch Processing](https://www.datasciencecentral.com/profiles/blogs/batch-vs-real-time-data-processing) |
#
# - Each stage in batch processing is multiple, smaller jobs/applications that have to run in specific orders.
#
#
# <hr>
# - [MapReduce](https://en.wikipedia.org/wiki/MapReduce) and [Hadoop](https://en.wikipedia.org/wiki/Apache_Hadoop) are modern approaches to batch processing.
#
#
# | <img src="../images/map_reduce_1.jpeg"> |
# | :---: |
# | __Map-Reduce__ |
#
# <hr>
#
# | <img src="../images/hadoop.jpeg"> |
# | :---: |
# | [Hadoop Ecosystem](https://www.quora.com/What-is-MapReduce-and-HDFS-in-Hadoop-ecosystem) |
#
# <br>
# - Setting up the multi-system HW and software is complex, and difficult to cover in an introduction course.

# %% [markdown]
# ### Simple Business Intelligence, Data Visualization and Decision Support
#
# - The core elements of the RDB approach are very good for interactive applications, ad hoc queries and ensuring "data integrity." "Data integrity is the maintenance of, and the assurance of the accuracy and consistency of, ... and is a critical aspect to the design, implementation and usage of any system which stores, processes, or retrieves data." (https://en.wikipedia.org/wiki/Data_integrity)
#
#
# - We have see how data modeling, schema definition, constraints, etc. enable "data integrity."
#
#
# - The core of BI, visualization, decision support is a __Data Warehouse Database:__
#     - Operational databases create-retrieve-update-delete data during on-line processing.
#     - Data Warehouse is a transformed copy of the data for more complex, read only queries and reports.
#
#
# | <img src="../images/data_warehouse_architecture.jpg"> |
# | :---: |
# | __Data Warehouse__ |
#
#
# - The data models and data design for analysis and decision support are __much, much different.__ Examples,
#     - Denormalization
#     - Star Schema
#     - OLAP Cube
#     - Pivot Table
#     - ...
#
#
# - __Why?__
#     - The queries are _read only._ Integrity is not an issue.
#     - The types of queries and how they access the data is very different.
#
#
# - The purpose is to pull together information to enable optimization and intelligent decisions.
#
#
# | <img src="../images/aws-quicksight.jpeg"> |
# | :---: |
# | [AWS Quicksight Charting and Analysis](https://aws.amazon.com/quicksight/) |
# <br><br>
#
# | <img src="../images/google_analytics.jpeg"> |
# | :---: |
# | Google Analytics |
#
# <br><br>

# %% [markdown]
# ## Schema
#
# ### Overview
#
# | <img src="../images/denormalization-1.jpg"> |
# | :---: |
# | __Denormalization__ |
#
#
# | <img src="../images/denormalization-2.jpg"> |
# | :---: |
# | __Denormalization__ |
#
#
# - If the data is read only, we do not have to worry about redundancy. There are no "updates."
#
#
# - We want to copy and "preprocess" that data to eliminate slow, complex queries during analysis.

# %% [markdown]
# ### Example Database (also on final exam)
#
# From [MySQL Tutorials](http://www.mysqltutorial.org/mysql-sample-database.aspx). The MySQL sample database schema consists of the following tables:
#
# - Customers: stores customer’s data.
# - Products: stores a list of scale model cars.
# - ProductLines: stores a list of product line categories.
# - Orders: stores sales orders placed by customers.
# - OrderDetails: stores sales order line items for each sales order.
# - Payments: stores payments made by customers based on their accounts.
# - Employees: stores all employee information as well as the organization structure such as who reports to whom.
# - Offices: stores sales office data.
#
# | <img src="../images/MySQL-Sample-Database-Schema.png" >
# | :---: |
# | __Classic Cars Database__ |
#
# - I have uploaded the simplified schema and data: https://courseworks2.columbia.edu/files/3855928/download?download_frd=1

# %% [markdown]
# ### Decision Support Schema
#
# #### Overview
#
# - The obvious business intelligence questions will be about products and sales.
#     - What products are "hot" and selling recently?
#     - How are sales trending in cities, states, countries and regions?
#     - Are there any trends in sales for various product categories?
#     - What is the on-going ratio of sales to inventory?
#
#
# #### Facts
#
# - The core data is in a __fact table.__
# <br><br>
# "Fact tables record measurements or metrics for a specific event. ... ... Fact tables are designed to a low level of uniform detail (referred to as "granularity" or "grain"), meaning facts can record events at a very atomic level. This can result in the accumulation of a large number of records in a fact table over time." (https://en.wikipedia.org/wiki/Star_schema)
#
#
# <img src="../images/classic-cars-facts.jpeg"> |
#
# - This "table"
#     - Includes information from 3 base tables.
#     - Data computed from columns in two tables.
#
#
# - There are two ways to produce this table:
#     - View
#     - Copy table

# %%
import pymysql
import time
import json

default_db_params = {
    "dbhost": "localhost",                    # Changeable defaults in constructor
    "port": 3306,
    "dbname": "classiccars",
    "dbuser": "dbuser",
    "dbpw": "dbuser",
    "cursorClass": pymysql.cursors.DictCursor,        # Default setting for DB connections
    "charset":  'utf8mb4'                             # Do not change
}

def get_new_connection(params=default_db_params):
    cnx = pymysql.connect(
        host=params["dbhost"],
        port=params["port"],
        user=params["dbuser"],
        password=params["dbpw"],
        db=params["dbname"],
        charset=params["charset"],
        cursorclass=params["cursorClass"])
    return cnx

cnx = get_new_connection()

# %%
def run_q(cnx, q, args, fetch=False, commit=True):
    """
    :param cnx: The database connection to use.
    :param q: The query string to run.
    :param args: Parameters to insert into query template if q is a template.
    :param fetch: True if this query produces a result and the function should perform and return fetchall()
    :return:
    """
    result = None

    try:
        cursor = cnx.cursor()
        result = cursor.execute(q, args)
        if fetch:
            result = cursor.fetchall()
        if commit:
            cnx.commit()
    except Exception as e:
        #print("dffutils.run_q got exception = ", original_e)
        raise(e)

    return result

# %%
def test_performance(q, args, count, debug):
    print("Starting test view performance.")
    start_time = time.time()
    for i in range(0,count):
        result = run_q(cnx, q, args, fetch=True, commit=True)
        if i == 0 and debug:
            print("Result = \n", json.dumps(result,indent=2, default=str))
    end_time = time.time()
    elapsed_time = end_time-start_time
    print("Elapsed time = ", elapsed_time)
    return elapsed_time

# %%
print("Starting performance test for views.")
q = "SELECT customerNumber, count(*), sum(quantityOrder*priceEach) as revenue from  classiccars.class_cars_facts_view \
	group by customerNumber order by customerNumber;"
ev = test_performance(q, None, 10, False)

print("\nStarting performance test for views.")
q = "SELECT customerNumber, count(*), sum(quantityOrder*priceEach) as revenue from  classiccars.class_cars_facts_copy \
	group by customerNumber order by customerNumber;"
ec = test_performance(q, None, 10, False)

print("\n\nView to copy ration is: ", ev/ec)
# Out:
# Starting performance test for views.
# Starting test view performance.
# Elapsed time =  6.567543983459473
#
# Starting performance test for views.
# Starting test view performance.
# Elapsed time =  0.05919790267944336
#
#
# View to copy ration is:  110.9421733912217

# %% [markdown]
# - The tables and query are simple, but using a copy table is 140x faster than using a view.<br>The DBA can also create new indexes on the copy table to optimize the query patterns.
#
#
# - The nice thing about a view is that the data is always accurate when there are new orders or order changes, but ...
#
#
# - Missing an order every now and then is not a problem when analyzing thousands or millions of orders.

# %% [markdown]
# #### Star Schema and Dimensions
#
# - A _fact_ occurs somewhere in each of multiple dimensions, e.g.
#     - Time
#     - Location
#     - Product hierarchies.
#
#
# - Many queries are about facts within values for dimensions, e.g.
#     - "What are sales in European contries for the past three months?"
#     - "What are sales for SW, books and toys per year for the past three years?"
#
#
# - Answer these questions requires position each fact in a _dimension (table)._ Fact tables combined with dimension tables produces a __star schema.__
#
# | <img src="../images/Star-schema-example.png" >
# | :---: |
# | [Star Schema Example](https://en.wikipedia.org/wiki/Star_schema) |

# %% [markdown]
# | <img src="../images/star-schema-2.jpeg" > |
# | :---: |
# | __Fact Table and Dimensions__ |

# %% [markdown]
# | <img src="../images/product-dimensions.jpeg" > |
# | :---: |
# | Product Dimensions |

# %% [markdown]
# - In Classic Cars, the product classification dimension is relatively simple. So, we will focus only on "location" and "time." To be more precise:
#     - $class\_cars\_facts\_copy.orderData$ can be the foreign key into the date dimension.
#     - "Where" is a little more complicated, and we have to extract from the customers.
#
# <u>Date Dimension</U>

# %%
# %sql select * from date_dimension limit 10;
# Out:
# 10 rows affected.
# [(datetime.date(2003, 1, 6), 2003, 1, 1, 2, 6),
#  (datetime.date(2003, 1, 9), 2003, 1, 1, 5, 9),
#  (datetime.date(2003, 1, 10), 2003, 1, 1, 6, 10),
#  (datetime.date(2003, 1, 29), 2003, 1, 1, 4, 29),
#  (datetime.date(2003, 1, 31), 2003, 1, 1, 6, 31),
#  (datetime.date(2003, 2, 11), 2003, 1, 2, 3, 11),
#  (datetime.date(2003, 2, 17), 2003, 1, 2, 2, 17),
#  (datetime.date(2003, 2, 24), 2003, 1, 2, 2, 24),
#  (datetime.date(2003, 3, 3), 2003, 1, 3, 2, 3),
#  (datetime.date(2003, 3, 10), 2003, 1, 3, 2, 10)]

# %% [markdown]
# <u>Location/Geography</u>
#
# - We can get some insight into location/geography dimension from looking at the addresses and offices.

# %%
import pandas as pd
customers=pd.read_sql("select * from customers", cnx)
customers.head(20)
# Out:
#     customerNumber                  customerName  contactLastName  \
# 0              103             Atelier graphique          Schmitt
# 1              112            Signal Gift Stores             King
# 2              114    Australian Collectors, Co.         Ferguson
# 3              119             La Rochelle Gifts          Labrune
# 4              121            Baane Mini Imports       Bergulfsen
# 5              124  Mini Gifts Distributors Ltd.           Nelson
# 6              125            Havel & Zbyszek Co  Piestrzeniewicz
# 7              128          Blauer See Auto, Co.           Keitel
# 8              129               Mini Wheels Co.           Murphy
# 9              131             Land of Toys Inc.              Lee
# 10             141        Euro+ Shopping Channel           Freyre
# 11             144      Volvo Model Replicas, Co         Berglund
# 12             145      Danish Wholesale Imports         Petersen
# 13             146        Saveley & Henriot, Co.          Saveley
# 14             148       Dragon Souveniers, Ltd.        Natividad
# 15             151            Muscle Machine Inc            Young
# 16             157         Diecast Classics Inc.            Leong
# 17             161          Technics Stores Inc.        Hashimoto
# 18             166              Handji Gifts& Co        Victorino
# 19             167                  Herkku Gifts           Oeztan
#
#    contactFirstName              phone                  addressLine1  \
# 0           Carine          40.32.2555                54, rue Royale
# 1              Jean         7025551838               8489 Strong St.
# 2             Peter       03 9520 4555             636 St Kilda Road
# 3           Janine          40.67.8555  67, rue des Cinquante Otages
# 4            Jonas          07-98 9555        Erling Skakkes gate 78
# 5             Susan         4155551450               5677 Strong St.
# 6          Zbyszek       (26) 642-7555               ul. Filtrowa 68
# 7            Roland  +49 69 66 90 2555                 Lyonerstr. 34
# 8             Julie         6505555787     5557 North Pendale Street
# 9              Kwai         2125557818       897 Long Airport Avenue
# 10           Diego      (91) 555 94 44            C/ Moralzarzal, 86
# 11       Christina        0921-12 3555               Berguvsvägen  8
# 12           Jytte          31 12 3555                  Vinbæltet 34
# 13            Mary          78.32.5555            2, rue du Commerce
# 14             Eric       +65 221 7555                    Bronz Sok.
# 15             Jeff         2125557413             4092 Furth Circle
# 16           Kelvin         2155551555              7586 Pompton St.
# 17             Juri         6505556809             9408 Furth Circle
# 18            Wendy       +65 224 1555       106 Linden Road Sandown
# 19           Veysel      +47 2267 3215               Brehmen St. 121
#
#                 addressLine2           city     state postalCode    country  \
# 0                       None         Nantes      None      44000     France
# 1                       None      Las Vegas        NV      83030        USA
# 2                    Level 3      Melbourne  Victoria       3004  Australia
# 3                       None         Nantes      None      44000     France
# 4                       None        Stavern      None       4110     Norway
# 5                       None     San Rafael        CA      97562        USA
# 6                       None       Warszawa      None     01-012     Poland
# 7                       None      Frankfurt      None      60528    Germany
# 8                       None  San Francisco        CA      94217        USA
# 9                       None            NYC        NY      10022        USA
# 10                      None         Madrid      None      28034      Spain
# 11                      None          Luleå      None   S-958 22     Sweden
# 12                      None      Kobenhavn      None       1734    Denmark
# 13                      None           Lyon      None      69004     France
# 14  Bronz Apt. 3/6 Tesvikiye      Singapore      None     079903  Singapore
# 15                 Suite 400            NYC        NY      10022        USA
# 16                      None      Allentown        PA      70267        USA
# 17                      None     Burlingame        CA      94217        USA
# 18                 2nd Floor      Singapore      None     069045  Singapore
# 19            PR 334 Sentrum         Bergen      None     N 5804   Norway
#
#     salesRepEmployeeNumber  creditLimit
# 0                   1370.0      21000.0
# 1                   1166.0      71800.0
# 2                   1611.0     117300.0
# 3                   1370.0     118200.0
# 4                   1504.0      81700.0
# 5                   1165.0     210500.0
# 6                      NaN          0.0
# 7                   1504.0      59700.0
# 8                   1165.0      64600.0
# 9                   1323.0     114900.0
# 10                  1370.0     227600.0
# 11                  1504.0      53100.0
# 12                  1401.0      83400.0
# 13                  1337.0     123900.0
# 14                  1621.0     103800.0
# 15                  1286.0     138500.0
# 16                  1216.0     100600.0
# 17                  1165.0      84600.0
# 18                  1612.0      97900.0
# 19                  1504.0      96800.0

# %%
offices=pd.read_sql("select * from offices", cnx)
offices.head(10)
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          1  San Francisco   +1 650 219 4782         100 Market Street
# 1          2         Boston   +1 215 837 0825          1550 Court Place
# 2          3            NYC   +1 212 555 3000      523 East 53rd Street
# 3          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 4          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 5          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 6          7         London  +44 20 7877 2041       25 Old Broad Street
#
#   addressLine2       state    country postalCode territory
# 0    Suite 300          CA        USA      94080        NA
# 1    Suite 102          MA        USA      02107        NA
# 2      apt. 5A          NY        USA      10022        NA
# 3         None        None     France      75017      EMEA
# 4         None  Chiyoda-Ku      Japan   102-8578     Japan
# 5     Floor #2        None  Australia   NSW 2010      APAC
# 6      Level 7        None         UK   EC2N 1HN      EMEA

# %% [markdown]
# - __Note:__ In this table,
#     - NA is "North America," not "not applicable.
#     - EMEA is "Europe, Middle East, Africa."
#     - APAC is "Asia Pacific."
#
# <u>Georgraphy/Location Dimension</u>

# %%
# %sql select * from geo_dimension_copy limit 10
# Out:
# 10 rows affected.
# [(25899012146069762, 'South San Francisco', 'CA', '94080', 'USA', 'NA', 'US'),
#  (25899012146069763, 'Boston', 'MA', '02107', 'USA', 'NA', 'US'),
#  (25899012146069764, 'New York', 'NY', '10022', 'USA', 'NA', 'US'),
#  (25899012146069765, 'Paris', 'Paris', '75017', 'France', 'EMEA', 'FR'),
#  (25899012146069766, 'Tokyo', 'Chiyoda-Ku', '102-8578', 'Japan', 'Japan', 'JP'),
#  (25899012146069767, 'Sydney', 'New South Wales', 'NSW 2010', 'Australia', 'APAC', 'AU'),
#  (25899012146069768, 'London', 'London', 'EC2N 1HN', 'UK', 'EMEA', 'UK'),
#  (25899012146069769, 'Nantes', 'Loire-Atlantique', '44000', 'France', 'EMEA', 'FR'),
#  (25899012146069770, 'Las Vegas', 'NV', '83030', 'USA', 'NA', 'US'),
#  (25899012146069771, 'Melbourne', 'Victoria', '3004', 'Australia', 'APAC', 'AU')]

# %% [markdown]
# - In a real system, we would have some more cleanup to do. This is a simple, contrived example for ETL and MapReduce.
#     - Set _territory_ based on country. <br>(__I did make this cleanup but it would also have to go into base tables and normalization of the schema__).
#     - Fill in missing city names from postal codes.
#     - etc.
#
#
# - A simple, contrived ETL flow might look the figure below.
#
#
# | <img src="../images/etl-example.jpeg"> |
# | :---: |
# | __Simplistic ETL Example__ |
#
# - There are databases and online APIs for a lot of data cleanup.
#
# | <img src="../images/geo_map_service.jpeg"> |
# | :---: |
# | __Simplistic ETL Example__ |

# %%
import os
from smartystreets_python_sdk import StaticCredentials, exceptions, ClientBuilder
from smartystreets_python_sdk.us_street import Lookup


def zipcode_to_city(zip):
    auth_id = "832b407d-f10b-3440-7a01-79a6acce008c"
    auth_token = "633aYTyBsRPmWiyDvc0p"

    # We recommend storing your secret keys in environment variables instead---it's safer!
    # auth_id = os.environ['SMARTY_AUTH_ID']
    # auth_token = os.environ['SMARTY_AUTH_TOKEN']

    credentials = StaticCredentials(auth_id, auth_token)

    client = ClientBuilder(credentials).build_us_zipcode_api_client()

    lookup = Lookup()
    lookup.zipcode=zip

    try:
        client.send_lookup(lookup)
    except exceptions.SmartyException as err:
        print(err)
        return

    result = lookup.result
    zipcodes = result.zipcodes
    cities = result.cities
    
    print(result.cities)

    for city in cities:
        print("\nCity: " + city.city)
        print("State: " + city.state)
        print("Mailable City: {}".format(city.mailable_city))

    for zipcode in zipcodes:
        print("\nZIP Code: " + zipcode.zipcode)
        print("Latitude: {}".format(zipcode.latitude))
        print("Longitude: {}".format(zipcode.longitude))

# %%
x = zipcode_to_city("10021")
x
# Out:
# [<smartystreets_python_sdk.us_zipcode.city.City object at 0x1a13ccb978>, <smartystreets_python_sdk.us_zipcode.city.City object at 0x1a13ccbcc0>, <smartystreets_python_sdk.us_zipcode.city.City object at 0x1a13ccb908>, <smartystreets_python_sdk.us_zipcode.city.City object at 0x1a13ccb198>, <smartystreets_python_sdk.us_zipcode.city.City object at 0x1a13ccb860>, <smartystreets_python_sdk.us_zipcode.city.City object at 0x1a13ccbeb8>]
#
# City: New York
# State: New York
# Mailable City: True
#
# City: Manhattan
# State: New York
# Mailable City: False
#
# City: New York City
# State: New York
# Mailable City: False
#
# City: Ny
# State: New York
# Mailable City: False
#
# City: NY City
# State: New York
# Mailable City: False
#
# City: Nyc
# State: New York
# Mailable City: False
#
# ZIP Code: 10021
# Latitude: 40.76364
# Longitude: -73.96183

# %% [markdown]
# - We should also cleanup _customers_ and _offices_ and anything with addresses in them. People are really, really base at correctly entering address information.
#
# | <img src="../images/address-er.jpeg"> |
# | :---: |
# | __Simplistic Address ER Model__ |

# %% [markdown]
# #### More Fun Cleaning Up Addresses
#
# - OK. I cleanup up the geography/location dimension.

# %%
# %sql select * from geo_dimension_copy limit 20
# Out:
# 20 rows affected.
# [(25899012146069762, 'South San Francisco', 'CA', '94080', 'USA', 'NA', 'US'),
#  (25899012146069763, 'Boston', 'MA', '02107', 'USA', 'NA', 'US'),
#  (25899012146069764, 'New York', 'NY', '10022', 'USA', 'NA', 'US'),
#  (25899012146069765, 'Paris', 'Paris', '75017', 'France', 'EMEA', 'FR'),
#  (25899012146069766, 'Tokyo', 'Chiyoda-Ku', '102-8578', 'Japan', 'Japan', 'JP'),
#  (25899012146069767, 'Sydney', 'New South Wales', 'NSW 2010', 'Australia', 'APAC', 'AU'),
#  (25899012146069768, 'London', 'London', 'EC2N 1HN', 'UK', 'EMEA', 'UK'),
#  (25899012146069769, 'Nantes', 'Loire-Atlantique', '44000', 'France', 'EMEA', 'FR'),
#  (25899012146069770, 'Las Vegas', 'NV', '83030', 'USA', 'NA', 'US'),
#  (25899012146069771, 'Melbourne', 'Victoria', '3004', 'Australia', 'APAC', 'AU'),
#  (25899012146069772, 'Nantes', 'Loire-Atlantique', '44000', 'France', 'EMEA', 'FR'),
#  (25899012146069773, 'Stavern', 'Forsand', '4110', 'Norway', 'EMEA', 'NO'),
#  (25899012146069774, 'San Rafael', 'CA', '97562', 'USA', 'NA', 'US'),
#  (25899012146069775, 'Warszawa', 'Warszawa', '01-012', 'Poland', 'EMEA', 'PL'),
#  (25899012146069776, 'Frankfurt', 'Regierungsbezirk Darmstadt', '60528', 'Germany', 'EMEA', 'DE'),
#  (25899012146069777, 'San Francisco', 'CA', '94217', 'USA', 'NA', 'US'),
#  (25899012146069778, 'NYC', 'NY', '10022', 'USA', 'NA', 'US'),
#  (25899012146069779, 'Madrid', 'Madrid', '28034', 'Spain', 'EMEA', 'ES'),
#  (25899012146069780, 'Luleå', None, 'S-958 22', 'Sweden', 'EMEA', 'SE'),
#  (25899012146069781, 'Kobenhavn', 'Københavns Kommune', '1734', 'Denmark', 'EMEA', 'DK')]

# %% [markdown]
# What did I do?
#
# - Country codes:
#     1. Downloaded a CSV file that mapped country names to the two-letter [ISO codes.](https://en.wikipedia.org/wiki/List_of_ISO_3166_country_codes)
#     1. Loaded the CSV file into a table.
#     1. Added the country code column to the dimension table.
#     1. Wrote a query that set the country code by looking the country name in the country name to code table.
#     1. Manually fixed a few where there was not a match.
#
#
# - Territory:
#     1. Searched on the web to find lists of country codes for continents.
#     2. Wrote a lot of statements of the form:<br><br>
#     ```update geo_dimension_copy set territory='EMEA' where code in
#         ('AL', 'AD', 'AM', 'AT', 'BY', 'BE', 'BA', 'BG', 'CH', 'CY', 'CZ', 'DE',
#         'DK', 'EE', 'ES', 'FO', 'FI', 'FR', 'GB', 'GE', 'GI', 'GR', 'HU', 'HR',
#         'IE', 'IS', 'IT', 'LT', 'LU', 'LV', 'MC', 'MK', 'MT', 'NO', 'NL', 'PL',
#         'PT', 'RO', 'RU', 'SE', 'SI', 'SK', 'SM', 'TR', 'UA', 'VA')
#     ```
#
#
# - Called some cloud web APIs
#     - Googled the web (BTW, this is why I keep harping on this skill).
#     - Decided to download some free data from [GeoNames](http://www.geonames.org/).
#     - Entire database file was 340MB. Downloaded but decided not to download into MySQL.
#     - Paid 40 euros and got an account with GeoNames to make API calls.
#     - That fixed most of the information, but not all.
#     - Decided I had enough fun and needed to go back to defining your final exam.
#
#
# | <img src="../images/postal_code_lookup.jpeg"> |
# | :---: |
# | __Web Service Post Code Look Up__ |
#
# ```
# def fix_null_state():
#
#     q = "select * from geo_dimension_copy where state is null"
#     curs = cnx.cursor()
#     r = curs.execute(q)
#     result = curs.fetchall()
#
#     for r in result:
#
#         try:
#             url = "http://176.9.107.169/postalCodeLookupJSON?postalcode=" + \
#             r['postalCode'] + '&country=' + r['Code'] + "&username=yyy&token=xxx"
#             l_result = requests.get(url)
#             info = l_result.json()
#             info = info['postalcodes'][0]
#             q2 = "update geo_dimension_copy set state='" + info['adminName2'] + "' " + \
#                 "where geoId='" + str(r['geoId']) + "'"
#             curs.execute(q2)
#             cnx.commit()
#         except Exception as e:
#             print("Update failed = ", e)
#
# ```
#
# - This is an example of a function that would run in a map stage in MapReduce.<br>
# There would preceding (map) phases that broke the data into smaller tables to enable parallel processing.

# %%
# %sql SELECT * FROM classiccars.geo_dimension_copy
# Out:
# 129 rows affected.
# [(25899012146069762, 'South San Francisco', 'CA', '94080', 'USA', 'NA', 'US'),
#  (25899012146069763, 'Boston', 'MA', '02107', 'USA', 'NA', 'US'),
#  (25899012146069764, 'New York', 'NY', '10022', 'USA', 'NA', 'US'),
#  (25899012146069765, 'Paris', 'Paris', '75017', 'France', 'EMEA', 'FR'),
#  (25899012146069766, 'Tokyo', 'Chiyoda-Ku', '102-8578', 'Japan', 'Japan', 'JP'),
#  (25899012146069767, 'Sydney', 'New South Wales', 'NSW 2010', 'Australia', 'APAC', 'AU'),
#  (25899012146069768, 'London', 'London', 'EC2N 1HN', 'UK', 'EMEA', 'UK'),
#  (25899012146069769, 'Nantes', 'Loire-Atlantique', '44000', 'France', 'EMEA', 'FR'),
#  (25899012146069770, 'Las Vegas', 'NV', '83030', 'USA', 'NA', 'US'),
#  (25899012146069771, 'Melbourne', 'Victoria', '3004', 'Australia', 'APAC', 'AU'),
#  (25899012146069772, 'Nantes', 'Loire-Atlantique', '44000', 'France', 'EMEA', 'FR'),
#  (25899012146069773, 'Stavern', 'Forsand', '4110', 'Norway', 'EMEA', 'NO'),
#  (25899012146069774, 'San Rafael', 'CA', '97562', 'USA', 'NA', 'US'),
#  (25899012146069775, 'Warszawa', 'Warszawa', '01-012', 'Poland', 'EMEA', 'PL'),
#  (25899012146069776, 'Frankfurt', 'Regierungsbezirk Darmstadt', '60528', 'Germany', 'EMEA', 'DE'),
#  (25899012146069777, 'San Francisco', 'CA', '94217', 'USA', 'NA', 'US'),
#  (25899012146069778, 'NYC', 'NY', '10022', 'USA', 'NA', 'US'),
#  (25899012146069779, 'Madrid', 'Madrid', '28034', 'Spain', 'EMEA', 'ES'),
#  (25899012146069780, 'Luleå', None, 'S-958 22', 'Sweden', 'EMEA', 'SE'),
#  (25899012146069781, 'Kobenhavn', 'Københavns Kommune', '1734', 'Denmark', 'EMEA', 'DK'),
#  (25899012146069782, 'Lyon', 'Rhône', '69004', 'France', 'EMEA', 'FR'),
#  (25899012146069783, 'Singapore', None, '079903', 'Singapore', 'APAC', 'SG'),
#  (25899012146069784, 'NYC', 'NY', '10022', 'USA', 'NA', 'US'),
#  (25899012146069785, 'Allentown', 'PA', '70267', 'USA', 'NA', 'US'),
#  (25899012146069786, 'Burlingame', 'CA', '94217', 'USA', 'NA', 'US'),
#  (25899012146069787, 'Singapore', None, '069045', 'Singapore', 'APAC', 'SG'),
#  (25899012146069788, 'Bergen', 'Bergen', 'N 5804', 'Norway  ', 'EMEA', 'NO'),
#  (25899012146069789, 'New Haven', 'CT', '97823', 'USA', 'NA', 'US'),
#  (25899012146069790, 'Lisboa', None, '1756', 'Portugal', 'EMEA', 'PT'),
#  (25899012146069791, 'Lille', 'Nord', '59000', 'France', 'EMEA', 'FR'),
#  (25899012146069792, 'Paris', 'Paris', '75012', 'France', 'EMEA', 'FR'),
#  (25899012146069793, 'Cambridge', 'MA', '51247', 'USA', 'NA', 'US'),
#  (25899012146069794, 'Bridgewater', 'CT', '97562', 'USA', 'NA', 'US'),
#  (25899012146069795, 'Kita-ku', 'Osaka', ' 530-0003', 'Japan', 'APAC', 'JP'),
#  (25899012146069796, 'NYC', 'NY', '10022', 'USA', 'NA', 'US'),
#  (25899012146069797, 'Helsinki', 'Turku', '21240', 'Finland', 'EMEA', 'FI'),
#  (25899012146069798, 'Manchester', None, 'EC2 5NT', 'UK', 'EMEA', 'UK'),
#  (25899012146069799, 'Dublin', None, '2', 'Ireland', 'EMEA', 'IE'),
#  (25899012146069800, 'Brickhaven', 'MA', '58339', 'USA', 'NA', 'US'),
#  (25899012146069801, 'Liverpool', None, 'WX1 6LT', 'UK', 'ENEA', 'UK'),
#  (25899012146069802, 'Vancouver', 'BC', 'V3F 2K1', 'Canada', 'NA', 'CA'),
#  (25899012146069803, 'Brickhaven', 'MA', '58339', 'USA', 'NA', 'US'),
#  (25899012146069804, 'Pasadena', 'CA', '90003', 'USA', 'NA', 'US'),
#  (25899012146069805, 'Singapore', None, '038988', 'Singapore', 'APAC', 'SG'),
#  (25899012146069806, 'Strasbourg', 'Bas-Rhin', '67000', 'France', 'EMEA', 'FR'),
#  (25899012146069807, 'Central Hong Kong', None, '999077', 'Hong Kong', 'APAC', 'HK'),
#  (25899012146069808, 'Barcelona', 'Barcelona', '08022', 'Spain', 'EMEA', 'ES'),
#  (25899012146069809, 'Glendale', 'CA', '92561', 'USA', 'NA', 'US'),
#  (25899012146069810, 'Cunewalde', None, '01307', 'Germany', 'EMEA', 'DE'),
#  (25899012146069811, 'Århus', 'Aarhus Kommune', '8200', 'Denmark', 'EMEA', 'DK'),
#  (25899012146069812, 'Montréal', 'Québec', 'H1J 1C3', 'Canada', 'NA', 'CA'),
#  (25899012146069813, 'Madrid', 'Madrid', '28001', 'Spain', 'EMEA', 'ES'),
#  (25899012146069814, 'San Diego', 'CA', '91217', 'USA', 'NA', 'US'),
#  (25899012146069815, 'Cowes', 'Isle of Wight', 'PO31 7PJ', 'UK', 'EMEA', 'UK'),
#  (25899012146069816, 'Toulouse', 'Haute-Garonne', '31000', 'France', 'EMEA', 'FR'),
#  (25899012146069817, 'Frankfurt', 'Regierungsbezirk Darmstadt', '60528', 'Germany', 'EMEA', 'DE'),
#  (25899012146069818, 'Torino', 'Torino', '10100', 'Italy', 'EMEA', 'IT'),
#  (25899012146069819, 'Paris', 'Paris', '75508', 'France', 'EMEA', 'FR'),
#  (25899012146069820, 'Versailles', 'Yvelines', '78000', 'France', 'EMEA', 'FR'),
#  (25899012146069821, 'Köln', 'Regierungsbezirk Köln', '50739', 'Germany', 'EMEA', 'DE'),
#  (25899012146069822, 'Tsawassen', 'BC', 'T2F 8M4', 'Canada', 'NA', 'CA'),
#  (25899012146069823, 'München', 'Upper Bavaria', '80805', 'Germany', 'EMEA', 'DE'),
#  (25899012146069824, 'North Sydney', 'NSW', '2060', 'Australia', 'APAC', 'AU'),
#  (25899012146069825, 'Bergamo', 'Bergamo', '24100', 'Italy', 'EMEA', 'IT'),
#  (25899012146069826, 'Chatswood', 'NSW', '2067', 'Australia', 'APAC', 'AU'),
#  (25899012146069827, 'Cambridge', 'MA', '51247', 'USA', 'NA', 'US'),
#  (25899012146069828, 'Fribourg', 'Sarine District', '1700', 'Switzerland', 'EMEA', 'CH'),
#  (25899012146069829, 'Genève', 'Geneva', '1203', 'Switzerland', 'EMEA', 'CH'),
#  (25899012146069830, 'Oslo', 'Oslo', 'N 0106', 'Norway  ', 'EMEA', 'NO'),
#  (25899012146069831, 'Amsterdam', 'Amsterdam', '1043 GR', 'Netherlands', 'EMEA', 'NL'),
#  (25899012146069832, 'Berlin', None, '12209', 'Germany', 'EMEA', 'DE'),
#  (25899012146069833, 'Oulu', None, '90110', 'Finland', 'EMEA', 'FI'),
#  (25899012146069834, 'Bruxelles', 'Bruxelles', 'B-1180', 'Belgium', 'EMEA', 'BE'),
#  (25899012146069835, 'White Plains', 'NY', '24067', 'USA', 'NA', 'US'),
#  (25899012146069836, 'New Bedford', 'MA', '50553', 'USA', 'NA', 'US'),
#  (25899012146069837, 'San Francisco', 'CA', '94217', 'USA', 'NA', 'US'),
#  (25899012146069838, 'Auckland  ', None, None, 'New Zealand', 'APAC', 'NZ'),
#  (25899012146069839, 'London', None, 'WX3 6FW', 'UK', 'EMEA', 'UK'),
#  (25899012146069840, 'Newark', 'NJ', '94019', 'USA', 'NA', 'US'),
#  (25899012146069841, 'South Brisbane', 'Queensland', '4101', 'Australia', 'APAC', 'AU'),
#  (25899012146069842, 'Espoo', None, 'FIN-02271', 'Finland', 'EMEA', 'FI'),
#  (25899012146069843, 'Brandenburg', None, '14776', 'Germany', 'EMEA', 'DE'),
#  (25899012146069844, 'Philadelphia', 'PA', '71270', 'USA', 'NA', 'US'),
#  (25899012146069845, 'Madrid', 'Madrid', '28023', 'Spain', 'EMEA', 'ES'),
#  (25899012146069846, 'Los Angeles', 'CA', '91003', 'USA', 'NA', 'US'),
#  (25899012146069847, 'Cork', 'Co. Cork', None, 'Ireland', 'EMEA', 'IE'),
#  (25899012146069848, 'Marseille', 'Bouches-du-Rhône', '13008', 'France', 'EMEA', 'FR'),
#  (25899012146069849, 'Reims', 'Marne', '51100', 'France', 'EMEA', 'FR'),
#  (25899012146069850, 'Hatfield', 'Pretoria', '0028', 'South Africa', 'EMEA', 'ZA'),
#  (25899012146069851, 'Auckland', None, None, 'New Zealand', 'APAC', 'NZ'),
#  (25899012146069852, 'Münster', None, '44087', 'Germany', 'EMEA', 'DE'),
#  (25899012146069853, 'Boston', 'MA', '51003', 'USA', 'NA', 'US'),
#  (25899012146069854, 'Nashua', 'NH', '62005', 'USA', 'NA', 'US'),
#  (25899012146069855, 'Lisboa', 'Odivelas', '1675', 'Portugal', 'EMEA', 'PT'),
#  (25899012146069856, 'Bern', 'Bern-Mittelland District', '3012', 'Switzerland', 'EMEA', 'CH'),
#  (25899012146069857, 'Brickhaven', 'MA', '58339', 'USA', 'NA', 'US'),
#  (25899012146069858, 'Charleroi', 'Hainaut', 'B-6000', 'Belgium', 'EMEA', 'BE'),
#  (25899012146069859, 'Salzburg', 'Salzburg Stadt', '5020', 'Austria', 'EMEA', 'AT'),
#  (25899012146069860, 'Makati City', None, '1227 MM', 'Philippines', 'APAC', 'PH'),
#  (25899012146069861, 'Reggio Emilia', None, '42100', 'Italy', 'EMEA', 'IT'),
#  (25899012146069862, 'Minato-ku', 'Tokyo', '106-0032', 'Japan', 'APAC', 'JP'),
#  (25899012146069863, 'Paris', 'Paris', '75016', 'France', 'EMEA', 'FR'),
#  (25899012146069864, 'Stuttgart', 'Regierungsbezirk Stuttgart', '70563', 'Germany', 'EMEA', 'DE'),
#  (25899012146069865, 'Wellington', None, None, 'New Zealand', 'APAC', 'NZ'),
#  (25899012146069866, 'Munich', 'Upper Bavaria', '80686', 'Germany', 'EMEA', 'DE'),
#  (25899012146069867, 'NYC', 'NY', '10022', 'USA', 'NA', 'US'),
#  (25899012146069868, 'Leipzig', None, '04179', 'Germany', 'EMEA', 'DE'),
#  (25899012146069869, 'Glendale', 'CT', '97561', 'USA', 'NA', 'US'),
#  (25899012146069870, 'Bräcke', None, 'S-844 67', 'Sweden', 'EMEA', 'SE'),
#  (25899012146069871, 'San Jose', 'CA', '94217', 'USA', 'NA', 'US'),
#  (25899012146069872, 'Graz', 'Politischer Bezirk Graz-Umgebung', '8010', 'Austria', 'EMEA', 'AT'),
#  (25899012146069873, 'New Haven', 'CT', '97823', 'USA', 'NA', 'US'),
#  (25899012146069874, 'NYC', 'NY', '10022', 'USA', 'NA', 'US'),
#  (25899012146069875, 'Madrid', 'Madrid', '28023', 'Spain', 'EMEA', 'ES'),
#  (25899012146069876, 'Aachen', 'Regierungsbezirk Köln', '52066', 'Germany', 'EMEA', 'DE'),
#  (25899012146069877, 'New Bedford', 'MA', '50553', 'USA', 'NA', 'US'),
#  (25899012146069878, 'Madrid', 'Madrid', '28023', 'Spain', 'EMEA', 'ES'),
#  (25899012146069879, 'Glen Waverly', 'Victoria', '3150', 'Australia', 'APAC', 'AU'),
#  (25899012146069880, 'Milan', None, None, 'Italy', 'EMEA', 'IT'),
#  (25899012146069881, 'Burbank', 'CA', '94019', 'USA', 'NA', 'US'),
#  (25899012146069882, 'Mannheim', None, '68306', 'Germany', 'EMEA', 'DE'),
#  (25899012146069883, 'Saint Petersburg', '', '196143', 'Russia', 'EMEA', 'RU'),
#  (25899012146069884, 'Herzlia', None, '47625', 'Israel', 'EMEA', 'IL'),
#  (25899012146069885, 'Sevilla', None, '41101', 'Spain', 'EMEA', 'ES'),
#  (25899012146069886, 'Philadelphia', 'PA', '71270', 'USA', 'NA', 'US'),
#  (25899012146069887, 'Brisbane', 'CA', '94217', 'USA', 'NA', 'US'),
#  (25899012146069888, 'London', None, 'WA1 1DP', 'UK', 'EMEA', 'UK'),
#  (25899012146069889, 'Boston', 'MA', '51003', 'USA', 'NA', 'US'),
#  (25899012146069890, 'Auckland  ', None, None, 'New Zealand', 'APAC', 'NZ')]

# %% [markdown]
# - Why did I do this?
#     - I get distracted easily.
#     - Just wanted to show you that the homework assignments could have been a lot worse.
#
#
# - Options for "finalizing" to get good data:
#     - Assign to the class as a final exam question.
#     - Admit that the semester is over and just use a subset of the data and columns for the last lecture.

# %%
# %sql select * from simple_geo_dimension
# Out:
# 122 rows affected.
# [(103, 25899012146070231, 'Nantes', 'France', 'EMEA'),
#  (112, 25899012146070232, 'Las Vegas', 'USA', 'NA'),
#  (114, 25899012146070233, 'Melbourne', 'Australia', 'APAC'),
#  (119, 25899012146070231, 'Nantes', 'France', 'EMEA'),
#  (121, 25899012146070234, 'Stavern', 'Norway', 'EMEA'),
#  (124, 25899012146070235, 'San Rafael', 'USA', 'NA'),
#  (125, 25899012146070236, 'Warszawa', 'Poland', 'EMEA'),
#  (128, 25899012146070237, 'Frankfurt', 'Germany', 'EMEA'),
#  (129, 25899012146070238, 'San Francisco', 'USA', 'NA'),
#  (131, 25899012146070226, 'New York', 'USA', 'NA'),
#  (141, 25899012146070240, 'Madrid', 'Spain', 'EMEA'),
#  (144, 25899012146070241, 'Luleå', 'Sweden', 'EMEA'),
#  (145, 25899012146070242, 'Kobenhavn', 'Denmark', 'EMEA'),
#  (146, 25899012146070243, 'Lyon', 'France', 'EMEA'),
#  (148, 25899012146070244, 'Singapore', 'Singapore', 'APAC'),
#  (151, 25899012146070226, 'New York', 'USA', 'NA'),
#  (157, 25899012146070245, 'Allentown', 'USA', 'NA'),
#  (161, 25899012146070238, 'San Francisco', 'USA', 'NA'),
#  (166, 25899012146070244, 'Singapore', 'Singapore', 'APAC'),
#  (167, 25899012146070248, 'Bergen', 'Norway  ', 'EMEA'),
#  (168, 25899012146070249, 'New Haven', 'USA', 'NA'),
#  (169, 25899012146070250, 'Lisboa', 'Portugal', 'EMEA'),
#  (171, 25899012146070251, 'Lille', 'France', 'EMEA'),
#  (172, 25899012146070227, 'Paris', 'France', 'EMEA'),
#  (173, 25899012146070253, 'Cambridge', 'USA', 'NA'),
#  (175, 25899012146070235, 'San Rafael', 'USA', 'NA'),
#  (177, 25899012146070255, 'Kita-ku', 'Japan', 'APAC'),
#  (181, 25899012146070226, 'New York', 'USA', 'NA'),
#  (186, 25899012146070256, 'Helsinki', 'Finland', 'EMEA'),
#  (187, 25899012146070257, 'Manchester', 'UK', 'EMEA'),
#  (189, 25899012146070258, 'Dublin', 'Ireland', 'EMEA'),
#  (198, 25899012146070259, 'Brickhaven', 'USA', 'NA'),
#  (201, 25899012146070260, 'Liverpool', 'UK', 'ENEA'),
#  (202, 25899012146070261, 'Vancouver', 'Canada', 'NA'),
#  (204, 25899012146070259, 'Brickhaven', 'USA', 'NA'),
#  (205, 25899012146070262, 'Pasadena', 'USA', 'NA'),
#  (206, 25899012146070244, 'Singapore', 'Singapore', 'APAC'),
#  (209, 25899012146070264, 'Strasbourg', 'France', 'EMEA'),
#  (211, 25899012146070265, 'Central Hong Kong', 'Hong Kong', 'APAC'),
#  (216, 25899012146070266, 'Barcelona', 'Spain', 'EMEA'),
#  (219, 25899012146070267, 'Glendale', 'USA', 'NA'),
#  (223, 25899012146070268, 'Cunewalde', 'Germany', 'EMEA'),
#  (227, 25899012146070269, 'Århus', 'Denmark', 'EMEA'),
#  (233, 25899012146070270, 'Montréal', 'Canada', 'NA'),
#  (237, 25899012146070240, 'Madrid', 'Spain', 'EMEA'),
#  (239, 25899012146070272, 'San Diego', 'USA', 'NA'),
#  (240, 25899012146070273, 'Cowes', 'UK', 'EMEA'),
#  (242, 25899012146070274, 'Toulouse', 'France', 'EMEA'),
#  (247, 25899012146070237, 'Frankfurt', 'Germany', 'EMEA'),
#  (249, 25899012146070275, 'Torino', 'Italy', 'EMEA'),
#  (250, 25899012146070227, 'Paris', 'France', 'EMEA'),
#  (256, 25899012146070277, 'Versailles', 'France', 'EMEA'),
#  (259, 25899012146070278, 'Köln', 'Germany', 'EMEA'),
#  (260, 25899012146070279, 'Tsawassen', 'Canada', 'NA'),
#  (273, 25899012146070280, 'München', 'Germany', 'EMEA'),
#  (276, 25899012146070281, 'North Sydney', 'Australia', 'APAC'),
#  (278, 25899012146070282, 'Bergamo', 'Italy', 'EMEA'),
#  (282, 25899012146070283, 'Chatswood', 'Australia', 'APAC'),
#  (286, 25899012146070253, 'Cambridge', 'USA', 'NA'),
#  (293, 25899012146070284, 'Fribourg', 'Switzerland', 'EMEA'),
#  (298, 25899012146070285, 'Genève', 'Switzerland', 'EMEA'),
#  (299, 25899012146070286, 'Oslo', 'Norway  ', 'EMEA'),
#  (303, 25899012146070287, 'Amsterdam', 'Netherlands', 'EMEA'),
#  (307, 25899012146070288, 'Berlin', 'Germany', 'EMEA'),
#  (311, 25899012146070289, 'Oulu', 'Finland', 'EMEA'),
#  (314, 25899012146070290, 'Bruxelles', 'Belgium', 'EMEA'),
#  (319, 25899012146070291, 'White Plains', 'USA', 'NA'),
#  (320, 25899012146070292, 'New Bedford', 'USA', 'NA'),
#  (321, 25899012146070238, 'San Francisco', 'USA', 'NA'),
#  (323, 25899012146070293, 'Auckland  ', 'New Zealand', 'APAC'),
#  (324, 25899012146070230, 'London', 'UK', 'EMEA'),
#  (328, 25899012146070295, 'Newark', 'USA', 'NA'),
#  (333, 25899012146070296, 'South Brisbane', 'Australia', 'APAC'),
#  (334, 25899012146070297, 'Espoo', 'Finland', 'EMEA'),
#  (335, 25899012146070298, 'Brandenburg', 'Germany', 'EMEA'),
#  (339, 25899012146070299, 'Philadelphia', 'USA', 'NA'),
#  (344, 25899012146070240, 'Madrid', 'Spain', 'EMEA'),
#  (347, 25899012146070301, 'Los Angeles', 'USA', 'NA'),
#  (348, 25899012146070302, 'Cork', 'Ireland', 'EMEA'),
#  (350, 25899012146070303, 'Marseille', 'France', 'EMEA'),
#  (353, 25899012146070304, 'Reims', 'France', 'EMEA'),
#  (356, 25899012146070305, 'Hatfield', 'South Africa', 'EMEA'),
#  (357, 25899012146070293, 'Auckland  ', 'New Zealand', 'APAC'),
#  (361, 25899012146070306, 'Münster', 'Germany', 'EMEA'),
#  (362, 25899012146070225, 'Boston', 'USA', 'NA'),
#  (363, 25899012146070308, 'Nashua', 'USA', 'NA'),
#  (369, 25899012146070250, 'Lisboa', 'Portugal', 'EMEA'),
#  (376, 25899012146070310, 'Bern', 'Switzerland', 'EMEA'),
#  (379, 25899012146070259, 'Brickhaven', 'USA', 'NA'),
#  (381, 25899012146070311, 'Charleroi', 'Belgium', 'EMEA'),
#  (382, 25899012146070312, 'Salzburg', 'Austria', 'EMEA'),
#  (385, 25899012146070313, 'Makati City', 'Philippines', 'APAC'),
#  (386, 25899012146070314, 'Reggio Emilia', 'Italy', 'EMEA'),
#  (398, 25899012146070315, 'Minato-ku', 'Japan', 'APAC'),
#  (406, 25899012146070227, 'Paris', 'France', 'EMEA'),
#  (409, 25899012146070317, 'Stuttgart', 'Germany', 'EMEA'),
#  (412, 25899012146070318, 'Wellington', 'New Zealand', 'APAC'),
#  (415, 25899012146070319, 'Munich', 'Germany', 'EMEA'),
#  (424, 25899012146070226, 'New York', 'USA', 'NA'),
#  (443, 25899012146070320, 'Leipzig', 'Germany', 'EMEA'),
#  (447, 25899012146070267, 'Glendale', 'USA', 'NA'),
#  (448, 25899012146070322, 'Bräcke', 'Sweden', 'EMEA'),
#  (450, 25899012146070238, 'San Francisco', 'USA', 'NA'),
#  (452, 25899012146070324, 'Graz', 'Austria', 'EMEA'),
#  (455, 25899012146070249, 'New Haven', 'USA', 'NA'),
#  (456, 25899012146070226, 'New York', 'USA', 'NA'),
#  (458, 25899012146070240, 'Madrid', 'Spain', 'EMEA'),
#  (459, 25899012146070325, 'Aachen', 'Germany', 'EMEA'),
#  (462, 25899012146070292, 'New Bedford', 'USA', 'NA'),
#  (465, 25899012146070240, 'Madrid', 'Spain', 'EMEA'),
#  (471, 25899012146070326, 'Glen Waverly', 'Australia', 'APAC'),
#  (473, 25899012146070327, 'Milan', 'Italy', 'EMEA'),
#  (475, 25899012146070295, 'Newark', 'USA', 'NA'),
#  (477, 25899012146070329, 'Mannheim', 'Germany', 'EMEA'),
#  (480, 25899012146070330, 'Saint Petersburg', 'Russia', 'EMEA'),
#  (481, 25899012146070331, 'Herzlia', 'Israel', 'EMEA'),
#  (484, 25899012146070332, 'Sevilla', 'Spain', 'EMEA'),
#  (486, 25899012146070299, 'Philadelphia', 'USA', 'NA'),
#  (487, 25899012146070238, 'San Francisco', 'USA', 'NA'),
#  (489, 25899012146070230, 'London', 'UK', 'EMEA'),
#  (495, 25899012146070225, 'Boston', 'USA', 'NA'),
#  (496, 25899012146070293, 'Auckland  ', 'New Zealand', 'APAC')]

# %% [markdown]
# - We can now position every fact into the location and time dimensions.

# %% [markdown]
# ## Using the Data/Schema
#
# ### Pivot Tables
#
# | <img src="../images/quicksight3.jpeg" >|
# | :---: |
# | [AWS QuickSight](https://aws.amazon.com/quicksight/) |
# <hr>

# %% [markdown]
# | <img src="../images/pivottable1.jpeg" >|
# | :---: |
# | [Pivot Table](https://en.wikipedia.org/wiki/Pivot_table) |
# <hr>
#
# <br><br>
# QuickSight demo.
# <br><br>

# %% [markdown]
# | <img src="../images/pivottable2.jpeg" >|
# | :---: |
# | __Pivot Table Data__ |
# <hr>

# %% [markdown]
# "A pivot table is a table of statistics that summarize the data of a more extensive table (such as from a database, spreadsheet, or business intelligence program). This summary might include sums, averages, or other statistics, which the pivot table groups together in a meaningful way.
#
# Pivot tables are a technique in data processing. They enable a person to arrange and rearrange (or "pivot") statistics in order to draw attention to useful information."
# (https://en.wikipedia.org/wiki/Pivot_table)
#
# Benefits:
# - Easy to Use
# - Easy Data Analysis
# - Easy Summary of Data
# - Find Data Patterns
# - Quick Report Creation
# - Helps in Quick Decision Making
#
# "A pivot table can be considered to be a valuable Excel reporting tool as it allows users to easily analyze the data and arrive at quick decisions. This serves as a huge advantage in the industrial world, where it is crucial to make precise and quick decisions."(http://www.associationofbusinesstraining.org/articles/view.php?article_id=11022)

# %% [markdown]
# ## Online Analytics and Processing (OLAP)
#
# "Online analytical processing, or OLAP, is an approach to answering multi-dimensional analytical (MDA) queries swiftly in computing. OLAP is part of the broader category of business intelligence, which also encompasses relational databases, report writing and data mining. Typical applications of OLAP include business reporting for sales, marketing, management reporting, business process management (BPM), budgeting and forecasting, financial reporting and similar areas, with new applications emerging, such as agriculture. The term OLAP was created as a slight modification of the traditional database term online transaction processing (OLTP).
#
# OLAP tools enable users to analyze multidimensional data interactively from multiple perspectives. OLAP consists of three basic analytical operations: consolidation (roll-up), drill-down, and slicing and dicing." (https://en.wikipedia.org/wiki/Online_analytical_processing)

# %% [markdown]
# | <img src="../images/OLAP1.png"> |
# | :---: |
# | [OLAP Cube](http://ora-pl-sql.blogspot.com/2015/08/olap.html) |

# %% [markdown]
# - An OLAP is a multi-dimensional generalization of a spreadsheet.
#
#
# - Useful for [multi-dimensional data analysis](https://en.wikipedia.org/wiki/Multidimensional_analysis)
#
#
# - There is a multi-dimensional space $D = <D_1, D_2, ..., D_n>.$
#
#
# - There is a array of metrics $M = <m_1, m_2, ..., m_k>$ at each point.
#
#
# - The cube is logical a function $F:B \rightarrow M.$
#
# | <img src="../images/star_dimensions.gif" > |
# | :---: |
# | [Cube, Facts, Dimensions, Hierarchies](https://docs.oracle.com/cd/E29633_01/CDMOG/GUID-428F33D4-04D0-4EDA-BA60-96EF3988C803.htm) |

# %% [markdown]
# | <img src="../images/olap_book_1.jpg" width="150%">
# | :---: |
# | __ROLAP and MOLAP__ |
#
# | <img src="../images/rolap_molap.jpeg" width="150%">
# | :---: |
# | __ROLAP and MOLAP__ |
#
# | <img src="../images/olap_dimensions.jpeg" width="150%">
# | :---: |
# | __Dimensions__ |
#
# | <img src="../images/book/slide09.jpg" width="150%">
# | :---: |
# | __Queries__ |
#
# | <img src="../images/book/slide11.jpg" width="150%">
# | :---: |
# | __Comparison with SQL__ |

# %% [markdown]
# - Engine implementation:
#     - Some database engines support optimized storage, querying, etc. for OLAP data.
#     - Others provide OLAP extensions to SQL on top of underlying relational engine and data storage.
#
#
# - There are query languages for OLAP Cubes, e.g. [Multi-Dimensional eXpressions (MDX)](https://en.wikipedia.org/wiki/MultiDimensional_eXpressions)
#
# ```
# SELECT
#    { [Measures].[Store Sales] } ON COLUMNS,
#    { [Date].[2002], [Date].[2003] } ON ROWS
# FROM Sales
# WHERE ( [Store].[USA].[CA] )
# ```
#
#
# - Last semester, I managed to go through some demos of an open source OLAP tool.
#
# | <img src="../images/data_brewery.jpeg" width="150%">
# | :---: |
# | [__Data Brewery__](http://databrewery.org/) |

# %% [markdown]
# ### Advanced Business Intelligence
#
# | <img src="../images/Tableau_dashboard2.jpg" >|
# | :---: |
# | [Tableau Dashboard](https://www.witinc.com/tableau-consulting/) |
#
# There is a large industry of business intelligence software, tools and analysts. BI tools offer many functions:
# - Advanced visualization and dashboard.
# - Data load, merge, clean, ... tools.
# - Analytics, trends, pattern detection, ...
# - Prediction, hypothesis testing, ...
#
# | <img src="../images/enterprise_big_data.png" width="100%"> |
# | :---: |
# | [__Enterprise Big Data__](https://hortonworks.com/blog/modern-data-architecture-applied-hadoop/)

# %% [markdown]
# ## PLAY (Moneyball) BALL!
#
# - [play ball](https://idioms.thefreedictionary.com/play+ball)  (idiom): Get going, start, as in It's time to get a move on; "_let's play ball._" This usage comes from the baseball umpire's call to start a game.
#
#
# - "[Moneyball: The Art of Winning an Unfair Game](https://en.wikipedia.org/wiki/Moneyball) is a book by Michael Lewis, published in 2003, about the Oakland Athletics baseball team and its general manager Billy Beane. Its focus is the team's analytical, evidence-based, sabermetric approach to assembling a competitive baseball team, despite Oakland's disadvantaged revenue situation."
#
# ### Reminder $-$ Why use Baseball in this Course?
#
# - Domain in which you probably have limited knowledge.
#
#
# - Computer scientists often perform data analytics and mining in domains that they do not deeply understand.
#     - They work with domain experts (me in our case)
#     - And come to incrementally understand the domain over time.
#
#
# - AND the real reason. "Whoever wants to know the heart and mind of America had better learn baseball, the rules and realities of the game — and do it by watching first some high school or small-town teams." Jacques Barzun, _God's Country and Mine,_ Little, Brown. (1954)
#     <br><br><hr>
#
# [<img src="../images/baseball.jpeg">](https://www.youtube.com/watch?v=__X7ybW9Ljg)

# %% [markdown]
# ### Data Model and Business Problem
#
# Core information (__Note:__ Master is now the table _People_ in 2017 data.)
#
# | <img src="../images/L5_HW_2_CM.jpeg"> |
# | :---: |
# | __Core Lahman 2016 Tables for Moneyball__ |
#
# There are a lot of facts about teams and players
#
#
# - There are some dimensions, e.g.
#     - Year
#     - League, team, division
#     - Pitcher, field player, position
#
#
# - Slicing and dicing the data on dimensions will provide some insights, e.g.
#     - How does player A's HR average over the past 5 years compare to the 5 year average of all outfielders?
#     - Histogram batting average into buckets and view team wins on batting average and year dimensions.
#
#
# - But, these are indirect approaches to solving the problem. We are trying to learn and optimize.
#
#
# - A vector of metrics $\vec{x}$ summarizes a team's performance capabilities, e.g. batting average, HRs, etc.
#
#
# - A similar vector $\vec{p}$ summarizes the performance contribution of a player to the team $T.$
#
#
# - Let $i$ be the subscript notation for the i-th metric. If $f_i$ is some aggregation function, e.g. sum, average, then
#
# \begin{equation}
# x_i = f_i(p_i), \forall p \in T.
# \end{equation}
#
#
# - $S(p)$ can denote player $p$ salary. This yields two constraints
#     - C1: $ \#(T) \leq 25$ (approximating the maximum number of allowed players per team)
#     - C2: $\sum_{p \in T}{S(p)} \leq B(T),$ team $T$ budget.
#
#
# - If
#     - $W(\vec{x})$ is the number of wins per season as a function of $\vec{x} \in X.$
#     - $P(\vec{x}) \rightarrow [0,1]$ is the probability of winning the World Series for $\vec{x} \in X.$
#
#
# - We want to pick the team of players $T$ such that we
#     - $Max(W(\vec{x}))$ or $Max(P(\vec{x}))$
#     - With minimal $\sum{S(p)}$
#     - Subject to C1 and C2.
#
#
# - __This boils down to two tasks:__
#     1. _Learning_ the relationship between $\vec{x}$ and wins (or winning world series).
#     1. Finding the price-optimal set of players. We are trying to build an artificial intelligence engine that replaces general managers for picking players.
#
#
# - Finding the price optimal set of players is an optimization problem. There are many techniques:
#     - Integer Programming (https://en.wikipedia.org/wiki/Integer_programming)
#     - Solving the problem is _NP-Hard,_ which means solvers apply various AI and heuristic techniques:
#         - Hill climbing
#         - Simulated annealing
#         - Reactive search optimization
#         - Ant colony optimization
#         - Hopfield neural networks
#         - ... ...
#
#
# - We are going to only consider the learning problem.

# %% [markdown]
# ### Let's Learn
#
# #### Overview
#
# | <img src="../images/scikit_learn.jpeg"> |
# | :---: |
# | [__scikit-learn__](http://scikit-learn.org/stable/) |
#
# - Machine learning is an incredibly complex, powerful and growing space.
#     - This is not a machine learning course.
#     - I am not a machine learning expert.
#
#
# - But, machine learning is often a data driven and hence database application. So, let's have a simple introduction.
#
#
# - The simplest, most natural model for learning $W(\vec{x})$ is _Regression._
#
#
# - __Regression is boring. The cool kids use AI.__

# %% [markdown]
# #### Multilayer Perceptron
#
# ##### Neuron and Perceptron
#
# - We are going to try a neural network because saying "multilayer perceptron" is cool.
#
#
# | <img src="../images/neuron1.jpeg"> |
# | :---: |
# | [__Neurons__](http://stackabuse.com/introduction-to-neural-networks-with-scikit-learn/) |
#
#
# | <img src="../images/neuron-perceptron.jpg">
# | :---: |
# | [__Neuron and Perceptron__](https://www.slideshare.net/jbhuang/lecture-29-convolutional-neural-networks-computer-vision-spring2015)

# %% [markdown]
# | <img src="../images/perceptron-model.jpg">
# | :---: |
# | [__Perceptron Model__](http://www.big-data.tips/neural-network)

# %% [markdown]
# <u>Behavior</u>
#
# - Step 1: Compute weighted sum of inputs to produce $s:$
# \begin{equation}
# s = w_0 + \sum_{i=1}^n (w_i * x_i)
# \end{equation}
#
#
# - Step 2: Apply an _activation function_  $f()$ to $s$ to produce the output $y = f(s).$
#
#
# - The weights $\vec{w}$ and the choice of the _activation function_ $(f)$ determine the perceptron's behavior.

# %% [markdown]
# <u>Training</u>
#
# - The training data is a set with elements of the form $(\vec{x}, d)$
#     - $\vec{x}$ is an input.
#     - $d$ is the correct value to compute from $\vec{x}.$
#
#
# - Assume that there are $k$ elements in the training data.
#     - $x_{ij}$ if the value of the i-th input field in the j-th training element.
#     - $d_j$ is the correct answer for the j-th training element.
#
#
# - $\vec{x}$ is the input vector. We will _train_ the neuron (network of neurons) with a set of input vectors.
#
#
# - The goal is to "learn" the value of $\vec{w}$ for the neurons. Since different neurons can learn different weight vectors, this learning adapts to non-linear functions between $\vec{x}$ and $y.$
#
#
# - Training goes through a set of steps $t = 0, 1, ..., k$ and adjusts the weights $w_i(t)$ based on an error function computed from $d_j, x_{ij}$ and $y(t).$
#
#
# - One of the more common adjustment formulas is [gradient descent](https://en.wikipedia.org/wiki/Gradient_descent) applied to the error. If $E$ is the error and $\alpha$ is the learning rate, gradient descent updates using
#
# \begin{equation}
# w_i(t+1) = w_i(t) - \alpha*(\frac{\partial E}{\partial w_i})
# \end{equation}
#
#
# - With a little bit of calculus applied to weighted average, this results in
#
# \begin{equation}
# w_i(t+1) = w_i(t) + (d_j - y(t)) *x_{ji}
# \end{equation}

# %% [markdown]
# | <img src="../images/mlp-layers.jpg">
# | :---: |
# | [__Multilayer__](https://www.safaribooksonline.com/library/view/getting-started-with/9781786468574/ch04s04.html)

# %% [markdown]
# ##### The Data

# %%
import pandas
result = %sql select yearid, teamid, w, r, h, ab, 2b as b2, 3b as b3, hr, bb, hbp, era from lahman2017.teams;
df = result.DataFrame()
df.head(10)
# Out:
# 2865 rows affected.
#   yearid teamid   w    r     h    ab   b2  b3   hr   bb hbp   era
# 0   1884    ALT   6   90   223   899   30   6    2   22      4.67
# 1   1997    ANA  84  829  1531  5628  279  25  161  617  45  4.52
# 2   1998    ANA  85  787  1530  5630  314  27  147  510  48  4.49
# 3   1999    ANA  70  711  1404  5494  248  22  158  511  43  4.79
# 4   2000    ANA  82  864  1574  5628  309  34  236  608  47  5.00
# 5   2001    ANA  75  691  1447  5551  275  26  158  494  77  4.20
# 6   2002    ANA  99  851  1603  5678  333  32  152  462  74  3.69
# 7   2003    ANA  77  736  1473  5487  276  33  150  476  56  4.28
# 8   2004    ANA  92  836  1603  5675  272  37  162  450  73  4.28
# 9   1998    ARI  65  665  1353  5491  235  46  159  489  64  4.63

# %% [markdown]
# - I am using Pandas (https://pandas.pydata.org/)
#
#
# | <img src="../images/pandas.jpeg"> |
# | :---: |
# | [Pandas](https://www.datacamp.com/community/blog/python-pandas-cheat-sheet) |

# %% [markdown]
# - I doubt that data before 2000 is meaningful. Baseball changes over time, e.g. number of games per season, manufacturing of bat and ball.
#
#
# - Pandas has a subset of the features of SQL for in memory data, e.g. selection or filtering.

# %%
refined_data = df[(df['yearid'] >= '2000')]

# %%
refined_data.head(10)
# Out:
#    yearid teamid   w    r     h    ab   b2  b3   hr   bb hbp   era
# 4    2000    ANA  82  864  1574  5628  309  34  236  608  47  5.00
# 5    2001    ANA  75  691  1447  5551  275  26  158  494  77  4.20
# 6    2002    ANA  99  851  1603  5678  333  32  152  462  74  3.69
# 7    2003    ANA  77  736  1473  5487  276  33  150  476  56  4.28
# 8    2004    ANA  92  836  1603  5675  272  37  162  450  73  4.28
# 11   2000    ARI  85  792  1466  5527  282  44  179  535  59  4.35
# 12   2001    ARI  92  818  1494  5595  284  35  208  587  57  3.87
# 13   2002    ARI  98  819  1471  5508  283  41  165  643  50  3.92
# 14   2003    ARI  84  717  1467  5570  303  47  152  531  45  3.84
# 15   2004    ARI  51  615  1401  5544  295  38  135  441  35  4.98

# %% [markdown]
# - Type conversion

# %%
df2 = refined_data.astype({"w": int, "r": int, "h": int, "ab": int, "b2": int, "b3": int, \
                                "hr": int, "bb": int, "hbp": int, "era": float})
df2.head(10)
# Out:
#    yearid teamid   w    r     h    ab   b2  b3   hr   bb  hbp   era
# 4    2000    ANA  82  864  1574  5628  309  34  236  608   47  5.00
# 5    2001    ANA  75  691  1447  5551  275  26  158  494   77  4.20
# 6    2002    ANA  99  851  1603  5678  333  32  152  462   74  3.69
# 7    2003    ANA  77  736  1473  5487  276  33  150  476   56  4.28
# 8    2004    ANA  92  836  1603  5675  272  37  162  450   73  4.28
# 11   2000    ARI  85  792  1466  5527  282  44  179  535   59  4.35
# 12   2001    ARI  92  818  1494  5595  284  35  208  587   57  3.87
# 13   2002    ARI  98  819  1471  5508  283  41  165  643   50  3.92
# 14   2003    ARI  84  717  1467  5570  303  47  152  531   45  3.84
# 15   2004    ARI  51  615  1401  5544  295  38  135  441   35  4.98

# %% [markdown]
# - Derived columns
#
# "In baseball statistics, on-base percentage (OBP; sometimes referred to as on-base average/OBA, as the statistic is rarely presented as a true percentage) is a statistic generally measuring how frequently a batter reaches base. Specifically, it records the ratio of the batter's times-on-base (TOB) (the sum of hits, walks, and times hit by pitch) to their number of plate appearances. It first became an official MLB statistic in 1984." (https://en.wikipedia.org/wiki/On-base_percentage)

# %%
obp = \
    (df2['h'] + df2['bb'] + df2['hbp']) / (df2['ab'] + df2['bb'] + df2['hbp'])
df2['obp'] = obp
df2.head(10)
# Out:
#    yearid teamid   w    r     h    ab   b2  b3   hr   bb  hbp   era       obp
# 4    2000    ANA  82  864  1574  5628  309  34  236  608   47  5.00  0.354767
# 5    2001    ANA  75  691  1447  5551  275  26  158  494   77  4.20  0.329631
# 6    2002    ANA  99  851  1603  5678  333  32  152  462   74  3.69  0.344223
# 7    2003    ANA  77  736  1473  5487  276  33  150  476   56  4.28  0.333112
# 8    2004    ANA  92  836  1603  5675  272  37  162  450   73  4.28  0.343014
# 11   2000    ARI  85  792  1466  5527  282  44  179  535   59  4.35  0.336546
# 12   2001    ARI  92  818  1494  5595  284  35  208  587   57  3.87  0.342683
# 13   2002    ARI  98  819  1471  5508  283  41  165  643   50  3.92  0.348976
# 14   2003    ARI  84  717  1467  5570  303  47  152  531   45  3.84  0.332411
# 15   2004    ARI  51  615  1401  5544  295  38  135  441   35  4.98  0.311794

# %% [markdown]
# "In baseball statistics, slugging percentage (SLG) is a measure of the batting productivity of a hitter. It is calculated as total bases divided by at bats, through the following formula, where AB is the number of at bats for a given player, and 1B, 2B, 3B, and HR are the number of singles, doubles, triples, and home runs, ..." (https://en.wikipedia.org/wiki/Slugging_percentage)

# %%
df2['b1'] = df2['h'] - df2['b2'] - df2['b3'] - df2['hr']
df2.head(10)
# Out:
#    yearid teamid   w    r     h    ab   b2  b3   hr   bb  hbp   era       obp  \
# 4    2000    ANA  82  864  1574  5628  309  34  236  608   47  5.00  0.354767
# 5    2001    ANA  75  691  1447  5551  275  26  158  494   77  4.20  0.329631
# 6    2002    ANA  99  851  1603  5678  333  32  152  462   74  3.69  0.344223
# 7    2003    ANA  77  736  1473  5487  276  33  150  476   56  4.28  0.333112
# 8    2004    ANA  92  836  1603  5675  272  37  162  450   73  4.28  0.343014
# 11   2000    ARI  85  792  1466  5527  282  44  179  535   59  4.35  0.336546
# 12   2001    ARI  92  818  1494  5595  284  35  208  587   57  3.87  0.342683
# 13   2002    ARI  98  819  1471  5508  283  41  165  643   50  3.92  0.348976
# 14   2003    ARI  84  717  1467  5570  303  47  152  531   45  3.84  0.332411
# 15   2004    ARI  51  615  1401  5544  295  38  135  441   35  4.98  0.311794
#
#       b1
# 4    995
# 5    988
# 6   1086
# 7   1014
# 8   1132
# 11   961
# 12   967
# 13   982
# 14   965
# 15   933

# %%
df2['slg'] = \
    ( df2['b1'] + 2*df2['b2'] + \
        3*df2['b3'] + 4*df2['hr'] ) / df2['ab']
df2.head(10)
# Out:
#    yearid teamid   w    r     h    ab   b2  b3   hr   bb  hbp   era       obp  \
# 4    2000    ANA  82  864  1574  5628  309  34  236  608   47  5.00  0.354767
# 5    2001    ANA  75  691  1447  5551  275  26  158  494   77  4.20  0.329631
# 6    2002    ANA  99  851  1603  5678  333  32  152  462   74  3.69  0.344223
# 7    2003    ANA  77  736  1473  5487  276  33  150  476   56  4.28  0.333112
# 8    2004    ANA  92  836  1603  5675  272  37  162  450   73  4.28  0.343014
# 11   2000    ARI  85  792  1466  5527  282  44  179  535   59  4.35  0.336546
# 12   2001    ARI  92  818  1494  5595  284  35  208  587   57  3.87  0.342683
# 13   2002    ARI  98  819  1471  5508  283  41  165  643   50  3.92  0.348976
# 14   2003    ARI  84  717  1467  5570  303  47  152  531   45  3.84  0.332411
# 15   2004    ARI  51  615  1401  5544  295  38  135  441   35  4.98  0.311794
#
#       b1       slg
# 4    995  0.472459
# 5    988  0.404972
# 6   1086  0.432547
# 7   1014  0.412794
# 8   1132  0.429075
# 11   961  0.429347
# 12   967  0.441823
# 13   982  0.423203
# 14   965  0.416517
# 15   933  0.392677

# %% [markdown]
# - Projection

# %%
df2 = df2[['w', 'r', 'hr', 'obp', 'slg', 'era']]
df2.head(10)
# Out:
#      w    r   hr       obp       slg   era
# 4   82  864  236  0.354767  0.472459  5.00
# 5   75  691  158  0.329631  0.404972  4.20
# 6   99  851  152  0.344223  0.432547  3.69
# 7   77  736  150  0.333112  0.412794  4.28
# 8   92  836  162  0.343014  0.429075  4.28
# 11  85  792  179  0.336546  0.429347  4.35
# 12  92  818  208  0.342683  0.441823  3.87
# 13  98  819  165  0.348976  0.423203  3.92
# 14  84  717  152  0.332411  0.416517  3.84
# 15  51  615  135  0.311794  0.392677  4.98

# %%
X = df2[['obp', 'slg', 'era']]
X.tail(10)
# Out:
#            obp       slg   era
# 2768  0.324524  0.372974  4.66
# 2769  0.338793  0.406153  5.00
# 2770  0.320682  0.390181  4.13
# 2771  0.310241  0.382650  3.58
# 2772  0.324042  0.427605  3.33
# 2773  0.314646  0.397535  3.59
# 2774  0.323140  0.392999  3.03
# 2775  0.323740  0.402542  3.62
# 2776  0.328900  0.425865  3.51
# 2777  0.334639  0.449307  3.88

# %% [markdown]
# ##### Let's Do Some Learning
#
# <u>Hypothesis 1</u>: ["Chicks Dig the Long Ball."](https://www.youtube.com/watch?v=UjkuJPvMrI8)
#
# 1. X, the matrix of variable.
# 2. y, the results.
# 3. Split into training and test data.

# %%
from sklearn.model_selection import train_test_split

X = df2[['hr']]
y = df2['w']
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# - "The neural network in Python may have difficulty converging before the maximum number of iterations allowed if the data is not normalized. Multi-layer Perceptron is sensitive to feature scaling, so it is highly recommended to scale your data." (https://www.springboard.com/blog/beginners-guide-neural-network-in-python-scikit-learn-0-18/)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

# Now apply the transformations to the data:
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# - New we can configure and setup the MLP

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(1,1,1),max_iter=50000)

# %% [markdown]
# - There are quite a few possible parameters. We chose
#     - 3 hidden layers, each with 3 neurons.
#     - 50000 iterations.
#     - Default for the rest.
#
#
# - Now run the training.

# %%
mlp.fit(X_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(1, 1, 1), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=50000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %% [markdown]
# - The definition of the classifier gives you a feel for the options and configuration parameters.
#
#
# - How did we do?

# %%
import matplotlib.pyplot as plt

predictions = mlp.predict(X_test)

cmp2 = pd.DataFrame()
cmp2['w'] = y_test
cmp2['pred_w'] = predictions

plt.figure(figsize=(20,10))
plt.scatter(cmp2['w'],cmp2['pred_w'])

# %%
cmp2.head(10)
# Out:
#        w  pred_w
# 2746  74      95
# 2649  67      86
# 2622  97      95
# 14    84      86
# 1020  74      95
# 2259  67      67
# 1033  81      67
# 1927  68      67
# 610   79      95
# 1875  79      67

# %% [markdown]
# - That is actually rather odd looking.
#
#
# - Let's look at the average error.

# %%
cmp3 = cmp2[['w', 'pred_w']]
cmp3.sort_values(by=['pred_w'])
plt.figure(figsize=(20,10))
plt.scatter(cmp3['w'],cmp3['pred_w'])

# %%
errs = pd.DataFrame()
errs['e']=cmp2['w']-cmp2['pred_w']
errs['e']=errs['e'].abs()
avg2=errs['e'].mean()
avg2
# Out:
# 4.466666666666667

# %% [markdown]
# - And the underlying correlation.

# %%
test_corr = df2[['w','hr']]
test_corr.corr()
# Out:
#            w        hr
# w   1.000000  0.378701
# hr  0.378701  1.000000

# %% [markdown]
# - Why the odd output? Well, with only one input value (HR), the best solution is an average.
#
#
# - Looking at the scatter plot of wins as a function of homeruns shows that guessing 86 wins for any value is pretty good.

# %%
plt.figure(figsize=(20,10))
plt.plot([90,250],[86,86], color='red', label="86 wins")
plt.scatter(df2['hr'], df2['w'])

# %% [markdown]
# - The correlation between wins and homeruns is a "weak positive" correlation.

# %% [markdown]
# <u>Hypothesis 2:</u> Offensive stats are what matters!

# %%
X = df2[['obp', 'slg', 'era']]
y = df2['w']

# %%
X = df2[['obp', 'slg', 'era']]
X.tail(10)
# Out:
#            obp       slg   era
# 2768  0.324524  0.372974  4.66
# 2769  0.338793  0.406153  5.00
# 2770  0.320682  0.390181  4.13
# 2771  0.310241  0.382650  3.58
# 2772  0.324042  0.427605  3.33
# 2773  0.314646  0.397535  3.59
# 2774  0.323140  0.392999  3.03
# 2775  0.323740  0.402542  3.62
# 2776  0.328900  0.425865  3.51
# 2777  0.334639  0.449307  3.88

# %%
y = df2['w']
y.tail(10)
# Out:
# 2768    59
# 2769    59
# 2770    69
# 2771    80
# 2772    98
# 2773    86
# 2774    96
# 2775    83
# 2776    95
# 2777    97
# Name: w, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

# Now apply the transformations to the data:
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(6,6,6),max_iter=500000)

# %%
mlp.fit(X_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(6, 6, 6), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=500000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
predictions = mlp.predict(X_test)

cmp2 = pd.DataFrame()
cmp2['w'] = y_test
cmp2['pred_w'] = predictions

cmp3 = cmp2.sort_values(by=['w'])
plt.figure(figsize=(20,10))
plt.scatter(cmp3['w'],abs(cmp3['pred_w']-cmp3['w']))

# %%
errs = pd.DataFrame()
errs['e']=cmp2['w']-cmp2['pred_w']
errs['e']=errs['e'].abs()
avg2=errs['e'].mean()
avg2
# Out:
# 4.888888888888889

# %% [markdown]
# <u>Hypothesis 3:</u> Let's add some pitching!

# %%
X = df2[['obp', 'slg', 'era']]
y = df2['w']
X_train, X_test, y_train, y_test = train_test_split(X, y)
scaler = StandardScaler()
scaler.fit(X_train)

# Now apply the transformations to the data:
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
mlp = MLPClassifier(hidden_layer_sizes=(3,3,3),max_iter=50000)
mlp.fit(X_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(3, 3, 3), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=50000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
predictions = mlp.predict(X_test)

cmp2 = pd.DataFrame()
cmp2['w'] = y_test
cmp2['pred_w'] = predictions

plt.figure(figsize=(20,10))
plt.scatter(cmp2['w'],cmp2['pred_w'])

# %%
errs = pd.DataFrame()
errs['e']=cmp2['w']-cmp2['pred_w']
errs['e']=errs['e'].abs()
avg2=errs['e'].mean()
avg2
# Out:
# 4.466666666666667

# %% [markdown]
# - OK. That helped a little bit.

# %% [markdown]
# <u>Hypothesis 3:</u> "More Power Scotty!"

# %%
X = df2[['obp', 'slg', 'era']]
y = df2['w']
X_train, X_test, y_train, y_test = train_test_split(X, y)
scaler = StandardScaler()
scaler.fit(X_train)

# Now apply the transformations to the data:
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)
mlp = MLPClassifier(hidden_layer_sizes=(160,160,160,160,160,160,160,160,160),max_iter=500000000)
mlp.fit(X_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(160, 160, 160, 160, 160, 160, 160, 160, 160),
#        learning_rate='constant', learning_rate_init=0.001,
#        max_iter=500000000, momentum=0.9, nesterovs_momentum=True,
#        power_t=0.5, random_state=None, shuffle=True, solver='adam',
#        tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
predictions = mlp.predict(X_test)

cmp2 = pd.DataFrame()
cmp2['w'] = y_test
cmp2['pred_w'] = predictions

plt.scatter(cmp2['w'],cmp2['pred_w'])

# %%
errs = pd.DataFrame()
errs['e']=cmp2['w']-cmp2['pred_w']
errs['e']=errs['e'].abs()
avg2=errs['e'].mean()
avg2
# Out:
# 4.481481481481482

# %%
# Import the learning modules.
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
from scipy import sparse as sp
## Create linear regression object
regr = linear_model.LinearRegression()
x_train = df2.drop('w', axis=1)
x_train2 = x_train[['obp','slg', 'era']]
#print(x_train2)
# Train the model using the training sets

regr.fit(x_train2, df2[['w']])

# We now take homeruns from the prediction test to produce the prediction.
pred = regr.predict(x_train2)

cmp = pd.DataFrame()
cmp['w']=df2['w']
cmp['pw']=pred
plt.figure(figsize=(20,10))
plt.scatter(cmp['pw'],cmp['w'])

# %%
errs = pd.DataFrame()
errs['e']=cmp['w']-cmp['pw']
errs['e']=errs['e'].abs()
avg2=errs['e'].mean()
avg2
# Out:
# 3.5163255960306206

# %% [markdown]
# - This problem, as currently specified, is a regression problem, not a learning problem,

# %% [markdown]
# ## Homework 5: How Well can You Do?
#
# - Take a copy of this notebook.
#
# - Tinker with the data, MLP configurations, ...
