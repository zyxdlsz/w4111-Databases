# %% [markdown]
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# # Introduction to Databases: Relational, Query and Web Application

# %% [markdown]
# ## Our Application -- Reminder
#
# __User Experience__
#
# <img src="../images/L4_search_page.jpeg">
#
# - Provide three UI controls on the baseball dashboard
#     - Select the resource to query (Players, Batting, Appearances)
#     - Find an instance of the resource if you know the identifying fields.
#     - Create an _ad doc_ query to locate resource instances based on columns and values. Choose which columns you want in responses.
#
#
# - Second phase will add support for create, update and delete.

# %% [markdown]
# __Physical Data Model__
#
# <img src="../images/L3_physical_model.jpeg">

# %% [markdown]
# __Application Topology__
#
# <img src="../images/webapp.jpeg">
#
# __Software Overview__
#
# <img src="../images/L3_application_structure_1.jpeg">
#
# __Comments__
#
# - This is a database course, not a web application or web UI course.
#
#
# - We will focus on mapping between the REST URL model and the database, and limit UI and business logic.
#
#
# - I will try to provide "your code goes here" for as much of the enabling software as possible.

# %% [markdown]
# __REST Model__
#
# <img src="../images/L3_REST.jpeg">
#
# - We will need to support the following paths:
#     - /api/baseball/$<resource>$/$<id>$?fields="f1,f2, ..."
#     - /api/baseball/$<resource>$/metadata
#     - /api/baseball/$<resource>$?$<query>$&fields="f1, f2, ..."
#
#
# - Where
#     - $<resource>$ is one of players, batting, appearances
#     - $<id>$ is the primary key for the resource.

# %% [markdown]
# ## Relational and Common Database Concepts
#
# - Almost all database engines and models have the concepts of
#     - Objects that are some form of array of (name, value) pairs.
#     - Sets of similar or related objects.
#     - Four basic (CRUD) operations on a set
#         - CREATE a new object and add to a set.
#         - RETRIEVE an object in a set based on a criteria.
#         - UPDATE an object in a set, e.g. change the data in the object.
#         - DELETE an object from a set, specifying the object(s) by some criteria.
#
#
# - In the file systems/CSV model
#     - A set is a file, e.g. students.csv.
#     - Each object is a row in the file.
#     - The header row gives the names of each column.
#     - The CRUD processing involves writing a program that reads the file, changes the two-dimensional array and writing the file.
#         - CREATE: Append a row and save the file.
#         - RETRIEVE: Scan the table and apply me kind of IF statement.
#         - UPDATE: Change a row in the two dimensional array.
#         - DELETE: Remove a row from the array.
#
#
# - In REST/HTTP,
#     - The set is a collection of resources, e.g. /baseball/players.
#     - An individual entity has an identifier relative to the collection URL, e.g. /baseball/players/willite01
#     - There is not explicit metadata defining the fields and types.
#     - The CRUD operations are
#         - Create is POST /baseball/players { ... JSON ...}
#         - Retrieve is GET, e.g. GET /baseball/players/willite01, GET /baseball/players?nameLast=Williams&nameFirst="Ted"
#         - Update is PUT, e.g. PUT /baseball/players/willite01 { ... JSON ... }
#         - Delete is DELETE, e.g. DELETE /baseball/players/willite01
#
#
# - In the "pure" relational model
#     - A set is a _relation_.
#     - An object is a _row_ or _tuple_.
#     - There is no support for CREATE, UPDATE or DELETE.
#     - There is an _algebra_ and language for producing a new relation from existing relations that implements a form of RETRIEVE.
#
#
# - In SQL,
#     - A set is a _table_.
#     - An object is a _row_ or _tuple_.
#     - INSERT is the create operation.
#     - UPDATE is the delete operation.
#     - DELETE is the delete operation.
#     - SELECT is the statement that realizes the relational _algebra_.

# %% [markdown]
# ## Algebraic Query Language
#
# Reference: Ramkrishan and Gherke, section 2.4.
#
# ### Algebra
#
# "... abstract algebra (occasionally called modern algebra) is the study of algebraic structures." (https://en.wikipedia.org/wiki/Abstract_algebra)
#
# "In mathematics, and more specifically in abstract algebra, an algebraic structure is a set (called carrier set or underlying set) with one or more operations defined on it that satisfies a list of axioms." (https://en.wikipedia.org/wiki/Algebraic_structure)
#
# __Group is an Example__ (http://mathworld.wolfram.com/Group.html)
#
# "A group G is a finite or infinite set of elements together with a binary operation (called the group operation) that together satisfy the four fundamental properties of closure, associativity, the identity property, and the inverse property. The operation with respect to which a group is defined is often called the "group operation," and a set is said to be a group "under" this operation. Elements A, B, C, ... with binary operation between A and B denoted AB form a group if
#
# 1. Closure: If A and B are two elements in G, then the product AB is also in G.
#
# 2. Associativity: The defined multiplication is associative, i.e., for all A,B,C in G, (AB)C=A(BC).
#
# 3. Identity: There is an identity element I (a.k.a. 1, E, or e) such that IA=AI=A for every element A in G.
#
# 4. Inverse: There must be an inverse (a.k.a. reciprocal) of each element. Therefore, for each element A of G, the set contains an element B=A<sup>-1</sup> such that AA<sup>-1</sup>=A<sup>-1</sup>A=I.
#
# ### Why a Special Query Language? Why a Formal Language?
#
# - Computing has a formal mathemetical model.
#
# - Programming languages derive from the model and have their own formal definition.
#
# - Almost every time someone publishes a new language, my reaction is, "What? Why another language? Can't we just pick one, use it and get it right?"
#
#
# - Relational algebra is less powerful and expressive than Java, C, ... and other programming languages.
#
#
# - The simplicity and constrained capabilities is actually the core of the value, enabling
#     - Vastly simplified programming and supporting tools that yields increased productivity.
#     - Development of algorithms that process the data definitions and query statements to automatically produce optimal execution plans, which are better than what a programmer can directly code.
#
#
# - We will see these benefits in coming lectures.
#
#
# _Simple Tool Example_ that enables "citizen programmers" to maniuplate data.
#
# <img src="../images/ss_1.jpeg">
#
# <br><br>
# _Simple Tool Example_ for enabling business professionals to analyze and report on data.
# <img src="../images/quicksite.jpeg" width="85%">

# %% [markdown]
# ### Relational Algebra
#
# #### Overview
#
# - There are two notations or representations of the algebra:
#     - The original, formal theory.
#     - SQL
#
# __Original, Formal Notation__
#
# - The "set" in the relational algebra is the set of _relations_.
#
#
# - The operations are:
#     - Common set operations:
#         - Union: $\cup$
#         - Intersection: $\cap$
#         - Difference: $-$
#     - Projection: $\pi$
#     - Selection: $\sigma$
#     - Cartesian Product: $\times$
#     - Join: $\bowtie$
#     - Rename/Alias
#
#
# - The formal notation does not support create, update or delete. You could emulate the operations by
#     - Defining new relations containing the created, updated or delete tuples.
#     - Using $\cup$, $\cap$, $-$ on the original relation and created/deleted/updated tuple relation.
#
#
# __SQL Notation__
#
# - The "set" in the relational algebra is the catalog of _tables_.
#
# - The operations are:
#     - Common set operations:
#         - Union: UNION
#         - Intersection: INTERSECT
#         - Difference: EXCEPT
#     - Selection, Projection, Cartesian Product, Rename/Alias and Join are clauses within a SELECT statement.
#
#     ```SELECT <project clause> FROM <table> [JOIN <table> [ON <join condition]] WHERE <select condition>```
#     <br><br>
#
# - SQL supports additional operations, e.g
#     - GROUP BY
#     - ORDER BY

# %% [markdown]
# ### Overview
#
# Ramakrishnan and Gehrke, section 4.2
#
# - The operations on an Entity Set are:
#     - Common set operations:
#         - Union: $\cup$
#         - Intersection: $\cap$
#         - Difference: $-$
#     - Projection: $\pi$
#     - Selection: $\sigma$
#     - Cartesian Product: $\times$
#     - Join: $\bowtie$
#     - Rename/Alias
#
#
# - Union, Intersection, Difference are the normal set operations.
#
#
#
# - <span style="color: red;">Projection</span> produces a new relation that
#     - Has the same rows as the original table
#     - But only containing the requested columns/fields
#
#
# - <span style="color: red;">Selection</span> produces a new relation that
#     - Has the same columns as the original relation
#     - But only contains rows with column values matching a predicate.
#
#
# - <span style="color: red;">Projection, Selection and Keys are required for phase 1 of the web solution.</span>
#
#
# - We will cover the other operations in the next few lectures.

# %% [markdown]
# ### Selection
#
# - The selection operators are: $\lt, \gt, =, \ne, \ge, \le$
#
#
# - The selection operator is $\sigma$
#
#
# - $\sigma(Players)$ selects all of the rows/tuples in the player relation.
#
#
# - The predicate/condition is a "subscript," e.g.
#     - $\sigma$<sub>playerID=napolmi01</sub>$(Players)$ selects all players with _playerID=napolmi01_
#     - $\sigma$<sub>((nameLast=Williams)$\land(throws=L))\lor(birthYear\ne1914)$</sub>$(Players)$ selects all players with
#         - Last name williams who threw lefthanded
#         - Bith year now equal to 1914
#
#
# - This notation is a little clunky. You can think of the selection predicate being similiar to what goes in an _if()_ statement if you were looping through an array testing for a match.
#
#
# - __Note:__ We also needed $\sigma$ to implement GET /players/< playerid >.
#     - I glossed over this fact.
#     - There is nothing special about primary (or any keys) relative to selection syntanx.
#     - _Keys have a profound impact on performance and data integrity, however._

# %% [markdown]
# ### Projection
#
# - The projection operator is $\pi$
#
#
# - The requested columns are subscripts on the operator, e.g. $\pi$<sub>$nameLast,nameFirst,throws$</sub>$(Players)$ returns a table
#     - Containing the $nameLast, nameFirst, throws$ column values, in that order
#     - For all tuples in the $Players$ table.

# %% [markdown]
# ### This is an Algebra
#
# - The operators $\sigma$ and $\pi$ operate on relations/tables and produce relations/tables.
#
#
# - This means that you can combine them into complex combinations just like any algebra.
#
#
# - For example
#     - T<sub>$1$</sub>$ = \pi$<sub>$nameLast,nameFirst,throws$</sub>$($$\sigma$<sub>((nameLast=Williams)$\land(throws=L))\lor(birthYear\ne1914)$</sub>$(Players)$$)$
#     - T<sub>$2$</sub>$ = \sigma$<sub>((nameLast=Williams)$\land(throws=L))\lor(birthYear\ne1914)$</sub>$(\pi$<sub>$nameLast,nameFirst,throws$</sub>$(Players))$
#     - Are both valid algebraic statements
#     - __And__ $T$<sub>$1$</sub>$ = T$<sub>$1$</sub> because $\sigma$ and $\pi$ are commutative if $\pi$ returns all columns that $\sigma$ tests.

# %% [markdown]
# ### Keys
#
# - "_Data integrity_ is the maintenance of, and the assurance of the accuracy and consistency of, data over its entire life-cycle, and is a critical aspect to the design, implementation and usage of any system which stores, processes, or retrieves data.
#
#
# - _Relational (integrity) constraints_ are central to the value of relational databases.
#     - The database designer _declares (defines)_ integrity constraints.
#     - The database management system _rejects_ any _create, update_ or _delete_ operation that would result in a constraint violation.
#
#
# - _Key(s)_ is a core  _(integrity) constraint_ enforcing _data integrity._
#     - A _super key_ is a combination of columns with the property that now two rows have the same values for the fields of a super key.
#     - A _candidate key_ is a minimal _super key_, that is removing a column from the key definition means that the key no longer uniquely identifies a row.,
#     - The _primary key_ is a candidate key subjectively chosen as the "best key" for uniquely identifying the tuples.
#
#
# - You will some times here the term _functionally determines._
#     - Assume we have a relation $R(a,b,c,d,e)$.
#     - If $(a,b)$ is a key $k$, then
#     - The we can say that $k(a,b)$ _functionally determines_ $(c,d,e).$
#     - Given values $(x,y)$ for $(a,b)$ we can functionally return $(c,d,e).$ The function is
#
#     $\pi$<sub>$c,d,e$</sub>$(\sigma$<sub>$(a=x)\land(b=y)$</sub>$(R))$
#
#
# - Consider the following snapshot of the CS courses table
#
# <img src="../images/L4_courses.jpeg">
#
# <br>
# - The underlying relation $C$ has the following fields
#     - callNumber
#     - courseTitle
#     - courseNumber
#     - courseSection
#     - term
#     - year
#     - instructor
#     - days
#     - time
#
#
# - Two candidate keys are
#     - _(callNumber)_
#     - _(courseNumber, courseSection, year, semester)_

# %% [markdown]
# ### SQL SELECT
#
# #### Overview
#
# - MySQL [SELECT syntax](https://dev.mysql.com/doc/refman/5.7/en/select.html)
#     - Other relational database management systems are very similiar)
#     - And there is a core standard for the [SQL language.](https://www.iso.org/committee/45342/x/catalogue/p/1/u/0/w/0/d/0)
#
# ```
# SELECT
#     [ALL | DISTINCT | DISTINCTROW ]
#       [HIGH_PRIORITY]
#       [STRAIGHT_JOIN]
#       [SQL_SMALL_RESULT] [SQL_BIG_RESULT] [SQL_BUFFER_RESULT]
#       [SQL_CACHE | SQL_NO_CACHE] [SQL_CALC_FOUND_ROWS]
#     select_expr [, select_expr ...]
#     [FROM table_references
#       [PARTITION partition_list]
#     [WHERE where_condition]
#     [GROUP BY {col_name | expr | position}
#       [ASC | DESC], ... [WITH ROLLUP]]
#     [HAVING where_condition]
#     [ORDER BY {col_name | expr | position}
#       [ASC | DESC], ...]
#     [LIMIT {[offset,] row_count | row_count OFFSET offset}]
#     [PROCEDURE procedure_name(argument_list)]
#     [INTO OUTFILE 'file_name'
#         [CHARACTER SET charset_name]
#         export_options
#       | INTO DUMPFILE 'file_name'
#       | INTO var_name [, var_name]]
#     [FOR UPDATE | LOCK IN SHARE MODE]]
# ```
#
# - The SELECT statement is complex because it is the implementation foundation for
#     - Selection
#     - Projection
#     - Join
#     - Cross-product
#     - Alias/renaming.
#
#
# - The easiest way to get started is with examples and practice.
#
# #### GET by Primary Key

# %%
import pymysql.cursors
import json


def connect():
    connection = pymysql.connect(host='localhost',
                                 user='dbuser',
                                 password='dbuser',
                                 db='lahman2016',
                                 charset='utf8mb4',
                                 cursorclass=pymysql.cursors.DictCursor)
    return connection

def disconnect(c):
    c.close()

def pretty_print(r):
    r = json.dumps(r, indent=4, sort_keys=True)
    print("Result = ", r)

try:
    print("Get by primary key.")
    sql1 = "SELECT nameLast FROM Master WHERE playerID = 'napolmi01';"
    print("SQL statement = ", sql1)
    
    connection = connect()

    with connection.cursor() as cursor:
        # Execute the SQL statement.
        print("Connected.")
        cursor.execute(sql1)
        
        # We know that this is a primary key. We only need to fetch ONE row.
        result = cursor.fetchone()
        
        pretty_print(result)
        
except:  
    print("Something bad happened.")
finally:
    disconnect(connection)
    print("Disconnected")
# Out:
# Get by primary key.
# SQL statement =  SELECT nameLast FROM Master WHERE playerID = 'napolmi01';
# Connected.
# Result =  {
#     "nameLast": "Napoli"
# }
# Disconnected

# %%
try:
    print("Get by primary key.")
    sql2 = "SELECT nameLast FROM Batting WHERE yearID = " 
    sql2 = sql2 + "%s AND playerID=%s and stint=%s;"
    print("SQL statement = ", sql2)
    
    connection = connect()

    with connection.cursor() as cursor:
        # Execute the SQL statement.
        print("Connected.")
        cursor.execute(sql2,('1959','willite01', 1))
        
        # We know that this is a primary key. We only need to fetch ONE row.
        result = cursor.fetchone()
        
        pretty_print(result)
        
except:  
    print("Something bad happened.")
finally:
    disconnect(connection)
    print("Disconnected")
# Out:
# Get by primary key.
# SQL statement =  SELECT nameLast FROM Batting WHERE yearID = %s AND playerID=%s and stint=%s;
# Connected.
# Something bad happened.
# Disconnected

# %% [markdown]
# - Database connectors usually support _parameterized query statements._
#     - SQL string with %s in various places.
#     - (v1, ..., vn) to insert into the SQL statement sent to the database.
#     - Generally is the preferred approach and also support [_prepared statements_](https://dev.mysql.com/doc/connector-python/en/connector-python-api-mysqlcursorprepared.html), which most databases support.

# %% [markdown]
# #### More General SELECT
#
# ##### Find All Players with Last name Williams and Bats with One Hand and Throws with Another, and Who Was Born before 1950

# %%
import pymysql.cursors
import json


def connect():
    connection = pymysql.connect(host='localhost',
                                 user='dbuser',
                                 password='dbuser',
                                 db='lahman2016',
                                 charset='utf8mb4',
                                 cursorclass=pymysql.cursors.DictCursor)
    return connection

def disconnect(c):
    c.close()

def pretty_print(r):
    r = json.dumps(r, indent=4, sort_keys=True)
    print("Result = ", r)
    
def execute_query(q):

    try:
        print("Executing query = ",q )

        connection = connect()

        with connection.cursor() as cursor:
            # Execute the SQL statement.
            print("Connected.")
            cursor.execute(q)

            # We know that this is a primary key. We only need to fetch ONE row.
            result = cursor.fetchall()
            return result;
    except:  
        print("Something bad happened.")
        return ([ { "Error ": "Error" }])
    finally:
        disconnect(connection)
        print("Disconnected")
        
        
q = "SELECT * FROM Master WHERE "
q = q + "nameLast='Williams' and NOT ( bats = throws ) "
q = q + "AND birthYear < '1950';"
r = execute_query(q)
pretty_print(r)
# Out:
# Executing query =  SELECT * FROM Master WHERE nameLast='Williams' and NOT ( bats = throws ) AND birthYear < '1950';
# Connected.
# Disconnected
# Result =  [
#     {
#         "bats": "R",
#         "bbrefID": "williac01",
#         "birthCity": "Montclair",
#         "birthCountry": "USA",
#         "birthDay": 18,
#         "birthMonth": 3,
#         "birthState": "NJ",
#         "birthYear": 1917,
#         "deathCity": "Fort Myers",
#         "deathCountry": "USA",
#         "deathDay": "16",
#         "deathMonth": "9",
#         "deathState": "FL",
#         "deathYear": "1999",
#         "debut": "1940-07-15",
#         "finalGame": "1946-04-22",
#         "height": 74,
#         "nameFirst": "Ace",
#         "nameGiven": "Robert Fulton",
#         "nameLast": "Williams",
#         "playerID": "williac01",
#         "retroID": "willa103",
#         "throws": "L",
#         "weight": 174
#     },
#     {
#         "bats": "L",
#         "bbrefID": "williar01",
#         "birthCity": "Somerville",
#         "birthCountry": "USA",
#         "birthDay": 24,
#         "birthMonth": 8,
#         "birthState": "MA",
#         "birthYear": 1877,
#         "deathCity": "Arlington",
#         "deathCountry": "USA",
#         "deathDay": "16",
#         "deathMonth": "5",
#         "deathState": "VA",
#         "deathYear": "1941",
#         "debut": "1902-05-07",
#         "finalGame": "1902-09-01",
#         "height": 0,
#         "nameFirst": "Art",
#         "nameGiven": "Arthur Frank",
#         "nameLast": "Williams",
#         "playerID": "williar01",
#         "retroID": "willa104",
#         "throws": "R",
#         "weight": 0
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willibi01",
#         "birthCity": "Whistler",
#         "birthCountry": "USA",
#         "birthDay": 15,
#         "birthMonth": 6,
#         "birthState": "AL",
#         "birthYear": 1938,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1959-08-06",
#         "finalGame": "1976-10-02",
#         "height": 73,
#         "nameFirst": "Billy",
#         "nameGiven": "Billy Leo",
#         "nameLast": "Williams",
#         "playerID": "willibi01",
#         "retroID": "willb104",
#         "throws": "R",
#         "weight": 175
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willibi02",
#         "birthCity": "Newberry",
#         "birthCountry": "USA",
#         "birthDay": 13,
#         "birthMonth": 6,
#         "birthState": "SC",
#         "birthYear": 1932,
#         "deathCity": "Berkeley",
#         "deathCountry": "USA",
#         "deathDay": "11",
#         "deathMonth": "6",
#         "deathState": "CA",
#         "deathYear": "2013",
#         "debut": "1969-08-15",
#         "finalGame": "1969-08-20",
#         "height": 75,
#         "nameFirst": "Billy",
#         "nameGiven": "William",
#         "nameLast": "Williams",
#         "playerID": "willibi02",
#         "retroID": "willb102",
#         "throws": "R",
#         "weight": 195
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willida02",
#         "birthCity": "Scranton",
#         "birthCountry": "USA",
#         "birthDay": 7,
#         "birthMonth": 2,
#         "birthState": "PA",
#         "birthYear": 1881,
#         "deathCity": "Hot Springs",
#         "deathCountry": "USA",
#         "deathDay": "25",
#         "deathMonth": "4",
#         "deathState": "AR",
#         "deathYear": "1918",
#         "debut": "1902-07-02",
#         "finalGame": "1902-08-03",
#         "height": 71,
#         "nameFirst": "Dave",
#         "nameGiven": "David Owen",
#         "nameLast": "Williams",
#         "playerID": "willida02",
#         "retroID": "willd103",
#         "throws": "L",
#         "weight": 167
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willide01",
#         "birthCity": "Portland",
#         "birthCountry": "USA",
#         "birthDay": 13,
#         "birthMonth": 12,
#         "birthState": "OR",
#         "birthYear": 1896,
#         "deathCity": "San Clemente",
#         "deathCountry": "USA",
#         "deathDay": "23",
#         "deathMonth": "3",
#         "deathState": "CA",
#         "deathYear": "1929",
#         "debut": "1921-04-15",
#         "finalGame": "1928-07-18",
#         "height": 68,
#         "nameFirst": "Denny",
#         "nameGiven": "Evon Daniel",
#         "nameLast": "Williams",
#         "playerID": "willide01",
#         "retroID": "willd105",
#         "throws": "R",
#         "weight": 150
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willike01",
#         "birthCity": "Grants Pass",
#         "birthCountry": "USA",
#         "birthDay": 28,
#         "birthMonth": 6,
#         "birthState": "OR",
#         "birthYear": 1890,
#         "deathCity": "Grants Pass",
#         "deathCountry": "USA",
#         "deathDay": "22",
#         "deathMonth": "1",
#         "deathState": "OR",
#         "deathYear": "1959",
#         "debut": "1915-07-14",
#         "finalGame": "1929-08-10",
#         "height": 72,
#         "nameFirst": "Ken",
#         "nameGiven": "Kenneth Roy",
#         "nameLast": "Williams",
#         "playerID": "willike01",
#         "retroID": "willk101",
#         "throws": "R",
#         "weight": 170
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willile01",
#         "birthCity": "Aurora",
#         "birthCountry": "USA",
#         "birthDay": 9,
#         "birthMonth": 3,
#         "birthState": "MO",
#         "birthYear": 1893,
#         "deathCity": "Laguna Beach",
#         "deathCountry": "USA",
#         "deathDay": "4",
#         "deathMonth": "11",
#         "deathState": "CA",
#         "deathYear": "1959",
#         "debut": "1913-09-17",
#         "finalGame": "1920-09-25",
#         "height": 69,
#         "nameFirst": "Lefty",
#         "nameGiven": "Claude Preston",
#         "nameLast": "Williams",
#         "playerID": "willile01",
#         "retroID": "willl104",
#         "throws": "L",
#         "weight": 160
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willipo01",
#         "birthCity": "Bowdoinham",
#         "birthCountry": "USA",
#         "birthDay": 19,
#         "birthMonth": 5,
#         "birthState": "ME",
#         "birthYear": 1874,
#         "deathCity": "Topsham",
#         "deathCountry": "USA",
#         "deathDay": "4",
#         "deathMonth": "8",
#         "deathState": "ME",
#         "deathYear": "1959",
#         "debut": "1898-09-14",
#         "finalGame": "1903-09-15",
#         "height": 71,
#         "nameFirst": "Pop",
#         "nameGiven": "Walter Merrill",
#         "nameLast": "Williams",
#         "playerID": "willipo01",
#         "retroID": "willp101",
#         "throws": "L",
#         "weight": 190
#     },
#     {
#         "bats": "L",
#         "bbrefID": "williri02",
#         "birthCity": "Santa Cruz",
#         "birthCountry": "USA",
#         "birthDay": 18,
#         "birthMonth": 12,
#         "birthState": "CA",
#         "birthYear": 1893,
#         "deathCity": "Cottonwood",
#         "deathCountry": "USA",
#         "deathDay": "24",
#         "deathMonth": "4",
#         "deathState": "AZ",
#         "deathYear": "1966",
#         "debut": "1914-10-08",
#         "finalGame": "1914-10-10",
#         "height": 0,
#         "nameFirst": "Rinaldo",
#         "nameGiven": "Rinaldo Louis",
#         "nameLast": "Williams",
#         "playerID": "williri02",
#         "retroID": "willr103",
#         "throws": "R",
#         "weight": 0
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willist01",
#         "birthCity": "Cascade",
#         "birthCountry": "USA",
#         "birthDay": 31,
#         "birthMonth": 1,
#         "birthState": "MT",
#         "birthYear": 1892,
#         "deathCity": "Deer River",
#         "deathCountry": "USA",
#         "deathDay": "29",
#         "deathMonth": "6",
#         "deathState": "MN",
#         "deathYear": "1979",
#         "debut": "1914-07-12",
#         "finalGame": "1916-10-01",
#         "height": 71,
#         "nameFirst": "Steamboat",
#         "nameGiven": "Rees Gephardt",
#         "nameLast": "Williams",
#         "playerID": "willist01",
#         "retroID": "wills101",
#         "throws": "R",
#         "weight": 170
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willite01",
#         "birthCity": "San Diego",
#         "birthCountry": "USA",
#         "birthDay": 30,
#         "birthMonth": 8,
#         "birthState": "CA",
#         "birthYear": 1918,
#         "deathCity": "Inverness",
#         "deathCountry": "USA",
#         "deathDay": "5",
#         "deathMonth": "7",
#         "deathState": "FL",
#         "deathYear": "2002",
#         "debut": "1939-04-20",
#         "finalGame": "1960-09-28",
#         "height": 75,
#         "nameFirst": "Ted",
#         "nameGiven": "Theodore Samuel",
#         "nameLast": "Williams",
#         "playerID": "willite01",
#         "retroID": "willt103",
#         "throws": "R",
#         "weight": 205
#     }
# ]

# %% [markdown]
# #### Where Clause

# %% [markdown]
# __Comments__
#
#
# - There [MySQL WHERE condition syntax](https://dev.mysql.com/doc/refman/5.7/en/expressions.html) (which is remarkably unhelpful) is
#
# ```
# expr:
#     expr OR expr
#   | expr || expr
#   | expr XOR expr
#   | expr AND expr
#   | expr && expr
#   | NOT expr
#   | ! expr
#   | boolean_primary IS [NOT] {TRUE | FALSE | UNKNOWN}
#   | boolean_primary
#
# boolean_primary:
#     boolean_primary IS [NOT] NULL
#   | boolean_primary <=> predicate
#   | boolean_primary comparison_operator predicate
#   | boolean_primary comparison_operator {ALL | ANY} (subquery)
#   | predicate
#
# comparison_operator: = | >= | > | <= | < | <> | !=
#
# predicate:
#     bit_expr [NOT] IN (subquery)
#   | bit_expr [NOT] IN (expr [, expr] ...)
#   | bit_expr [NOT] BETWEEN bit_expr AND predicate
#   | bit_expr SOUNDS LIKE bit_expr
#   | bit_expr [NOT] LIKE simple_expr [ESCAPE simple_expr]
#   | bit_expr [NOT] REGEXP bit_expr
#   | bit_expr
#
# bit_expr:
#     bit_expr | bit_expr
#   | bit_expr & bit_expr
#   | bit_expr << bit_expr
#   | bit_expr >> bit_expr
#   | bit_expr + bit_expr
#   | bit_expr - bit_expr
#   | bit_expr * bit_expr
#   | bit_expr / bit_expr
#   | bit_expr DIV bit_expr
#   | bit_expr MOD bit_expr
#   | bit_expr % bit_expr
#   | bit_expr ^ bit_expr
#   | bit_expr + interval_expr
#   | bit_expr - interval_expr
#   | simple_expr
#
# simple_expr:
#     literal
#   | identifier
#   | function_call
#   | simple_expr COLLATE collation_name
#   | param_marker
#   | variable
#   | simple_expr || simple_expr
#   | + simple_expr
#   | - simple_expr
#   | ~ simple_expr
#   | ! simple_expr
#   | BINARY simple_expr
#   | (expr [, expr] ...)
#   | ROW (expr, expr [, expr] ...)
#   | (subquery)
#   | EXISTS (subquery)
#   | {identifier expr}
#   | match_expr
#   | case_expr
#   | interval_expr
# ```
#
#
# - All RDBs have similar and approximately equivalent functionality and syntax.
#
#
# - "How do you get to be good at this? The same way you get to Carnegie Hall. __Practice.__"
#     - There are some good online tutorials.
#     - We will go through a lot of examples in class.
#     - CAs and I will help if you have trouble on homework or take home exams.

# %% [markdown]
# - The SQL statement provides an overview of the condition syntax
#
# ```
# SELECT * FROM Master WHERE nameLast='Williams' and NOT ( bats = throws ) AND  (deathYear - birthYear) > 80;
# ```
#
# - The basic element is $term$  $operand$  $term$ or $operand(column)$
#     - A term is a literal, column name or computed expression.
#     - The operands are
#         - $\lt$, $\leq$, $=$, $\gt$, $\ge$, $<>$ and have the obvious meanings.
#         - $LIKE$ returns true if the string operand matches a [pattern.](https://dev.mysql.com/doc/refman/5.7/en/pattern-matching.html)
#         - $term$ $BETWEEN$ $operand$ AND $OPERAND$ returns true of the $term$ is in the range.
#     - There are additional operands and different RDBS have different extensions and modifications.

# %%
q = "SELECT * FROM Master WHERE nameLast LIKE 'willi%';"
r = execute_query(q)
pretty_print(r)
# Out:
# Executing query =  SELECT * FROM Master WHERE nameLast LIKE 'willi%';
# Connected.
# Disconnected
# Result =  [
#     {
#         "bats": "R",
#         "bbrefID": "williac01",
#         "birthCity": "Montclair",
#         "birthCountry": "USA",
#         "birthDay": 18,
#         "birthMonth": 3,
#         "birthState": "NJ",
#         "birthYear": 1917,
#         "deathCity": "Fort Myers",
#         "deathCountry": "USA",
#         "deathDay": "16",
#         "deathMonth": "9",
#         "deathState": "FL",
#         "deathYear": "1999",
#         "debut": "1940-07-15",
#         "finalGame": "1946-04-22",
#         "height": 74,
#         "nameFirst": "Ace",
#         "nameGiven": "Robert Fulton",
#         "nameLast": "Williams",
#         "playerID": "williac01",
#         "retroID": "willa103",
#         "throws": "L",
#         "weight": 174
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willial02",
#         "birthCity": "Valhermosa Springs",
#         "birthCountry": "USA",
#         "birthDay": 11,
#         "birthMonth": 5,
#         "birthState": "AL",
#         "birthYear": 1914,
#         "deathCity": "Groves",
#         "deathCountry": "USA",
#         "deathDay": "19",
#         "deathMonth": "7",
#         "deathState": "TX",
#         "deathYear": "1969",
#         "debut": "1937-04-19",
#         "finalGame": "1938-09-04",
#         "height": 75,
#         "nameFirst": "Al",
#         "nameGiven": "Almon Edward",
#         "nameLast": "Williams",
#         "playerID": "willial02",
#         "retroID": "willa101",
#         "throws": "R",
#         "weight": 200
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willial03",
#         "birthCity": "Pearl Lagoon",
#         "birthCountry": "Nicaragua",
#         "birthDay": 6,
#         "birthMonth": 5,
#         "birthState": "Atlantico Sur",
#         "birthYear": 1954,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1980-05-07",
#         "finalGame": "1984-09-26",
#         "height": 76,
#         "nameFirst": "Albert",
#         "nameGiven": "Albert Hamilton",
#         "nameLast": "Williams",
#         "playerID": "willial03",
#         "retroID": "willa001",
#         "throws": "R",
#         "weight": 190
#     },
#     {
#         "bats": "L",
#         "bbrefID": "williar01",
#         "birthCity": "Somerville",
#         "birthCountry": "USA",
#         "birthDay": 24,
#         "birthMonth": 8,
#         "birthState": "MA",
#         "birthYear": 1877,
#         "deathCity": "Arlington",
#         "deathCountry": "USA",
#         "deathDay": "16",
#         "deathMonth": "5",
#         "deathState": "VA",
#         "deathYear": "1941",
#         "debut": "1902-05-07",
#         "finalGame": "1902-09-01",
#         "height": 0,
#         "nameFirst": "Art",
#         "nameGiven": "Arthur Frank",
#         "nameLast": "Williams",
#         "playerID": "williar01",
#         "retroID": "willa104",
#         "throws": "R",
#         "weight": 0
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willibe01",
#         "birthCity": "Alameda",
#         "birthCountry": "USA",
#         "birthDay": 8,
#         "birthMonth": 10,
#         "birthState": "CA",
#         "birthYear": 1948,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1970-09-07",
#         "finalGame": "1974-05-12",
#         "height": 73,
#         "nameFirst": "Bernie",
#         "nameGiven": "Bernard",
#         "nameLast": "Williams",
#         "playerID": "willibe01",
#         "retroID": "willb105",
#         "throws": "R",
#         "weight": 175
#     },
#     {
#         "bats": "B",
#         "bbrefID": "willibe02",
#         "birthCity": "San Juan",
#         "birthCountry": "P.R.",
#         "birthDay": 13,
#         "birthMonth": 9,
#         "birthState": "",
#         "birthYear": 1968,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1991-07-07",
#         "finalGame": "2006-10-01",
#         "height": 74,
#         "nameFirst": "Bernie",
#         "nameGiven": "Bernabe",
#         "nameLast": "Williams",
#         "playerID": "willibe02",
#         "retroID": "willb002",
#         "throws": "R",
#         "weight": 180
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willibi01",
#         "birthCity": "Whistler",
#         "birthCountry": "USA",
#         "birthDay": 15,
#         "birthMonth": 6,
#         "birthState": "AL",
#         "birthYear": 1938,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1959-08-06",
#         "finalGame": "1976-10-02",
#         "height": 73,
#         "nameFirst": "Billy",
#         "nameGiven": "Billy Leo",
#         "nameLast": "Williams",
#         "playerID": "willibi01",
#         "retroID": "willb104",
#         "throws": "R",
#         "weight": 175
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willibi02",
#         "birthCity": "Newberry",
#         "birthCountry": "USA",
#         "birthDay": 13,
#         "birthMonth": 6,
#         "birthState": "SC",
#         "birthYear": 1932,
#         "deathCity": "Berkeley",
#         "deathCountry": "USA",
#         "deathDay": "11",
#         "deathMonth": "6",
#         "deathState": "CA",
#         "deathYear": "2013",
#         "debut": "1969-08-15",
#         "finalGame": "1969-08-20",
#         "height": 75,
#         "nameFirst": "Billy",
#         "nameGiven": "William",
#         "nameLast": "Williams",
#         "playerID": "willibi02",
#         "retroID": "willb102",
#         "throws": "R",
#         "weight": 195
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willibo01",
#         "birthCity": "Monday",
#         "birthCountry": "USA",
#         "birthDay": 27,
#         "birthMonth": 4,
#         "birthState": "OH",
#         "birthYear": 1884,
#         "deathCity": "Nelsonville",
#         "deathCountry": "USA",
#         "deathDay": "6",
#         "deathMonth": "8",
#         "deathState": "OH",
#         "deathYear": "1962",
#         "debut": "1911-07-03",
#         "finalGame": "1913-09-30",
#         "height": 72,
#         "nameFirst": "Bob",
#         "nameGiven": "Robert Elias",
#         "nameLast": "Williams",
#         "playerID": "willibo01",
#         "retroID": "willb103",
#         "throws": "R",
#         "weight": 190
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willibr01",
#         "birthCity": "Lancaster",
#         "birthCountry": "USA",
#         "birthDay": 15,
#         "birthMonth": 2,
#         "birthState": "SC",
#         "birthYear": 1969,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1991-09-16",
#         "finalGame": "2000-07-05",
#         "height": 75,
#         "nameFirst": "Brian",
#         "nameGiven": "Brian O'Neal",
#         "nameLast": "Williams",
#         "playerID": "willibr01",
#         "retroID": "willb001",
#         "throws": "R",
#         "weight": 205
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willich01",
#         "birthCity": "Flushing",
#         "birthCountry": "USA",
#         "birthDay": 11,
#         "birthMonth": 10,
#         "birthState": "NY",
#         "birthYear": 1947,
#         "deathCity": "Port Orange",
#         "deathCountry": "USA",
#         "deathDay": "27",
#         "deathMonth": "1",
#         "deathState": "FL",
#         "deathYear": "2015",
#         "debut": "1971-04-23",
#         "finalGame": "1978-09-11",
#         "height": 74,
#         "nameFirst": "Charlie",
#         "nameGiven": "Charles Prosek",
#         "nameLast": "Williams",
#         "playerID": "willich01",
#         "retroID": "willc101",
#         "throws": "R",
#         "weight": 200
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willicy01",
#         "birthCity": "Wadena",
#         "birthCountry": "USA",
#         "birthDay": 21,
#         "birthMonth": 12,
#         "birthState": "IN",
#         "birthYear": 1887,
#         "deathCity": "Eagle River",
#         "deathCountry": "USA",
#         "deathDay": "23",
#         "deathMonth": "4",
#         "deathState": "WI",
#         "deathYear": "1974",
#         "debut": "1912-07-18",
#         "finalGame": "1930-09-22",
#         "height": 74,
#         "nameFirst": "Cy",
#         "nameGiven": "Fred",
#         "nameLast": "Williams",
#         "playerID": "willicy01",
#         "retroID": "willc103",
#         "throws": "L",
#         "weight": 180
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willida01",
#         "birthCity": "Ludlow",
#         "birthCountry": "USA",
#         "birthDay": 6,
#         "birthMonth": 10,
#         "birthState": "KY",
#         "birthYear": 1855,
#         "deathCity": "Covington",
#         "deathCountry": "USA",
#         "deathDay": "22",
#         "deathMonth": "10",
#         "deathState": "KY",
#         "deathYear": "1939",
#         "debut": "1876-08-12",
#         "finalGame": "1876-09-09",
#         "height": 69,
#         "nameFirst": "Dale",
#         "nameGiven": "Elisha Alphonso",
#         "nameLast": "Williams",
#         "playerID": "willida01",
#         "retroID": "willd106",
#         "throws": "R",
#         "weight": 175
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willida02",
#         "birthCity": "Scranton",
#         "birthCountry": "USA",
#         "birthDay": 7,
#         "birthMonth": 2,
#         "birthState": "PA",
#         "birthYear": 1881,
#         "deathCity": "Hot Springs",
#         "deathCountry": "USA",
#         "deathDay": "25",
#         "deathMonth": "4",
#         "deathState": "AR",
#         "deathYear": "1918",
#         "debut": "1902-07-02",
#         "finalGame": "1902-08-03",
#         "height": 71,
#         "nameFirst": "Dave",
#         "nameGiven": "David Owen",
#         "nameLast": "Williams",
#         "playerID": "willida02",
#         "retroID": "willd103",
#         "throws": "L",
#         "weight": 167
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willida03",
#         "birthCity": "Dallas",
#         "birthCountry": "USA",
#         "birthDay": 2,
#         "birthMonth": 11,
#         "birthState": "TX",
#         "birthYear": 1927,
#         "deathCity": "Farmers Branch",
#         "deathCountry": "USA",
#         "deathDay": "17",
#         "deathMonth": "8",
#         "deathState": "TX",
#         "deathYear": "2009",
#         "debut": "1949-09-16",
#         "finalGame": "1955-07-31",
#         "height": 70,
#         "nameFirst": "Davey",
#         "nameGiven": "David Carlous",
#         "nameLast": "Williams",
#         "playerID": "willida03",
#         "retroID": "willd102",
#         "throws": "R",
#         "weight": 160
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willida05",
#         "birthCity": "Brooklyn",
#         "birthCountry": "USA",
#         "birthDay": 28,
#         "birthMonth": 2,
#         "birthState": "NY",
#         "birthYear": 1958,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1981-09-19",
#         "finalGame": "1983-10-02",
#         "height": 71,
#         "nameFirst": "Dallas",
#         "nameGiven": "Dallas McKinley",
#         "nameLast": "Williams",
#         "playerID": "willida05",
#         "retroID": "willd101",
#         "throws": "L",
#         "weight": 165
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willida06",
#         "birthCity": "Weirton",
#         "birthCountry": "USA",
#         "birthDay": 20,
#         "birthMonth": 3,
#         "birthState": "WV",
#         "birthYear": 1963,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1989-06-19",
#         "finalGame": "1989-07-02",
#         "height": 70,
#         "nameFirst": "Dana",
#         "nameGiven": "Dana Lamont",
#         "nameLast": "Williams",
#         "playerID": "willida06",
#         "retroID": "willd001",
#         "throws": "R",
#         "weight": 170
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willida07",
#         "birthCity": "Anchorage",
#         "birthCountry": "USA",
#         "birthDay": 12,
#         "birthMonth": 3,
#         "birthState": "AK",
#         "birthYear": 1979,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "2001-06-06",
#         "finalGame": "2007-09-24",
#         "height": 75,
#         "nameFirst": "David",
#         "nameGiven": "David Aaron",
#         "nameLast": "Williams",
#         "playerID": "willida07",
#         "retroID": "willd002",
#         "throws": "L",
#         "weight": 215
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willide01",
#         "birthCity": "Portland",
#         "birthCountry": "USA",
#         "birthDay": 13,
#         "birthMonth": 12,
#         "birthState": "OR",
#         "birthYear": 1896,
#         "deathCity": "San Clemente",
#         "deathCountry": "USA",
#         "deathDay": "23",
#         "deathMonth": "3",
#         "deathState": "CA",
#         "deathYear": "1929",
#         "debut": "1921-04-15",
#         "finalGame": "1928-07-18",
#         "height": 68,
#         "nameFirst": "Denny",
#         "nameGiven": "Evon Daniel",
#         "nameLast": "Williams",
#         "playerID": "willide01",
#         "retroID": "willd105",
#         "throws": "R",
#         "weight": 150
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willide02",
#         "birthCity": "Durham",
#         "birthCountry": "USA",
#         "birthDay": 5,
#         "birthMonth": 2,
#         "birthState": "NC",
#         "birthYear": 1916,
#         "deathCity": "Williston",
#         "deathCountry": "USA",
#         "deathDay": "19",
#         "deathMonth": "3",
#         "deathState": "ND",
#         "deathYear": "2000",
#         "debut": "1944-06-28",
#         "finalGame": "1948-09-26",
#         "height": 72,
#         "nameFirst": "Dewey",
#         "nameGiven": "Dewey Edgar",
#         "nameLast": "Williams",
#         "playerID": "willide02",
#         "retroID": "willd109",
#         "throws": "R",
#         "weight": 160
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willidi01",
#         "birthCity": "Greenbrier",
#         "birthCountry": "USA",
#         "birthDay": 19,
#         "birthMonth": 1,
#         "birthState": "AR",
#         "birthYear": 1910,
#         "deathCity": "Searcy",
#         "deathCountry": "USA",
#         "deathDay": "2",
#         "deathMonth": "4",
#         "deathState": "AR",
#         "deathYear": "1992",
#         "debut": "1930-04-27",
#         "finalGame": "1935-09-29",
#         "height": 71,
#         "nameFirst": "Dib",
#         "nameGiven": "Edwin Dibrell",
#         "nameLast": "Williams",
#         "playerID": "willidi01",
#         "retroID": "willd107",
#         "throws": "R",
#         "weight": 175
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willidi02",
#         "birthCity": "St. Louis",
#         "birthCountry": "USA",
#         "birthDay": 7,
#         "birthMonth": 5,
#         "birthState": "MO",
#         "birthYear": 1929,
#         "deathCity": "Las Vegas",
#         "deathCountry": "USA",
#         "deathDay": "7",
#         "deathMonth": "7",
#         "deathState": "NV",
#         "deathYear": "2011",
#         "debut": "1951-06-10",
#         "finalGame": "1964-10-01",
#         "height": 72,
#         "nameFirst": "Dick",
#         "nameGiven": "Richard Hirschfeld",
#         "nameLast": "Williams",
#         "playerID": "willidi02",
#         "retroID": "willd104",
#         "throws": "R",
#         "weight": 190
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willido01",
#         "birthCity": "Floyd",
#         "birthCountry": "USA",
#         "birthDay": 14,
#         "birthMonth": 9,
#         "birthState": "VA",
#         "birthYear": 1931,
#         "deathCity": "Floyd",
#         "deathCountry": "USA",
#         "deathDay": "16",
#         "deathMonth": "10",
#         "deathState": "VA",
#         "deathYear": "2011",
#         "debut": "1958-09-12",
#         "finalGame": "1962-08-23",
#         "height": 74,
#         "nameFirst": "Don",
#         "nameGiven": "Don Fred",
#         "nameLast": "Williams",
#         "playerID": "willido01",
#         "retroID": "willd108",
#         "throws": "R",
#         "weight": 180
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willido02",
#         "birthCity": "Los Angeles",
#         "birthCountry": "USA",
#         "birthDay": 2,
#         "birthMonth": 9,
#         "birthState": "CA",
#         "birthYear": 1935,
#         "deathCity": "La Jolla",
#         "deathCountry": "USA",
#         "deathDay": "20",
#         "deathMonth": "12",
#         "deathState": "CA",
#         "deathYear": "1991",
#         "debut": "1963-08-04",
#         "finalGame": "1963-08-17",
#         "height": 77,
#         "nameFirst": "Don",
#         "nameGiven": "Donald Reid",
#         "nameLast": "Williams",
#         "playerID": "willido02",
#         "retroID": "willd110",
#         "throws": "R",
#         "weight": 218
#     },
#     {
#         "bats": "R",
#         "bbrefID": "williea01",
#         "birthCity": "Cumberland Gap",
#         "birthCountry": "USA",
#         "birthDay": 27,
#         "birthMonth": 1,
#         "birthState": "TN",
#         "birthYear": 1903,
#         "deathCity": "Knoxville",
#         "deathCountry": "USA",
#         "deathDay": "10",
#         "deathMonth": "3",
#         "deathState": "TN",
#         "deathYear": "1958",
#         "debut": "1928-05-27",
#         "finalGame": "1928-06-02",
#         "height": 72,
#         "nameFirst": "Earl",
#         "nameGiven": "Earl Baxter",
#         "nameLast": "Williams",
#         "playerID": "williea01",
#         "retroID": "wille102",
#         "throws": "R",
#         "weight": 185
#     },
#     {
#         "bats": "R",
#         "bbrefID": "williea02",
#         "birthCity": "Newark",
#         "birthCountry": "USA",
#         "birthDay": 14,
#         "birthMonth": 7,
#         "birthState": "NJ",
#         "birthYear": 1948,
#         "deathCity": "Somerset",
#         "deathCountry": "USA",
#         "deathDay": "28",
#         "deathMonth": "1",
#         "deathState": "NJ",
#         "deathYear": "2013",
#         "debut": "1970-09-13",
#         "finalGame": "1977-09-25",
#         "height": 75,
#         "nameFirst": "Earl",
#         "nameGiven": "Earl Craig",
#         "nameLast": "Williams",
#         "playerID": "williea02",
#         "retroID": "wille101",
#         "throws": "R",
#         "weight": 215
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willied01",
#         "birthCity": "Shreveport",
#         "birthCountry": "USA",
#         "birthDay": 1,
#         "birthMonth": 11,
#         "birthState": "LA",
#         "birthYear": 1964,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1986-04-18",
#         "finalGame": "1998-05-27",
#         "height": 72,
#         "nameFirst": "Eddie",
#         "nameGiven": "Edward Laquan",
#         "nameLast": "Williams",
#         "playerID": "willied01",
#         "retroID": "wille001",
#         "throws": "R",
#         "weight": 175
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willifr01",
#         "birthCity": "Seattle",
#         "birthCountry": "USA",
#         "birthDay": 13,
#         "birthMonth": 2,
#         "birthState": "WA",
#         "birthYear": 1958,
#         "deathCity": "Victoria",
#         "deathCountry": "CAN",
#         "deathDay": "9",
#         "deathMonth": "1",
#         "deathState": "BC",
#         "deathYear": "2009",
#         "debut": "1984-04-05",
#         "finalGame": "1989-09-27",
#         "height": 73,
#         "nameFirst": "Frank",
#         "nameGiven": "Frank Lee",
#         "nameLast": "Williams",
#         "playerID": "willifr01",
#         "retroID": "willf001",
#         "throws": "R",
#         "weight": 180
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willige01",
#         "birthCity": "Detroit",
#         "birthCountry": "USA",
#         "birthDay": 23,
#         "birthMonth": 10,
#         "birthState": "MI",
#         "birthYear": 1939,
#         "deathCity": "Detroit",
#         "deathCountry": "USA",
#         "deathDay": "14",
#         "deathMonth": "5",
#         "deathState": "MI",
#         "deathYear": "2009",
#         "debut": "1961-07-16",
#         "finalGame": "1964-07-05",
#         "height": 71,
#         "nameFirst": "George",
#         "nameGiven": "George",
#         "nameLast": "Williams",
#         "playerID": "willige01",
#         "retroID": "willg101",
#         "throws": "R",
#         "weight": 165
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willige02",
#         "birthCity": "New Orleans",
#         "birthCountry": "USA",
#         "birthDay": 10,
#         "birthMonth": 8,
#         "birthState": "LA",
#         "birthYear": 1966,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1992-09-15",
#         "finalGame": "2005-10-02",
#         "height": 74,
#         "nameFirst": "Gerald",
#         "nameGiven": "Gerald Floyd",
#         "nameLast": "Williams",
#         "playerID": "willige02",
#         "retroID": "willg001",
#         "throws": "R",
#         "weight": 190
#     },
#     {
#         "bats": "B",
#         "bbrefID": "willige03",
#         "birthCity": "La Crosse",
#         "birthCountry": "USA",
#         "birthDay": 22,
#         "birthMonth": 4,
#         "birthState": "WI",
#         "birthYear": 1969,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1995-07-14",
#         "finalGame": "2000-09-13",
#         "height": 70,
#         "nameFirst": "George",
#         "nameGiven": "George Erik",
#         "nameLast": "Williams",
#         "playerID": "willige03",
#         "retroID": "willg002",
#         "throws": "R",
#         "weight": 190
#     },
#     {
#         "bats": "B",
#         "bbrefID": "willigl01",
#         "birthCity": "Gosford",
#         "birthCountry": "Australia",
#         "birthDay": 18,
#         "birthMonth": 7,
#         "birthState": "New South Wales",
#         "birthYear": 1977,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "2005-06-07",
#         "finalGame": "2005-06-28",
#         "height": 74,
#         "nameFirst": "Glenn",
#         "nameGiven": "Glenn David",
#         "nameLast": "Williams",
#         "playerID": "willigl01",
#         "retroID": "willg003",
#         "throws": "R",
#         "weight": 195
#     },
#     {
#         "bats": "",
#         "bbrefID": "willigu01",
#         "birthCity": "New York",
#         "birthCountry": "USA",
#         "birthDay": 0,
#         "birthMonth": 0,
#         "birthState": "NY",
#         "birthYear": 1870,
#         "deathCity": "New York",
#         "deathCountry": "USA",
#         "deathDay": "14",
#         "deathMonth": "10",
#         "deathState": "NY",
#         "deathYear": "1890",
#         "debut": "1890-04-18",
#         "finalGame": "1890-04-22",
#         "height": 71,
#         "nameFirst": "Gus",
#         "nameGiven": "Augustine H.",
#         "nameLast": "Williams",
#         "playerID": "willigu01",
#         "retroID": "willg102",
#         "throws": "",
#         "weight": 170
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willigu02",
#         "birthCity": "Omaha",
#         "birthCountry": "USA",
#         "birthDay": 7,
#         "birthMonth": 5,
#         "birthState": "NE",
#         "birthYear": 1888,
#         "deathCity": "Sterling",
#         "deathCountry": "USA",
#         "deathDay": "16",
#         "deathMonth": "4",
#         "deathState": "IL",
#         "deathYear": "1964",
#         "debut": "1911-04-12",
#         "finalGame": "1915-06-18",
#         "height": 72,
#         "nameFirst": "Gus",
#         "nameGiven": "August Joseph",
#         "nameLast": "Williams",
#         "playerID": "willigu02",
#         "retroID": "willg103",
#         "throws": "L",
#         "weight": 185
#     },
#     {
#         "bats": "R",
#         "bbrefID": "williha01",
#         "birthCity": "Omaha",
#         "birthCountry": "USA",
#         "birthDay": 23,
#         "birthMonth": 6,
#         "birthState": "NE",
#         "birthYear": 1890,
#         "deathCity": "Huntington Park",
#         "deathCountry": "USA",
#         "deathDay": "21",
#         "deathMonth": "12",
#         "deathState": "CA",
#         "deathYear": "1963",
#         "debut": "1913-08-07",
#         "finalGame": "1914-06-30",
#         "height": 73,
#         "nameFirst": "Harry",
#         "nameGiven": "Harry Peter",
#         "nameLast": "Williams",
#         "playerID": "williha01",
#         "retroID": "willh103",
#         "throws": "R",
#         "weight": 200
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willija01",
#         "birthCity": "Tulsa",
#         "birthCountry": "USA",
#         "birthDay": 14,
#         "birthMonth": 5,
#         "birthState": "OK",
#         "birthYear": 1986,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "2014-08-27",
#         "finalGame": "2015-10-04",
#         "height": 71,
#         "nameFirst": "Jackson",
#         "nameGiven": "Jackson Thomas",
#         "nameLast": "Williams",
#         "playerID": "willija01",
#         "retroID": "willj005",
#         "throws": "R",
#         "weight": 200
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willije02",
#         "birthCity": "Canberra",
#         "birthCountry": "Australia",
#         "birthDay": 6,
#         "birthMonth": 6,
#         "birthState": "Capital Territory",
#         "birthYear": 1972,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1999-09-12",
#         "finalGame": "2002-09-28",
#         "height": 72,
#         "nameFirst": "Jeff",
#         "nameGiven": "Jeffrey F.",
#         "nameLast": "Williams",
#         "playerID": "willije01",
#         "retroID": "willj002",
#         "throws": "L",
#         "weight": 185
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willije01",
#         "birthCity": "Honolulu",
#         "birthCountry": "USA",
#         "birthDay": 4,
#         "birthMonth": 12,
#         "birthState": "HI",
#         "birthYear": 1981,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "2003-04-26",
#         "finalGame": "2016-09-26",
#         "height": 75,
#         "nameFirst": "Jerome",
#         "nameGiven": "Jerome Lee",
#         "nameLast": "Williams",
#         "playerID": "willije02",
#         "retroID": "willj003",
#         "throws": "R",
#         "weight": 260
#     },
#     {
#         "bats": "R",
#         "bbrefID": "williji01",
#         "birthCity": "St. Louis",
#         "birthCountry": "USA",
#         "birthDay": 20,
#         "birthMonth": 12,
#         "birthState": "MO",
#         "birthYear": 1876,
#         "deathCity": "St. Petersburg",
#         "deathCountry": "USA",
#         "deathDay": "16",
#         "deathMonth": "1",
#         "deathState": "FL",
#         "deathYear": "1965",
#         "debut": "1899-04-15",
#         "finalGame": "1909-10-03",
#         "height": 69,
#         "nameFirst": "Jimmy",
#         "nameGiven": "James Thomas",
#         "nameLast": "Williams",
#         "playerID": "williji01",
#         "retroID": "willj106",
#         "throws": "R",
#         "weight": 175
#     },
#     {
#         "bats": "R",
#         "bbrefID": "williji03",
#         "birthCity": "Santa Maria",
#         "birthCountry": "USA",
#         "birthDay": 4,
#         "birthMonth": 10,
#         "birthState": "CA",
#         "birthYear": 1943,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1966-04-26",
#         "finalGame": "1967-09-21",
#         "height": 70,
#         "nameFirst": "Jimy",
#         "nameGiven": "James Francis",
#         "nameLast": "Williams",
#         "playerID": "williji03",
#         "retroID": "willj107",
#         "throws": "R",
#         "weight": 170
#     },
#     {
#         "bats": "R",
#         "bbrefID": "williji04",
#         "birthCity": "Zachary",
#         "birthCountry": "USA",
#         "birthDay": 29,
#         "birthMonth": 4,
#         "birthState": "LA",
#         "birthYear": 1947,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1969-09-08",
#         "finalGame": "1970-09-30",
#         "height": 74,
#         "nameFirst": "Jim",
#         "nameGiven": "James Alfred",
#         "nameLast": "Williams",
#         "playerID": "williji04",
#         "retroID": "willj108",
#         "throws": "R",
#         "weight": 190
#     },
#     {
#         "bats": "",
#         "bbrefID": "williji99",
#         "birthCity": "Catawba",
#         "birthCountry": "USA",
#         "birthDay": 4,
#         "birthMonth": 1,
#         "birthState": "OH",
#         "birthYear": 1847,
#         "deathCity": "Westbury",
#         "deathCountry": "USA",
#         "deathDay": "23",
#         "deathMonth": "10",
#         "deathState": "NY",
#         "deathYear": "1918",
#         "debut": "",
#         "finalGame": "",
#         "height": 0,
#         "nameFirst": "Jimmy",
#         "nameGiven": "James Andrew",
#         "nameLast": "Williams",
#         "playerID": "williji99",
#         "retroID": "willj801",
#         "throws": "",
#         "weight": 0
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willijo02",
#         "birthCity": "Honolulu",
#         "birthCountry": "USA",
#         "birthDay": 16,
#         "birthMonth": 7,
#         "birthState": "HI",
#         "birthYear": 1889,
#         "deathCity": "Long Beach",
#         "deathCountry": "USA",
#         "deathDay": "8",
#         "deathMonth": "9",
#         "deathState": "CA",
#         "deathYear": "1963",
#         "debut": "1914-04-21",
#         "finalGame": "1914-08-19",
#         "height": 72,
#         "nameFirst": "Johnnie",
#         "nameGiven": "John Brodie",
#         "nameLast": "Williams",
#         "playerID": "willijo02",
#         "retroID": "willj101",
#         "throws": "R",
#         "weight": 180
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willijo99",
#         "birthCity": "Seguin",
#         "birthCountry": "USA",
#         "birthDay": 6,
#         "birthMonth": 4,
#         "birthState": "TX",
#         "birthYear": 1885,
#         "deathCity": "New York",
#         "deathCountry": "USA",
#         "deathDay": "25",
#         "deathMonth": "2",
#         "deathState": "NY",
#         "deathYear": "1951",
#         "debut": "",
#         "finalGame": "",
#         "height": 76,
#         "nameFirst": "Smokey Joe",
#         "nameGiven": "Joseph",
#         "nameLast": "Williams",
#         "playerID": "willijo99",
#         "retroID": "",
#         "throws": "R",
#         "weight": 190
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willike01",
#         "birthCity": "Grants Pass",
#         "birthCountry": "USA",
#         "birthDay": 28,
#         "birthMonth": 6,
#         "birthState": "OR",
#         "birthYear": 1890,
#         "deathCity": "Grants Pass",
#         "deathCountry": "USA",
#         "deathDay": "22",
#         "deathMonth": "1",
#         "deathState": "OR",
#         "deathYear": "1959",
#         "debut": "1915-07-14",
#         "finalGame": "1929-08-10",
#         "height": 72,
#         "nameFirst": "Ken",
#         "nameGiven": "Kenneth Roy",
#         "nameLast": "Williams",
#         "playerID": "willike01",
#         "retroID": "willk101",
#         "throws": "R",
#         "weight": 170
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willike02",
#         "birthCity": "Berkeley",
#         "birthCountry": "USA",
#         "birthDay": 6,
#         "birthMonth": 4,
#         "birthState": "CA",
#         "birthYear": 1964,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1986-09-02",
#         "finalGame": "1991-10-04",
#         "height": 74,
#         "nameFirst": "Ken",
#         "nameGiven": "Kenneth Royal",
#         "nameLast": "Williams",
#         "playerID": "willike02",
#         "retroID": "willk001",
#         "throws": "R",
#         "weight": 187
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willike03",
#         "birthCity": "Bedford",
#         "birthCountry": "USA",
#         "birthDay": 21,
#         "birthMonth": 4,
#         "birthState": "PA",
#         "birthYear": 1972,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1996-06-07",
#         "finalGame": "1996-06-23",
#         "height": 72,
#         "nameFirst": "Keith",
#         "nameGiven": "David Keith",
#         "nameLast": "Williams",
#         "playerID": "willike03",
#         "retroID": "willk002",
#         "throws": "R",
#         "weight": 190
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willile01",
#         "birthCity": "Aurora",
#         "birthCountry": "USA",
#         "birthDay": 9,
#         "birthMonth": 3,
#         "birthState": "MO",
#         "birthYear": 1893,
#         "deathCity": "Laguna Beach",
#         "deathCountry": "USA",
#         "deathDay": "4",
#         "deathMonth": "11",
#         "deathState": "CA",
#         "deathYear": "1959",
#         "debut": "1913-09-17",
#         "finalGame": "1920-09-25",
#         "height": 69,
#         "nameFirst": "Lefty",
#         "nameGiven": "Claude Preston",
#         "nameLast": "Williams",
#         "playerID": "willile01",
#         "retroID": "willl104",
#         "throws": "L",
#         "weight": 160
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willile03",
#         "birthCity": "Macon",
#         "birthCountry": "USA",
#         "birthDay": 2,
#         "birthMonth": 12,
#         "birthState": "GA",
#         "birthYear": 1905,
#         "deathCity": "Atlanta",
#         "deathCountry": "USA",
#         "deathDay": "20",
#         "deathMonth": "11",
#         "deathState": "GA",
#         "deathYear": "1984",
#         "debut": "1926-05-26",
#         "finalGame": "1926-09-06",
#         "height": 70,
#         "nameFirst": "Leon",
#         "nameGiven": "Leon Theo",
#         "nameLast": "Williams",
#         "playerID": "willile03",
#         "retroID": "willl101",
#         "throws": "L",
#         "weight": 154
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willima01",
#         "birthCity": "Faison",
#         "birthCountry": "USA",
#         "birthDay": 21,
#         "birthMonth": 2,
#         "birthState": "NC",
#         "birthYear": 1893,
#         "deathCity": "Tucson",
#         "deathCountry": "USA",
#         "deathDay": "22",
#         "deathMonth": "2",
#         "deathState": "AZ",
#         "deathYear": "1935",
#         "debut": "1916-07-07",
#         "finalGame": "1916-08-25",
#         "height": 72,
#         "nameFirst": "Marsh",
#         "nameGiven": "Marshall McDiarmid",
#         "nameLast": "Williams",
#         "playerID": "willima01",
#         "retroID": "willm104",
#         "throws": "R",
#         "weight": 180
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willima02",
#         "birthCity": "Elmira",
#         "birthCountry": "USA",
#         "birthDay": 28,
#         "birthMonth": 7,
#         "birthState": "NY",
#         "birthYear": 1953,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1977-05-20",
#         "finalGame": "1977-05-22",
#         "height": 72,
#         "nameFirst": "Mark",
#         "nameGiven": "Mark Westley",
#         "nameLast": "Williams",
#         "playerID": "willima02",
#         "retroID": "willm105",
#         "throws": "L",
#         "weight": 180
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willima03",
#         "birthCity": "Houston",
#         "birthCountry": "USA",
#         "birthDay": 25,
#         "birthMonth": 7,
#         "birthState": "TX",
#         "birthYear": 1959,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1983-08-02",
#         "finalGame": "1985-10-05",
#         "height": 73,
#         "nameFirst": "Matt",
#         "nameGiven": "Matthew Evan",
#         "nameLast": "Williams",
#         "playerID": "willima03",
#         "retroID": "willm001",
#         "throws": "R",
#         "weight": 200
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willima04",
#         "birthCity": "Bishop",
#         "birthCountry": "USA",
#         "birthDay": 28,
#         "birthMonth": 11,
#         "birthState": "CA",
#         "birthYear": 1965,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1987-04-11",
#         "finalGame": "2003-05-31",
#         "height": 74,
#         "nameFirst": "Matt",
#         "nameGiven": "Matthew Derrick",
#         "nameLast": "Williams",
#         "playerID": "willima04",
#         "retroID": "willm003",
#         "throws": "R",
#         "weight": 205
#     },
#     {
#         "bats": "B",
#         "bbrefID": "willima09",
#         "birthCity": "Virginia Beach",
#         "birthCountry": "USA",
#         "birthDay": 12,
#         "birthMonth": 4,
#         "birthState": "VA",
#         "birthYear": 1971,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "2000-04-05",
#         "finalGame": "2000-04-29",
#         "height": 72,
#         "nameFirst": "Matt",
#         "nameGiven": "Matt Taylor",
#         "nameLast": "Williams",
#         "playerID": "willima06",
#         "retroID": "willm006",
#         "throws": "L",
#         "weight": 185
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willima10",
#         "birthCity": "Pawtucket",
#         "birthCountry": "USA",
#         "birthDay": 21,
#         "birthMonth": 8,
#         "birthState": "RI",
#         "birthYear": 1991,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "2015-06-12",
#         "finalGame": "2016-10-02",
#         "height": 73,
#         "nameFirst": "Mason",
#         "nameGiven": "Mason",
#         "nameLast": "Williams",
#         "playerID": "willima07",
#         "retroID": "willm007",
#         "throws": "R",
#         "weight": 185
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willimi02",
#         "birthCity": "Santa Ana",
#         "birthCountry": "USA",
#         "birthDay": 17,
#         "birthMonth": 11,
#         "birthState": "CA",
#         "birthYear": 1964,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1986-04-09",
#         "finalGame": "1997-05-10",
#         "height": 75,
#         "nameFirst": "Mitch",
#         "nameGiven": "Mitchell Steven",
#         "nameLast": "Williams",
#         "playerID": "willimi02",
#         "retroID": "willm002",
#         "throws": "L",
#         "weight": 180
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willimi03",
#         "birthCity": "Radford",
#         "birthCountry": "USA",
#         "birthDay": 29,
#         "birthMonth": 7,
#         "birthState": "VA",
#         "birthYear": 1968,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1992-06-30",
#         "finalGame": "2003-09-28",
#         "height": 74,
#         "nameFirst": "Mike",
#         "nameGiven": "Michael Darren",
#         "nameLast": "Williams",
#         "playerID": "willimi03",
#         "retroID": "willm005",
#         "throws": "R",
#         "weight": 190
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willimu01",
#         "birthCity": "Ozark",
#         "birthCountry": "USA",
#         "birthDay": 31,
#         "birthMonth": 7,
#         "birthState": "AR",
#         "birthYear": 1892,
#         "deathCity": "Fayetteville",
#         "deathCountry": "USA",
#         "deathDay": "30",
#         "deathMonth": "3",
#         "deathState": "AR",
#         "deathYear": "1962",
#         "debut": "1913-10-04",
#         "finalGame": "1914-10-01",
#         "height": 75,
#         "nameFirst": "Mutt",
#         "nameGiven": "David Carter",
#         "nameLast": "Williams",
#         "playerID": "willimu01",
#         "retroID": "willm103",
#         "throws": "R",
#         "weight": 195
#     },
#     {
#         "bats": "R",
#         "bbrefID": "williot01",
#         "birthCity": "Newark",
#         "birthCountry": "USA",
#         "birthDay": 2,
#         "birthMonth": 11,
#         "birthState": "NJ",
#         "birthYear": 1877,
#         "deathCity": "Omaha",
#         "deathCountry": "USA",
#         "deathDay": "19",
#         "deathMonth": "3",
#         "deathState": "NE",
#         "deathYear": "1937",
#         "debut": "1902-10-05",
#         "finalGame": "1906-06-09",
#         "height": 68,
#         "nameFirst": "Otto",
#         "nameGiven": "Otto George",
#         "nameLast": "Williams",
#         "playerID": "williot01",
#         "retroID": "willo101",
#         "throws": "R",
#         "weight": 165
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willipa01",
#         "birthCity": "Meridian",
#         "birthCountry": "USA",
#         "birthDay": 17,
#         "birthMonth": 7,
#         "birthState": "MS",
#         "birthYear": 1913,
#         "deathCity": "Meridian",
#         "deathCountry": "USA",
#         "deathDay": "2",
#         "deathMonth": "11",
#         "deathState": "MS",
#         "deathYear": "1993",
#         "debut": "1945-04-19",
#         "finalGame": "1945-07-08",
#         "height": 73,
#         "nameFirst": "Papa",
#         "nameGiven": "Fred",
#         "nameLast": "Williams",
#         "playerID": "willipa01",
#         "retroID": "willp102",
#         "throws": "R",
#         "weight": 200
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willipo01",
#         "birthCity": "Bowdoinham",
#         "birthCountry": "USA",
#         "birthDay": 19,
#         "birthMonth": 5,
#         "birthState": "ME",
#         "birthYear": 1874,
#         "deathCity": "Topsham",
#         "deathCountry": "USA",
#         "deathDay": "4",
#         "deathMonth": "8",
#         "deathState": "ME",
#         "deathYear": "1959",
#         "debut": "1898-09-14",
#         "finalGame": "1903-09-15",
#         "height": 71,
#         "nameFirst": "Pop",
#         "nameGiven": "Walter Merrill",
#         "nameLast": "Williams",
#         "playerID": "willipo01",
#         "retroID": "willp101",
#         "throws": "L",
#         "weight": 190
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willira01",
#         "birthCity": "Harlingen",
#         "birthCountry": "USA",
#         "birthDay": 18,
#         "birthMonth": 9,
#         "birthState": "TX",
#         "birthYear": 1975,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "2004-09-11",
#         "finalGame": "2011-08-05",
#         "height": 75,
#         "nameFirst": "Randy",
#         "nameGiven": "Randall Duane",
#         "nameLast": "Williams",
#         "playerID": "willira01",
#         "retroID": "willr003",
#         "throws": "L",
#         "weight": 200
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willire01",
#         "birthCity": "Memphis",
#         "birthCountry": "USA",
#         "birthDay": 29,
#         "birthMonth": 8,
#         "birthState": "TN",
#         "birthYear": 1960,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1985-09-02",
#         "finalGame": "1988-10-02",
#         "height": 71,
#         "nameFirst": "Reggie",
#         "nameGiven": "Reginald Dewayne",
#         "nameLast": "Williams",
#         "playerID": "willire01",
#         "retroID": "willr001",
#         "throws": "R",
#         "weight": 185
#     },
#     {
#         "bats": "B",
#         "bbrefID": "willire02",
#         "birthCity": "Laurens",
#         "birthCountry": "USA",
#         "birthDay": 5,
#         "birthMonth": 5,
#         "birthState": "SC",
#         "birthYear": 1966,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1992-09-08",
#         "finalGame": "1999-07-25",
#         "height": 73,
#         "nameFirst": "Reggie",
#         "nameGiven": "Reginald Bernard",
#         "nameLast": "Williams",
#         "playerID": "willire02",
#         "retroID": "willr002",
#         "throws": "R",
#         "weight": 180
#     },
#     {
#         "bats": "R",
#         "bbrefID": "williri01",
#         "birthCity": "Carthage",
#         "birthCountry": "USA",
#         "birthDay": 31,
#         "birthMonth": 1,
#         "birthState": "IL",
#         "birthYear": 1882,
#         "deathCity": "Keokuk",
#         "deathCountry": "USA",
#         "deathDay": "23",
#         "deathMonth": "7",
#         "deathState": "IA",
#         "deathYear": "1933",
#         "debut": "1911-04-12",
#         "finalGame": "1918-06-09",
#         "height": 71,
#         "nameFirst": "Rip",
#         "nameGiven": "Alva Mitchell",
#         "nameLast": "Williams",
#         "playerID": "williri01",
#         "retroID": "willr104",
#         "throws": "R",
#         "weight": 187
#     },
#     {
#         "bats": "L",
#         "bbrefID": "williri02",
#         "birthCity": "Santa Cruz",
#         "birthCountry": "USA",
#         "birthDay": 18,
#         "birthMonth": 12,
#         "birthState": "CA",
#         "birthYear": 1893,
#         "deathCity": "Cottonwood",
#         "deathCountry": "USA",
#         "deathDay": "24",
#         "deathMonth": "4",
#         "deathState": "AZ",
#         "deathYear": "1966",
#         "debut": "1914-10-08",
#         "finalGame": "1914-10-10",
#         "height": 0,
#         "nameFirst": "Rinaldo",
#         "nameGiven": "Rinaldo Louis",
#         "nameLast": "Williams",
#         "playerID": "williri02",
#         "retroID": "willr103",
#         "throws": "R",
#         "weight": 0
#     },
#     {
#         "bats": "R",
#         "bbrefID": "williri03",
#         "birthCity": "Merced",
#         "birthCountry": "USA",
#         "birthDay": 9,
#         "birthMonth": 11,
#         "birthState": "CA",
#         "birthYear": 1952,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1978-06-12",
#         "finalGame": "1979-09-26",
#         "height": 73,
#         "nameFirst": "Rick",
#         "nameGiven": "Richard Allen",
#         "nameLast": "Williams",
#         "playerID": "williri03",
#         "retroID": "willr101",
#         "throws": "R",
#         "weight": 180
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willish01",
#         "birthCity": "Fresno",
#         "birthCountry": "USA",
#         "birthDay": 10,
#         "birthMonth": 3,
#         "birthState": "CA",
#         "birthYear": 1971,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1996-05-18",
#         "finalGame": "1997-07-22",
#         "height": 72,
#         "nameFirst": "Shad",
#         "nameGiven": "Shad Clayton",
#         "nameLast": "Williams",
#         "playerID": "willish01",
#         "retroID": "wills001",
#         "throws": "R",
#         "weight": 185
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willist01",
#         "birthCity": "Cascade",
#         "birthCountry": "USA",
#         "birthDay": 31,
#         "birthMonth": 1,
#         "birthState": "MT",
#         "birthYear": 1892,
#         "deathCity": "Deer River",
#         "deathCountry": "USA",
#         "deathDay": "29",
#         "deathMonth": "6",
#         "deathState": "MN",
#         "deathYear": "1979",
#         "debut": "1914-07-12",
#         "finalGame": "1916-10-01",
#         "height": 71,
#         "nameFirst": "Steamboat",
#         "nameGiven": "Rees Gephardt",
#         "nameLast": "Williams",
#         "playerID": "willist01",
#         "retroID": "wills101",
# ...
#         "bats": "R",
#         "bbrefID": "williwo01",
#         "birthCity": "Pamplin",
#         "birthCountry": "USA",
#         "birthDay": 21,
#         "birthMonth": 8,
#         "birthState": "VA",
#         "birthYear": 1912,
#         "deathCity": "Appomattox",
#         "deathCountry": "USA",
#         "deathDay": "24",
#         "deathMonth": "2",
#         "deathState": "VA",
#         "deathYear": "1995",
#         "debut": "1938-09-05",
#         "finalGame": "1945-09-30",
#         "height": 71,
#         "nameFirst": "Woody",
#         "nameGiven": "Woodrow Wilson",
#         "nameLast": "Williams",
#         "playerID": "williwo01",
#         "retroID": "willw101",
#         "throws": "R",
#         "weight": 175
#     },
#     {
#         "bats": "R",
#         "bbrefID": "williwo02",
#         "birthCity": "Houston",
#         "birthCountry": "USA",
#         "birthDay": 19,
#         "birthMonth": 8,
#         "birthState": "TX",
#         "birthYear": 1966,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1993-05-14",
#         "finalGame": "2007-09-22",
#         "height": 72,
#         "nameFirst": "Woody",
#         "nameGiven": "Gregory Scott",
#         "nameLast": "Williams",
#         "playerID": "williwo02",
#         "retroID": "willw001",
#         "throws": "R",
#         "weight": 180
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willial01",
#         "birthCity": "Buckville",
#         "birthCountry": "USA",
#         "birthDay": 20,
#         "birthMonth": 2,
#         "birthState": "AR",
#         "birthYear": 1900,
#         "deathCity": "Hot Springs",
#         "deathCountry": "USA",
#         "deathDay": "29",
#         "deathMonth": "11",
#         "deathState": "AR",
#         "deathYear": "1978",
#         "debut": "1928-04-27",
#         "finalGame": "1928-04-27",
#         "height": 71,
#         "nameFirst": "Al",
#         "nameGiven": "Silas Albert",
#         "nameLast": "Williamson",
#         "playerID": "willial01",
#         "retroID": "willa102",
#         "throws": "R",
#         "weight": 160
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willian01",
#         "birthCity": "Harbor City",
#         "birthCountry": "USA",
#         "birthDay": 18,
#         "birthMonth": 7,
#         "birthState": "CA",
#         "birthYear": 1973,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1997-05-31",
#         "finalGame": "1997-07-03",
#         "height": 73,
#         "nameFirst": "Antone",
#         "nameGiven": "Anthony Joseph",
#         "nameLast": "Williamson",
#         "playerID": "willian01",
#         "retroID": "willa002",
#         "throws": "R",
#         "weight": 195
#     },
#     {
#         "bats": "L",
#         "bbrefID": "williho01",
#         "birthCity": "Little Rock",
#         "birthCountry": "USA",
#         "birthDay": 23,
#         "birthMonth": 12,
#         "birthState": "AR",
#         "birthYear": 1904,
#         "deathCity": "Texarkana",
#         "deathCountry": "USA",
#         "deathDay": "15",
#         "deathMonth": "8",
#         "deathState": "AR",
#         "deathYear": "1969",
#         "debut": "1928-07-07",
#         "finalGame": "1928-08-17",
#         "height": 72,
#         "nameFirst": "Howie",
#         "nameGiven": "Nathaniel Howard",
#         "nameLast": "Williamson",
#         "playerID": "williho01",
#         "retroID": "willh101",
#         "throws": "L",
#         "weight": 170
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willima05",
#         "birthCity": "Corpus Christi",
#         "birthCountry": "USA",
#         "birthDay": 21,
#         "birthMonth": 7,
#         "birthState": "TX",
#         "birthYear": 1959,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1987-04-08",
#         "finalGame": "1994-08-04",
#         "height": 72,
#         "nameFirst": "Mark",
#         "nameGiven": "Mark Alan",
#         "nameLast": "Williamson",
#         "playerID": "willima05",
#         "retroID": "willm004",
#         "throws": "R",
#         "weight": 155
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willima11",
#         "birthCity": "Jacksonville",
#         "birthCountry": "USA",
#         "birthDay": 15,
#         "birthMonth": 7,
#         "birthState": "FL",
#         "birthYear": 1990,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "2015-09-23",
#         "finalGame": "2016-09-25",
#         "height": 76,
#         "nameFirst": "Mac",
#         "nameGiven": "Johnathan Mackensey",
#         "nameLast": "Williamson",
#         "playerID": "willima08",
#         "retroID": "willm008",
#         "throws": "R",
#         "weight": 240
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willine01",
#         "birthCity": "Philadelphia",
#         "birthCountry": "USA",
#         "birthDay": 24,
#         "birthMonth": 10,
#         "birthState": "PA",
#         "birthYear": 1857,
#         "deathCity": "Mountain Valley Springs",
#         "deathCountry": "USA",
#         "deathDay": "3",
#         "deathMonth": "3",
#         "deathState": "AR",
#         "deathYear": "1894",
#         "debut": "1878-05-01",
#         "finalGame": "1890-09-27",
#         "height": 71,
#         "nameFirst": "Ned",
#         "nameGiven": "Edward Nagle",
#         "nameLast": "Williamson",
#         "playerID": "willine01",
#         "retroID": "willn102",
#         "throws": "R",
#         "weight": 210
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willisc01",
#         "birthCity": "Fort Polk",
#         "birthCountry": "USA",
#         "birthDay": 17,
#         "birthMonth": 2,
#         "birthState": "LA",
#         "birthYear": 1976,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1999-04-05",
#         "finalGame": "2007-06-29",
#         "height": 72,
#         "nameFirst": "Scott",
#         "nameGiven": "Scott Ryan",
#         "nameLast": "Williamson",
#         "playerID": "willisc01",
#         "retroID": "wills002",
#         "throws": "R",
#         "weight": 195
#     },
#     {
#         "bats": "L",
#         "bbrefID": "williju01",
#         "birthCity": "Marshalltown",
#         "birthCountry": "USA",
#         "birthDay": 27,
#         "birthMonth": 10,
#         "birthState": "IA",
#         "birthYear": 1857,
#         "deathCity": "San Francisco",
#         "deathCountry": "USA",
#         "deathDay": "27",
#         "deathMonth": "11",
#         "deathState": "CA",
#         "deathYear": "1906",
#         "debut": "1882-07-15",
#         "finalGame": "1882-08-19",
#         "height": 69,
#         "nameFirst": "Julius",
#         "nameGiven": "Julius",
#         "nameLast": "Willigrod",
#         "playerID": "williju01",
#         "retroID": "willj105",
#         "throws": "",
#         "weight": 0
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willihu01",
#         "birthCity": "Dalhart",
#         "birthCountry": "USA",
#         "birthDay": 30,
#         "birthMonth": 5,
#         "birthState": "TX",
#         "birthYear": 1906,
#         "deathCity": "El Reno",
#         "deathCountry": "USA",
#         "deathDay": "15",
#         "deathMonth": "6",
#         "deathState": "OK",
#         "deathYear": "1988",
#         "debut": "1930-09-13",
#         "finalGame": "1933-05-04",
#         "height": 72,
#         "nameFirst": "Hugh",
#         "nameGiven": "Thomas Hugh",
#         "nameLast": "Willingham",
#         "playerID": "willihu01",
#         "retroID": "willh102",
#         "throws": "R",
#         "weight": 180
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willijo03",
#         "birthCity": "Florence",
#         "birthCountry": "USA",
#         "birthDay": 17,
#         "birthMonth": 2,
#         "birthState": "AL",
#         "birthYear": 1979,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "2004-07-06",
#         "finalGame": "2014-09-28",
#         "height": 74,
#         "nameFirst": "Josh",
#         "nameGiven": "Joshua David",
#         "nameLast": "Willingham",
#         "playerID": "willijo03",
#         "retroID": "willj004",
#         "throws": "R",
#         "weight": 230
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willica01",
#         "birthCity": "Danville",
#         "birthCountry": "USA",
#         "birthDay": 28,
#         "birthMonth": 12,
#         "birthState": "VA",
#         "birthYear": 1960,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1984-06-09",
#         "finalGame": "1995-05-03",
#         "height": 76,
#         "nameFirst": "Carl",
#         "nameGiven": "Carl Blake",
#         "nameLast": "Willis",
#         "playerID": "willica01",
#         "retroID": "willc001",
#         "throws": "R",
#         "weight": 210
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willida04",
#         "birthCity": "Calhoun",
#         "birthCountry": "USA",
#         "birthDay": 29,
#         "birthMonth": 5,
#         "birthState": "GA",
#         "birthYear": 1938,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1963-04-14",
#         "finalGame": "1963-09-13",
#         "height": 71,
#         "nameFirst": "Dale",
#         "nameGiven": "Dale Jerome",
#         "nameLast": "Willis",
#         "playerID": "willida04",
#         "retroID": "willd111",
#         "throws": "R",
#         "weight": 165
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willido03",
#         "birthCity": "Oakland",
#         "birthCountry": "USA",
#         "birthDay": 12,
#         "birthMonth": 1,
#         "birthState": "CA",
#         "birthYear": 1982,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "2003-05-09",
#         "finalGame": "2011-09-27",
#         "height": 74,
#         "nameFirst": "Dontrelle",
#         "nameGiven": "Dontrelle Wayne",
#         "nameLast": "Willis",
#         "playerID": "willido03",
#         "retroID": "willd003",
#         "throws": "L",
#         "weight": 230
#     },
#     {
#         "bats": "L",
#         "bbrefID": "williji02",
#         "birthCity": "Doyline",
#         "birthCountry": "USA",
#         "birthDay": 20,
#         "birthMonth": 3,
#         "birthState": "LA",
#         "birthYear": 1927,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1953-04-22",
#         "finalGame": "1954-06-05",
#         "height": 75,
#         "nameFirst": "Jim",
#         "nameGiven": "James Gladden",
#         "nameLast": "Willis",
#         "playerID": "williji02",
#         "retroID": "willj104",
#         "throws": "R",
#         "weight": 175
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willijo01",
#         "birthCity": "Coal Grove",
#         "birthCountry": "USA",
#         "birthDay": 9,
#         "birthMonth": 4,
#         "birthState": "OH",
#         "birthYear": 1890,
#         "deathCity": "Ironton",
#         "deathCountry": "USA",
#         "deathDay": "4",
#         "deathMonth": "12",
#         "deathState": "OH",
#         "deathYear": "1966",
#         "debut": "1911-05-03",
#         "finalGame": "1913-06-10",
#         "height": 73,
#         "nameFirst": "Joe",
#         "nameGiven": "Joseph Dank",
#         "nameLast": "Willis",
#         "playerID": "willijo01",
#         "retroID": "willj103",
#         "throws": "L",
#         "weight": 185
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willile02",
#         "birthCity": "Leetown",
#         "birthCountry": "USA",
#         "birthDay": 4,
#         "birthMonth": 11,
#         "birthState": "WV",
#         "birthYear": 1905,
#         "deathCity": "Bethesda",
#         "deathCountry": "USA",
#         "deathDay": "10",
#         "deathMonth": "5",
#         "deathState": "MD",
#         "deathYear": "1962",
#         "debut": "1925-10-03",
#         "finalGame": "1927-07-12",
#         "height": 73,
#         "nameFirst": "Lefty",
#         "nameGiven": "Charles William",
#         "nameLast": "Willis",
#         "playerID": "willile02",
#         "retroID": "willl103",
#         "throws": "L",
#         "weight": 175
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willile04",
#         "birthCity": "Nacogdoches",
#         "birthCountry": "USA",
#         "birthDay": 17,
#         "birthMonth": 1,
#         "birthState": "TX",
#         "birthYear": 1908,
#         "deathCity": "Jasper",
#         "deathCountry": "USA",
#         "deathDay": "22",
#         "deathMonth": "1",
#         "deathState": "TX",
#         "deathYear": "1982",
#         "debut": "1947-04-28",
#         "finalGame": "1947-08-23",
#         "height": 69,
#         "nameFirst": "Les",
#         "nameGiven": "Lester Evans",
#         "nameLast": "Willis",
#         "playerID": "willile04",
#         "retroID": "willl102",
#         "throws": "L",
#         "weight": 195
#     },
#     {
#         "bats": "L",
#         "bbrefID": "willimi01",
#         "birthCity": "Oklahoma City",
#         "birthCountry": "USA",
#         "birthDay": 26,
#         "birthMonth": 12,
#         "birthState": "OK",
#         "birthYear": 1950,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "1977-04-13",
#         "finalGame": "1981-06-11",
#         "height": 74,
#         "nameFirst": "Mike",
#         "nameGiven": "Michael Henry",
#         "nameLast": "Willis",
#         "playerID": "willimi01",
#         "retroID": "willm101",
#         "throws": "L",
#         "weight": 205
#     },
#     {
#         "bats": "R",
#         "bbrefID": "williro01",
#         "birthCity": "Willisville",
#         "birthCountry": "USA",
#         "birthDay": 12,
#         "birthMonth": 7,
#         "birthState": "TN",
#         "birthYear": 1943,
#         "deathCity": "Memphis",
#         "deathCountry": "USA",
#         "deathDay": "21",
#         "deathMonth": "11",
#         "deathState": "TN",
#         "deathYear": "1977",
#         "debut": "1966-09-20",
#         "finalGame": "1970-09-29",
#         "height": 74,
#         "nameFirst": "Ron",
#         "nameGiven": "Ronald Earl",
#         "nameLast": "Willis",
#         "playerID": "williro01",
#         "retroID": "willr102",
#         "throws": "R",
#         "weight": 185
#     },
#     {
#         "bats": "R",
#         "bbrefID": "willivi01",
#         "birthCity": "Cecil County",
#         "birthCountry": "USA",
#         "birthDay": 12,
#         "birthMonth": 4,
#         "birthState": "MD",
#         "birthYear": 1876,
#         "deathCity": "Elkton",
#         "deathCountry": "USA",
#         "deathDay": "3",
#         "deathMonth": "8",
#         "deathState": "MD",
#         "deathYear": "1947",
#         "debut": "1898-04-20",
#         "finalGame": "1910-09-05",
#         "height": 74,
#         "nameFirst": "Vic",
#         "nameGiven": "Victor Gazaway",
#         "nameLast": "Willis",
#         "playerID": "willivi01",
#         "retroID": "willv101",
#         "throws": "R",
#         "weight": 185
#     },
#     {
#         "bats": "B",
#         "bbrefID": "willire03",
#         "birthCity": "Chickasha",
#         "birthCountry": "USA",
#         "birthDay": 30,
#         "birthMonth": 5,
#         "birthState": "OK",
#         "birthYear": 1981,
#         "deathCity": "",
#         "deathCountry": "",
#         "deathDay": "",
#         "deathMonth": "",
#         "deathState": "",
#         "deathYear": "",
#         "debut": "2006-04-26",
#         "finalGame": "2011-06-03",
#         "height": 71,
#         "nameFirst": "Reggie",
#         "nameGiven": "Reggie Gene",
#         "nameLast": "Willits",
#         "playerID": "willire03",
#         "retroID": "willr004",
#         "throws": "R",
#         "weight": 185
#     }
# ]

# %% [markdown]
# ### Project Clause (the Clause that Follows SELECT)
#
# - AKA _Select Expression_
#
#
# - The basic syntax is $term, term,...$ where $term$ is a column name or function of column names.
#
#
# - $term $ $AS $ $alias$ renames a term (result column) in the result table.

# %%
q = "SELECT nameLast as last_name, nameFirst as first_name, "
q = q + "(deathYear - birthYear) AS lifespan, " 
q = q + "CONCAT(nameGiven,' ',nameLast) as greatest_hitter_ever FROM Master "
q = q + "WHERE nameLast='Williams' AND nameFirst='Ted';"
r = execute_query(q)
pretty_print(r)
# Out:
# Executing query =  SELECT nameLast as last_name, nameFirst as first_name, (deathYear - birthYear) AS lifespan, CONCAT(nameGiven,' ',nameLast) as greatest_hitter_ever FROM Master WHERE nameLast='Williams' AND nameFirst='Ted';
# Connected.
# Disconnected
# Result =  [
#     {
#         "first_name": "Ted",
#         "greatest_hitter_ever": "Theodore Samuel Williams",
#         "last_name": "Williams",
#         "lifespan": 84.0
#     }
# ]

# %% [markdown]
# ### Keys and Indexes
#
# - Relational theory treats keys as an _integrity constraint._
#     - The ICs ensure that create, update and delete do not cause data integrity.
#     - This is a very important capability, and RDBs have advanced IC functionality, which we will see in future lectures.
#
#
# - For read, most RDBs implement $keys$ using an _index._
#     - A table can have many indexes.
#     - The indexes optimize both constraint implementation, _and SELECT performance._
#     - An index may or may not enforce uniqueness.
#
#
# - The CREATE statement below
#     - Has a _primary key_ on _playerID,_ which enforces uniqueness and optimizes SELECT.
#     - A _non-unique index_ on _nameLast,_ which optimizes SELECT performance
#
# ```
# CREATE TABLE `Master` (
#   `playerID` varchar(255) NOT NULL,
#   `birthYear` int(11) DEFAULT NULL,
#   `birthMonth` int(11) NOT NULL,
#   `birthDay` int(11) DEFAULT NULL,
#   `birthCountry` varchar(255) DEFAULT NULL,
#   `birthState` varchar(255) DEFAULT NULL,
#   `birthCity` varchar(255) DEFAULT NULL,
#   `deathYear` varchar(255) DEFAULT NULL,
#   `deathMonth` varchar(255) DEFAULT NULL,
#   `deathDay` varchar(255) DEFAULT NULL,
#   `deathCountry` varchar(255) DEFAULT NULL,
#   `deathState` varchar(255) DEFAULT NULL,
#   `deathCity` varchar(255) DEFAULT NULL,
#   `nameFirst` varchar(255) NOT NULL,
#   `nameLast` varchar(255) NOT NULL,
#   `nameGiven` varchar(255) DEFAULT NULL,
#   `weight` int(11) DEFAULT NULL,
#   `height` int(11) DEFAULT NULL,
#   `bats` varchar(255) DEFAULT NULL,
#   `throws` varchar(255) DEFAULT NULL,
#   `debut` varchar(255) DEFAULT NULL,
#   `finalGame` varchar(255) DEFAULT NULL,
#   `retroID` varchar(255) DEFAULT NULL,
#   `bbrefID` varchar(255) DEFAULT NULL,
#   PRIMARY KEY (`playerID`),
#   KEY `player_idx` (`playerID`),
#   KEY `name_l` (`nameLast`)
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
# ```
#
# - The SQL Workbench is a good way to view and edit indexes.
#
# <img src="../images/L4_index_workbench.jpeg">

# %% [markdown]
# Execution Examples:
#
# <img src="../images/L4_index_performance.jpeg">

# %% [markdown]
# - SELECTs that cannot use an index have to scan the table, which is $O(N).$
#
#
# - SELECTs that can use an index are
#     - $O(N*Log(N))$ if it can use a tree index.
#     - $O(1)$ if it can use a hash index.
#
#
# - We will cover indexes, performance implications and  implementation in future lectures.
#
#
# - The obvious question is, "Why not index everything?" Indexes take up storage, and there is a [space-time tradeoff.](https://en.wikipedia.org/wiki/Space%E2%80%93time_tradeoff)

# %% [markdown]
# ### SQL is an Algebra
#
# - All SQL DML statements produce a relation/table.
#
#
# - This means, and it is normally the case, that SQL statements are algebraic combinations of simpler SQL statements.
#
# ```
# SELECT
# 	playerID, nameLast, nameFirst
# FROM
# 	(SELECT * FROM Master WHERE nameLast LIKE 'William%') as a;
# ```
#
# - SELECTS all players with nameList LIKE 'William%' to produce derived table a.
#
#
# - PROJECTS on a to get columns playerID, nameLast, nameFirst.
#
#
# - And is equivalent to
#
# ```
# SELECT
# 	*
# FROM
# 	(SELECT playerID, nameLast, nameFirst FROM Master ) as a
# WHERE
# 	nameLast LIKE 'William%'
# ```

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### Conceptual Data Model
#
# Reminder
# <br><br>
# <img src="../images/conceptuallogicalphysical.jpeg">
#
# - There are three entities
#     - _Master_ represents information about an individual in the database.
#     - _Appearances_ represents information about a person's appearances in games.
#     - _Batting_ represents information about a player's batting for teams and seasons.
#
#
# - How do you identify entity types/entities? From http://www.agiledata.org/essays/dataModeling101.html
#     - "An entity type, also simply called entity (not exactly accurate terminology, but very common in practice), is similar conceptually to object-orientation’s concept of a class – an entity type represents a collection of similar objects.  An entity type could represent a collection of people, places, things, events, or concepts. Examples of entities in an order entry system would include Customer, Address, Order, Item, and Tax. If you were class modeling you would expect to discover classes with the exact same names. However, the difference between a class and an entity type is that classes have both data and behavior whereas entity types just have data.
#     - "Ideally an entity should be normal, the data modeling world’s version of cohesive. A normal entity depicts one concept, just like a cohesive class models one concept. For example, customer and order are clearly two different concepts; therefore it makes sense to model them as separate entities."
#
#
# - How do you identity relationships?
#     - "In the real world entities have relationships with other entities.  For example, customers PLACE orders, customers LIVE AT addresses, and line items ARE PART OF orders. Place, live at, and are part of are all terms that define relationships between entities.  The relationships between entities are conceptually identical to the relationships (associations) between objects."
#
#
# <img src="../images/L3_baseball_conceptual.jpeg">

# %% [markdown]
# ### Logical Data Model
#
# ##### Overview
#
# - The logical data model requires adding:
#     - Attributes
#     - Primary Keys
#     - Foreign Keys
#
# ##### Attributes
#
# Identifying attributes (http://www.agiledata.org/essays/dataModeling101.html)
#
# - "Each entity type will have one or more data attributes.  For example,
#     - ... [a] Customer entity has attributes such as First Name and Surname and ...
#     - the TCUSTOMER table had corresponding data columns CUST_FIRST_NAME and CUST_SURNAME (a column is the implementation of a data attribute within a relational database).
#
#
# - Attributes should also be cohesive from the point of view of your domain, something that is often a judgment call. ... ...
#     - we decided that we wanted to model the fact that people had both first and last names instead of just a name (e.g. “Scott" and “Ambler" vs. “Scott Ambler")
#     - we did not distinguish between the sections of an American zip code (e.g. 90210-1234-5678).
#
#
# - Getting the level of detail right can have a significant impact on your development and maintenance efforts.
#     - Refactoring a single data column into several columns can be difficult, ...
#     - over-specifying an attribute (e.g. having three attributes for zip code when you only needed one) can result in overbuilding your system and hence you incur greater development and maintenance costs than you actually needed.
#
#
# - In our scenario,
#     - We were given the data, which partially defined the attributes.
#     - We could have, and will, re-factor how the given data fits into a good data model.
#
# <br><br>

# %% [markdown]
# <img src="../images/masterlogical.jpeg">
# <br>

# %% [markdown]
# <img src="../images/battinglogical.jpeg" width="80%">

# %% [markdown]
# <img src="../images/appearanceslogical.jpeg">

# %% [markdown]
# ##### Keys and Primary Keys
#
# Ramakrishnan and Gehrke, 2.4.1, 3.2
#
# _Relational Theory_
#
# (Entity) keys refers to a set of attributes that uniquely defines an entity in an entity set. Entity keys can be _super,_ _candidate_ or _primary._
# - _Super key:_ A set of attributes (one or more) that together define (uniquely identify) an entity in an entity set.
# - _Candidate key:_ A minimal super key, meaning it has the least possible number of attributes to still be a super key. An entity set may have more than one candidate key.
# - _Primary key:_ A candidate key chosen by the database designer to uniquely identify the entity set.
#
# In our data model,
# - _Master_ primary key is _playerID_
# - _Batting_ is more complicated.
#     - _playerID_ does not uniquely identify a row. Players play for many years.
#     - _(playerID, yearID)_ does not uniquely identify a row. A player could get traded, and play for more than a single team in a year.
#     - No problem, we can use _(playerID, yearID, teamID)._ But, a player can have more than one stint with a team in a year.
#     - The answer is _(playerID, yearID, stint)._
#         - How do I know this? I understand baseball.
#         - What if you or I do not understand the domain? We are typically working with a domain expert and these decisions are part of collaborative design in the local modeling phase.
# - _Appearances_ primary key is _(playerID, yearID, teamID)._
#
# _An aside:_ I ran the following queries for batting
# ```
# -- (1) What is the maximum number of rows for a given playerID? Also, look up the names.
# SELECT playerID,
# 	(SELECT nameLast FROM Master WHERE Master.playerID=Batting.playerID) as nameLast,
#     (SELECT nameFirst FROM Master WHERE Master.playerID=Batting.playerID) as nameFirst,
#     count(*) as row_count FROM batting GROUP BY playerID,nameFirst,nameLast
# 	ORDER BY row_count DESC LIMIT 1;
#
# -- (2) What is the maximum number of rows if I try playerID and yearID for a primary key? Also, look up the names.
# SELECT playerID,
# 	(SELECT nameLast FROM Master WHERE Master.playerID=Batting.playerID) as nameLast,
#     (SELECT nameFirst FROM Master WHERE Master.playerID=Batting.playerID) as nameFirst,
#     count(*) as row_count FROM batting GROUP BY playerID, yearID
# 	ORDER BY row_count DESC LIMIT 1;
#
# -- (3) Same question using playerID, yearID, teamID. Also, look up the names.
# SELECT playerID,
# 	(SELECT nameLast FROM Master WHERE Master.playerID=Batting.playerID) as nameLast,
#     (SELECT nameFirst FROM Master WHERE Master.playerID=Batting.playerID) as nameFirst,
#     count(*) as row_count FROM batting GROUP BY playerID, yearID, teamID
# 	ORDER BY row_count DESC LIMIT 1;
#
# -- (4) Same question using playerID, yearID, strint. Also, look up the names.
# SELECT playerID,
# 	(SELECT nameLast FROM Master WHERE Master.playerID=Batting.playerID) as nameLast,
#     (SELECT nameFirst FROM Master WHERE Master.playerID=Batting.playerID) as nameFirst,
#     count(*) as row_count FROM batting GROUP BY playerID,yearID,stint
# 	ORDER BY row_count DESC LIMIT 1;
# ```
#
# These queries returned the following information.
#
# | Query No. | Possible Key             | playerID  | last name | first name | row count |
# |-----------|--------------------------|-----------|-----------|------------|-----------|
# | 1         | playerID                 | mcguide01 | McGuire   | Deacon     | 31        |
# | 2         | playerID, yearID         | chouife01 | Chouinard | Felix      | 5         |
# | 3         | playerID, yearID, teamID | chouife01 | Chouinard | Felix      | 3         |
# | 4         | playerID, yearID, stint  | zay01     | Zay       | William    | 1         |
#
# What do the queries do?
# - For a possible key combination.
# - Count the maximum number of rows that have any common combination of keys.
# - Returns the largest count.
# - And provides information about one of the rows with the largest count.
#
# Do not worry if you do not understand these queries, _you will!_ But, the queries verify that _(playerID,yearID,stint)_ is uniquely identifies a row/entry.

# %% [markdown]
# ##### Foreign Keys
#
# Ramakrishan and Gehrke, section 3.2.2
#
# "In the context of relational databases, a foreign key is a field (or collection of fields) in one table that uniquely identifies a row of another table or the same table. In simpler words, the foreign key is defined in a second table, but it refers to the primary key or a unique key in the first table." (https://en.wikipedia.org/wiki/Foreign_key)
#
# There are at least two perspectives on _foreign key:_
# 1. Foreign keys implement _Integrity Constraint,_ which we will cover later. A tuple in one table can exists only if the foreign key matches a primary key in another table.
# 2. Foreign keys define _Relationships._ I can use a foreign key to find tuples in two different tables that are related.
#
# In our simple example
# - Batting.playerID is a foreign key for Master.playerID.
# - Appearances.playerID is a foreign key for Master.playerID.
#
# We will see this in more detail in future lectures.

# %% [markdown]
# ### SQL Data Model (Our Initial Physical Model)
#
# The physical model requires that we add the following:
#
#
# - The create table DDL statement
#     - Table names
#     - Column names
#     - Column data types
#
#
# - Instead of drawing a diagram, we will do directly in SQL DDL.
#
#
# - Note: We should adjust the column types and sizes.
#
# ```
# CREATE TABLE `Master` (
#   `playerID` varchar(255) NOT NULL,
#   `birthYear` int(11) DEFAULT NULL,
#   `birthMonth` int(11) NOT NULL,
#   `birthDay` int(11) DEFAULT NULL,
#   `birthCountry` varchar(255) DEFAULT NULL,
#   `birthState` varchar(255) DEFAULT NULL,
#   `birthCity` varchar(255) DEFAULT NULL,
#   `deathYear` varchar(255) DEFAULT NULL,
#   `deathMonth` varchar(255) DEFAULT NULL,
#   `deathDay` varchar(255) DEFAULT NULL,
#   `deathCountry` varchar(255) DEFAULT NULL,
#   `deathState` varchar(255) DEFAULT NULL,
#   `deathCity` varchar(255) DEFAULT NULL,
#   `nameFirst` varchar(255) NOT NULL,
#   `nameLast` varchar(255) NOT NULL,
#   `nameGiven` varchar(255) DEFAULT NULL,
#   `weight` int(11) DEFAULT NULL,
#   `height` int(11) DEFAULT NULL,
#   `bats` varchar(255) DEFAULT NULL,
#   `throws` varchar(255) DEFAULT NULL,
#   `debut` varchar(255) DEFAULT NULL,
#   `finalGame` varchar(255) DEFAULT NULL,
#   `retroID` varchar(255) DEFAULT NULL,
#   `bbrefID` varchar(255) DEFAULT NULL,
#   PRIMARY KEY (`playerID`),
#   KEY `player_idx` (`playerID`),
#   KEY `name_l` (`nameLast`),
#   KEY `name_f` (`nameFirst`)
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
#
# CREATE TABLE `Appearances` (
#   `yearID` int(11) NOT NULL,
#   `teamID` varchar(255) NOT NULL,
#   `lgID` varchar(255) DEFAULT NULL,
#   `playerID` varchar(255) NOT NULL,
#   `G_all` int(11) DEFAULT NULL,
#   `GS` varchar(255) DEFAULT NULL,
#   `G_batting` int(11) DEFAULT NULL,
#   `G_defense` int(11) DEFAULT NULL,
#   `G_p` int(11) DEFAULT NULL,
#   `G_c` int(11) DEFAULT NULL,
#   `G_1b` int(11) DEFAULT NULL,
#   `G_2b` int(11) DEFAULT NULL,
#   `G_3b` int(11) DEFAULT NULL,
#   `G_ss` int(11) DEFAULT NULL,
#   `G_lf` int(11) DEFAULT NULL,
#   `G_cf` int(11) DEFAULT NULL,
#   `G_rf` int(11) DEFAULT NULL,
#   `G_of` int(11) DEFAULT NULL,
#   `G_dh` varchar(255) DEFAULT NULL,
#   `G_ph` varchar(255) DEFAULT NULL,
#   `G_pr` varchar(255) DEFAULT NULL,
#   PRIMARY KEY (`yearID`,`teamID`,`playerID`),
#   UNIQUE KEY `ux` (`playerID`,`teamID`,`yearID`),
#   KEY `player_idx` (`playerID`),
#   KEY `year_idx` (`yearID`) USING BTREE,
#   CONSTRAINT `playerID` FOREIGN KEY (`playerID`) REFERENCES `Master` (`playerID`) ON DELETE NO ACTION ON UPDATE NO ACTION
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
#
# CREATE TABLE `Batting` (
#   `playerID` varchar(255) NOT NULL,
#   `yearID` int(11) NOT NULL,
#   `stint` int(11) NOT NULL,
#   `teamID` varchar(255) DEFAULT NULL,
#   `lgID` varchar(255) DEFAULT NULL,
#   `G` int(11) DEFAULT NULL,
#   `AB` int(11) DEFAULT NULL,
#   `R` int(11) DEFAULT NULL,
#   `H` int(11) DEFAULT NULL,
#   `2B` int(11) DEFAULT NULL,
#   `3B` int(11) DEFAULT NULL,
#   `HR` int(11) DEFAULT NULL,
#   `RBI` int(11) DEFAULT NULL,
#   `SB` int(11) DEFAULT NULL,
#   `CS` int(11) DEFAULT NULL,
#   `BB` int(11) DEFAULT NULL,
#   `SO` int(11) DEFAULT NULL,
#   `IBB` varchar(255) DEFAULT NULL,
#   `HBP` varchar(255) DEFAULT NULL,
#   `SH` varchar(255) DEFAULT NULL,
#   `SF` varchar(255) DEFAULT NULL,
#   `GIDP` varchar(255) DEFAULT NULL,
#   PRIMARY KEY (`playerID`,`yearID`,`stint`),
#   CONSTRAINT `batting_player` FOREIGN KEY (`playerID`) REFERENCES `Master` (`playerID`) ON DELETE NO ACTION ON UPDATE NO ACTION
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
#
# ```
#
# - The core SQL column types are
# <br><br>
# <img src="../images/datatypes.jpg">
#
#
# - All database management systems significantly extend the set of data/column types.
#
#
# - The length options play a significant role in the database management systems optimization of storage use, which we will cover in future lectures.
#     - INT(8), INT(11), TINY INT, ...
#     - VARCHAR(16), VARCHAR(1024), ...
#
#
# - If we have the DDL defined and have created the tables, we can _reverse engineer_ the physical model.
#
#
# - The line endings have very precise meanings, which we will cover in future lectures.
#
#
# <img src="../images/scenario1physical.jpeg">

# %% [markdown]
# ### Web Resource Model -- Getting Started
#
# We plan to start gathering displaying information about players. Our web resource model (URLs) with be
# - /players?<query> to find players matching a template.
# - /players/playerID to find a specific player.
#
# _Example_
#
# GET http://localhost:8000/baseball/api/players/napolmi01
#
# Returns
#
# ```
# {
#     "playerID": "napolmi01",
#     "birthYear": 1981,
#     "birthMonth": "10",
#     "birthDay": 31,
#     "birthCountry": "USA",
#     "birthState": "FL",
#     "birthCity": "Hollywood",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Mike",
#     "nameLast": "Napoli",
#     "nameGiven": "Michael Anthony",
#     "weight": 225,
#     "height": 73,
#     "bats": "R",
#     "throws": "R",
#     "debut": "2006-05-04",
#     "finalGame": "2016-10-02",
#     "retroID": "napom001",
#     "bbrefID": "napolmi01"
# }
# ```
#
# <img src="../images/playergetpostman.jpeg">
