# %% [markdown]
# # COMS W4111-02 Spring 2018 Take Home Midterm

# %% [markdown]
# ## Instructions

# %% [markdown]
# ##

# %%
# %load_ext sql
# %sql sqlite:///webshop.sqlite
# Out:
# 'Connected: None@webshop.sqlite'

# %%
# %sql select * from sales
# Out:
# Done.
# [('2', '13_Jul_2012', 'Wayne_Enterprises', 'Sports_Tent_for_extreme_weather', 'Europe_Spain', 3.0, 190.05),
#  ('3', '24_May_2013', 'Flowers_By_Irene', 'Sports_Snowboard_table', 'Europe_Denmark', 1.0, 261.9),
#  ('4', '18_Dec_2013', 'Mammoth_Pictures', 'Sports_Mountain_Bike', 'South_America_Ecuador', 1.0, 257.75),
#  ('5', '14_Feb_2013', 'Transworld_Consortium', 'Sports_Mountain_Bike', 'North_America_United_States_of_America', 1.0, 242.1),
#  ('6', '05_Feb_2012', 'Demo_Company', 'Sports_Snowboard_table', 'South_America_Uruguay', 2.0, 241.5),
#  ('7', '23_Mar_2012', 'Powell_Motors', 'Sports_Mountain_Bike', 'Europe_Spain', 1.0, 236.5),
#  ('8', '27_Sep_2012', 'Industrial_Automation', 'Sports_Mountain_Bike', 'Europe_Spain', 1.0, 236.5),
#  ('9', '20_Jun_2012', 'Wentworth_Industries', 'Various_Various', 'Europe_Ireland', 1.0, 242.5),
#  ('10', '15_Jan_2013', 'Acme__inc_', 'Sports_Mountain_Bike', 'Europe_Spain', 1.0, 217.0),
# ...
