# %% [markdown]
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# <h1 style="display:none;">Test</h1>
# # Introduction to Databases: Relational, SQL and Modeling Details

# %%
# %load_ext sql
# %sql mysql+pymysql://dbuser:dbuser@localhost/lahman2017
# %sql select * from people where playerid='willite01'
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# (pymysql.err.OperationalError) (2006, "MySQL server has gone away (BrokenPipeError(32, 'Broken pipe'))") [SQL: "select * from people where playerid='willite01'"]

# %% [markdown]
# ## Questions or Comments?

# %% [markdown]
# ## Lecture Overview

# %% [markdown]
# ## Different Types of Database Applications/Systems
#
# ### The Big Picture
#
# - There are several (too many) ways to classify applications and scenarios that use databases. Some examples
#
#
# - One classification approach:
#     - <span style="color: red;"> _Real-time (online) systems,_ where you submit requests to do a small amount of work that has to be done before some very early deadline, or interactively why the user waits.</span>
#     - _Batch processing systems,_ where you submit a a bunch of files, a "job" containing multiple subprograms, and later receive output in the form of a file.
#     - _Data warehouse systems,_ where reporting programs and ad hoc queries access data that is integrated from multiple data sources.
#
#
# - Real-time (online) system:
#     - Most familiar is interactive web applications, e.g. CourseWorks, online banking.
#     - Other examples: ATMs, airline check-in kiosks and boarding pass readers, ...
#
# <br><br>
#
# | <img src="../../images/simple_aws_web_app.jpeg" width="75%"> |
# | :---: |
# | Web Application Architecture |
#
# <br><br>
#
#
# - Big data/Batch processing:
#     - These applications are usually in the backend and not directly seen by users.
#     - The applications process and produce information used by other applications.
#     - Examples: recommendation engines for commerce web sites, Google Analytics.
#
# <br><br>
#
# | <img src="../../images/google_analytics.jpeg"> |
# | :---: |
# | Google Analytics |
#
# <br><br>
#
# | <img src="../../images/batch_1.jpeg"> |
# | :---: |
# | [Batch Processing](https://www.datasciencecentral.com/profiles/blogs/batch-vs-real-time-data-processing) |

# %% [markdown]
# - Each stage in batch processing is multiple, smaller jobs/applications that have to run in specific orders.
#
#
# - [MapReduce](https://en.wikipedia.org/wiki/MapReduce) and [Hadoop](https://en.wikipedia.org/wiki/Apache_Hadoop) are modern approaches to batch processing.
#
#
# - I am going to try to find a way to do a little of this, but setting up all of the SW is complex.
#
#
# | <img src="../../images/map_reduce_1.jpeg"> |
# | :---: |
# | __Map-Reduce__ |
#
# ### Other Classifications and Models
#
# - Another classification approach is to think of the _functions_ the databases support.
#
#
# - A data processing system may involve some combination of the following functions
#     - Conversion - converting data to another format.
#     - Validation – Ensuring that supplied data is "clean, correct and useful."
#     - Sorting – "arranging items in some sequence and/or in different sets."
#     - Summarization – reducing detail data to its main points.
#     - Aggregation – combining multiple pieces of data.
#     - Analysis – the "collection, organization, analysis, interpretation and presentation of data.".
#     - Reporting – list detail or summary data or computed information.
#
#
# - Both SQL/online and batch/MaoReduce/Hadoop have operators/steps implementing the functions. For example,
#     - Summarization can be a Reducer in MapReduce and a GROUP BY operator in RDBs
#     - Many batch systems use SQL and extensions as the language for programming mappers, shufflers, reducers, etc.
#
# - A third classification approach
#     - <span style="color: red;">Operational Database:</span> SSOL, CourseWorks, etc. are examples.
#     - <span style="color: red;">External Database:</span> On-line banking, IMDB, etc. are examples.
#     - End User Database: The local caches of data for mobile applications are an example.
#     - Distributed Database
#     - Data Warehouse Database:
#         - Operational databases create-retrieve-update-delete data during on-line processing.
#         - Data Warehouse is a transformed copy of the data for more complex, read only queries and reports.
#     - Analytical Database
#     - Hypermedia Database: Database for storing, retrieving, categorizing, searching, etc. linked, unstructured content like documents, images, recording, etc. You can consider the web itself to be a Hypermedia Database.

# %% [markdown]
# - Data Warehouse Database:
#     - Operational databases create-retrieve-update-delete data during on-line processing.
#     - Data Warehouse is a transformed copy of the data for more complex, read only queries and reports.
#     - We will do OLAP and analysis in the course, but on a small scale. The scenarios assume that ETL has already loaded the simple warehouse.
#
# | <img src="../../images/data_warehouse_architecture.jpg"> |
# | :---: |
# | __Data Warehouse__ |

# %% [markdown]
# ## Web Applications
#
# ### Overview
#
# | <img src="../../images/webapp.jpeg"> |
# | :---: |
# | __Web Application Architecture__ |

# %% [markdown]
# - (Static) Content are various forms of semi-structured or unstructured data files. The browser, e.g. Chrome, retrieves and interprets the data files to render the browser page(s). Examples of file types are:
#     - HTML: [Hypertext Markup Language](https://en.wikipedia.org/wiki/HTML)- Rich text and documents.
#     - [JPEG](https://en.wikipedia.org/wiki/JPEG): Images
#     - [MP4](https://en.wikipedia.org/wiki/MPEG-4_Part_14): Videos
#     - [CSS](https://en.wikipedia.org/wiki/Cascading_Style_Sheets): Cascading Style Sheets - Customize colors, fonts, etc.
#
# | <img src ="../../images/web_app_ui.jpeg"> |
# | :---: |
# | __HTML, JPEG, CSS UI__|

# %% [markdown]
# - The static content is a directory structure of files.
#
#
# - http://127.0.0.1:5000 connects to the local server using [HTTP](https://en.wikipedia.org/wiki/Hypertext_Transfer_Protocol).
#     - The root directory is /static, but this is just a convention or choice.
#     - Some paths
#         - /static/W4111/index.html: The main page.
#         - /static/W4111/images/columbia.jpg: The picture of Columbia's campus.
#         - /static/W4111/homeController.js: JavaScript controller code that the browser will download and execute.
#
# | <img src ="../../images/static_content.jpeg"> |
# | :---: |
# | __Static Content__|

# %% [markdown]
# - Controllers and service/model scripts implement elements of a UI pattern:
#     - [Model-View-Controller (MVC)](https://en.wikipedia.org/wiki/Model%E2%80%93view%E2%80%93controller)
#     - [Model-View-Viewmodel (MVVM)](https://en.wikipedia.org/wiki/Model%E2%80%93view%E2%80%93viewmodel)
#     - This code uses [AngularJS](https://en.wikipedia.org/wiki/AngularJS) for the basis of the implementation.
#
# |<img src="../../images/angular_mvc.jpg"> |
# | :---: |
# | __AngularJS__ |

# %% [markdown]
# - /api will contain code that runs on the server side. Will implement CRUD and other logic for various REST resources.
#
#
# - /lahman is the "main program" and exposes the APIs via REST.
#
#
# - There are MANY good on-line tutorials for learning the basics of all of these technologies.

# %% [markdown]
# ## Representational State Transfer (REST)
#
# - "Representational State Transfer (REST) is an architectural style that defines a set of constraints to be used for creating web services. Web Services that conform to the REST architectural style, or RESTful web services, provide interoperability between computer systems on the Internet. REST-compliant web services allow the requesting systems to access and manipulate textual representations of web resources by __using a uniform and predefined set of stateless operations.__ Other kinds of web services, such as SOAP web services, expose their own arbitrary sets of operations." \(Emphasis added\).(https://en.wikipedia.org/wiki/Representational_state_transfer)
#
#
# - Non-RESTful applications surface service/domain specific operations, e.g.
#     - ```open_account(...)```
#     - ```transfer(...)```
#     - ```check_balance(...)```
#
#
# - The uniform, predefined REST operations are the HTTP Methods:
#     - GET
#     - PUT (or PATCH)
#     - POST
#     - DELETE
#
#
# - These represent Create-Retrieve-Update-Delete operations on __resources__ identified by __URLs.__
#     - POST is Create
#     - GET is Retrieve
#     - PUT (or PATCH) is Update
#     - DELETE is Delete.
#
#
# - __Note:__ People often confuse:
#     - Remote procedure call/service invocation using HTTP
#     - REST
#     - They are not the same thing.
#
#
# - The six core characteristics of the REST style are:
#     1. Client–server architecture
#     1. Statelessness
#     3. Cacheability
#     3. Layered system
#     4. Code on demand (optional)
#     6. Uniform interface
#
#
# - You may also hear the term __Hypermedia As The Engine Of Application State (HATEOAS).__
#
#
# | <img src="../../images/rest-client-server.jpg"> |
# | :---: |
# | __REST Client Server__ |
#
#
# - We will not spend too much time on the full details of REST. I have covered in my 6998 and 6156 courses.
#
#
# - The core concepts for the purposes of this course are:
#     - POST maps to SQL INSERT.
#     - GET maps to SQL SELECT.
#     - PUT maps to SQL UPDATE.
#     - DELETE maps to SQL DELETE.

# %% [markdown]
# ## REST-SQL Basic Mapping
#
# ### Overview
#
# - [Thoughts on RESTful API Design](https://restful-api-design.readthedocs.io/en/latest/) is good introduction to the concept of resources and REST.
#
#
# - The core REST/HTTP concept is a __resource.__
#
#
# "The fundamental concept in any RESTful API is the resource. A resource is an object with a type, associated data, relationships to other resources, and a set of methods that operate on it. It is similar to an object instance in an object-oriented programming language, with the important difference that only a few standard methods are defined for the resource (corresponding to the standard HTTP GET, POST, PUT and DELETE methods), while an object instance typically has many methods.
#
# Resources can be grouped into collections. Each collection is homogeneous so that it contains only one type of resource, and unordered. Resources can also exist outside any collection. In this case, we refer to these resources as singleton resources. Collections are themselves resources as well.
#
# Collections can exist globally, at the top level of an API, but can also be contained inside a single resource. In the latter case, we refer to these collections as sub-collections. Sub-collections are usually used to express some kind of “contained in” relationship." (https://restful-api-design.readthedocs.io/en/latest/resources.html)
#
#
# | <img src="https://restful-api-design.readthedocs.io/en/latest/_images/concepts.png"> |
# | :---: |
# | __Resource__ |

# %% [markdown]
# - Very simplistically, the mapping is:
#     - OO
#         - Collection usually often _class_ but often also often an instance of a _collection class._
#         - Resource maps to _object instance._
#         - Sub-collection and sub-resource map to _containment_ in OO.
#     - Entity-Relationship/Relational:
#         - Collection maps to a _relation_ (aka _table._)
#         - Resource maps to a _row_ (aka _tuple._)
#         - Sub-resources map to a _weak entity._ (Ramakrishnan and Gherke, pp. 35,36)
#
#
# - You "locate" or "identify" a REST resource with a _Uniform Resource Identifier (URI)._ "A Uniform Resource Identifier (URI) is a string of characters that unambiguously identifies a particular resource. To guarantee uniformity, all URIs follow a predefined set of syntax rules ..." (https://en.wikipedia.org/wiki/Uniform_Resource_Identifier)
#
#
# - A [Uniform Resource Locator (URL)](https://en.wikipedia.org/wiki/URL) A Uniform Resource Locator (URL), colloquially termed a web address,[1] is a reference to a web resource that specifies its location on a computer network and a mechanism for retrieving it. A URL is a specific type of Uniform Resource Identifier (URI),[2][3] although many people use the two terms interchangeably.[4][a] URLs occur most commonly to reference web pages (http), but are also used for file transfer (ftp), email (mailto), database access (JDBC), and many other applications.
#
#
# - "Every HTTP URL conforms to the syntax of a generic URI. The URI generic syntax consists of a hierarchical sequence of five components:" The components are:
#     1. Scheme
#     2. Authority
#     3. Path
#     4. Query
#     5. Fragment
#
# ```
# URI = scheme:[//authority]path[?query][#fragment]
# where the authority component divides into three subcomponents:
#
# authority = [userinfo@]host[:port]
# ```
#
#
# - Normally,
#     - The URL/URI maps to _business logic_ that implements enhanced functions on top of the database and not directly to the underlying data.
#     - Since this is a "database" course, many of our REST paths/resources will go directly to the database.
#
#
# - We have already seen examples of URLs:
#
# ```
#  mysql+pymysql://dbuser:dbuser@localhost/lahman2017
# ```

# %% [markdown]
# ### Resource/REST Mappings to SQL
#
# #### GET
#
# ##### Pattern 1: Primary Key
#
# - Consider GET on ```/People/willite01```.
#
#
# - This retrieves a specific row/tuple in a relation/table.
#
#
# - This maps to ```SELECT * FROM People where playerID='willite01'.```

# %%
# This is an example of some of the code that would run in a client.
# This is Python code. There is similar code for JavaScript.
# I am using Python because this is an iPython Notebook.
import requests
import json
r = requests.get("http://127.0.0.1:5000/api/lahman2017/people/willite01")
result = r.json()

print("The result is: \n", json.dumps(result, indent=2))
# Out:
# The result is:
#  {
#   "data": {
#     "playerID": {
#       "value": "willite01",
#       "link": {
#         "rel": "people",
#         "href": "/api/people/willite01"
#       }
#     },
#     "birthYear": 1918,
#     "birthMonth": 8,
#     "birthDay": 30,
#     "birthCountry": "USA",
#     "birthState": "CA",
#     "birthCity": "San Diego",
#     "deathYear": 2002,
#     "deathMonth": 7,
#     "deathDay": 5,
#     "deathCountry": "USA",
#     "deathState": "FL",
#     "deathCity": "Inverness",
#     "nameFirst": "Ted",
#     "nameLast": "Williams",
#     "nameGiven": "Theodore Samuel",
#     "weight": "205",
#     "height": "75",
#     "bats": "L",
#     "throws": "R",
#     "debut": "1939-04-20",
#     "finalGame": "1960-09-28",
#     "retroID": "willt103",
#     "bbrefID": "willite01",
#     "DOD": "2002-07-05",
#     "DOB": "1918-08-30",
#     "appearances": [
#       {
#         "yearID": "1939",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "149",
#         "GS": "149",
#         "G_batting": "149",
#         "G_defense": "149",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "0",
#         "G_cf": "0",
#         "G_rf": "149",
#         "G_of": "149",
#         "G_dh": "0",
#         "G_ph": "0",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1940",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "144",
#         "GS": "143",
#         "G_batting": "144",
#         "G_defense": "143",
#         "G_p": "1",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "129",
#         "G_cf": "0",
#         "G_rf": "15",
#         "G_of": "143",
#         "G_dh": "0",
#         "G_ph": "0",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1941",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "143",
#         "GS": "133",
#         "G_batting": "143",
#         "G_defense": "133",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "130",
#         "G_cf": "0",
#         "G_rf": "4",
#         "G_of": "133",
#         "G_dh": "0",
#         "G_ph": "5",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1942",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "150",
#         "GS": "150",
#         "G_batting": "150",
#         "G_defense": "150",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "149",
#         "G_cf": "0",
#         "G_rf": "1",
#         "G_of": "150",
#         "G_dh": "0",
#         "G_ph": "0",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1946",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "150",
#         "GS": "150",
#         "G_batting": "150",
#         "G_defense": "150",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "150",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "150",
#         "G_dh": "0",
#         "G_ph": "0",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1947",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "156",
#         "GS": "156",
#         "G_batting": "156",
#         "G_defense": "156",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "156",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "156",
#         "G_dh": "0",
#         "G_ph": "0",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1948",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "137",
#         "GS": "134",
#         "G_batting": "137",
#         "G_defense": "134",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "134",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "134",
#         "G_dh": "0",
#         "G_ph": "3",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1949",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "155",
#         "GS": "155",
#         "G_batting": "155",
#         "G_defense": "155",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "155",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "155",
#         "G_dh": "0",
#         "G_ph": "0",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1950",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "89",
#         "GS": "86",
#         "G_batting": "89",
#         "G_defense": "86",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "86",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "86",
#         "G_dh": "0",
#         "G_ph": "3",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1951",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "148",
#         "GS": "147",
#         "G_batting": "148",
#         "G_defense": "147",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "147",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "147",
#         "G_dh": "0",
#         "G_ph": "1",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1952",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "6",
#         "GS": "2",
#         "G_batting": "6",
#         "G_defense": "2",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "2",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "2",
#         "G_dh": "0",
#         "G_ph": "4",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1953",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "37",
#         "GS": "26",
#         "G_batting": "37",
#         "G_defense": "26",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "26",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "26",
#         "G_dh": "0",
#         "G_ph": "11",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1954",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "117",
#         "GS": "113",
#         "G_batting": "117",
#         "G_defense": "115",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "115",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "115",
#         "G_dh": "0",
#         "G_ph": "4",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1955",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "98",
#         "GS": "93",
#         "G_batting": "98",
#         "G_defense": "93",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "93",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "93",
#         "G_dh": "0",
#         "G_ph": "5",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1956",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "136",
#         "GS": "110",
#         "G_batting": "136",
#         "G_defense": "109",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "109",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "109",
#         "G_dh": "0",
#         "G_ph": "26",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1957",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "132",
#         "GS": "125",
#         "G_batting": "132",
#         "G_defense": "125",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "125",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "125",
#         "G_dh": "0",
#         "G_ph": "7",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1958",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "129",
#         "GS": "114",
#         "G_batting": "129",
#         "G_defense": "114",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "114",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "114",
#         "G_dh": "0",
#         "G_ph": "15",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1959",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "103",
#         "GS": "75",
#         "G_batting": "103",
#         "G_defense": "76",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "76",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "76",
#         "G_dh": "0",
#         "G_ph": "28",
#         "G_pr": "0"
#       },
#       {
#         "yearID": "1960",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "playerID": "willite01",
#         "G_all": "113",
#         "GS": "87",
#         "G_batting": "113",
#         "G_defense": "86",
#         "G_p": "0",
#         "G_c": "0",
#         "G_1b": "0",
#         "G_2b": "0",
#         "G_3b": "0",
#         "G_ss": "0",
#         "G_lf": "86",
#         "G_cf": "0",
#         "G_rf": "0",
#         "G_of": "86",
#         "G_dh": "0",
#         "G_ph": "26",
#         "G_pr": "0"
#       }
#     ],
#     "batting": [
#       {
#         "playerID": "willite01",
#         "yearID": "1939",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "149",
#         "AB": "565",
#         "R": "131",
#         "H": "185",
#         "2B": "44",
#         "3B": "11",
#         "HR": "31",
#         "RBI": "145",
#         "SB": "2",
#         "CS": "1",
#         "BB": "107",
#         "SO": "64",
#         "IBB": "",
#         "HBP": "2",
#         "SH": "3",
#         "SF": "",
#         "GIDP": "10"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1940",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "144",
#         "AB": "561",
#         "R": "134",
#         "H": "193",
#         "2B": "43",
#         "3B": "14",
#         "HR": "23",
#         "RBI": "113",
#         "SB": "4",
#         "CS": "4",
#         "BB": "96",
#         "SO": "54",
#         "IBB": "",
#         "HBP": "3",
#         "SH": "1",
#         "SF": "",
#         "GIDP": "13"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1941",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "143",
#         "AB": "456",
#         "R": "135",
#         "H": "185",
#         "2B": "33",
#         "3B": "3",
#         "HR": "37",
#         "RBI": "120",
#         "SB": "2",
#         "CS": "4",
#         "BB": "147",
#         "SO": "27",
#         "IBB": "",
#         "HBP": "3",
#         "SH": "0",
#         "SF": "",
#         "GIDP": "10"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1942",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "150",
#         "AB": "522",
#         "R": "141",
#         "H": "186",
#         "2B": "34",
#         "3B": "5",
#         "HR": "36",
#         "RBI": "137",
#         "SB": "3",
#         "CS": "2",
#         "BB": "145",
#         "SO": "51",
#         "IBB": "",
#         "HBP": "4",
#         "SH": "0",
#         "SF": "",
#         "GIDP": "12"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1946",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "150",
#         "AB": "514",
#         "R": "142",
#         "H": "176",
#         "2B": "37",
#         "3B": "8",
#         "HR": "38",
#         "RBI": "123",
#         "SB": "0",
#         "CS": "0",
#         "BB": "156",
#         "SO": "44",
#         "IBB": "",
#         "HBP": "2",
#         "SH": "0",
#         "SF": "",
#         "GIDP": "12"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1947",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "156",
#         "AB": "528",
#         "R": "125",
#         "H": "181",
#         "2B": "40",
#         "3B": "9",
#         "HR": "32",
#         "RBI": "114",
#         "SB": "0",
#         "CS": "1",
#         "BB": "162",
#         "SO": "47",
#         "IBB": "",
#         "HBP": "2",
#         "SH": "1",
#         "SF": "",
#         "GIDP": "10"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1948",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "137",
#         "AB": "509",
#         "R": "124",
#         "H": "188",
#         "2B": "44",
#         "3B": "3",
#         "HR": "25",
#         "RBI": "127",
#         "SB": "4",
#         "CS": "0",
#         "BB": "126",
#         "SO": "41",
#         "IBB": "",
#         "HBP": "3",
#         "SH": "0",
#         "SF": "",
#         "GIDP": "10"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1949",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "155",
#         "AB": "566",
#         "R": "150",
#         "H": "194",
#         "2B": "39",
#         "3B": "3",
#         "HR": "43",
#         "RBI": "159",
#         "SB": "1",
#         "CS": "1",
#         "BB": "162",
#         "SO": "48",
#         "IBB": "",
#         "HBP": "2",
#         "SH": "0",
#         "SF": "",
#         "GIDP": "22"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1950",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "89",
#         "AB": "334",
#         "R": "82",
#         "H": "106",
#         "2B": "24",
#         "3B": "1",
#         "HR": "28",
#         "RBI": "97",
#         "SB": "3",
#         "CS": "0",
#         "BB": "82",
#         "SO": "21",
#         "IBB": "",
#         "HBP": "0",
#         "SH": "0",
#         "SF": "",
#         "GIDP": "12"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1951",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "148",
#         "AB": "531",
#         "R": "109",
#         "H": "169",
#         "2B": "28",
#         "3B": "4",
#         "HR": "30",
#         "RBI": "126",
#         "SB": "1",
#         "CS": "1",
#         "BB": "144",
#         "SO": "45",
#         "IBB": "",
#         "HBP": "0",
#         "SH": "0",
#         "SF": "",
#         "GIDP": "10"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1952",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "6",
#         "AB": "10",
#         "R": "2",
#         "H": "4",
#         "2B": "0",
#         "3B": "1",
#         "HR": "1",
#         "RBI": "3",
#         "SB": "0",
#         "CS": "0",
#         "BB": "2",
#         "SO": "2",
#         "IBB": "",
#         "HBP": "0",
#         "SH": "0",
#         "SF": "",
#         "GIDP": "0"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1953",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "37",
#         "AB": "91",
#         "R": "17",
#         "H": "37",
#         "2B": "6",
#         "3B": "0",
#         "HR": "13",
#         "RBI": "34",
#         "SB": "0",
#         "CS": "1",
#         "BB": "19",
#         "SO": "10",
#         "IBB": "",
#         "HBP": "0",
#         "SH": "0",
#         "SF": "",
#         "GIDP": "1"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1954",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "117",
#         "AB": "386",
#         "R": "93",
#         "H": "133",
#         "2B": "23",
#         "3B": "1",
#         "HR": "29",
#         "RBI": "89",
#         "SB": "0",
#         "CS": "0",
#         "BB": "136",
#         "SO": "32",
#         "IBB": "",
#         "HBP": "1",
#         "SH": "0",
#         "SF": "3",
#         "GIDP": "10"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1955",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "98",
#         "AB": "320",
#         "R": "77",
#         "H": "114",
#         "2B": "21",
#         "3B": "3",
#         "HR": "28",
#         "RBI": "83",
#         "SB": "2",
#         "CS": "0",
#         "BB": "91",
#         "SO": "24",
#         "IBB": "17",
#         "HBP": "2",
#         "SH": "0",
#         "SF": "4",
#         "GIDP": "8"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1956",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "136",
#         "AB": "400",
#         "R": "71",
#         "H": "138",
#         "2B": "28",
#         "3B": "2",
#         "HR": "24",
#         "RBI": "82",
#         "SB": "0",
#         "CS": "0",
#         "BB": "102",
#         "SO": "39",
#         "IBB": "11",
#         "HBP": "1",
#         "SH": "0",
#         "SF": "0",
#         "GIDP": "13"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1957",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "132",
#         "AB": "420",
#         "R": "96",
#         "H": "163",
#         "2B": "28",
#         "3B": "1",
#         "HR": "38",
#         "RBI": "87",
#         "SB": "0",
#         "CS": "1",
#         "BB": "119",
#         "SO": "43",
#         "IBB": "33",
#         "HBP": "5",
#         "SH": "0",
#         "SF": "2",
#         "GIDP": "11"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1958",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "129",
#         "AB": "411",
#         "R": "81",
#         "H": "135",
#         "2B": "23",
#         "3B": "2",
#         "HR": "26",
#         "RBI": "85",
#         "SB": "1",
#         "CS": "0",
#         "BB": "98",
#         "SO": "49",
#         "IBB": "12",
#         "HBP": "4",
#         "SH": "0",
#         "SF": "4",
#         "GIDP": "19"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1959",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "103",
#         "AB": "272",
#         "R": "32",
#         "H": "69",
#         "2B": "15",
#         "3B": "0",
#         "HR": "10",
#         "RBI": "43",
#         "SB": "0",
#         "CS": "0",
#         "BB": "52",
#         "SO": "27",
#         "IBB": "6",
#         "HBP": "2",
#         "SH": "0",
#         "SF": "5",
#         "GIDP": "7"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1960",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "G": "113",
#         "AB": "310",
#         "R": "56",
#         "H": "98",
#         "2B": "15",
#         "3B": "0",
#         "HR": "29",
#         "RBI": "72",
#         "SB": "1",
#         "CS": "1",
#         "BB": "75",
#         "SO": "41",
#         "IBB": "7",
#         "HBP": "3",
#         "SH": "0",
#         "SF": "2",
#         "GIDP": "7"
#       }
#     ],
#     "fielding": [
#       {
#         "playerID": "willite01",
#         "yearID": "1939",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 149,
#         "GS": null,
#         "InnOuts": "",
#         "PO": "318",
#         "A": "11",
#         "E": "19",
#         "DP": "3",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1940",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "P",
#         "G": 1,
#         "GS": null,
#         "InnOuts": "",
#         "PO": "0",
#         "A": "2",
#         "E": "0",
#         "DP": "0",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1940",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 143,
#         "GS": null,
#         "InnOuts": "",
#         "PO": "302",
#         "A": "13",
#         "E": "13",
#         "DP": "2",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1941",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 133,
#         "GS": null,
#         "InnOuts": "",
#         "PO": "262",
#         "A": "11",
#         "E": "11",
#         "DP": "2",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1942",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 150,
#         "GS": null,
#         "InnOuts": "",
#         "PO": "312",
#         "A": "15",
#         "E": "4",
#         "DP": "4",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1946",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 150,
#         "GS": null,
#         "InnOuts": "",
#         "PO": "325",
#         "A": "7",
#         "E": "10",
#         "DP": "2",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1947",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 156,
#         "GS": null,
#         "InnOuts": "",
#         "PO": "347",
#         "A": "10",
#         "E": "9",
#         "DP": "2",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1948",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 134,
#         "GS": null,
#         "InnOuts": "",
#         "PO": "289",
#         "A": "9",
#         "E": "5",
#         "DP": "2",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1949",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 155,
#         "GS": null,
#         "InnOuts": "",
#         "PO": "337",
#         "A": "12",
#         "E": "6",
#         "DP": "3",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1950",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 86,
#         "GS": null,
#         "InnOuts": "",
#         "PO": "165",
#         "A": "7",
#         "E": "8",
#         "DP": "0",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1951",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 147,
#         "GS": null,
#         "InnOuts": "",
#         "PO": "315",
#         "A": "12",
#         "E": "4",
#         "DP": "6",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1952",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 2,
#         "GS": null,
#         "InnOuts": "",
#         "PO": "4",
#         "A": "0",
#         "E": "0",
#         "DP": "0",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1953",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 26,
#         "GS": null,
#         "InnOuts": "",
#         "PO": "31",
#         "A": "1",
#         "E": "1",
#         "DP": "1",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1954",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 115,
#         "GS": 113,
#         "InnOuts": "2887",
#         "PO": "213",
#         "A": "5",
#         "E": "4",
#         "DP": "0",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1955",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 93,
#         "GS": 93,
#         "InnOuts": "2192",
#         "PO": "170",
#         "A": "5",
#         "E": "2",
#         "DP": "0",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1956",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 110,
#         "GS": 110,
#         "InnOuts": "2579",
#         "PO": "174",
#         "A": "7",
#         "E": "5",
#         "DP": "2",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1957",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 125,
#         "GS": 125,
#         "InnOuts": "2966",
#         "PO": "215",
#         "A": "2",
#         "E": "1",
#         "DP": "0",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1958",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 114,
#         "GS": 114,
#         "InnOuts": "2762",
#         "PO": "154",
#         "A": "3",
#         "E": "7",
#         "DP": "0",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1959",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 76,
#         "GS": 75,
#         "InnOuts": "1648",
#         "PO": "94",
#         "A": "4",
#         "E": "3",
#         "DP": "0",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1960",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "POS": "OF",
#         "G": 87,
#         "GS": 87,
#         "InnOuts": "2028",
#         "PO": "131",
#         "A": "6",
#         "E": "1",
#         "DP": "1",
#         "PB": "",
#         "WP": "",
#         "SB": "",
#         "CS": "",
#         "ZR": ""
#       }
#     ],
#     "managers": [
#       {
#         "playerID": "willite01",
#         "yearID": "1972",
#         "teamID": "TEX",
#         "lgID": "AL",
#         "inseason": "1",
#         "G": "154",
#         "W": "54",
#         "L": "100",
#         "rank": "6",
#         "plyrMgr": "N"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1969",
#         "teamID": "WS2",
#         "lgID": "AL",
#         "inseason": "1",
#         "G": "162",
#         "W": "86",
#         "L": "76",
#         "rank": "4",
#         "plyrMgr": "N"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1970",
#         "teamID": "WS2",
#         "lgID": "AL",
#         "inseason": "1",
#         "G": "162",
#         "W": "70",
#         "L": "92",
#         "rank": "6",
#         "plyrMgr": "N"
#       },
#       {
#         "playerID": "willite01",
#         "yearID": "1971",
#         "teamID": "WS2",
#         "lgID": "AL",
#         "inseason": "1",
#         "G": "159",
#         "W": "63",
#         "L": "96",
#         "rank": "5",
#         "plyrMgr": "N"
#       }
#     ],
#     "pitching": [
#       {
#         "playerID": "willite01",
#         "yearID": "1940",
#         "stint": "1",
#         "teamID": "BOS",
#         "lgID": "AL",
#         "W": "0",
#         "L": "0",
#         "G": "1",
#         "GS": "0",
#         "CG": "0",
#         "SHO": "0",
#         "SV": "0",
#         "IPouts": "6",
#         "H": "3",
#         "ER": "1",
#         "HR": "0",
#         "BB": "0",
#         "SO": "1",
#         "BAOpp": "0.33",
#         "ERA": "4.5",
#         "IBB": "",
#         "WP": "0",
#         "HBP": "0",
#         "BK": "0",
#         "BFP": "9",
#         "GF": "1",
#         "R": "1",
#         "SH": "",
#         "SF": "",
#         "GIDP": ""
#       }
#     ]
#   },
#   "links": [
#     {
#       "rel": "current",
#       "href": "http://127.0.0.1:5000/api/lahman2017/people/willite01"
#     }
#   ]
# }

# %% [markdown]
# - The corresponding SQL statement.

# %%
result2 = %sql select * from People where playerID='willite01'
result2 = dict(result2[0])
print("The SQL result: \n", json.dumps(result2, indent=2, default=str))
# Out:
# 1 rows affected.
# The SQL result:
#  {
#   "playerID": "willite01",
#   "birthYear": 1918,
#   "birthMonth": 8,
#   "birthDay": 30,
#   "birthCountry": "USA",
#   "birthState": "CA",
#   "birthCity": "San Diego",
#   "deathYear": 2002,
#   "deathMonth": 7,
#   "deathDay": 5,
#   "deathCountry": "USA",
#   "deathState": "FL",
#   "deathCity": "Inverness",
#   "nameFirst": "Ted",
#   "nameLast": "Williams",
#   "nameGiven": "Theodore Samuel",
#   "weight": "205",
#   "height": "75",
#   "bats": "L",
#   "throws": "R",
#   "debut": "1939-04-20",
#   "finalGame": "1960-09-28",
#   "retroID": "willt103",
#   "bbrefID": "willite01",
#   "DOD": "2002-07-05",
#   "DOB": "1918-08-30"
# }

# %% [markdown]
# - Comments:
#     - The exact response formats are slightly different, which is normal.
#     - The language, connector and adapter determine the format for SQL API calls.
#     - REST best practices and [HATEOAS](https://en.wikipedia.org/wiki/HATEOAS) provide guidelines for REST/web.

# %% [markdown]
# ##### Pattern 2: Query Strings
#
# - The format of a query string is (usually)
#
# ```
# ?field1=value1&field2=value2&...
# ```
#
#
# - An example of a full URL is ```http://127.0.0.1:5000/api/people?nameLast=Williams&birthCity=San Diego```

# %%
r = requests.get("http://127.0.0.1:5000/api/lahman2017/people?nameLast=Williams&birthCity=San Diego")
result = r.json()

print("The result is: \n", json.dumps(result, indent=2))
# Out:
# The result is:
#  {
#   "data": [
#     {
#       "playerID": {
#         "value": "willite01",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/willite01"
#         }
#       },
#       "birthYear": 1918,
#       "birthMonth": 8,
#       "birthDay": 30,
#       "birthCountry": "USA",
#       "birthState": "CA",
#       "birthCity": "San Diego",
#       "deathYear": 2002,
#       "deathMonth": 7,
#       "deathDay": 5,
#       "deathCountry": "USA",
#       "deathState": "FL",
#       "deathCity": "Inverness",
#       "nameFirst": "Ted",
#       "nameLast": "Williams",
#       "nameGiven": "Theodore Samuel",
#       "weight": "205",
#       "height": "75",
#       "bats": "L",
#       "throws": "R",
#       "debut": "1939-04-20",
#       "finalGame": "1960-09-28",
#       "retroID": "willt103",
#       "bbrefID": "willite01",
#       "DOD": "2002-07-05",
#       "DOB": "1918-08-30"
#     },
#     {
#       "playerID": {
#         "value": "willitr01",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/willitr01"
#         }
#       },
#       "birthYear": 1992,
#       "birthMonth": 4,
#       "birthDay": 25,
#       "birthCountry": "USA",
#       "birthState": "CA",
#       "birthCity": "San Diego",
#       "deathYear": null,
#       "deathMonth": null,
#       "deathDay": null,
#       "deathCountry": "",
#       "deathState": "",
#       "deathCity": "",
#       "nameFirst": "Trevor",
#       "nameLast": "Williams",
#       "nameGiven": "Trevor Anthony",
#       "weight": "230",
#       "height": "75",
#       "bats": "R",
#       "throws": "R",
#       "debut": "2016-09-07",
#       "finalGame": "2017-09-26",
#       "retroID": "willt002",
#       "bbrefID": "willitr01",
#       "DOD": null,
#       "DOB": "1992-04-25"
#     }
#   ],
#   "links": [
#     {
#       "rel": "current",
#       "href": "http://127.0.0.1:5000/api/lahman2017/people?nameLast=Williams&birthCity=San Diego"
#     }
#   ]
# }

# %% [markdown]
# - The corresponding SQL statement is:

# %%
result2 = %sql select * from People where nameLast='Williams' and birthCity='San Diego'
result2 = [dict(r) for r in result2]
print("The SQL result: \n", json.dumps(result2, indent=2, default=str))
# Out:
# 2 rows affected.
# The SQL result:
#  [
#   {
#     "playerID": "willite01",
#     "birthYear": 1918,
#     "birthMonth": 8,
#     "birthDay": 30,
#     "birthCountry": "USA",
#     "birthState": "CA",
#     "birthCity": "San Diego",
#     "deathYear": 2002,
#     "deathMonth": 7,
#     "deathDay": 5,
#     "deathCountry": "USA",
#     "deathState": "FL",
#     "deathCity": "Inverness",
#     "nameFirst": "Ted",
#     "nameLast": "Williams",
#     "nameGiven": "Theodore Samuel",
#     "weight": "205",
#     "height": "75",
#     "bats": "L",
#     "throws": "R",
#     "debut": "1939-04-20",
#     "finalGame": "1960-09-28",
#     "retroID": "willt103",
#     "bbrefID": "willite01",
#     "DOD": "2002-07-05",
#     "DOB": "1918-08-30"
#   },
#   {
#     "playerID": "willitr01",
#     "birthYear": 1992,
#     "birthMonth": 4,
#     "birthDay": 25,
#     "birthCountry": "USA",
#     "birthState": "CA",
#     "birthCity": "San Diego",
#     "deathYear": null,
#     "deathMonth": null,
#     "deathDay": null,
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Trevor",
#     "nameLast": "Williams",
#     "nameGiven": "Trevor Anthony",
#     "weight": "230",
#     "height": "75",
#     "bats": "R",
#     "throws": "R",
#     "debut": "2016-09-07",
#     "finalGame": "2017-09-26",
#     "retroID": "willt002",
#     "bbrefID": "willitr01",
#     "DOD": null,
#     "DOB": "1992-04-25"
#   }
# ]

# %% [markdown]
# ##### Pattern 3: PROJECT
#
# - An SQL ```SELECT``` statement allows choosing the subset of the columns.
#
#
# - There is no "standard" way to achieve the same result with REST.
#
#
# - There is a convention of using a special query parameter ```f=field1,field2,field3``` to choose the subset of the top-level elements you want from the resources.
#
# - An example of a URL is ```http://127.0.0.1:5000/api/people?nameLast=Williams&birthCity=San Diego&fields=nameLast,nameFirst,playerID```

# %%
r = requests.get( \
    "http://127.0.0.1:5000/api/lahman2017/people?nameLast=Williams&birthCity=San Diego&fields=nameLast,nameFirst,playerID")
result = r.json()

print("The result is: \n", json.dumps(result, indent=2))
# Out:
# The result is:
#  {
#   "data": [
#     {
#       "nameLast": "Williams",
#       "nameFirst": "Ted",
#       "playerID": {
#         "value": "willite01",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/willite01"
#         }
#       }
#     },
#     {
#       "nameLast": "Williams",
#       "nameFirst": "Trevor",
#       "playerID": {
#         "value": "willitr01",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/willitr01"
#         }
#       }
#     }
#   ],
#   "links": [
#     {
#       "rel": "current",
#       "href": "http://127.0.0.1:5000/api/lahman2017/people?nameLast=Williams&birthCity=San Diego&fields=nameLast,nameFirst,playerID"
#     }
#   ]
# }

# %% [markdown]
# - The corresponding SQL query is

# %%
result2 = %sql select nameLast,nameFirst,playerID from People where nameLast='Williams' and birthCity='San Diego'
result2 = [dict(r) for r in result2]
print("The SQL result: \n", json.dumps(result2, indent=2, default=str))
# Out:
# 2 rows affected.
# The SQL result:
#  [
#   {
#     "nameLast": "Williams",
#     "nameFirst": "Ted",
#     "playerID": "willite01"
#   },
#   {
#     "nameLast": "Williams",
#     "nameFirst": "Trevor",
#     "playerID": "willitr01"
#   }
# ]

# %% [markdown]
# #### Associations/Paths Following
#
# ##### Concept
#
# | <img src="https://restful-api-design.readthedocs.io/en/latest/_images/concepts.png"> |
# | :---: |
# | __Resource__ |
#
# - There are _relationships_ (also known as _associations_) between resources. The details of semantics are not well-defined.
#
#
#
# - OO/UML provide a conceptual model:
#     1. _IsA_ models specialization and interitance. We will cover later in the course.
#     2. _Containment/Aggregation:_ One more resources in "inside" another resource.
#     3. Associated:_ There is a logical link between two resources.
#
# | <img src="../../images/uml_endings.jpeg" > |
# | :---: |
# | __UML Relationship models__ |
#
#
# - The relational model implements _containment_ and _related._
#     - Containment:
#         - Relations (tables) contain tuples (rows).
#         - _Weak Entity:_ Entity ```A``` exists/has identity _if and only if_ entity ```B``` exists. Entity ```B``` contains the weak entity ```A,``` but ```A``` is in a different table.
#         - There is a foreign key relationship.
#     - Related:
#         - Some of the fields of ```B```
#         - Enable finding a related resource ```A.```
#         - Often, a foreign key is the modeling approach.
#
# - Example:
#     - ```Customers``` and ```Orders``` are associated.
#     - An ```Order``` contains ```OrderDetails.```
#
# | <img src="../../images/rest_paths.jpeg" > |
# | :---: |
# | __Simple E-R Diagram__ |

# %% [markdown]
# ##### Associations
#
# - In the example above, some example of paths could be:
#     - ```/Customers/103/orders```
#     - ```/Orders/10101/customer```
#
#
# - Sample REST call

# %%
r = requests.get( \
    "http://127.0.0.1:5000/api/classiccars/Customers/103/Orders")
result = r.json()
print("Result = ", json.dumps(result, indent=2, default=str))
# Out:
# Result =  {
#   "data": [
#     {
#       "orderNumber": 10123,
#       "orderDate": "2003-05-20",
#       "requiredDate": "2003-05-29",
#       "shippedDate": "2003-05-22",
#       "status": "Shipped",
#       "comments": null,
#       "customerNumber": 103
#     },
#     {
#       "orderNumber": 10298,
#       "orderDate": "2004-09-27",
#       "requiredDate": "2004-10-05",
#       "shippedDate": "2004-10-01",
#       "status": "Shipped",
#       "comments": null,
#       "customerNumber": 103
#     },
#     {
#       "orderNumber": 10345,
#       "orderDate": "2004-11-25",
#       "requiredDate": "2004-12-01",
#       "shippedDate": "2004-11-26",
#       "status": "Shipped",
#       "comments": null,
#       "customerNumber": 103
#     }
#   ],
#   "links": [
#     {
#       "rel": "current",
#       "href": "http://127.0.0.1:5000/api/classiccars/Customers/103/Orders"
#     }
#   ]
# }

# %% [markdown]
# - Another sample REST call.

# %%
r = requests.get( \
    "http://127.0.0.1:5000/api/classiccars/Orders/10101/Customers")
result = r.json()
print("Result = ", json.dumps(result, indent=2, default=str))
# Out:
# Result =  {
#   "data": [
#     {
#       "customerNumber": 128,
#       "customerName": "Blauer See Auto, Co.",
#       "contactLastName": "Keitel",
#       "contactFirstName": "Roland",
#       "phone": "+49 69 66 90 2555",
#       "addressLine1": "Lyonerstr. 34",
#       "addressLine2": null,
#       "city": "Frankfurt",
#       "state": null,
#       "postalCode": "60528",
#       "country": "Germany",
#       "salesRepEmployeeNumber": 1504,
#       "creditLimit": "59700.00"
#     }
#   ],
#   "links": [
#     {
#       "rel": "current",
#       "href": "http://127.0.0.1:5000/api/classiccars/Orders/10101/Customers"
#     }
#   ]
# }

# %% [markdown]
# - The SQL mapping of these REST calls is a little "odd" or "unintuitive."
#     - The REST call goes through the source path.
#     - But is actually a query on the target/referenced resource.
#
#
# - ```/classiccars/Customers/103/Orders``` maps to the SQL

# %%
# %sql select * from classiccars.orders where customerNumber=103
# Out:
# 3 rows affected.
# [(10123, datetime.date(2003, 5, 20), datetime.date(2003, 5, 29), datetime.date(2003, 5, 22), 'Shipped', None, 103),
#  (10298, datetime.date(2004, 9, 27), datetime.date(2004, 10, 5), datetime.date(2004, 10, 1), 'Shipped', None, 103),
#  (10345, datetime.date(2004, 11, 25), datetime.date(2004, 12, 1), datetime.date(2004, 11, 26), 'Shipped', None, 103)]

# %% [markdown]
# ##### Sub-reources
#
# <u>Concept</u>
#
# - Unlike related resources, _sub-resources_ are logically "inside" another resource.
#
#
# - ```OrderDetails``` is an example.
#
# | <img src="../../images/relationships.jpeg"> |
# | :---: |
# | __Relationships and Sub-resources__ |
#
#
# - An ```Order```
#     - _Requires_ or _depends on_ a customer.
#     - But, has an _identity_ or _primary key_ independent of the ```Customer.```
#
#
# - An ```OrderDetails``` does not have identity and cannot form a primary key without an associated ```Order.```
#
#
# - ```Order``` to ```OrderDetails``` is an _identifying relationship_ and ```OrderDetails``` is a [Weak Entity](https://en.wikipedia.org/wiki/Weak_entity)
#
#
# - The most natural way to model this in REST is a _sub-resource._ ```OrderDetails``` is "inside" ```Orders.```
#
#
# - In a OO programming language like Java, the natural representation is something like ...
#
# ```
# package org.columbia.w4111.classiccars;
#
# public class Customer {
#
# 	int customerNumber;
# 	String customerName;
# 	String contactFirstName;
# 	String contactLastName;
# 	String phone;
# 	String addressLine1;
# 	String addressLine2;
# 	String city;
# 	String state;
# 	String postalCode;
# 	String country;
# 	double creditLimit;
#
# 	/*
# 	 * Employee	salesRep;
# 	 */
#
# }
#
# public class Order {
#
# 	public int orderNumber;
# 	public Customer customer;
# 	public Date orderDate;
# 	public Date requiredDate;
# 	public Date shippedDate;
#
# 	public enum status {
# 	    SHIPPED, RESOLVED, CANCELLED, ON_HOLD,
# 	    DISPUTED, IN_PROCESS
# 	}
#
# 	public String comment;
#
# 	public OrderDetails orderDetails[];
#
# }
#
# public class OrderDetails {
#
# 	String productCode;
# 	int quantityOrdered;
# 	long priceEach;
#
# }
#
# ```

# %% [markdown]
# - __NOTE:__ This is not a very good OO model.
#
#
# - You cannot have compound types (classes, maps, lists) as column values, i.e. tables inside tables.
#
# ```
# CREATE TABLE `customers` (
#   `customerNumber` int(11) NOT NULL AUTO_INCREMENT,
#   `customerName` varchar(50) NOT NULL,
#   `contactLastName` varchar(50) NOT NULL,
#   `contactFirstName` varchar(50) NOT NULL,
#   `phone` varchar(50) NOT NULL,
#   `addressLine1` varchar(50) NOT NULL,
#   `addressLine2` varchar(50) DEFAULT NULL,
#   `city` varchar(50) NOT NULL,
#   `state` varchar(50) DEFAULT NULL,
#   `postalCode` varchar(15) DEFAULT NULL,
#   `country` varchar(50) NOT NULL,
#   `salesRepEmployeeNumber` int(11) DEFAULT NULL,
#   `creditLimit` decimal(10,2) DEFAULT NULL,
#   PRIMARY KEY (`customerNumber`)
# ) ENGINE=InnoDB AUTO_INCREMENT=505 DEFAULT CHARSET=utf8;
#
# CREATE TABLE `orders` (
#   `orderNumber` int(11) NOT NULL,
#   `orderDate` date NOT NULL,
#   `requiredDate` date NOT NULL,
#   `shippedDate` date DEFAULT NULL,
#   `status` varchar(15) NOT NULL,
#   `comments` text,
#   `customerNumber` int(11) NOT NULL,
#   PRIMARY KEY (`orderNumber`),
#   KEY `order_to_customer_idx` (`customerNumber`),
#   CONSTRAINT `order_to_customer` FOREIGN KEY (`customerNumber`) REFERENCES `customers` (`customerNumber`) ON DELETE NO ACTION ON UPDATE NO ACTION
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
#
# CREATE TABLE `orderdetails` (
#   `orderNumber` int(11) NOT NULL,
#   `productCode` varchar(15) NOT NULL,
#   `quantityOrdered` int(11) NOT NULL,
#   `priceEach` decimal(10,2) NOT NULL,
#   `orderLineNumber` smallint(6) NOT NULL,
#   PRIMARY KEY (`orderNumber`,`orderLineNumber`),
#   KEY `ol_to_p_idx` (`productCode`),
#   CONSTRAINT `od_to_o` FOREIGN KEY (`orderNumber`) REFERENCES `orders` (`orderNumber`) ON DELETE NO ACTION ON UPDATE NO ACTION,
#   CONSTRAINT `ol_to_p` FOREIGN KEY (`productCode`) REFERENCES `products` (`productCode`) ON DELETE NO ACTION ON UPDATE NO ACTION
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
#
# ```

# %% [markdown]
# - You can have more complex "things" inside "things" in other types of databases, and we will see examples.
#
# <u>Example</u>
#
# - In our model, ```OrderDetails```
#     - Is a separate table ...
#     - But is logically an array/list inside ```Orders.```

# %%
r = requests.get("http://127.0.0.1:5000/api/classiccars/orders/10100")
result = r.json()
result
# Out:
# {'data': {'comments': None,
#   'customerNumber': 363,
#   'orderDate': '2003-01-06',
#   'orderNumber': 10100,
#   'order_notes': [{'comment': 'Annoyingly late',
#     'id': 1,
#     'orderNumber': 10100}],
#   'orderdetails': [{'orderLineNumber': 1,
#     'orderNumber': 10100,
#     'priceEach': '35.29',
#     'productCode': 'S24_3969',
#     'quantityOrdered': 49},
#    {'orderLineNumber': 2,
#     'orderNumber': 10100,
#     'priceEach': '55.09',
#     'productCode': 'S18_2248',
#     'quantityOrdered': 50},
#    {'orderLineNumber': 3,
#     'orderNumber': 10100,
#     'priceEach': '136.00',
#     'productCode': 'S18_1749',
#     'quantityOrdered': 30},
#    {'orderLineNumber': 4,
#     'orderNumber': 10100,
#     'priceEach': '75.46',
#     'productCode': 'S18_4409',
#     'quantityOrdered': 22}],
#   'requiredDate': '2003-01-13',
#   'shippedDate': '2003-01-10',
#   'status': 'Shipped'},
#  'links': [{'href': 'http://127.0.0.1:5000/api/classiccars/orders/10100',
#    'rel': 'current'}]}

# %% [markdown]
# #### POST/INSERT

# %% [markdown]
# - The SQL statement for create is ```INSERT.```
#
#
# ```
# INSERT INTO table_name (customerName, contactFirstName, contactLastName, phone,
#                             addressLine1, addressLine2, city, state, postalCode, creditLimit, country)
#     VALUES ("DFF, Inc.", "Donald", "Ferguson", "123", "111 street", "apt 6",
#         "New York", "NY", "10027", 1000.0, "USA");
# ```
#
# - The corresponding HTTP/REST operation is ```POST.```
#
# ```
# POST /api/classiccars/customers HTTP/1.1
# Host: localhost:5000
# Content-Type: application/json
# Cache-Control: no-cache
# Postman-Token: 8b6033ff-2656-4e62-2fb8-66dca1cb445f
#
# {
#     "customerName": "DFF, Inc.",
#     "contactFirstName": "Donald",
#     "contactLastName": "Ferguson",
#     "phone": "123",
#     "addressLine1": "111 street",
#     "addressLine2": "apt 6",
#     "city": "New York",
#     "state": "NY",
#     "postalCode": "10027",
#     "creditLimit": 1000.0,
#     "country": "USA"
# }
# ```
#
# - Some examples ...
#
# <u>GET with query</u>

# %%
r = requests.get( \
    "http://127.0.0.1:5000/api/classiccars/customers?customerName=DFF, Inc.")
result = r.json()

print("The result is: \n", json.dumps(result, indent=2))
# Out:
# The result is:
#  {
#   "data": null,
#   "links": []
# }

# %% [markdown]
# - OK. Not there.
#
#
# - Let's create it.
#
#
# <u>Create using POST</u>

# %%
new_customer = {
    "customerName": "DFF, Inc.",
    "contactFirstName": "Donald",
    "contactLastName": "Ferguson",
    "phone": "String",
    "addressLine1": "None",
    "addressLine2": "None",
    "city": "New York",
    "state": "NY",
    "postalCode": "10027",
    "creditLimit": 1000.0,
    "country": "USA"
}

result = requests.post('http://127.0.0.1:5000/api/classiccars/customers', 
             json = new_customer)
print("The result is: \n", result.status_code) 
print(result.text)
# Out:
# The result is:
#  201
# Created

# %% [markdown]
# - The primary key is ```customerNumber,``` which is created by the web application.
#
#
# - How does an application know the URL of what the web application created?
#
#
# - REST API _should_ return the URL of a created resource in a _location_ header.

# %%
print("The headers are: ", json.dumps(dict(result.headers), indent=2))
# Out:
# The headers are:  {
#   "Content-Type": "text/plain; charset=utf-8",
#   "location": "http://localhost:5000/api/classiccars/customers/516",
#   "Content-Length": "7",
#   "Server": "Werkzeug/0.14.1 Python/3.6.1",
#   "Date": "Sun, 20 Jan 2019 13:47:30 GMT"
# }

# %% [markdown]
# - What does these headers mean? The headers are metadata about the response:
#     - [content-type](https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Type) informs the caller of the [MIME Type](https://developer.mozilla.org/en-US/docs/Web/HTTP/Basics_of_HTTP/MIME_types) of the response body, e.g. text, JSON, jpeg, ...
#     - Server indicates information about the web server that produced the response.
#     - Date is obvious
#     - Content-Length is the length of the body, which in this case is: "Created"

# %% [markdown]
# <u>Try GET Again</u>
#
# - Using the location returned by create.

# %%
created_url = result.headers['location']

r = requests.get(created_url)
result = r.json()

print("The result is: \n", json.dumps(result, indent=2))
# Out:
# The result is:
#  {
#   "data": {
#     "customerNumber": 516,
#     "customerName": "DFF, Inc.",
#     "contactLastName": "Ferguson",
#     "contactFirstName": "Donald",
#     "phone": "String",
#     "addressLine1": "None",
#     "addressLine2": "None",
#     "city": "New York",
#     "state": "NY",
#     "postalCode": "10027",
#     "country": "USA",
#     "salesRepEmployeeNumber": null,
#     "creditLimit": "1000.00"
#   },
#   "links": [
#     {
#       "rel": "current",
#       "href": "http://localhost:5000/api/classiccars/customers/516"
#     }
#   ]
# }

# %% [markdown]
# - Using query.

# %%
r = requests.get( \
    "http://127.0.0.1:5000/api/classiccars/customers?customerName=DFF, Inc.")
result = r.json()

print("The result is: \n", json.dumps(result, indent=2))
# Out:
# The result is:
#  {
#   "data": [
#     {
#       "customerNumber": 516,
#       "customerName": "DFF, Inc.",
#       "contactLastName": "Ferguson",
#       "contactFirstName": "Donald",
#       "phone": "String",
#       "addressLine1": "None",
#       "addressLine2": "None",
#       "city": "New York",
#       "state": "NY",
#       "postalCode": "10027",
#       "country": "USA",
#       "salesRepEmployeeNumber": null,
#       "creditLimit": "1000.00"
#     }
#   ],
#   "links": [
#     {
#       "rel": "current",
#       "href": "http://127.0.0.1:5000/api/classiccars/customers?customerName=DFF, Inc."
#     }
#   ]
# }

# %% [markdown]
# #### UPDATE/PUT

# %% [markdown]
# #### DELETE

# %% [markdown]
# #### More Advanced Concepts
#
# ##### Advanced Query Languages
#
# ##### SQL Injection

# %% [markdown]
# ## Where am I Going with all of This?

# %% [markdown]
# ## Codd's 12 Rules
#
# <span style="color:red"><strong>Reminder: I let you cut and paste code to save typing. That means I get to cut and paste text to save typing.</strong></span>
#
# From [Wikipedia:](https://en.wikipedia.org/wiki/Codd%27s_12_rules)
#
# "Codd's twelve rules are a set of thirteen rules (numbered zero to twelve) proposed by Edgar F. Codd, a pioneer of the relational model for databases, designed to define what is required from a database management system in order for it to be considered relational, i.e., a relational database management system (RDBMS)"
#
# - __Rule 0 $-$ The foundation rule:__ For any system that is advertised as, or claimed to be, a relational data base management system, that system must be able to manage data bases entirely through its relational capabilities.
#
#
# - __Rule 1 $-$ The information rule:__ All information in a relational data base is represented explicitly at the logical level and in exactly one way – by values in tables.
#
#
# - __Rule 2 $-$ The guaranteed access rule:__ Each and every datum (atomic value) in a relational data base is guaranteed to be logically accessible by resorting to a combination of table name, primary key value and column name.
#
#
# - __Rule 3 $-$ Systematic treatment of null values:__ Null values (distinct from the empty character string or a string of blank characters and distinct from zero or any other number) are supported in fully relational DBMS for representing missing information and inapplicable information in a systematic way, independent of data type.
#
#
# - __Rule 4 $-$ Dynamic online catalog based on the relational model:__ The data base description is represented at the logical level in the same way as ordinary data, so that authorized users can apply the same relational language to its interrogation as they apply to the regular data.
#
#
# - __Rule 5 $-$ The comprehensive data sublanguage rule:__ A relational system may support several languages and various modes of terminal use (for example, the fill-in-the-blanks mode). However, there must be at least one language whose statements are expressible, per some well-defined syntax, as character strings and that is comprehensive in supporting all of the following items:
#     - Data definition.
#     - View definition.
#     - Data manipulation (interactive and by program).
#     - Integrity constraints.
#     - Authorization.
#     - Transaction boundaries (begin, commit and rollback).
#
#
# - __Rule 6 $-$ The view updating rule:__ All views that are theoretically updatable are also updatable by the system.
#
#
# - __Rule 7 $-$ Possible for High-level insert, update, and delete:__ The capability of handling a base relation or a derived relation as a single operand applies not only to the retrieval of data but also to the insertion, update and deletion of data.
#
#
# - __Rule 8 $-$ Physical data independence:__ Application programs and terminal activities remain logically unimpaired whenever any changes are made in either storage representations or access methods.
#
#
# - __Rule  $-$ Logical data independence:__ Application programs and terminal activities remain logically unimpaired when information-preserving changes of any kind that theoretically permit unimpairment are made to the base tables.
#
#
# - __Rule 10 $-$ Integrity independence:__ Integrity constraints specific to a particular relational data base must be definable in the relational data sublanguage and storable in the catalog, not in the application programs.
#
#
# - __Rule 11 $-$ Distribution independence:__ The end-user must not be able to see that the data is distributed over various locations. Users should always get the impression that the data is located at one site only.
#
#
# - __Rule 12 $-$ The nonsubversion rule:__ If a relational system has a low-level (single-record-at-a-time) language, that low level cannot be used to subvert or bypass the integrity rules and constraints expressed in the higher level relational language (multiple-records-at-a-time).
#
#
# - This lecture will introduce and focus on some realizations of these rules, specifically:
#     - Information Rule
#     - Null
#     - Integrity

# %% [markdown]
# ## Attribute/Column Types
#
# ### SQL Data Types
#
# | <img src="../images/MySQL-Data-Types.jpg"> |
# | :---: |
# | [Core MySQL Data Types](http://www.mysqltutorial.org/wp-content/uploads/0211/03/MySQL-Data-Types.jpg) |
#
# <br><br>
#
# |  <img src="../images/sql_server_data_types.png" width="150%"> |
# | :---: |
# | [Core SQL Server Data Types](https://sqlserverrider.files.wordpress.com/2013/04/pic116.png) |

# %% [markdown]
# - Most SQL products have a large, shared set of column types:
#     - Numeric
#     - Date and time
#     - Text and strings
#
#
# - The specific syntax and term may vary slightly between products.
#
#
# - All products and versions define enhanced data types, e.g.
#     - Geometry/Spatial: Polygon, Line, ...
#     - JSON
#     - Geography
#
#
# - There is a lot of focus on precision and size.
#     - Understanding the storage requirement allows the database engine to very efficiently manage storage of massive amounts of data in memory, on-disk, etc.
#     - We cover the approach in Module II

# %% [markdown]
# ### Lahman Tables
#
# - Consider creating a table from importing a CSV file.
#
# | <img src="../images/data_import.jpeg"> |
# | :---: |
# | __Data Import Tool__ |
#
#
# - Importing file data, which is inherently just a sequence of strings, into typed data often fails.
#
#
# - There are entries that the import tool cannot automatically map:
#     - Bad data, e.g. "12 3.04"
#     - Incompatible format, e.g. "January 1 (Friday) 2018"
#     - Missing, e.g. "" for a numeric column.
#
#
# - A common approach, and one you should follow for now, is to import everything as raw text and then clean up with various tools.

# %% [markdown]
# ### Data Improvement
#
# #### NULL
#
# __Rule 3 $-$ Systematic treatment of null values:__ Null values (distinct from the empty character string or a string of blank characters and distinct from zero or any other number) are supported in fully relational DBMS for representing missing information and inapplicable information in a systematic way, independent of data type.
#
#
# - NULL is a fundamental concept in RDBs. Replace varying, ad hoc approach in text files, e.g.
#     - "" for a missing value for a string column.
#     - "U" for an unknown numeric value.
#
#
# - NULL has very specific meaning in relational semantics relative to constraints and relational operations, which we will see.
#
# __Example:__ ```People```
#
# - I added sizes for the text columns, converting ```TEXT``` to ```VARCHAR()```
#
# ```
# CREATE TABLE `people` (
#   `playerID` varchar(12) NOT NULL,
#   `birthYear` char(4) DEFAULT NULL,
#   `birthMonth` char(2) DEFAULT NULL,
#   `birthDay` char(2) DEFAULT NULL,
#   `birthCountry` varchar(64) DEFAULT NULL,
#   `birthState` varchar(32) DEFAULT NULL,
#   `birthCity` varchar(64) DEFAULT NULL,
#   `deathYear` char(4) DEFAULT NULL,
#   `deathMonth` char(2) DEFAULT NULL,
#   `deathDay` char(2) DEFAULT NULL,
#   `deathCountry` varchar(64) DEFAULT NULL,
#   `deathState` varchar(32) DEFAULT NULL,
#   `deathCity` varchar(64) DEFAULT NULL,
#   `nameFirst` varchar(64) NOT NULL,
#   `nameLast` varchar(64) NOT NULL,
#   `nameGiven` varchar(128) DEFAULT NULL,
#   `weight` char(3) DEFAULT NULL,
#   `height` char(3) DEFAULT NULL,
#   `bats` char(1) DEFAULT NULL,
#   `throws` char(1) DEFAULT NULL,
#   `debut` varchar(16) DEFAULT NULL,
#   `finalGame` varchar(16) DEFAULT NULL,
#   `retroID` varchar(12) DEFAULT NULL,
#   `bbrefID` varchar(12) DEFAULT NULL,
#   PRIMARY KEY (`playerID`),
#   KEY `names_idx` (`nameLast`,`nameFirst`)
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
# ```

# %% [markdown]
# - Consider ```nameFirst``` $-$ 38 entries have an unknown first name.

# %%
# %sql select count(*) from people where nameFirst=""
# Out:
# 1 rows affected.
# [(38,)]

# %% [markdown]
# - There are other examples:

# %%
# %sql select count(*) from people where throws=""
# Out:
# 1 rows affected.
# [(979,)]

# %%
# %sql select count(*) from people where birthCountry=""
# Out:
# 1 rows affected.
# [(68,)]

# %% [markdown]
# - The first cleanup we need to do on our tables is converting ad hoc approaches to NULL to the correct representation.
#
#
# - I could write programs to do this, use better importing tools or just use the SQL ```UPDATE,``` which we will cover in more detail later.
#
#
# - Allow NULL values

# %%
# %sql ALTER TABLE `lahman2017`.`people`  CHANGE COLUMN `nameFirst` `nameFirst` VARCHAR(64) NULL ;
# Out:
# 0 rows affected.
# []

# %%
# %sql update people set nameFirst=NULL where nameFirst="";
# Out:
# 38 rows affected.
# []

# %% [markdown]
# #### Numeric Types
#
# - Height and weight are clearly numeric, but ... 755 entries have "" for height.

# %%
# %sql select count(*) from people where height=""
# Out:
# 1 rows affected.
# [(755,)]

# %% [markdown]
# - The resolution is a two-step process:
#     - Convert "" to NULL. "" is not a valid numeric type.
#     - Convert string to numeric type.

# %%
# %sql update people set height=NULL where height="";
# Out:
# 755 rows affected.
# []

# %%
# %sql ALTER TABLE `lahman2017`.`people`  CHANGE COLUMN `height` `height` INT NULL DEFAULT NULL ;
# Out:
# 19371 rows affected.
# []

# %% [markdown]
# - I can do similar things for the other string encoded, numeric values.
#
#
# - These changes become important in scenarios in which we perform math (sum, avg, etc) on columns and relations.

# %% [markdown]
# #### ENUM
#
# - ENUM is useful for representing a column that can have a small number of distinct values:
#     - Enable more efficient storage management.
#     - Prevents accidental entry of incorrect data.

# %%
# %sql select distinct throws from people;
# Out:
# 4 rows affected.
# [('R',), ('L',), ('',), ('S',)]

# %% [markdown]
# - Notice: You can "see" 3 values but query returned four rows. There is a "" you cannot see.

# %%
# %sql update people set throws=NULL where throws=""
# Out:
# 979 rows affected.
# []

# %%
# %sql ALTER TABLE `lahman2017`.`people` CHANGE COLUMN `throws` `throws` ENUM('L', 'R', 'S') NULL DEFAULT NULL ;
# Out:
# 0 rows affected.
# []

# %% [markdown]
# #### Dates and Times, and Consistency

# %%
# %sql select birthYear, birthMonth, birthDay, finalGame from people where \
    birthYear="" or birthMonth="" or birthDay="" limit 10
# Out:
# 10 rows affected.
# [('1868', '', '', '1890-04-21'),
#  ('1842', '2', '', '1877-10-06'),
#  ('1858', '', '', '1880-06-19'),
#  ('1860', '9', '', '1891-09-22'),
#  ('1848', '', '', '1872-10-21'),
#  ('1851', '', '', '1873-10-23'),
#  ('1844', '10', '', '1873-08-07'),
#  ('1858', '', '', '1884-04-22'),
#  ('1872', '4', '', '1898-10-15'),
#  ('1853', '', '', '1875-06-05')]

# %% [markdown]
# - We have two problems here:
#     - We are missing some birth data for some individuals.
#     - We are representing date information in two different formats, which may make comparing dates impossible.

# %% [markdown]
# - I did a little probing with SQL statements. The following situations occur:
#     - Do not know ```birthYear.```
#     - Know ```birthYear``` but do not know ```month``` or ```day,``` or both.
#     - Do not know ```finalGame.```
#     - Do not know ```debut.```
#
#
# - Cleaning up all of this is complex, but there are some simple things we can do:
#     - Convert "" to NULL
#     - Alter column types to numerics for birthYear and deathYear.
#
#
# - Consistent approach to partial dates is something we will decide later.

# %% [markdown]
# #### Comments
#
# - This was a bit of a diversion.
#
#
# - I covered because:
#     - I wanted to give some examples of data types and NULL.
#     - You will have to follow a similar approach when you import data moving forward.
#     - I will have to do some of the cleanup for some integrity constraints, keys, advanced SELECT statements, etc.

# %% [markdown]
# ## Integrity Constraints
#
# ### Basic
#
# [Integrity Constrain Types:](https://en.wikipedia.org/wiki/Data_integrity)
#
#
# - _Entity integrity_ concerns the concept of a primary key. Entity integrity is an integrity rule which states that every table must have a primary key and that the column or columns chosen to be the primary key should be unique and not null.
#
#
# - _Referential integrity_ concerns the concept of a foreign key. The referential integrity rule states that any foreign-key value can only be in one of two states. The usual state of affairs is that the foreign-key value refers to a primary key value of some table in the database. Occasionally, and this will depend on the rules of the data owner, a foreign-key value can be null. In this case, we are explicitly saying that either there is no relationship between the objects represented in the database or that this relationship is unknown.
#
#
# - _Domain integrity_ specifies that all columns in a relational database must be declared upon a defined domain. The primary unit of data in the relational data model is the data item. Such data items are said to be non-decomposable or atomic. A domain is a set of values of the same type. Domains are therefore pools of values from which actual values appearing in the columns of a table are drawn.
#
#
# - _User-defined integrity_ refers to a set of rules specified by a user, which do not belong to the entity, domain and referential integrity categories.

# %% [markdown]
# - Comments:
#     - Entity integrity's meaning is clear.
#     - Domain integrity has two parts:
#         - For a given column, all rows have the same "type" for that column value.
#         - Atomic: Do not have columns whose domain can be decomposed into two sub-domains. The classic example is "name." "Donald Ferguson" is really two domains: first name, last name.
#         - We will see reasons for this requirement moving forward.
#     - User defined integrity constraints are done in "the code" that manipulates the data. For example,
#         - $0 < weight <= 300$
#         - $throws \in \{L,R,S\}$
#         - $birthYear <= deathYear$
#     - SQL has the concept of a _check constraint_ that implements some user defined integrity constraints.
#         - MySQL does not support check constraints.
#         - We will use triggers instead.
#
#
# - SQL/MySQL Constraints
#
#
# | <img src="../images/mysql_constraints.png"> |
# | :---: |
# | __MySQL Constraints__ |

# %% [markdown]
# ### Referential Integrity and Foreign Keys
#
# #### Concept
#
# "In the context of relational databases, a foreign key is a field (or collection of fields) in one table that uniquely identifies a row of another table or the same table. In simpler words, the foreign key is defined in a second table, but it refers to the primary key or a unique key in the first table." (https://en.wikipedia.org/wiki/Foreign_key)
#
#
# #### From Textbook (Ramakrishnan and Gehrke, Chapter 3)
#
# <img src="../images/Bookslides/Chapter_3/Slide04.jpg">
# <img src="../images/Bookslides/Chapter_3/Slide15.jpg">
# <img src="../images/Bookslides/Chapter_3/Slide16.jpg">
# <img src="../images/Bookslides/Chapter_3/Slide17.jpg">
# <img src="../images/Bookslides/Chapter_3/Slide18.jpg">
# <img src="../images/Bookslides/Chapter_3/Slide19.jpg">

# %% [markdown]
# #### More Realistic Academic Example
#
# - This course in Vergil (or class directory)
#
# | <img src="../images/vergil_course.jpeg"> |
# | :---: |
# | __Vergil Entry__ |

# %% [markdown]
# | <img src="../images/new_university.jpeg"> |
# | :---: |
# | __Simple Data Model__ |

# %% [markdown]
# - Database Schema
#
# ```
# CREATE TABLE `CoursePartipations` (
#   `participant_uni` varchar(6) NOT NULL,
#   `dept_code` varchar(6) NOT NULL,
#   `course_no` varchar(6) NOT NULL,
#   `semester` int(11) NOT NULL,
#   `year` year(4) NOT NULL,
#   `role` enum('S','I','TA') NOT NULL,
#   `section` varchar(4) NOT NULL,
#   PRIMARY KEY (`participant_uni`,`dept_code`,`course_no`,`semester`,`year`,`section`),
#   KEY `cp_to_section_idx` (`dept_code`,`course_no`,`semester`,`year`,`section`),
#   CONSTRAINT `cp_to_person` FOREIGN KEY (`participant_uni`) REFERENCES `People` (`UNI`) ON DELETE NO ACTION ON UPDATE NO ACTION,
#   CONSTRAINT `cp_to_section` FOREIGN KEY (`dept_code`, `course_no`, `semester`, `year`, `section`) REFERENCES `Sections` (`dept_code`, `course_no`, `semester`, `year`, `section_no`) ON DELETE NO ACTION ON UPDATE NO ACTION
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
#
# CREATE TABLE `Courses` (
#   `dept_code` varchar(6) NOT NULL,
#   `course_no` varchar(6) NOT NULL,
#   `title` varchar(32) NOT NULL,
#   `description` varchar(512) NOT NULL,
#   PRIMARY KEY (`dept_code`,`course_no`)
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
# /*!40101 SET character_set_client = @saved_cs_client */;
#
# CREATE TABLE `People` (
#   `UNI` varchar(12) NOT NULL,
#   `last_name` varchar(32) NOT NULL,
#   `first_name` varchar(32) NOT NULL,
#   `middle_name` varchar(32) DEFAULT NULL,
#   `email` varchar(128) NOT NULL,
#   PRIMARY KEY (`UNI`)
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
#
#
# CREATE TABLE `Sections` (
#   `dept_code` varchar(6) NOT NULL,
#   `course_no` varchar(6) NOT NULL,
#   `section_no` varchar(4) NOT NULL,
#   `semester` int(11) NOT NULL,
#   `year` year(4) NOT NULL,
#   `days_code` varchar(4) NOT NULL,
#   `time_slot_code` varchar(4) NOT NULL,
#   `room_id` varchar(4) NOT NULL,
#   PRIMARY KEY (`dept_code`,`course_no`,`semester`,`year`),
#   CONSTRAINT `section_to_course` FOREIGN KEY (`dept_code`, `course_no`) REFERENCES `Courses` (`dept_code`, `course_no`) ON DELETE NO ACTION ON UPDATE NO ACTION
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
# ```

# %% [markdown]
# - Primary Keys:
#     - People: UNI
#     - Courses: dept_code, course_no (e.g COMS W4111)
#     - Sections: dept_code, course_no, section_no, semester, year
#     - CourseParticipants: (uni, dept_code, course_no, section_no, semester, year)
#
#
# - Foreign Keys:
#     - $Sections(dept\_code, course\_no) \Rightarrow Sections(dept\_code, course\_no)$
#     - $CourseParticipations(dept\_code, course\_no, section\_no, semester, year) \Rightarrow Sections(dept\_code, course\_no, section, semester, year)$
#     - $CourseParticipations(UNI) \Rightarrow People(UNI)$
#
#
# - __Comments:__
#     - The column names do not need to be the same.
#     - The columns types must be compatible.
#     - The indexes must be compatible, i.e. order of columns in indexes. We cover later.

# %% [markdown]
# #### Why Did I Change Examples?
#
# - The example from the book is a little trivial and too simple.
#
#
# - The data in the Lahman database is "dirty."
#     - Logically, the primary key for ```Teams``` is ```(TeamID, YearID)```
#     - A player "appears" for a team, e.g. BOS, in a season/year, e.g. 1967.
#
#
# - Does this work?

# %%
# %sql select count(*) as count, teamid, yearid from teams group by teamid, yearid order by count desc limit 5;
# Out:
# 5 rows affected.
# [(1, 'MIN', '2012'),
#  (1, 'SLA', '1934'),
#  (1, 'NYN', '2013'),
#  (1, 'SLA', '1938'),
#  (1, 'PHI', '2014')]

# %%
# %sql select count(*) as count, teamid, yearid, playerid from appearances group by teamid, yearid, playerid \
    order by count desc limit 5;
# Out:
# 5 rows affected.
# [(1, 'CIN', '1990', 'armstja01'),
#  (1, 'BOS', '1929', 'hevinjo01'),
#  (1, 'BRO', '1932', 'stripjo01'),
#  (1, 'PHI', '1946', 'oneiljo02'),
#  (1, 'NY1', '1949', 'gordosi01')]

# %% [markdown]
# - OK. Both ends seem reasonable.
#
#
# - But, ...

# %%
# %sql select count(*) as count from appearances where \
    not exists (select * from teams where appearances.yearid = teams.yearid and appearances.teamid = teams.teamid);
# Out:
# 1 rows affected.
# [(23596,)]

# %% [markdown]
# - There are 23,000 appearances records with corresponding team.
#
#
# - Team data is incomplete.

# %% [markdown]
# ### Check Constraints
#
# "A check constraint is a type of integrity constraint in SQL which specifies a requirement that must be met by each row in a database table. The constraint must be a predicate. It can refer to a single column, or multiple columns of the table. The result of the predicate can be either TRUE, FALSE, or UNKNOWN, depending on the presence of NULLs. If the predicate evaluates to UNKNOWN, then the constraint is not violated and the row can be inserted or updated in the table. This is contrary to predicates in WHERE clauses in SELECT or UPDATE statements."
#
# - Basically, the same syntax as a where statement.
#
#
# - Unfortunately, MySQL and many databases do not support check constraints. We will use triggers instead.
#
#
# ### Data Improvment

# %% [markdown]
# | <img src="../images/lahman_cleaner.jpeg"> |
# | :---: |
# | __Lahman - A Little Cleaner__ |

# %% [markdown]
# - There has been some cleanup that will be useful as we expand the web application, and in other apps.
#
#
# - Most tables have a primary key, except exploring the data does not yield a sensible primary key for fielding.
#
#
# - There are foreign keys back to the ```People``` table. Someone cannot appear, bat, field or pitch if they "do not exist."
#
#
# - We will deal with "icky" fielding later.

# %% [markdown]
# ## Keys, Compound Keys, Foreign Keys and REST URLs
#
#
# - The URL linking the description of this class in the [CU course bulletin](http://www.columbia.edu/cu/bulletin/uwb/) to the entry in Vergil is: https://vergil.registrar.columbia.edu/#/courses/COMSW4111_001_2018_3.
#
#
# - Linking the data (via APIs) via REST follows the same pattern. You can think of the web as both:
#     - Linked pages.
#     - Linked data.
#
#
# - Our web application should support the following paths:
#     - ```/api/batting/<playerID_teamID_yearID_stint>``` representing a compound primary key.
#     - ```/api/people/<playerID>/batting``` representing one side of the foreign key relationship.
#     - ```/api/batting/<playerID_teamID_yearID_stint>/people/<playerID>``` representing the other end of the foreign key relationship.
#
#
# - A REST call that return data also returns links to "related" data in URL format.
#
#
# - How do you know the keys, compound keys, foreign keys, etc. without hard coding? Part of the power of the relational model is that the metadata, e.g. constraints, is also relational data.

# %%
# %sql select constraint_schema as s_schema, constraint_name as c_name, table_name as s_table, \
        column_name as s_col_name, ordinal_position as o_position, position_in_unique_constraint as u_position, \
        referenced_table_schema as r_schema, referenced_table_name as r_table, referenced_column_name as r_column \
from information_schema.KEY_COLUMN_USAGE \
        WHERE CONSTRAINT_SCHEMA = 'lahman2017';
# Out:
# 18 rows affected.
# [('lahman2017', 'PRIMARY', 'appearances', 'playerID', 1, None, None, None, None),
#  ('lahman2017', 'PRIMARY', 'appearances', 'teamID', 2, None, None, None, None),
#  ('lahman2017', 'PRIMARY', 'appearances', 'yearID', 3, None, None, None, None),
#  ('lahman2017', 'apptopeople', 'appearances', 'playerID', 1, 1, 'lahman2017', 'people', 'playerID'),
#  ('lahman2017', 'PRIMARY', 'batting', 'playerID', 1, None, None, None, None),
#  ('lahman2017', 'PRIMARY', 'batting', 'teamID', 2, None, None, None, None),
#  ('lahman2017', 'PRIMARY', 'batting', 'yearID', 3, None, None, None, None),
#  ('lahman2017', 'PRIMARY', 'batting', 'stint', 4, None, None, None, None),
#  ('lahman2017', 'battingtopeople', 'batting', 'playerID', 1, 1, 'lahman2017', 'people', 'playerID'),
#  ('lahman2017', 'field_to_person', 'fielding', 'playerID', 1, 1, 'lahman2017', 'people', 'playerID'),
#  ('lahman2017', 'PRIMARY', 'people', 'playerID', 1, None, None, None, None),
#  ('lahman2017', 'PRIMARY', 'pitching', 'playerID', 1, None, None, None, None),
#  ('lahman2017', 'PRIMARY', 'pitching', 'yearID', 2, None, None, None, None),
#  ('lahman2017', 'PRIMARY', 'pitching', 'stint', 3, None, None, None, None),
#  ('lahman2017', 'PRIMARY', 'pitching', 'teamID', 4, None, None, None, None),
#  ('lahman2017', 'pitching_to_player', 'pitching', 'playerID', 1, 1, 'lahman2017', 'people', 'playerID'),
#  ('lahman2017', 'PRIMARY', 'teams', 'yearID', 1, None, None, None, None),
#  ('lahman2017', 'PRIMARY', 'teams', 'teamID', 2, None, None, None, None)]

# %% [markdown]
# - If my REST API code is dealing with a resource (table) ```appearances,``` the following query shows me all of the relevant constraints, including primary key and foreign keys:

# %%
# %sql select constraint_schema as s_schema, constraint_name as c_name, table_name as s_table, \
        column_name as s_col_name, ordinal_position as o_position, position_in_unique_constraint as u_position, \
        referenced_table_schema as r_schema, referenced_table_name as r_table, referenced_column_name as r_column \
from information_schema.KEY_COLUMN_USAGE \
        WHERE CONSTRAINT_SCHEMA = 'lahman2017' \
        and (table_name = 'appearances' or referenced_table_name = 'appearances');
# Out:
# 4 rows affected.
# [('lahman2017', 'PRIMARY', 'appearances', 'playerID', 1, None, None, None, None),
#  ('lahman2017', 'PRIMARY', 'appearances', 'teamID', 2, None, None, None, None),
#  ('lahman2017', 'PRIMARY', 'appearances', 'yearID', 3, None, None, None, None),
#  ('lahman2017', 'apptopeople', 'appearances', 'playerID', 1, 1, 'lahman2017', 'people', 'playerID')]

# %% [markdown]
# - The corresponding query for ```people``` is:

# %%
# %sql select constraint_schema as s_schema, constraint_name as c_name, table_name as s_table, \
        column_name as s_col_name, ordinal_position as o_position, position_in_unique_constraint as u_position, \
        referenced_table_schema as r_schema, referenced_table_name as r_table, referenced_column_name as r_column \
from information_schema.KEY_COLUMN_USAGE \
        WHERE CONSTRAINT_SCHEMA = 'lahman2017' \
        and (table_name = 'people' or referenced_table_name = 'people');
# Out:
# 5 rows affected.
# [('lahman2017', 'apptopeople', 'appearances', 'playerID', 1, 1, 'lahman2017', 'people', 'playerID'),
#  ('lahman2017', 'battingtopeople', 'batting', 'playerID', 1, 1, 'lahman2017', 'people', 'playerID'),
#  ('lahman2017', 'field_to_person', 'fielding', 'playerID', 1, 1, 'lahman2017', 'people', 'playerID'),
#  ('lahman2017', 'PRIMARY', 'people', 'playerID', 1, None, None, None, None),
#  ('lahman2017', 'pitching_to_player', 'pitching', 'playerID', 1, 1, 'lahman2017', 'people', 'playerID')]

# %% [markdown]
# ## Lecture Topics and Homework Checkpoint
#
# - The first four lectures have been all over the place:
#     - Basic SELECT and PROJECT.
#     - Web application structure.
#     - Weird queries probing data to figure it out.
#     - Cleaning data.
#     - Keys
#     - Constraints.
#
#
# - I wanted to provide an overview and preview of the concepts we will use in the web application.
#
#
# - HW1 lays the foundation with ```RDBDataTable:```
#     - JSON query templates $\rightarrow$ WHERE clause.
#     - Ability to choose a subset of fields.
#     - Basic concept of constraints and keys.
#
#
# - We have seen many of the basic concepts necessary to implement the web application. This will help you get started experimenting to prepare for the web application.
#
#
# - If I had systematically exposed and went deep on topics, we would not have been able to start the web app early enough in the semester.
#
#
# - I will publish HW2 this weekend. We will discuss the beginning of lecture 5.
#
#
# - The lectures will be much more orderly and systematics moving forward.

# %% [markdown]
# ## More Advanced SELECT $-$ PROJECT
#
# ### SELECT Statement Reminder
#
# ```
# SELECT
#     [ALL | DISTINCT | DISTINCTROW ]
#       [HIGH_PRIORITY]
#       [STRAIGHT_JOIN]
#       [SQL_SMALL_RESULT] [SQL_BIG_RESULT] [SQL_BUFFER_RESULT]
#       SQL_NO_CACHE [SQL_CALC_FOUND_ROWS]
#     select_expr [, select_expr ...]
#     [FROM table_references
#       [PARTITION partition_list]
#     [WHERE where_condition]
#     [GROUP BY {col_name | expr | position}, ... [WITH ROLLUP]]
#     [HAVING where_condition]
#     [WINDOW window_name AS (window_spec)
#         [, window_name AS (window_spec)] ...]
#     [ORDER BY {col_name | expr | position}
#       [ASC | DESC], ... [WITH ROLLUP]]
#     [LIMIT {[offset,] row_count | row_count OFFSET offset}]
#     [INTO OUTFILE 'file_name'
#         [CHARACTER SET charset_name]
#         export_options
#       | INTO DUMPFILE 'file_name'
#       | INTO var_name [, var_name]]
#     [FOR {UPDATE | SHARE} [OF tbl_name [, tbl_name] ...] [NOWAIT | SKIP LOCKED]
#       | LOCK IN SHARE MODE]]
# ```

# %% [markdown]
# - There are many, many capabilities. The most common and useful ones are:
#     - EXPRESSION: Compute values from columns/attributes.
#     - DISTINCT: Eliminate duplicate tuples in derived table.
#     - ORDERY BY: Sorting
#     - GROUP BY ... HAVING ...: Map tables into sets and then combine elements to produce a single row.

# %% [markdown]
# ### Expressions
#
# #### User Story: On-Base-Percentage and Slugging-Percentage.
#
# - An example of a single row in the batting table is:

# %%
# %sql select * from batting where playerid='willite01' and yearid='1960' and teamid='BOS'
# Out:
# 1 rows affected.
# [('willite01', 'BOS', '1960', 1, 'AL', '113', '310', '56', '98', '15', '0', '29', '72', '1', '1', '75', '41', '7', '3', '0', '2', '7')]

# %% [markdown]
# - Two derived metrics summarize a player's performance:
#     - "In baseball statistics, [on-base percentage](https://en.wikipedia.org/wiki/On-base_percentage) (OBP; sometimes referred to as on-base average/OBA, as the statistic is rarely presented as a true percentage) is a statistic generally measuring how frequently a batter reaches base. Specifically, it records the ratio of the batter's times-on-base (TOB) (the sum of hits, walks, and times hit by pitch) to their number of plate appearances.[1] It first became an official MLB statistic in 1984."
#     - "In baseball statistics, [slugging percentage](https://en.wikipedia.org/wiki/Slugging_percentage) (SLG) is a measure of the batting productivity of a hitter. It is calculated as total bases divided by at bats"
#
#
# - The formulas are:
# <br><br>
#
# \begin{equation}
# OBP = \frac{H+BB+HBP}{AB + BB + HBP + SH + SF}
# \end{equation}
# <br>
#
# \begin{equation}
# SLG = \frac{(H - (2B + 3B + HR)) + 2*2B + 3*3B + 4*HR}{AB}
# \end{equation}

# %% [markdown]
# - U41: "As a baseball fan, I want to see OBP and SLG in batting statistics."
#
#
# - SQL supports a rich set of operators and functions on columns and groups of columns. All engines support a core set and additional operators in several catagories:
#     - Strings.
#     - Comparison and logical.
#     - Numeric
#     - Cast and conversion.
#     - Data and time.
#     - JSON
#     - ... ...
#
#
# - The query that includes OBP and SLG is:

# %%
# %sql select *, (H+BB+HBP)/(AB + BB + HBP + SH + SF) as OBP, \
    ((H - (`2B` + `3B` + HR)) + 2*`2B` + 3*`3B` + 3*HR)/AB as SLG \
    from batting where playerid='willite01'
# Out:
# 19 rows affected.
# [('willite01', 'BOS', '1939', 1, 'AL', '149', '565', '131', '185', '44', '11', '31', '145', '2', '1', '107', '64', '', '2', '3', '', '10', 0.4342688330871492, 0.5539823008849557),
#  ('willite01', 'BOS', '1940', 1, 'AL', '144', '561', '134', '193', '43', '14', '23', '113', '4', '4', '96', '54', '', '3', '1', '', '13', 0.44175491679273826, 0.5525846702317291),
#  ('willite01', 'BOS', '1941', 1, 'AL', '143', '456', '135', '185', '33', '3', '37', '120', '2', '4', '147', '27', '', '3', '0', '', '10', 0.5528052805280528, 0.6535087719298246),
#  ('willite01', 'BOS', '1942', 1, 'AL', '150', '522', '141', '186', '34', '5', '36', '137', '3', '2', '145', '51', '', '4', '0', '', '12', 0.4992548435171386, 0.578544061302682),
#  ('willite01', 'BOS', '1946', 1, 'AL', '150', '514', '142', '176', '37', '8', '38', '123', '0', '0', '156', '44', '', '2', '0', '', '12', 0.49702380952380953, 0.5933852140077821),
#  ('willite01', 'BOS', '1947', 1, 'AL', '156', '528', '125', '181', '40', '9', '32', '114', '0', '1', '162', '47', '', '2', '1', '', '10', 0.49783549783549785, 0.5738636363636364),
#  ('willite01', 'BOS', '1948', 1, 'AL', '137', '509', '124', '188', '44', '3', '25', '127', '4', '0', '126', '41', '', '3', '0', '', '10', 0.49686520376175547, 0.5658153241650294),
#  ('willite01', 'BOS', '1949', 1, 'AL', '155', '566', '150', '194', '39', '3', '43', '159', '1', '1', '162', '48', '', '2', '0', '', '22', 0.4904109589041096, 0.5742049469964664),
#  ('willite01', 'BOS', '1950', 1, 'AL', '89', '334', '82', '106', '24', '1', '28', '97', '3', '0', '82', '21', '', '0', '0', '', '12', 0.4519230769230769, 0.562874251497006),
#  ('willite01', 'BOS', '1951', 1, 'AL', '148', '531', '109', '169', '28', '4', '30', '126', '1', '1', '144', '45', '', '0', '0', '', '10', 0.46370370370370373, 0.4990583804143126),
#  ('willite01', 'BOS', '1952', 1, 'AL', '6', '10', '2', '4', '0', '1', '1', '3', '0', '0', '2', '2', '', '0', '0', '', '0', 0.5, 0.8),
#  ('willite01', 'BOS', '1953', 1, 'AL', '37', '91', '17', '37', '6', '0', '13', '34', '0', '1', '19', '10', '', '0', '0', '', '1', 0.509090909090909, 0.7582417582417582),
#  ('willite01', 'BOS', '1954', 1, 'AL', '117', '386', '93', '133', '23', '1', '29', '89', '0', '0', '136', '32', '', '1', '0', '3', '10', 0.5133079847908745, 0.5595854922279793),
#  ('willite01', 'BOS', '1955', 1, 'AL', '98', '320', '77', '114', '21', '3', '28', '83', '2', '0', '91', '24', '17', '2', '0', '4', '8', 0.49640287769784175, 0.615625),
#  ('willite01', 'BOS', '1956', 1, 'AL', '136', '400', '71', '138', '28', '2', '24', '82', '0', '0', '102', '39', '11', '1', '0', '0', '13', 0.47912524850894633, 0.545),
#  ('willite01', 'BOS', '1957', 1, 'AL', '132', '420', '96', '163', '28', '1', '38', '87', '0', '1', '119', '43', '33', '5', '0', '2', '11', 0.5256410256410257, 0.6404761904761904),
#  ('willite01', 'BOS', '1958', 1, 'AL', '129', '411', '81', '135', '23', '2', '26', '85', '1', '0', '98', '49', '12', '4', '0', '4', '19', 0.4584139264990329, 0.5206812652068127),
#  ('willite01', 'BOS', '1959', 1, 'AL', '103', '272', '32', '69', '15', '0', '10', '43', '0', '0', '52', '27', '6', '2', '0', '5', '7', 0.3716012084592145, 0.38235294117647056),
#  ('willite01', 'BOS', '1960', 1, 'AL', '113', '310', '56', '98', '15', '0', '29', '72', '1', '1', '75', '41', '7', '3', '0', '2', '7', 0.4512820512820513, 0.5516129032258065)]

# %% [markdown]
# - An implied aspect of the story is to show the data in more reasonable format.

# %%
# %sql select *, round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3) as OBP, \
    round(((H - (`2B` + `3B` + HR)) + 2*`2B` + 3*`3B` + 3*HR)/AB, 3) as SLG \
    from batting where playerid='willite01'
# Out:
# 19 rows affected.
# [('willite01', 'BOS', '1939', 1, 'AL', '149', '565', '131', '185', '44', '11', '31', '145', '2', '1', '107', '64', '', '2', '3', '', '10', 0.434, 0.554),
#  ('willite01', 'BOS', '1940', 1, 'AL', '144', '561', '134', '193', '43', '14', '23', '113', '4', '4', '96', '54', '', '3', '1', '', '13', 0.442, 0.553),
#  ('willite01', 'BOS', '1941', 1, 'AL', '143', '456', '135', '185', '33', '3', '37', '120', '2', '4', '147', '27', '', '3', '0', '', '10', 0.553, 0.654),
#  ('willite01', 'BOS', '1942', 1, 'AL', '150', '522', '141', '186', '34', '5', '36', '137', '3', '2', '145', '51', '', '4', '0', '', '12', 0.499, 0.579),
#  ('willite01', 'BOS', '1946', 1, 'AL', '150', '514', '142', '176', '37', '8', '38', '123', '0', '0', '156', '44', '', '2', '0', '', '12', 0.497, 0.593),
#  ('willite01', 'BOS', '1947', 1, 'AL', '156', '528', '125', '181', '40', '9', '32', '114', '0', '1', '162', '47', '', '2', '1', '', '10', 0.498, 0.574),
#  ('willite01', 'BOS', '1948', 1, 'AL', '137', '509', '124', '188', '44', '3', '25', '127', '4', '0', '126', '41', '', '3', '0', '', '10', 0.497, 0.566),
#  ('willite01', 'BOS', '1949', 1, 'AL', '155', '566', '150', '194', '39', '3', '43', '159', '1', '1', '162', '48', '', '2', '0', '', '22', 0.49, 0.574),
#  ('willite01', 'BOS', '1950', 1, 'AL', '89', '334', '82', '106', '24', '1', '28', '97', '3', '0', '82', '21', '', '0', '0', '', '12', 0.452, 0.563),
#  ('willite01', 'BOS', '1951', 1, 'AL', '148', '531', '109', '169', '28', '4', '30', '126', '1', '1', '144', '45', '', '0', '0', '', '10', 0.464, 0.499),
#  ('willite01', 'BOS', '1952', 1, 'AL', '6', '10', '2', '4', '0', '1', '1', '3', '0', '0', '2', '2', '', '0', '0', '', '0', 0.5, 0.8),
#  ('willite01', 'BOS', '1953', 1, 'AL', '37', '91', '17', '37', '6', '0', '13', '34', '0', '1', '19', '10', '', '0', '0', '', '1', 0.509, 0.758),
#  ('willite01', 'BOS', '1954', 1, 'AL', '117', '386', '93', '133', '23', '1', '29', '89', '0', '0', '136', '32', '', '1', '0', '3', '10', 0.513, 0.56),
#  ('willite01', 'BOS', '1955', 1, 'AL', '98', '320', '77', '114', '21', '3', '28', '83', '2', '0', '91', '24', '17', '2', '0', '4', '8', 0.496, 0.616),
#  ('willite01', 'BOS', '1956', 1, 'AL', '136', '400', '71', '138', '28', '2', '24', '82', '0', '0', '102', '39', '11', '1', '0', '0', '13', 0.479, 0.545),
#  ('willite01', 'BOS', '1957', 1, 'AL', '132', '420', '96', '163', '28', '1', '38', '87', '0', '1', '119', '43', '33', '5', '0', '2', '11', 0.526, 0.64),
#  ('willite01', 'BOS', '1958', 1, 'AL', '129', '411', '81', '135', '23', '2', '26', '85', '1', '0', '98', '49', '12', '4', '0', '4', '19', 0.458, 0.521),
#  ('willite01', 'BOS', '1959', 1, 'AL', '103', '272', '32', '69', '15', '0', '10', '43', '0', '0', '52', '27', '6', '2', '0', '5', '7', 0.372, 0.382),
#  ('willite01', 'BOS', '1960', 1, 'AL', '113', '310', '56', '98', '15', '0', '29', '72', '1', '1', '75', '41', '7', '3', '0', '2', '7', 0.451, 0.552)]

# %% [markdown]
# - You can use expressions in many places.
#
#
# - U42: "As a baseball fan, I want to see all players with an OBP over 0.500, for players with more than 100 ABs."

# %%
# %sql select *, round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3) as OBP, \
    round(((H - (`2B` + `3B` + HR)) + 2*`2B` + 3*`3B` + 3*HR)/AB, 3) as SLG \
    from batting where \
    ab > 100 AND \
    round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3) > 0.500 limit 10;
# Out:
# 10 rows affected.
# [('bondsba01', 'SFN', '2001', 1, 'NL', '153', '476', '129', '156', '32', '2', '73', '137', '13', '3', '177', '93', '35', '9', '0', '2', '5', 0.515, 0.71),
#  ('bondsba01', 'SFN', '2002', 1, 'NL', '143', '403', '117', '149', '31', '2', '46', '110', '9', '2', '198', '47', '68', '9', '0', '2', '4', 0.582, 0.685),
#  ('bondsba01', 'SFN', '2003', 1, 'NL', '130', '390', '111', '133', '22', '1', '45', '90', '7', '0', '148', '58', '61', '10', '0', '2', '7', 0.529, 0.633),
#  ('bondsba01', 'SFN', '2004', 1, 'NL', '147', '373', '129', '135', '27', '3', '45', '101', '6', '1', '232', '41', '120', '9', '0', '3', '5', 0.609, 0.692),
#  ('hamilbi01', 'PHI', '1894', 1, 'NL', '132', '558', '198', '225', '25', '15', '4', '90', '100', '', '128', '19', '', '9', '7', '', '', 0.516, 0.516),
#  ('mantlmi01', 'NYA', '1957', 1, 'AL', '144', '474', '121', '173', '28', '6', '34', '94', '16', '3', '146', '75', '23', '0', '0', '3', '5', 0.512, 0.593),
#  ('mcgrajo01', 'BLA', '1901', 1, 'AL', '73', '232', '71', '81', '14', '9', '0', '28', '24', '', '61', '', '', '14', '1', '', '', 0.506, 0.487),
#  ('mcgrajo01', 'BLN', '1899', 1, 'NL', '117', '399', '140', '156', '13', '3', '1', '33', '73', '', '124', '21', '', '14', '2', '', '', 0.545, 0.444),
#  ('ruthba01', 'NYA', '1920', 1, 'AL', '142', '457', '158', '172', '36', '9', '54', '137', '14', '14', '150', '80', '', '3', '5', '', '', 0.528, 0.731),
#  ('ruthba01', 'NYA', '1921', 1, 'AL', '152', '540', '177', '204', '44', '16', '59', '171', '17', '13', '145', '81', '', '4', '4', '', '', 0.509, 0.737)]

# %% [markdown]
# - Another stat is on-base-plus-slugging, which is simply $OBP+SLG.$
#
#
# - U43: "As a baseball nerd, I want to see players with $OBP+SLG>1.2$ for players with $AB > 100.$

# %%
# %sql select *, round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3) as OBP, \
        round(((H - (`2B` + `3B` + HR)) + 2*`2B` + 3*`3B` + 3*HR)/AB, 3) as SLG \
    from batting where \
        ab > 100 AND \
        (round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3) + \
            round(((H - (`2B` + `3B` + HR)) + 2*`2B` + 3*`3B` + 3*HR)/AB, 3)) > 1.2;
# Out:
# 7 rows affected.
# [('bondsba01', 'SFN', '2001', 1, 'NL', '153', '476', '129', '156', '32', '2', '73', '137', '13', '3', '177', '93', '35', '9', '0', '2', '5', 0.515, 0.71),
#  ('bondsba01', 'SFN', '2002', 1, 'NL', '143', '403', '117', '149', '31', '2', '46', '110', '9', '2', '198', '47', '68', '9', '0', '2', '4', 0.582, 0.685),
#  ('bondsba01', 'SFN', '2004', 1, 'NL', '147', '373', '129', '135', '27', '3', '45', '101', '6', '1', '232', '41', '120', '9', '0', '3', '5', 0.609, 0.692),
#  ('ruthba01', 'NYA', '1920', 1, 'AL', '142', '457', '158', '172', '36', '9', '54', '137', '14', '14', '150', '80', '', '3', '5', '', '', 0.528, 0.731),
#  ('ruthba01', 'NYA', '1921', 1, 'AL', '152', '540', '177', '204', '44', '16', '59', '171', '17', '13', '145', '81', '', '4', '4', '', '', 0.509, 0.737),
#  ('ruthba01', 'NYA', '1923', 1, 'AL', '152', '522', '151', '205', '45', '13', '41', '131', '17', '21', '170', '93', '', '4', '3', '', '', 0.542, 0.686),
#  ('willite01', 'BOS', '1941', 1, 'AL', '143', '456', '135', '185', '33', '3', '37', '120', '2', '4', '147', '27', '', '3', '0', '', '10', 0.553, 0.654)]

# %% [markdown]
# __Note:__ There is extensive documentation and examples for the functions and operators. My going through all of the capabilities would be boring. You can look them up, and the CAs and I will help you if you get stuck.

# %% [markdown]
# #### Career Statistics
#
# - U41A: "As a user, I want to see a computation of a player's career statistics."
#
#
# - SQL supports _aggregating operators_ that computes a single value from a set of row values for a column.

# %%
# %sql select playerid, sum(g) as total_games, sum(ab) total_abs, \
    sum(r) as total_runs, sum(h) as total_hits, sum(hr) as total_hrs, sum(rbi) as total_rbi, \
    round(sum(h)/sum(ab), 3) as career_ba \
        from batting where playerid='willite01'
# Out:
# 1 rows affected.
# [('willite01', 2292.0, 7706.0, 1798.0, 2654.0, 521.0, 1839.0, 0.344)]

# %% [markdown]
# - SQL supports the obvious aggregating operators: ```min, max, avg, sum``` and specific products support additional operators, e.g. ```std()``` for standard deviation.
#
#
# - ```count()``` counts the total number of rows or distinct values for a column.
#
#
# - I can improve the preceding query.

# %%
# %sql select playerid, cast(sum(g) as unsigned) as total_games, cast(sum(ab) as unsigned) as total_abs, \
    cast(sum(r) as unsigned) as total_runs, cast(sum(h) as unsigned) as total_hits, \
    cast(sum(hr) as unsigned) as total_hrs, cast(sum(rbi) as unsigned) as total_rbi, \
    round(sum(h)/sum(ab), 3) as career_ba, count(yearID) as total_seasons \
        from batting where playerid='willite01'
# Out:
# 1 rows affected.
# [('willite01', 2292, 7706, 1798, 2654, 521, 1839, 0.344, 19)]

# %% [markdown]
# #### A Note in Implementation
#
# - I could have done the math in several places:
#     - SQL
#     - Data access layer
#     - Business logic layer
#
#
# - Pushing the math as close to the data as possible can vastly reduce the amount of RAM usage and data movement for large databases.

# %% [markdown]
# ### DISTINCT
#
# - A __derived table__ is a table that a relational algebra expression produces.
#
#
# - A derived table may not have a primary key, for many reasons. This can result in many, many duplicate rows.
#
#
# - ```SELECT DISTINCT``` returns one instance of duplicates.
#
#
# - U44: "As a fan, I want to know the IDs of players who ever had ```OBP+SLG > 1.2```."
#
#
# - The initial idea would be just to use ```PROJECT.```

# %%
# %sql select playerID \
    from batting where \
        ab > 100 AND \
        (round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3) + \
            round(((H - (`2B` + `3B` + HR)) + 2*`2B` + 3*`3B` + 3*HR)/AB, 3)) > 1.2;
# Out:
# 7 rows affected.
# [('bondsba01',),
#  ('bondsba01',),
#  ('bondsba01',),
#  ('ruthba01',),
#  ('ruthba01',),
#  ('ruthba01',),
#  ('willite01',)]

# %% [markdown]
# - Well, that is a little annoying. ```DISTINCT``` eliminates the duplicates.

# %%
# %sql select distinct playerID \
    from batting where \
        ab > 100 AND \
        (round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3) + \
            round(((H - (`2B` + `3B` + HR)) + 2*`2B` + 3*`3B` + 3*HR)/AB, 3)) > 1.2;
# Out:
# 3 rows affected.
# [('bondsba01',), ('ruthba01',), ('willite01',)]

# %% [markdown]
# - Implementing the ```DISTINCT``` in the UI, business logic, data access is fine for such a small result. Sometimes the derived table has an enormous number of rows and an enormous number of duplicates.

# %% [markdown]
# ### ORDER BY ...
#
# - Exactly what it sounds like.
#
#
# - ```ORDER By A,B,C ASC``` means:
#     - Sort by column ```A``` from largest to smallest value.
#     - For results with an equal value for ```A,``` do the smae for ```B.```
#     - Then do the same for ```B``` and ```C.```
#
#
# - U45: "As a baseball fan, I want to see all playerIDs for players who ever had ```OBP > 0.400``` sorted by ```OBP``` from largest to smallest.

# %%
# %sql select playerID, round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3) as obp\
    from batting where \
        ab > 100 AND \
        (round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3) > 0.400) \
   order by \
        obp desc;
# Out:
# 1774 rows affected.
# [('bondsba01', 0.609),
#  ('bondsba01', 0.582),
#  ('willite01', 0.553),
#  ('mcgrajo01', 0.545),
#  ('ruthba01', 0.542),
#  ('bondsba01', 0.529),
#  ('ruthba01', 0.528),
#  ('willite01', 0.526),
#  ('hamilbi01', 0.516),
#  ('bondsba01', 0.515),
#  ('willite01', 0.513),
#  ('mantlmi01', 0.512),
#  ('ruthba01', 0.509),
#  ('ruthba01', 0.508),
#  ('ruthba01', 0.508),
#  ('mcgrajo01', 0.506),
#  ('meyerle01', 0.5),
#  ('mcgrajo01', 0.499),
#  ('willite01', 0.499),
#  ('joycebi01', 0.498),
#  ('willite01', 0.498),
#  ('hornsro01', 0.497),
#  ('willite01', 0.497),
#  ('willite01', 0.497),
#  ('willite01', 0.496),
#  ('ruthba01', 0.495),
#  ('delahed01', 0.495),
#  ('duffyhu01', 0.494),
#  ('hamilbi01', 0.49),
#  ('joycebi01', 0.49),
#  ('oneilti01', 0.49),
#  ('willite01', 0.49),
#  ('ruthba01', 0.489),
#  ('ramirma02', 0.489),
#  ('bladera01', 0.488),
#  ('kellejo01', 0.487),
#  ('thomafr04', 0.487),
#  ('carrofr01', 0.486),
#  ('mantlmi01', 0.486),
#  ('cashno01', 0.485),
#  ('vaughar01', 0.485),
#  ('hamilbi01', 0.483),
#  ('kellyki01', 0.483),
#  ('mcgwima01', 0.483),
#  ('cobbty01', 0.48),
#  ('bondsba01', 0.48),
#  ('martied01', 0.479),
#  ('willite01', 0.479),
#  ('ruthba01', 0.478),
#  ('hamilbi01', 0.478),
#  ('hornsro01', 0.478),
#  ('burkeje01', 0.477),
#  ('giambja01', 0.477),
#  ('ruthba01', 0.476),
#  ('boggswa01', 0.476),
#  ('gehrilo01', 0.476),
#  ('giambja01', 0.476),
#  ('hornsro01', 0.476),
#  ('cullero01', 0.475),
#  ('hamilbi01', 0.474),
#  ('vottojo01', 0.474),
#  ('delahed01', 0.473),
#  ('gehrilo01', 0.473),
#  ('johnsni01', 0.473),
#  ('olerujo01', 0.473),
#  ('childcu01', 0.472),
#  ('broutda01', 0.471),
#  ('dietzdi01', 0.471),
#  ('hazlebo01', 0.471),
#  ('mcgrajo01', 0.471),
#  ('delgaca01', 0.47),
#  ('jonesch06', 0.47),
#  ('mcgwima01', 0.47),
#  ('foxxji01', 0.469),
#  ('applilu01', 0.469),
#  ('delahed01', 0.469),
#  ('heltoto01', 0.469),
#  ('henderi01', 0.469),
#  ('speaktr01', 0.469),
#  ('mcgwima01', 0.467),
#  ('sheffga01', 0.467),
#  ('broutda01', 0.466),
#  ('brownpe01', 0.466),
#  ('gehrilo01', 0.466),
#  ('kellejo01', 0.466),
#  ('morgajo02', 0.466),
#  ('barnero01', 0.465),
#  ('gehrilo01', 0.465),
#  ('hanseda01', 0.465),
#  ('sheffga01', 0.465),
#  ('speaktr01', 0.465),
#  ('brownpe01', 0.464),
#  ('martied01', 0.464),
#  ('mcgrajo01', 0.464),
#  ('wakefdi01', 0.464),
#  ('walkela01', 0.464),
#  ('willite01', 0.464),
#  ('cobbty01', 0.463),
#  ('carutbo01', 0.463),
#  ('childcu01', 0.463),
#  ('delluda01', 0.463),
#  ('heilmha01', 0.463),
#  ('heltoto01', 0.463),
#  ('jacksjo01', 0.463),
#  ('jennihu01', 0.463),
#  ('mantlmi01', 0.463),
#  ('speaktr01', 0.463),
#  ('barnero01', 0.462),
#  ('broutda01', 0.462),
#  ('griffmi01', 0.462),
#  ('lajoina01', 0.462),
#  ('pujolal01', 0.462),
#  ('foxxji01', 0.461),
#  ('foxxji01', 0.461),
#  ('bondsba01', 0.461),
#  ('broutda01', 0.461),
#  ('burkeje01', 0.461),
#  ('gehrilo01', 0.461),
#  ('heilmha01', 0.461),
#  ('lyonsde01', 0.461),
#  ('foxxji01', 0.46),
#  ('boggswa01', 0.46),
#  ('delahed01', 0.46),
#  ('gehrilo01', 0.46),
#  ('harpebr03', 0.46),
#  ('joycebi01', 0.46),
#  ('oneilpa01', 0.46),
#  ('cobbty01', 0.459),
#  ('cobbty01', 0.459),
#  ('valoel01', 0.459),
#  ('brownpe01', 0.459),
#  ('burkeje01', 0.459),
#  ('clarkfr01', 0.459),
#  ('clarkja01', 0.459),
#  ('dimagjo01', 0.459),
#  ('speaktr01', 0.459),
#  ('speaktr01', 0.459),
#  ('thomafr04', 0.459),
#  ('vottojo01', 0.459),
#  ('ruthba01', 0.458),
#  ('bondsba01', 0.458),
#  ('gamblos01', 0.458),
#  ('hamilbi01', 0.458),
#  ('heltoto01', 0.458),
#  ('thompsa01', 0.458),
#  ('walkela01', 0.458),
#  ('willite01', 0.458),
#  ('cobbty01', 0.457),
#  ('burkeje01', 0.457),
#  ('burkeje01', 0.457),
#  ('childcu01', 0.457),
#  ('odoulle01', 0.457),
#  ('ramirma02', 0.457),
#  ('bondsba01', 0.456),
#  ('cochrmi01', 0.456),
#  ('gehrilo01', 0.456),
#  ('martied01', 0.456),
#  ('sislege01', 0.456),
#  ('thomafr04', 0.456),
#  ('ansonca01', 0.455),
#  ('collied01', 0.455),
#  ('gehrich01', 0.455),
#  ('keelewi01', 0.455),
#  ('speaktr01', 0.455),
#  ('fainfe01', 0.454),
#  ('ruthba01', 0.454),
#  ('alexada01', 0.454),
#  ('bagweje01', 0.454),
#  ('bondsba01', 0.454),
#  ('brettge01', 0.454),
#  ('cartyri01', 0.454),
#  ('harrijo03', 0.454),
#  ('hornsro01', 0.454),
#  ('mcgrajo01', 0.454),
#  ('stanked01', 0.454),
#  ('thomafr04', 0.454),
#  ('thomafr04', 0.454),
#  ('vottojo01', 0.454),
#  ('cangejo01', 0.453),
#  ('delahed01', 0.453),
#  ('gwynnto01', 0.453),
#  ('hamilbi01', 0.453),
#  ('hemusso01', 0.453),
#  ('jacksjo01', 0.453),
#  ('mccovwi01', 0.453),
#  ('mcgrajo01', 0.453),
#  ('thomafr04', 0.453),
#  ('barnero01', 0.452),
#  ('carbobe01', 0.452),
#  ('clemeja01', 0.452),
#  ('gamblos01', 0.452),
#  ('joycebi01', 0.452),
#  ('kinerra01', 0.452),
#  ('walkela01', 0.452),
#  ('willite01', 0.452),
#  ('yastrca01', 0.452),
#  ('fainfe01', 0.451),
#  ('foxxji01', 0.451),
#  ('myerbu01', 0.451),
#  ('bagweje01', 0.451),
#  ('bagweje01', 0.451),
#  ('cunnijo01', 0.451),
#  ('gehrilo01', 0.451),
#  ('willite01', 0.451),
#  ('cobbty01', 0.45),
#  ('berkmla01', 0.45),
#  ('boggswa01', 0.45),
#  ('broutda01', 0.45),
#  ('connoro01', 0.45),
#  ('gilesbr02', 0.45),
#  ('jennihu01', 0.45),
#  ('musiast01', 0.45),
#  ('ramirma02', 0.45),
#  ('thomeji01', 0.45),
#  ('tucketo01', 0.45),
#  ('foxxji01', 0.449),
#  ('ansonca01', 0.449),
#  ('boggswa01', 0.449),
#  ('cochrmi01', 0.449),
#  ('hornsro01', 0.449),
#  ('jennihu01', 0.449),
#  ('langebi01', 0.449),
#  ('prattto02', 0.449),
#  ('rosemch01', 0.449),
#  ('smithel01', 0.449),
#  ('stanked01', 0.449),
#  ('teixema01', 0.449),
#  ('walkela01', 0.449),
#  ('fainfe01', 0.448),
#  ('foxxji01', 0.448),
#  ('ruthba01', 0.448),
#  ('cabremi01', 0.448),
#  ('carewro01', 0.448),
#  ('carutbo01', 0.448),
#  ('cullero01', 0.448),
#  ('cunnijo01', 0.448),
#  ('dunlafr01', 0.448),
#  ('hornsro01', 0.448),
#  ('knoblch01', 0.448),
#  ('musiast01', 0.448),
#  ('palmede01', 0.448),
#  ('tiernmi01', 0.448),
#  ('turnetu01', 0.448),
#  ('turnetu01', 0.448),
#  ('ashburi01', 0.447),
#  ('barnero01', 0.447),
#  ('bautijo02', 0.447),
#  ('cavarph01', 0.447),
#  ('collied01', 0.447),
#  ('jacksjo01', 0.447),
#  ('kellejo01', 0.447),
#  ('mantlmi01', 0.447),
#  ('martied01', 0.447),
#  ('mitchke01', 0.447),
#  ('olerujo01', 0.447),
#  ('schuljo04', 0.447),
#  ('tiernmi01', 0.447),
#  ('vaughar01', 0.447),
#  ('abreubo01', 0.446),
#  ('bondsba01', 0.446),
#  ('galanau01', 0.446),
#  ('gehrich01', 0.446),
#  ('gwynnto01', 0.446),
#  ('hamilbi01', 0.446),
#  ('morgaed01', 0.446),
#  ('odoulle01', 0.446),
#  ('broutda01', 0.445),
#  ('galanau01', 0.445),
#  ('hermaba01', 0.445),
#  ('hornsro01', 0.445),
#  ('lyonsde01', 0.445),
#  ('ortizda01', 0.445),
#  ('robinya01', 0.445),
#  ('selkige01', 0.445),
#  ('thomeji01', 0.445),
#  ('walkela01', 0.445),
#  ('ottme01', 0.444),
#  ('cobbty01', 0.444),
#  ('camildo01', 0.444),
#  ('dickebi01', 0.444),
#  ('garmsde01', 0.444),
#  ('gehrilo01', 0.444),
#  ('glassja01', 0.444),
#  ('heltoto01', 0.444),
#  ('mauerjo01', 0.444),
#  ('mccovwi01', 0.444),
#  ('morgajo02', 0.444),
#  ('sheffga01', 0.444),
#  ('simmoal01', 0.444),
#  ('swarted01', 0.444),
#  ('vaughar01', 0.444),
#  ('riceha01', 0.443),
#  ('ansonca01', 0.443),
#  ('childcu01', 0.443),
#  ('cochrmi01', 0.443),
#  ('dimagjo01', 0.443),
#  ('herzowh01', 0.443),
#  ('phillto02', 0.443),
#  ('pujolal01', 0.443),
#  ('wanerpa01', 0.443),
#  ('wilsoha01', 0.443),
#  ('wingoal01', 0.443),
#  ('ottme01', 0.442),
#  ('cobbty01', 0.442),
#  ('ruthba01', 0.442),
#  ('ansonca01', 0.442),
#  ('boggswa01', 0.442),
#  ('boudrlo01', 0.442),
#  ('cabremi01', 0.442),
#  ('clemeja01', 0.442),
#  ('mantlmi01', 0.442),
#  ('ramirma02', 0.442),
#  ('thomaro01', 0.442),
#  ('troutmi01', 0.442),
#  ('wertzvi01', 0.442),
#  ('willite01', 0.442),
#  ('ottme01', 0.441),
#  ('cobbty01', 0.441),
#  ('cobbty01', 0.441),
#  ('wardpi01', 0.441),
#  ('clarkja01', 0.441),
#  ('heilmha01', 0.441),
#  ('jonesch06', 0.441),
#  ('kauffbe01', 0.441),
#  ('mantlmi01', 0.441),
#  ('mcgrajo01', 0.441),
#  ('mcgwima01', 0.441),
#  ('niemabo01', 0.441),
#  ('sislege01', 0.441),
#  ('thomaro01', 0.441),
#  ('troutmi01', 0.441),
#  ('ottme01', 0.44),
#  ('dobyla01', 0.44),
#  ('wardpi01', 0.44),
#  ('ansonca01', 0.44),
#  ('bishoma01', 0.44),
#  ('bishoma01', 0.44),
#  ('bondsba01', 0.44),
#  ('burkeje01', 0.44),
#  ('cabremi01', 0.44),
#  ('corcoti01', 0.44),
#  ('delahed01', 0.44),
#  ('dimagjo01', 0.44),
#  ('giambja01', 0.44),
#  ('grantge01', 0.44),
#  ('hamilbi01', 0.44),
#  ('jorgemi01', 0.44),
#  ('kellejo01', 0.44),
#  ('seweljo01', 0.44),
#  ('ottme01', 0.439),
#  ('foxxji01', 0.439),
#  ('camildo01', 0.439),
#  ('fournja01', 0.439),
#  ('furcara01', 0.439),
#  ('hafnetr01', 0.439),
#  ('joycebi01', 0.439),
#  ('pujolal01', 0.439),
#  ('ramirma02', 0.439),
#  ('stenzja01', 0.439),
#  ('terrybi01', 0.439),
#  ('thomafr04', 0.439),
#  ('myerbu01', 0.438),
#  ('belleal01', 0.438),
#  ('bondsba01', 0.438),
#  ('burkeje01', 0.438),
#  ('campbbr01', 0.438),
#  ('cunnijo01', 0.438),
#  ('dahlebi01', 0.438),
#  ('grimera01', 0.438),
#  ('henderi01', 0.438),
#  ('larkiba01', 0.438),
#  ('musiast01', 0.438),
#  ('musiast01', 0.438),
#  ('sheffga01', 0.438),
#  ('singlke01', 0.438),
#  ('thomaro01', 0.438),
#  ('thomeji01', 0.438),
#  ('wanerpa01', 0.438),
#  ('mizejo01', 0.437),
#  ('sosasa01', 0.437),
#  ('averiea01', 0.437),
#  ('chancfr01', 0.437),
#  ('chrisll01', 0.437),
#  ('collied01', 0.437),
#  ('collied01', 0.437),
#  ('flickel01', 0.437),
#  ('hassero01', 0.437),
#  ('kellech01', 0.437),
#  ('manseto01', 0.437),
#  ('morneju01', 0.437),
#  ('musiast01', 0.437),
#  ('musiast01', 0.437),
#  ('schanwa01', 0.437),
#  ('spierbi01', 0.437),
#  ('thompja01', 0.437),
#  ('drewjd01', 0.436),
#  ('mizejo01', 0.436),
#  ('wardda01', 0.436),
#  ('ashburi01', 0.436),
#  ('bishoma01', 0.436),
#  ('bradlmi01', 0.436),
#  ('brettge01', 0.436),
#  ('chancfr01', 0.436),
#  ('greenha01', 0.436),
#  ('jeterde01', 0.436),
#  ('kauffbe01', 0.436),
#  ('padgedo01', 0.436),
#  ('robinja02', 0.436),
#  ('robinya01', 0.436),
#  ('stenzja01', 0.436),
#  ('tenacge01', 0.436),
#  ('thomafr04', 0.436),
#  ('youngro01', 0.436),
#  ('fainfe01', 0.435),
#  ('wynnji01', 0.435),
#  ('yosted01', 0.435),
#  ('applilu01', 0.435),
#  ('bruckea01', 0.435),
#  ('connoro01', 0.435),
#  ('giambja01', 0.435),
#  ('goldspa01', 0.435),
#  ('greenha01', 0.435),
#  ('griffmi01', 0.435),
#  ('heilmha01', 0.435),
#  ('jonesch06', 0.435),
#  ('joycebi01', 0.435),
#  ('mcveyca01', 0.435),
#  ('phillto02', 0.435),
#  ('schmimi01', 0.435),
#  ('shochge01', 0.435),
#  ('smithel01', 0.435),
#  ('stephri01', 0.435),
#  ('vottojo01', 0.435),
#  ('willibe02', 0.435),
#  ('gorege01', 0.434),
#  ('browefr01', 0.434),
#  ('childcu01', 0.434),
#  ('clarkja01', 0.434),
#  ('crabtes01', 0.434),
#  ('farredo01', 0.434),
#  ('garcino01', 0.434),
#  ('gilesbr02', 0.434),
#  ('heltoto01', 0.434),
#  ('mcinnst01', 0.434),
#  ('molitpa01', 0.434),
#  ('ordonma01', 0.434),
#  ('phelpke01', 0.434),
#  ('stephri01', 0.434),
#  ('thomafr04', 0.434),
#  ('vottojo01', 0.434),
#  ('willite01', 0.434),
#  ('rayir01', 0.433),
#  ('cobbty01', 0.433),
#  ('yosted01', 0.433),
#  ('ansonca01', 0.433),
#  ('applilu01', 0.433),
#  ('giambje01', 0.433),
#  ('grebecr01', 0.433),
#  ('jacksjo01', 0.433),
#  ('johnsbo01', 0.433),
#  ('mooreed01', 0.433),
#  ('musiast01', 0.433),
#  ('peskyjo01', 0.433),
#  ('smithel01', 0.433),
#  ('gorege01', 0.432),
#  ('ashburi01', 0.432),
#  ('barbebr01', 0.432),
#  ('bassljo01', 0.432),
#  ('bresnro01', 0.432),
#  ('broutda01', 0.432),
#  ('burroje01', 0.432),
#  ('collied01', 0.432),
#  ('gilesbr02', 0.432),
#  ('kinerra01', 0.432),
#  ('meyerch01', 0.432),
#  ('musiast01', 0.432),
#  ('troutmi01', 0.432),
#  ('tulowtr01', 0.432),
#  ('vandejo02', 0.432),
#  ('virtuja01', 0.432),
#  ('walkedi02', 0.432),
#  ('willicy01', 0.432),
#  ('willike01', 0.432),
#  ('cobbty01', 0.431),
#  ('moonwa01', 0.431),
#  ('boggswa01', 0.431),
#  ('bondsba01', 0.431),
#  ('burgesm01', 0.431),
#  ('clarkwi02', 0.431),
#  ('collied01', 0.431),
#  ('cravaga01', 0.431),
#  ('greenha01', 0.431),
#  ('hargrmi01', 0.431),
#  ('harrida01', 0.431),
#  ('heltoto01', 0.431),
#  ('hornsro01', 0.431),
#  ('lajoina01', 0.431),
#  ('piazzmi01', 0.431),
#  ('pujolal01', 0.431),
#  ('stengca01', 0.431),
#  ('vaughar01', 0.431),
#  ('wagneho01', 0.431),
#  ('wrighta01', 0.431),
#  ('cobbty01', 0.43),
#  ('dalyto01', 0.43),
#  ('fainfe01', 0.43),
#  ('krukjo01', 0.43),
#  ('ruthba01', 0.43),
#  ('bassljo01', 0.43),
#  ('berkmla01', 0.43),
#  ('boggswa01', 0.43),
#  ('brownpe01', 0.43),
#  ('cabremi01', 0.43),
#  ('chapmbe01', 0.43),
#  ('gehrich01', 0.43),
#  ('gilesbr02', 0.43),
#  ('hamilbi01', 0.43),
#  ('harrato01', 0.43),
#  ('johnsbo01', 0.43),
#  ('lyonsde01', 0.43),
#  ('mageesh01', 0.43),
#  ('mccarto01', 0.43),
#  ('ofarrbo01', 0.43),
#  ('pujolal01', 0.43),
#  ('retteme01', 0.43),
#  ('salkebi01', 0.43),
#  ('speaktr01', 0.43),
#  ('tenacge01', 0.43),
#  ('averiea01', 0.429),
#  ('crawfsa01', 0.429),
#  ('davisch01', 0.429),
#  ('gonzalu01', 0.429),
#  ('heltoto01', 0.429),
#  ('lucrojo01', 0.429),
#  ('mantlmi01', 0.429),
#  ('martied01', 0.429),
#  ('mauerjo01', 0.429),
#  ('mccarto01', 0.429),
#  ('mccovwi01', 0.429),
#  ('mitchke01', 0.429),
#  ('pujolal01', 0.429),
#  ('raineti01', 0.429),
#  ('salmoti01', 0.429),
#  ('schanwa01', 0.429),
#  ('smithol01', 0.429),
#  ('speaktr01', 0.429),
#  ('thompsa01', 0.429),
#  ('walkeha01', 0.429),
#  ('dobyla01', 0.428),
#  ('hackst01', 0.428),
#  ('valoel01', 0.428),
#  ('abreubo01', 0.428),
#  ('danieka01', 0.428),
#  ('davisge01', 0.428),
#  ('dickebi01', 0.428),
#  ('kendaja01', 0.428),
#  ('kleinch01', 0.428),
#  ('larkihe01', 0.428),
#  ('musiast01', 0.428),
#  ('snodgfr01', 0.428),
#  ('wrighra01', 0.428),
#  ('mizejo01', 0.427),
#  ('rosepe01', 0.427),
#  ('snowjt01', 0.427),
#  ('abreubo01', 0.427),
#  ('collied01', 0.427),
#  ('fernato01', 0.427),
#  ('hermaba01', 0.427),
#  ('herzobu01', 0.427),
#  ('johnsni01', 0.427),
#  ('jonesch06', 0.427),
#  ('joosted01', 0.427),
#  ('justida01', 0.427),
#  ('killeha01', 0.427),
#  ('magadda01', 0.427),
#  ('olerujo01', 0.427),
#  ('ramirma02', 0.427),
#  ('vaughar01', 0.427),
#  ('woodlge01', 0.427),
#  ('bluelu01', 0.426),
#  ('bondsba01', 0.426),
#  ('broutda01', 0.426),
#  ('clarkwi02', 0.426),
#  ('collied01', 0.426),
#  ('connoro01', 0.426),
#  ('cuyleki01', 0.426),
#  ('delgaca01', 0.426),
#  ('guerrvl01', 0.426),
#  ('heilmha01', 0.426),
#  ('henderi01', 0.426),
#  ('hornsro01', 0.426),
#  ('lopezfe01', 0.426),
#  ('lyonsde01', 0.426),
#  ('morgajo02', 0.426),
#  ('murcebo01', 0.426),
#  ('posadjo01', 0.426),
#  ('scottlu01', 0.426),
#  ('smithre06', 0.426),
#  ('thomafr04', 0.426),
#  ('thomaro01', 0.426),
#  ('thomeji01', 0.426),
#  ('yastrca01', 0.426),
#  ('mayswi01', 0.425),
#  ('valoel01', 0.425),
#  ('woodji01', 0.425),
#  ('alfoned01', 0.425),
#  ('bagweje01', 0.425),
#  ('bishoma01', 0.425),
#  ('bonurze01', 0.425),
#  ('cangejo01', 0.425),
#  ('carewro01', 0.425),
#  ('dietzdi01', 0.425),
#  ('dimagjo01', 0.425),
#  ('fairlro01', 0.425),
#  ('gosligo01', 0.425),
#  ('hanseda01', 0.425),
#  ('henderi01', 0.425),
#  ('howarry01', 0.425),
#  ('johnsbo01', 0.425),
#  ('jonesch06', 0.425),
#  ('mcbrial01', 0.425),
#  ('mumphje01', 0.425),
#  ('robinja02', 0.425),
#  ('rosenla01', 0.425),
#  ('sheckji01', 0.425),
#  ('singlke01', 0.425),
#  ('tayloca01', 0.425),
#  ('thornan01', 0.425),
#  ('wheatza01', 0.425),
#  ('hoydu01', 0.424),
#  ('kentje01', 0.424),
#  ('applilu01', 0.424),
#  ('bagweje01', 0.424),
#  ('bagweje01', 0.424),
#  ('cochrmi01', 0.424),
#  ('collipa01', 0.424),
#  ('davisal01', 0.424),
#  ('engliwo01', 0.424),
#  ('galanau01', 0.424),
#  ('gehrilo01', 0.424),
#  ('jennihu01', 0.424),
#  ('knoblch01', 0.424),
#  ('mcgwima01', 0.424),
#  ('randowi01', 0.424),
#  ('sheffga01', 0.424),
#  ('thompsa01', 0.424),
#  ('vottojo01', 0.424),
#  ('wanerpa01', 0.424),
#  ('krukjo01', 0.423),
#  ('lappja01', 0.423),
#  ('lynnfr01', 0.423),
#  ('myerbu01', 0.423),
#  ('ashburi01', 0.423),
#  ('baineha01', 0.423),
#  ('bishoma01', 0.423),
#  ('collied01', 0.423),
#  ('collied01', 0.423),
#  ('delahed01', 0.423),
#  ('delahed01', 0.423),
#  ('fishesh01', 0.423),
#  ('gehrich01', 0.423),
#  ('gehrilo01', 0.423),
#  ('gentiji01', 0.423),
#  ('gilesbr02', 0.423),
#  ('gradymi01', 0.423),
#  ('hamilbi01', 0.423),
#  ('heganmi01', 0.423),
#  ('heilmha01', 0.423),
#  ('henderi01', 0.423),
#  ('keelewi01', 0.423),
#  ('mantlmi01', 0.423),
#  ('martied01', 0.423),
#  ('martied01', 0.423),
#  ('minosmi01', 0.423),
#  ('mondari01', 0.423),
#  ('musiast01', 0.423),
#  ('orourti01', 0.423),
#  ('roushed01', 0.423),
#  ('schanwa01', 0.423),
#  ('seeryem01', 0.423),
#  ('seymocy01', 0.423),
#  ('snidedu01', 0.423),
#  ('speaktr01', 0.423),
#  ('staubru01', 0.423),
#  ('stenzja01', 0.423),
#  ('thomeji01', 0.423),
#  ('tiernmi01', 0.423),
#  ('wanerpa01', 0.423),
#  ('ottme01', 0.422),
#  ('cobbty01', 0.422),
#  ('mizejo01', 0.422),
#  ('ansonca01', 0.422),
#  ('astrojo01', 0.422),
#  ('bishoma01', 0.422),
#  ('cliftha01', 0.422),
#  ('cliftha01', 0.422),
#  ('cranddo01', 0.422),
#  ('durazer01', 0.422),
#  ('giambja01', 0.422),
#  ('grossgr01', 0.422),
#  ('guerrpe01', 0.422),
#  ('henderi01', 0.422),
#  ('henderi01', 0.422),
#  ('hermage01', 0.422),
#  ('hernake01', 0.422),
#  ('judgeaa01', 0.422),
#  ('larkihe01', 0.422),
#  ('madlobi01', 0.422),
#  ('mazzile01', 0.422),
#  ('mcphebi01', 0.422),
#  ('piazzmi01', 0.422),
#  ('randowi01', 0.422),
#  ('retteme01', 0.422),
#  ('robinja02', 0.422),
#  ('rodrial01', 0.422),
#  ('rosenal01', 0.422),
#  ('smithea02', 0.422),
#  ('speaktr01', 0.422),
#  ('stanked01', 0.422),
#  ('vanhage01', 0.422),
#  ('wagneho01', 0.422),
#  ('walkela01', 0.422),
#  ('willibe02', 0.422),
#  ('wilsoar01', 0.422),
#  ('ottme01', 0.421),
#  ('choosh01', 0.421),
#  ('cruzne02', 0.421),
#  ('ruthba01', 0.421),
#  ('wolfji01', 0.421),
#  ('applilu01', 0.421),
#  ('boggswa01', 0.421),
#  ('bradlmi01', 0.421),
#  ('childcu01', 0.421),
#  ('cronijo01', 0.421),
#  ('elliobo01', 0.421),
#  ('eversjo01', 0.421),
#  ('fletcel01', 0.421),
#  ('flickel01', 0.421),
#  ('galanau01', 0.421),
#  ('gehrich01', 0.421),
#  ('goodmbi01', 0.421),
#  ('harrijo03', 0.421),
#  ('hollibu01', 0.421),
#  ('jonescl01', 0.421),
#  ('jonesfi01', 0.421),
#  ('kalinal01', 0.421),
#  ('lyonsde01', 0.421),
#  ('matheed01', 0.421),
#  ('musiast01', 0.421),
#  ('orourti01', 0.421),
#  ('phelpba01', 0.421),
#  ('readyra01', 0.421),
#  ('robinfr02', 0.421),
#  ('rodrial01', 0.421),
#  ('schofdi01', 0.421),
#  ('smithel01', 0.421),
#  ('stahlch01', 0.421),
#  ('walkela01', 0.421),
#  ('westlwa01', 0.421),
#  ('hoppjo01', 0.42),
#  ('allendi01', 0.42),
#  ('berkmla01', 0.42),
#  ('berkmla01', 0.42),
#  ('cabremi01', 0.42),
#  ('cochrmi01', 0.42),
#  ('connoro01', 0.42),
#  ('delahed01', 0.42),
#  ('dykstle01', 0.42),
#  ('edmonji01', 0.42),
#  ('fairlro01', 0.42),
#  ('fournja01', 0.42),
#  ('freembu01', 0.42),
#  ('hargrmi01', 0.42),
#  ('harpege02', 0.42),
#  ('huggimi01', 0.42),
#  ('kleinch01', 0.42),
#  ('mccosba01', 0.42),
#  ('mccovwi01', 0.42),
#  ('northro01', 0.42),
#  ('odoulle01', 0.42),
#  ('palmera01', 0.42),
#  ('plantph01', 0.42),
#  ('rodrial01', 0.42),
#  ('salkebi01', 0.42),
#  ('torrejo01', 0.42),
#  ('vaughmo01', 0.42),
#  ('vaughmo01', 0.42),
#  ('weintph01', 0.42),
#  ('mayswi01', 0.419),
#  ('suhrgu01', 0.419),
#  ('woodjo02', 0.419),
#  ('abramca01', 0.419),
#  ('bladera01', 0.419),
#  ('bresnro01', 0.419),
#  ('burksel01', 0.419),
#  ('caminke01', 0.419),
#  ('connoro01', 0.419),
#  ('cruiswa01', 0.419),
#  ('fairlro01', 0.419),
#  ('fioremi01', 0.419),
#  ('haneyfr01', 0.419),
#  ('henderi01', 0.419),
#  ('hollima01', 0.419),
#  ('holmedu01', 0.419),
#  ('johnsni01', 0.419),
#  ('larkihe01', 0.419),
#  ('longmto01', 0.419),
#  ('lopesda01', 0.419),
#  ('musiast01', 0.419),
#  ('newsowa01', 0.419),
#  ('oneilti01', 0.419),
#  ('retteme01', 0.419),
#  ('schanwa01', 0.419),
#  ('selbaki01', 0.419),
#  ('sheffga01', 0.419),
#  ('stephri01', 0.419),
#  ('tettlmi01', 0.419),
#  ('wagneho01', 0.419),
#  ('wistete01', 0.419),
#  ('youngro01', 0.419),
#  ('zarilal01', 0.419),
#  ('hoydu01', 0.418),
#  ('leede02', 0.418),
#  ('foxxji01', 0.418),
#  ('hahned01', 0.418),
#  ('riosar01', 0.418),
#  ('rosepe01', 0.418),
#  ('applilu01', 0.418),
#  ('applilu01', 0.418),
#  ('carrofr01', 0.418),
#  ('collied01', 0.418),
#  ('cuyleki01', 0.418),
#  ('doyleja01', 0.418),
#  ('edmonji01', 0.418),
#  ('fournja01', 0.418),
#  ('garcino01', 0.418),
#  ('gilesbr02', 0.418),
#  ('glavito01', 0.418),
#  ('hickmji02', 0.418),
#  ('holmeto01', 0.418),
#  ('justida01', 0.418),
#  ('mcfarhe01', 0.418),
#  ('porteda02', 0.418),
#  ('ramirma02', 0.418),
#  ('robinja02', 0.418),
#  ('snidedu01', 0.418),
#  ('stonejo01', 0.418),
#  ('wanerpa01', 0.418),
#  ('woodlge01', 0.418),
#  ('yastrca01', 0.418),
#  ('yastrca01', 0.418),
#  ('dunnad01', 0.417),
#  ('hackst01', 0.417),
#  ('odeake01', 0.417),
#  ('yorkru01', 0.417),
#  ('bishoma01', 0.417),
#  ('bladera01', 0.417),
#  ('bressru01', 0.417),
#  ('burkeje01', 0.417),
#  ('carewro01', 0.417),
#  ('combsea01', 0.417),
#  ('dahlebi01', 0.417),
#  ('dykstle01', 0.417),
#  ('edwarha01', 0.417),
#  ('evansdw01', 0.417),
#  ('ferguch01', 0.417),
#  ('fletcel01', 0.417),
#  ('guerrvl01', 0.417),
#  ('hartnga01', 0.417),
#  ('henderi01', 0.417),
#  ('henrito01', 0.417),
#  ('hernake01', 0.417),
#  ('keelewi01', 0.417),
#  ('kellyki01', 0.417),
#  ('kurowwh01', 0.417),
#  ('lazzeto01', 0.417),
#  ('maybejo01', 0.417),
#  ('minosmi01', 0.417),
#  ('morgajo02', 0.417),
#  ('murphda05', 0.417),
#  ('piazzmi01', 0.417),
#  ('posadjo01', 0.417),
#  ('schomot01', 0.417),
#  ('selkige01', 0.417),
#  ('sheffga01', 0.417),
#  ('simmoal01', 0.417),
#  ('smithlo01', 0.417),
#  ('sweenmi01', 0.417),
#  ('zimmech01', 0.417),
#  ('aloumo01', 0.416),
#  ('bluelu01', 0.416),
#  ('gorege01', 0.416),
#  ('ryanji01', 0.416),
#  ('yosted01', 0.416),
#  ('abreubo01', 0.416),
#  ('bressru01', 0.416),
#  ('cuyleki01', 0.416),
#  ('dickebi01', 0.416),
#  ('downibr01', 0.416),
#  ('duffyhu01', 0.416),
#  ('duffyhu01', 0.416),
#  ('fribebe01', 0.416),
#  ('greenmi01', 0.416),
#  ('guerrpe01', 0.416),
#  ('heltoto01', 0.416),
#  ('henrito01', 0.416),
#  ('hornsro01', 0.416),
#  ('howarfr01', 0.416),
#  ('kellech01', 0.416),
#  ('kellech01', 0.416),
#  ('kinerra01', 0.416),
#  ('lindsfr01', 0.416),
#  ('maybejo01', 0.416),
#  ('mccovwi01', 0.416),
#  ('michaja01', 0.416),
#  ('musiast01', 0.416),
#  ('robinja02', 0.416),
#  ('severha01', 0.416),
#  ('snidedu01', 0.416),
#  ('thomeji01', 0.416),
#  ('thomeji01', 0.416),
#  ('thompsa01', 0.416),
#  ('vanhage01', 0.416),
#  ('vottojo01', 0.416),
#  ('wrighda03', 0.416),
#  ('cobbty01', 0.415),
#  ('mackre01', 0.415),
#  ('morame01', 0.415),
#  ('ryanji01', 0.415),
#  ('abreubo01', 0.415),
#  ('alomaro01', 0.415),
#  ('ansonca01', 0.415),
#  ('beltrca01', 0.415),
#  ('biggicr01', 0.415),
#  ('bollija01', 0.415),
#  ('bresnro01', 0.415),
#  ('cavarph01', 0.415),
#  ('clemeja01', 0.415),
#  ('fennefr01', 0.415),
#  ('fieldpr01', 0.415),
#  ('gowdyha01', 0.415),
#  ('hanseda01', 0.415),
#  ('hargrmi01', 0.415),
#  ('jamiech01', 0.415),
#  ('johnsni01', 0.415),
#  ('kalinal01', 0.415),
#  ('lajoina01', 0.415),
#  ('mauerjo01', 0.415),
#  ('morgajo02', 0.415),
#  ('niarhgu01', 0.415),
#  ('oneilst01', 0.415),
#  ('ortizda01', 0.415),
#  ('pearsal02', 0.415),
#  ('pujolal01', 0.415),
#  ('ramirma02', 0.415),
#  ('robinfr02', 0.415),
#  ('sefcike01', 0.415),
#  ('severha01', 0.415),
#  ('simmoal01', 0.415),
#  ('smithea02', 0.415),
#  ('snidedu01', 0.415),
#  ('speaktr01', 0.415),
#  ('stiveja01', 0.415),
#  ('stransa01', 0.415),
#  ('torgeea01', 0.415),
#  ('wagneha01', 0.415),
#  ('wanerpa01', 0.415),
#  ('willibe02', 0.415),
#  ('willike01', 0.415),
#  ('willike01', 0.415),
#  ('wilsoha01', 0.415),
#  ('hoydu01', 0.414),
#  ('orrda01', 0.414),
#  ('ottme01', 0.414),
#  ('hillgl01', 0.414),
#  ('jahajo01', 0.414),
#  ('myerbu01', 0.414),
#  ('neunjo01', 0.414),
#  ('owensp01', 0.414),
#  ('wardtu01', 0.414),
#  ('batesjo02', 0.414),
#  ('bottoji01', 0.414),
#  ('bradlmi01', 0.414),
#  ('burnsoy01', 0.414),
#  ('davisge01', 0.414),
#  ('delanbi02', 0.414),
#  ('donlimi01', 0.414),
#  ('epstemi01', 0.414),
#  ('floydcl01', 0.414),
#  ('fonsele01', 0.414),
#  ('gehrich01', 0.414),
#  ('germaes01', 0.414),
#  ('gilesbr02', 0.414),
#  ('hargrmi01', 0.414),
#  ('hoilech01', 0.414),
#  ('irvinmo01', 0.414),
#  ('jeterde01', 0.414),
#  ('keelewi01', 0.414),
#  ('keelewi01', 0.414),
#  ('keelewi01', 0.414),
#  ...]

# %% [markdown]
# - That is not quite what the user story asked. The query had to select and compute OBP to include in ```order by```
#
#
# - This results in seeing ```playerID``` more than once.
#
#
# - This is where the power of an algebra becomes apparent. The result compute is a table, which itself can be queried.

# %%
# %sql select distinct playerid from \
    (select playerID, round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3) as obp\
        from batting  \
             where \
            ab > 100 AND \
            (round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3) > 0.400) \
       order by \
            obp desc) as temp;
# Out:
# 728 rows affected.
# [('aaronha01',),
#  ('abramca01',),
#  ('abreubo01',),
#  ('alexada01',),
#  ('alexaga01',),
#  ('alfoned01',),
#  ('allendi01',),
#  ('allisbo01',),
#  ('alomaro01',),
#  ('aloumo01',),
#  ('altuvjo01',),
#  ('anderbr01',),
#  ('ansonca01',),
#  ('applilu01',),
#  ('ashburi01',),
#  ('astrojo01',),
#  ('atkinga01',),
#  ('averiea01',),
#  ('bagweje01',),
#  ('bailebo01',),
#  ('baineha01',),
#  ('bakerfl01',),
#  ('bakerfr01',),
#  ('bandosa01',),
#  ('bannial01',),
#  ('bannoji01',),
#  ('barbebr01',),
#  ('bardjo01',),
#  ('barneau01',),
#  ('barnero01',),
#  ('barrebi02',),
#  ('bassljo01',),
#  ('batesjo02',),
#  ('bautijo02',),
#  ('bayja01',),
#  ('beaumgi01',),
#  ('beckehe02',),
#  ('belleal01',),
#  ('beltrca01',),
#  ('berbelo01',),
#  ('berkmla01',),
#  ('biggicr01',),
#  ('bishoma01',),
#  ('bladera01',),
#  ('blausje01',),
#  ('bluelu01',),
#  ('boggswa01',),
#  ('bollija01',),
#  ('bondsba01',),
#  ('bonnefr01',),
#  ('bonurze01',),
#  ('booneik01',),
#  ('boonera01',),
#  ('bottoji01',),
#  ('boudrlo01',),
#  ('bradlmi01',),
#  ('bradlph01',),
#  ('braunst01',),
#  ('bresnro01',),
#  ('bressru01',),
#  ('brettge01',),
#  ('broutda01',),
#  ('browefr01',),
#  ('brownga01',),
#  ('brownpe01',),
#  ('bruckea01',),
#  ('bryankr01',),
#  ('bufordo01',),
#  ('burgesm01',),
#  ('burkeje01',),
#  ('burksel01',),
#  ('burnije01',),
#  ('burnsoy01',),
#  ('burroje01',),
#  ('bushra01',),
#  ('butlebr01',),
#  ('byrdsa01',),
#  ('cabremi01',),
#  ('camildo01',),
#  ('caminke01',),
#  ('campbbr01',),
#  ('cangejo01',),
#  ('carbobe01',),
#  ('carewro01',),
#  ('careyma01',),
#  ('carrofr01',),
#  ('cartyri01',),
#  ('carutbo01',),
#  ('cashno01',),
#  ('castilu01',),
#  ('cavarph01',),
#  ('chancfr01',),
#  ('chapmbe01',),
#  ('childcu01',),
#  ('choosh01',),
#  ('chriscu01',),
#  ('chrisll01',),
#  ('clarkfr01',),
#  ('clarkja01',),
#  ('clarkwi02',),
#  ('clemeja01',),
#  ('clemero01',),
#  ('cliftha01',),
#  ('cobbty01',),
#  ('cochrmi01',),
#  ('colavro01',),
#  ('colbrgr01',),
#  ('collied01',),
#  ('collipa01',),
#  ('combsea01',),
#  ('connafr01',),
#  ('connoro01',),
#  ('cookedu01',),
#  ('corcoti01',),
#  ('crabtes01',),
#  ('cranddo01',),
#  ('cravaga01',),
#  ('crawfsa01',),
#  ('creebi01',),
#  ('cronijo01',),
#  ('crookja01',),
#  ('crossla01',),
#  ('crousbu01',),
#  ('cruiswa01',),
#  ('cruzne02',),
#  ('cullero01',),
#  ('cunnijo01',),
#  ('custja01',),
#  ('cuyleki01',),
#  ('dahlebi01',),
#  ('dalyto01',),
#  ('danieka01',),
#  ('darlide01',),
#  ('davanje01',),
#  ('davisal01',),
#  ('davisch01',),
#  ('davisge01',),
#  ('davisle01',),
#  ('davissp01',),
#  ('delahed01',),
#  ('delanbi02',),
#  ('delgaca01',),
#  ('delluda01',),
#  ('dickebi01',),
#  ('dickech01',),
#  ('dietzdi01',),
#  ('dimagdo01',),
#  ('dimagjo01',),
#  ('dobyla01',),
#  ('donaljo02',),
#  ('donlimi01',),
#  ('doranbi02',),
#  ('doughpa01',),
#  ('douthta01',),
#  ('downibr01',),
#  ('doyleja01',),
#  ('drewjd01',),
#  ('duffyhu01',),
#  ('dunlafr01',),
#  ('dunnad01',),
#  ('durazer01',),
#  ('dwyerji01',),
#  ('dykesji01',),
#  ('dykstle01',),
#  ('eayrsed01',),
#  ('edmonji01',),
#  ('edwarha01',),
#  ('eisenji01',),
#  ('elberki01',),
#  ('elliobo01',),
#  ('engliwo01',),
#  ('epstemi01',),
#  ('erstada01',),
#  ('ettenni01',),
#  ('evansda01',),
#  ('evansdw01',),
#  ('evansjo01',),
#  ('evansst01',),
#  ('eversho01',),
#  ('eversjo01',),
#  ('ewingbu01',),
#  ('fainfe01',),
#  ('fairlro01',),
#  ('farredo01',),
#  ('fennefr01',),
#  ('ferguch01',),
#  ('fernato01',),
#  ('ferreri01',),
#  ('ferrewe01',),
#  ('fieldpr01',),
#  ('fioremi01',),
#  ('fishesh01',),
#  ('flagsir01',),
#  ('flemile01',),
#  ('fletcel01',),
#  ('flickel01',),
#  ('floydcl01',),
#  ('fonsele01',),
#  ('forceda01',),
#  ('fothebo01',),
#  ('fournja01',),
#  ('foxxji01',),
#  ('francju01',),
#  ('francti01',),
#  ('frankch01',),
#  ('freembu01',),
#  ('freemfr01',),
#  ('fribebe01',),
#  ('furcara01',),
#  ('galanau01',),
#  ('galaran01',),
#  ('gamblos01',),
#  ('garagjo01',),
#  ('garcino01',),
#  ('garmsde01',),
#  ('gehrich01',),
#  ('gehrilo01',),
#  ('gentiji01',),
#  ('germaes01',),
#  ('giambja01',),
#  ('giambje01',),
#  ('gilesbr02',),
#  ('gladdda01',),
#  ('glassja01',),
#  ('glaustr01',),
#  ('glavito01',),
#  ('goldspa01',),
#  ('gonzaad01',),
#  ('gonzalu01',),
#  ('goodmbi01',),
#  ('gordojo01',),
#  ('gordosi01',),
#  ('gorege01',),
#  ('gosligo01',),
#  ('gowdyha01',),
#  ('gracejo01',),
#  ('gracema01',),
#  ('gradymi01',),
#  ('grantge01',),
#  ('grebecr01',),
#  ('greenha01',),
#  ('greenmi01',),
#  ('greerru01',),
#  ('grichbo01',),
#  ('griffke01',),
#  ('griffke02',),
#  ('griffmi01',),
#  ('grimera01',),
#  ('grossgr01',),
#  ('grothjo01',),
#  ('grubbjo01',),
#  ('guerrpe01',),
#  ('guerrvl01',),
#  ('gwynnto01',),
#  ('hackst01',),
#  ('hafeych01',),
#  ('hafnetr01',),
#  ('hahned01',),
#  ('halech01',),
#  ('hamilbi01',),
#  ('hamilda02',),
#  ('hamiljo03',),
#  ('haneyfr01',),
#  ('hanigry01',),
#  ('hanseda01',),
#  ('hargrbu01',),
#  ('hargrmi01',),
#  ('harpebr03',),
#  ('harpege02',),
#  ('harrato01',),
#  ('harrida01',),
#  ('harrijo03',),
#  ('hartnga01',),
#  ('hartsto01',),
#  ('hassero01',),
#  ('hastisc01',),
#  ('hayesvo01',),
#  ('hazlebo01',),
#  ('heathje01',),
#  ('heckegu01',),
#  ('heganmi01',),
#  ('heilmha01',),
#  ('heltoto01',),
#  ('hemusso01',),
#  ('henderi01',),
#  ('henlibu01',),
#  ('henrito01',),
#  ('hermaba01',),
#  ('hermabi01',),
#  ('hermage01',),
#  ('hernake01',),
#  ('herzobu01',),
#  ('herzowh01',),
#  ('hickmji02',),
#  ('higgibo02',),
#  ('hillgl01',),
#  ('hoilech01',),
#  ('holbrsa01',),
#  ('hollato01',),
#  ('hollibu01',),
#  ('hollima01',),
#  ('holmedu01',),
#  ('holmeto01',),
#  ('hoopeha01',),
#  ('hoppjo01',),
#  ('hornsro01',),
#  ('howarfr01',),
#  ('howarry01',),
#  ('hoydu01',),
#  ('huggimi01',),
#  ('huntro01',),
#  ('hurstdo01',),
#  ('irvinmo01',),
#  ('jacksjo01',),
#  ('jacksre01',),
#  ('jahajo01',),
#  ('jamiech01',),
#  ('jeffegr01',),
#  ('jennihu01',),
#  ('jenseja01',),
#  ('jeterde01',),
#  ('johnsbo01',),
#  ('johnsch04',),
#  ('johnscl01',),
#  ('johnsda02',),
#  ('johnser01',),
#  ('johnsni01',),
#  ('johnssp01',),
#  ('jonesch06',),
#  ('jonescl01',),
#  ('jonesfi01',),
#  ('joosted01',),
#  ('jorgemi01',),
#  ('joycebi01',),
#  ('joycema01',),
#  ('judgeaa01',),
#  ('judgejo01',),
#  ('judniwa01',),
#  ('jurgebi01',),
#  ('justida01',),
#  ('kalinal01',),
#  ('kauffbe01',),
#  ('kearnau01',),
#  ('keelewi01',),
#  ('kellech01',),
#  ('kellejo01',),
#  ('kellge01',),
#  ('kellyki01',),
#  ('kendaja01',),
#  ('kentje01',),
#  ('kieltbo01',),
#  ('killeha01',),
#  ('kinerra01',),
#  ('kleinch01',),
#  ('kluszte01',),
#  ('knoblch01',),
#  ('koenele01',),
#  ('kreutch01',),
#  ('krukjo01',),
#  ('kurowwh01',),
#  ('lajoina01',),
#  ('lakeed01',),
#  ('langebi01',),
#  ('lankfra01',),
#  ('lappja01',),
#  ('larkiba01',),
#  ('larkihe01',),
#  ('larocad01',),
#  ('lawtoma02',),
#  ('lazzeto01',),
#  ('leede02',),
#  ('leibeha01',),
#  ('lemahdj01',),
#  ('lennoed01',),
#  ('leslisa01',),
#  ('lewisbu01',),
#  ('lewisma01',),
#  ('leyriji01',),
#  ('lezcasi01',),
#  ('lindsfr01',),
#  ('loftoke01',),
#  ('lombaer01',),
#  ('longmto01',),
#  ('lopesda01',),
#  ('lopezfe01',),
#  ('lowenjo01',),
#  ('lucasre01',),
#  ('lucrojo01',),
#  ('lynchje01',),
#  ('lynnfr01',),
#  ('lyonsde01',),
#  ('mackre01',),
#  ('macksh01',),
#  ('madlobi01',),
#  ('magadda01',),
#  ('mageesh01',),
#  ('mancugu01',),
#  ('mannle01',),
#  ('manseto01',),
#  ('mantlmi01',),
#  ('manushe01',),
#  ('markani01',),
#  ('marrle01',),
#  ('martied01',),
#  ('martivi01',),
#  ('matheed01',),
#  ('matthga01',),
#  ('mauerjo01',),
#  ('maulal01',),
#  ('maxwech01',),
#  ('maybejo01',),
#  ('mayca01',),
#  ('mayswi01',),
#  ('mazzile01',),
#  ('mcbrial01',),
#  ('mccarti01',),
#  ('mccarto01',),
#  ('mccosba01',),
#  ('mccovwi01',),
#  ('mccreto01',),
#  ('mccutan01',),
#  ('mcdonte01',),
#  ('mcfarhe01',),
#  ('mcgrajo01',),
#  ('mcgrifr01',),
#  ('mcgwima01',),
#  ('mcinnst01',),
#  ('mckeaed01',),
#  ('mcphebi01',),
#  ('mcraeha01',),
#  ('mctamji01',),
#  ('mcveyca01',),
#  ('medwijo01',),
#  ('merceor01',),
#  ('merribi01',),
#  ('meyerbe01',),
#  ('meyerch01',),
#  ('meyerle01',),
#  ('michaca01',),
#  ('michaja01',),
#  ('milledo01',),
#  ('millijo01',),
#  ('millira01',),
#  ('minchdo01',),
#  ('minosmi01',),
#  ('mitchke01',),
#  ('mizejo01',),
#  ('mokanjo01',),
#  ('molitpa01',),
#  ('mondari01',),
#  ('moonwa01',),
#  ('mooreed01',),
#  ('morame01',),
#  ('morgaed01',),
#  ('morgajo02',),
#  ('morneju01',),
#  ('morriha02',),
#  ('moseswa01',),
#  ('mostijo01',),
#  ('mumphje01',),
#  ('murcebo01',),
#  ('murphda05',),
#  ('murphed02',),
#  ('murraed02',),
#  ('musiast01',),
#  ('myerbu01',),
#  ('naehrti01',),
#  ('napolmi01',),
#  ('neunjo01',),
#  ('newsowa01',),
#  ('niarhgu01',),
#  ('niemabo01',),
#  ('nilssda01',),
#  ('northro01',),
#  ('ochoaal01',),
#  ('odeake01',),
#  ('odoulle01',),
#  ('ofarrbo01',),
#  ('offerjo01',),
#  ('olerujo01',),
#  ('oneilpa01',),
#  ('oneilst01',),
#  ('oneilti01',),
#  ('oquenjo01',),
#  ('ordonma01',),
#  ('orourji01',),
#  ('orourti01',),
#  ('orrda01',),
#  ('ortizda01',),
#  ('ottme01',),
#  ('owensp01',),
#  ('padgedo01',),
#  ('pagemi02',),
#  ('palmede01',),
#  ('palmera01',),
#  ('paschbe01',),
#  ('paskedo01',),
#  ('pearsal02',),
#  ('penaca01',),
#  ('perezed02',),
#  ('perezto01',),
#  ('perkicy01',),
#  ('peskyjo01',),
#  ('petrori01',),
#  ('phamth01',),
#  ('phelpba01',),
#  ('phelpke01',),
#  ('phillto02',),
#  ('piazzmi01',),
#  ('pinknge01',),
#  ('plantph01',),
#  ('porteda02',),
#  ('portedi01',),
#  ('posadjo01',),
#  ('poseybu01',),
#  ('powelbo01',),
#  ('prattto02',),
#  ('pujolal01',),
#  ('quinlro01',),
#  ('radfopa01',),
#  ('raineti01',),
#  ('ramirha01',),
#  ('ramirma02',),
#  ('randowi01',),
#  ('rayir01',),
#  ('readyra01',),
#  ('reesepe01',),
#  ('reisepe01',),
#  ('rendoan01',),
#  ('retteme01',),
#  ('rhodedu01',),
#  ('riceha01',),
#  ('richaha01',),
#  ('riosar01',),
#  ('rizzuph01',),
#  ('robined01',),
#  ('robinfr02',),
#  ('robinja02',),
#  ('robinwi01',),
#  ('robinya01',),
#  ('rodrial01',),
#  ('roeniro01',),
#  ('rolensc01',),
#  ('rolfere01',),
#  ('rosemch01',),
#  ('rosenal01',),
#  ('rosenla01',),
#  ('rosepe01',),
#  ('rossco01',),
#  ('roushed01',),
#  ('runnepe01',),
#  ('russere01',),
#  ('ruthba01',),
#  ('ryanji01',),
#  ('saenzol01',),
#  ('salkebi01',),
#  ('salmoti01',),
#  ('santaca01',),
#  ('santoro01',),
#  ('sauerha01',),
#  ('schanwa01',),
#  ('scheifr01',),
#  ('scheiri01',),
#  ('schmimi01',),
#  ('schoere01',),
#  ('schofdi01',),
#  ('schomot01',),
#  ('schuljo04',),
#  ('scottlu01',),
#  ('seeryem01',),
#  ('sefcike01',),
#  ('seguida01',),
#  ('seitzke01',),
#  ('selbaki01',),
#  ('selkige01',),
#  ('severha01',),
#  ('seweljo01',),
#  ('seymocy01',),
#  ('sheckji01',),
#  ('sheelea01',),
#  ('sheffga01',),
#  ('shirear01',),
#  ('shochge01',),
#  ('shottbu01',),
#  ('shumpte01',),
#  ('siebeno01',),
#  ('silvech01',),
#  ('simmoal01',),
#  ('simmote01',),
#  ('singlke01',),
#  ('sislege01',),
#  ('slaugen01',),
#  ('smithal01',),
#  ('smithal04',),
#  ('smithea02',),
#  ('smithel01',),
#  ('smithlo01',),
#  ('smithol01',),
#  ('smithre06',),
#  ('snidedu01',),
#  ('snodgfr01',),
#  ('snowjt01',),
#  ('soderer01',),
#  ('sosasa01',),
#  ('southbi01',),
#  ('speaktr01',),
#  ('spierbi01',),
#  ('spilbry01',),
#  ('stahlch01',),
#  ('stanked01',),
#  ('stargwi01',),
#  ('staubru01',),
#  ('stengca01',),
#  ('stenzja01',),
#  ('stephri01',),
#  ('stiveja01',),
#  ('stockke01',),
#  ('stonege01',),
#  ('stonejo01',),
#  ('stoveha01',),
#  ('stransa01',),
#  ('suhrgu01',),
#  ('sullijo01',),
#  ('sullima01',),
#  ('summech01',),
#  ('sutclsy01',),
#  ('suzukic01',),
#  ('swansev01',),
#  ('swarted01',),
#  ('sweenmi01',),
#  ('tartada01',),
#  ('tatisfe01',),
#  ('tayloca01',),
#  ('tebeage01',),
#  ('teixema01',),
#  ('tenacge01',),
#  ('tennefr02',),
#  ('terrybi01',),
#  ('tettlmi01',),
#  ('thomafr04',),
#  ('thomaro01',),
#  ('thomeji01',),
#  ('thompja01',),
#  ('thompsa01',),
#  ('thornan01',),
#  ('tiernmi01',),
#  ('titusjo01',),
#  ('torgeea01',),
#  ('torrejo01',),
#  ('trammal01',),
#  ('travice01',),
#  ('traynpi01',),
#  ('treadge01',),
#  ('troskha01',),
#  ('troutmi01',),
#  ('tucketo01',),
#  ('tulowtr01',),
#  ('turneju01',),
#  ('turnetu01',),
#  ('twombba01',),
#  ('utleych01',),
#  ('valoel01',),
#  ('vandejo02',),
#  ('vanhage01',),
#  ('vaughar01',),
#  ('vaughmo01',),
#  ('verasqu01',),
#  ('vernomi01',),
#  ('virtuja01',),
#  ('vosmijo01',),
#  ('vottojo01',),
#  ('wagneha01',),
#  ('wagneho01',),
#  ('wakefdi01',),
#  ('walkecu01',),
#  ('walkedi02',),
#  ('walkeha01',),
#  ('walkela01',),
#  ('walkene01',),
#  ('wanerpa01',),
#  ('wardda01',),
#  ('wardpi01',),
#  ('wardtu01',),
#  ('watkige01',),
#  ('watsobo01',),
#  ('webbea01',),
#  ('weintph01',),
#  ('werdepe01',),
#  ('werthja01',),
#  ('wertzvi01',),
#  ('westlwa01',),
#  ('wheatza01',),
#  ('whitalo01',),
#  ('whitede01',),
#  ('whitejo01',),
#  ('whittpo01',),
#  ('willibe02',),
#  ('willicy01',),
#  ('williji01',),
#  ('willike01',),
#  ('willite01',),
#  ('wilsoar01',),
#  ('wilsoha01',),
#  ('wingoal01',),
#  ('wistete01',),
#  ('wolfji01',),
#  ('woltery01',),
#  ('woodbo01',),
#  ('woodji01',),
#  ('woodjo02',),
#  ('woodlge01',),
#  ('wrighda03',),
#  ('wrighge01',),
#  ('wrighra01',),
#  ('wrighta01',),
#  ('wynegbu01',),
#  ('wynnji01',),
#  ('yastrca01',),
#  ('yorkru01',),
#  ('yosted01',),
#  ('youklke01',),
#  ('younger01',),
#  ('youngro01',),
#  ('zarilal01',),
#  ('zaungr01',),
#  ('zimmech01',),
#  ('zimmehe01',),
#  ('zobribe01',)]

# %% [markdown]
# - Hmm, this is not quite right either.
#     - The derived table is sorted, ...
#     - I did not specify a sort for the result table.
#     - I cannot apply the sort by ```OBP``` because I did not ask for the column in the second derived table.
#
#
# - This is an example of the value of ```GROUP BY```

# %% [markdown]
# ### GROUP BY
#
# <img src="../images/Ch5_SQL-95/Slide19.jpg">
# <img src="../images/Ch5_SQL-95/Slide20.jpg">
# <img src="../images/Ch5_SQL-95/Slide21.jpg">

# %% [markdown]
# <img src="../images/group_by.jpg">

# %% [markdown]
# - Fixing the previous query

# %%
# %sql select distinct playerid, temp.obp as career_max_obp from \
    (select playerID, max(round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3)) as obp\
        from batting  \
             where \
            ab > 100 AND \
            (round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3) > 0.400) \
       group by playerid) as temp \
    order by temp.obp desc;
# Out:
# 728 rows affected.
# [('bondsba01', 0.609),
#  ('willite01', 0.553),
#  ('mcgrajo01', 0.545),
#  ('ruthba01', 0.542),
#  ('hamilbi01', 0.516),
#  ('mantlmi01', 0.512),
#  ('meyerle01', 0.5),
#  ('joycebi01', 0.498),
#  ('hornsro01', 0.497),
#  ('delahed01', 0.495),
#  ('duffyhu01', 0.494),
#  ('oneilti01', 0.49),
#  ('ramirma02', 0.489),
#  ('bladera01', 0.488),
#  ('kellejo01', 0.487),
#  ('thomafr04', 0.487),
#  ('carrofr01', 0.486),
#  ('cashno01', 0.485),
#  ('vaughar01', 0.485),
#  ('kellyki01', 0.483),
#  ('mcgwima01', 0.483),
#  ('cobbty01', 0.48),
#  ('martied01', 0.479),
#  ('burkeje01', 0.477),
#  ('giambja01', 0.477),
#  ('boggswa01', 0.476),
#  ('gehrilo01', 0.476),
#  ('cullero01', 0.475),
#  ('vottojo01', 0.474),
#  ('johnsni01', 0.473),
#  ('olerujo01', 0.473),
#  ('childcu01', 0.472),
#  ('broutda01', 0.471),
#  ('dietzdi01', 0.471),
#  ('hazlebo01', 0.471),
#  ('delgaca01', 0.47),
#  ('jonesch06', 0.47),
#  ('applilu01', 0.469),
#  ('foxxji01', 0.469),
#  ('heltoto01', 0.469),
#  ('henderi01', 0.469),
#  ('speaktr01', 0.469),
#  ('sheffga01', 0.467),
#  ('brownpe01', 0.466),
#  ('morgajo02', 0.466),
#  ('barnero01', 0.465),
#  ('hanseda01', 0.465),
#  ('wakefdi01', 0.464),
#  ('walkela01', 0.464),
#  ('carutbo01', 0.463),
#  ('delluda01', 0.463),
#  ('heilmha01', 0.463),
#  ('jacksjo01', 0.463),
#  ('jennihu01', 0.463),
#  ('griffmi01', 0.462),
#  ('lajoina01', 0.462),
#  ('pujolal01', 0.462),
#  ('lyonsde01', 0.461),
#  ('harpebr03', 0.46),
#  ('oneilpa01', 0.46),
#  ('clarkfr01', 0.459),
#  ('clarkja01', 0.459),
#  ('dimagjo01', 0.459),
#  ('valoel01', 0.459),
#  ('gamblos01', 0.458),
#  ('thompsa01', 0.458),
#  ('odoulle01', 0.457),
#  ('cochrmi01', 0.456),
#  ('sislege01', 0.456),
#  ('ansonca01', 0.455),
#  ('collied01', 0.455),
#  ('gehrich01', 0.455),
#  ('keelewi01', 0.455),
#  ('alexada01', 0.454),
#  ('bagweje01', 0.454),
#  ('brettge01', 0.454),
#  ('cartyri01', 0.454),
#  ('fainfe01', 0.454),
#  ('harrijo03', 0.454),
#  ('stanked01', 0.454),
#  ('cangejo01', 0.453),
#  ('gwynnto01', 0.453),
#  ('hemusso01', 0.453),
#  ('mccovwi01', 0.453),
#  ('carbobe01', 0.452),
#  ('clemeja01', 0.452),
#  ('kinerra01', 0.452),
#  ('yastrca01', 0.452),
#  ('cunnijo01', 0.451),
#  ('myerbu01', 0.451),
#  ('berkmla01', 0.45),
#  ('connoro01', 0.45),
#  ('gilesbr02', 0.45),
#  ('musiast01', 0.45),
#  ('thomeji01', 0.45),
#  ('tucketo01', 0.45),
#  ('langebi01', 0.449),
#  ('prattto02', 0.449),
#  ('rosemch01', 0.449),
#  ('smithel01', 0.449),
#  ('teixema01', 0.449),
#  ('cabremi01', 0.448),
#  ('carewro01', 0.448),
#  ('dunlafr01', 0.448),
#  ('knoblch01', 0.448),
#  ('palmede01', 0.448),
#  ('tiernmi01', 0.448),
#  ('turnetu01', 0.448),
#  ('ashburi01', 0.447),
#  ('bautijo02', 0.447),
#  ('cavarph01', 0.447),
#  ('mitchke01', 0.447),
#  ('schuljo04', 0.447),
#  ('abreubo01', 0.446),
#  ('galanau01', 0.446),
#  ('morgaed01', 0.446),
#  ('hermaba01', 0.445),
#  ('ortizda01', 0.445),
#  ('robinya01', 0.445),
#  ('selkige01', 0.445),
#  ('camildo01', 0.444),
#  ('dickebi01', 0.444),
#  ('garmsde01', 0.444),
#  ('glassja01', 0.444),
#  ('mauerjo01', 0.444),
#  ('ottme01', 0.444),
#  ('simmoal01', 0.444),
#  ('swarted01', 0.444),
#  ('herzowh01', 0.443),
#  ('phillto02', 0.443),
#  ('riceha01', 0.443),
#  ('wanerpa01', 0.443),
#  ('wilsoha01', 0.443),
#  ('wingoal01', 0.443),
#  ('boudrlo01', 0.442),
#  ('thomaro01', 0.442),
#  ('troutmi01', 0.442),
#  ('wertzvi01', 0.442),
#  ('kauffbe01', 0.441),
#  ('niemabo01', 0.441),
#  ('wardpi01', 0.441),
#  ('bishoma01', 0.44),
#  ('corcoti01', 0.44),
#  ('dobyla01', 0.44),
#  ('grantge01', 0.44),
#  ('jorgemi01', 0.44),
#  ('seweljo01', 0.44),
#  ('fournja01', 0.439),
#  ('furcara01', 0.439),
#  ('hafnetr01', 0.439),
#  ('stenzja01', 0.439),
#  ('terrybi01', 0.439),
#  ('belleal01', 0.438),
#  ('campbbr01', 0.438),
#  ('dahlebi01', 0.438),
#  ('grimera01', 0.438),
#  ('larkiba01', 0.438),
#  ('singlke01', 0.438),
#  ('averiea01', 0.437),
#  ('chancfr01', 0.437),
#  ('chrisll01', 0.437),
#  ('flickel01', 0.437),
#  ('hassero01', 0.437),
#  ('kellech01', 0.437),
#  ('manseto01', 0.437),
#  ('mizejo01', 0.437),
#  ('morneju01', 0.437),
#  ('schanwa01', 0.437),
#  ('sosasa01', 0.437),
#  ('spierbi01', 0.437),
#  ('thompja01', 0.437),
#  ('bradlmi01', 0.436),
#  ('drewjd01', 0.436),
#  ('greenha01', 0.436),
#  ('jeterde01', 0.436),
#  ('padgedo01', 0.436),
#  ('robinja02', 0.436),
#  ('tenacge01', 0.436),
#  ('wardda01', 0.436),
#  ('youngro01', 0.436),
#  ('bruckea01', 0.435),
#  ('goldspa01', 0.435),
#  ('mcveyca01', 0.435),
#  ('schmimi01', 0.435),
#  ('shochge01', 0.435),
#  ('stephri01', 0.435),
#  ('willibe02', 0.435),
#  ('wynnji01', 0.435),
#  ('yosted01', 0.435),
#  ('browefr01', 0.434),
#  ('crabtes01', 0.434),
#  ('farredo01', 0.434),
#  ('garcino01', 0.434),
#  ('gorege01', 0.434),
#  ('mcinnst01', 0.434),
#  ('molitpa01', 0.434),
#  ('ordonma01', 0.434),
#  ('phelpke01', 0.434),
#  ('giambje01', 0.433),
#  ('grebecr01', 0.433),
#  ('johnsbo01', 0.433),
#  ('mooreed01', 0.433),
#  ('peskyjo01', 0.433),
#  ('rayir01', 0.433),
#  ('barbebr01', 0.432),
#  ('bassljo01', 0.432),
#  ('bresnro01', 0.432),
#  ('burroje01', 0.432),
#  ('meyerch01', 0.432),
#  ('tulowtr01', 0.432),
#  ('vandejo02', 0.432),
#  ('virtuja01', 0.432),
#  ('walkedi02', 0.432),
#  ('willicy01', 0.432),
#  ('willike01', 0.432),
#  ('burgesm01', 0.431),
#  ('clarkwi02', 0.431),
#  ('cravaga01', 0.431),
#  ('hargrmi01', 0.431),
#  ('harrida01', 0.431),
#  ('moonwa01', 0.431),
#  ('piazzmi01', 0.431),
#  ('stengca01', 0.431),
#  ('wagneho01', 0.431),
#  ('wrighta01', 0.431),
#  ('chapmbe01', 0.43),
#  ('dalyto01', 0.43),
#  ('harrato01', 0.43),
#  ('krukjo01', 0.43),
#  ('mageesh01', 0.43),
#  ('mccarto01', 0.43),
#  ('ofarrbo01', 0.43),
#  ('retteme01', 0.43),
#  ('salkebi01', 0.43),
#  ('crawfsa01', 0.429),
#  ('davisch01', 0.429),
#  ('gonzalu01', 0.429),
#  ('lucrojo01', 0.429),
#  ('raineti01', 0.429),
#  ('salmoti01', 0.429),
#  ('smithol01', 0.429),
#  ('walkeha01', 0.429),
#  ('danieka01', 0.428),
#  ('davisge01', 0.428),
#  ('hackst01', 0.428),
#  ('kendaja01', 0.428),
#  ('kleinch01', 0.428),
#  ('larkihe01', 0.428),
#  ('snodgfr01', 0.428),
#  ('wrighra01', 0.428),
#  ('fernato01', 0.427),
#  ('herzobu01', 0.427),
#  ('joosted01', 0.427),
#  ('justida01', 0.427),
#  ('killeha01', 0.427),
#  ('magadda01', 0.427),
#  ('rosepe01', 0.427),
#  ('snowjt01', 0.427),
#  ('woodlge01', 0.427),
#  ('bluelu01', 0.426),
#  ('cuyleki01', 0.426),
#  ('guerrvl01', 0.426),
#  ('lopezfe01', 0.426),
#  ('murcebo01', 0.426),
#  ('posadjo01', 0.426),
#  ('scottlu01', 0.426),
#  ('smithre06', 0.426),
#  ('alfoned01', 0.425),
#  ('bonurze01', 0.425),
#  ('fairlro01', 0.425),
#  ('gosligo01', 0.425),
#  ('howarry01', 0.425),
#  ('mayswi01', 0.425),
#  ('mcbrial01', 0.425),
#  ('mumphje01', 0.425),
#  ('rosenla01', 0.425),
#  ('sheckji01', 0.425),
#  ('tayloca01', 0.425),
#  ('thornan01', 0.425),
#  ('wheatza01', 0.425),
#  ('woodji01', 0.425),
#  ('collipa01', 0.424),
#  ('davisal01', 0.424),
#  ('engliwo01', 0.424),
#  ('hoydu01', 0.424),
#  ('kentje01', 0.424),
#  ('randowi01', 0.424),
#  ('baineha01', 0.423),
#  ('fishesh01', 0.423),
#  ('gentiji01', 0.423),
#  ('gradymi01', 0.423),
#  ('heganmi01', 0.423),
#  ('lappja01', 0.423),
#  ('lynnfr01', 0.423),
#  ('minosmi01', 0.423),
#  ('mondari01', 0.423),
#  ('orourti01', 0.423),
#  ('roushed01', 0.423),
#  ('seeryem01', 0.423),
#  ('seymocy01', 0.423),
#  ('snidedu01', 0.423),
#  ('staubru01', 0.423),
#  ('astrojo01', 0.422),
#  ('cliftha01', 0.422),
#  ('cranddo01', 0.422),
#  ('durazer01', 0.422),
#  ('grossgr01', 0.422),
#  ('guerrpe01', 0.422),
#  ('hermage01', 0.422),
#  ('hernake01', 0.422),
#  ('judgeaa01', 0.422),
#  ('madlobi01', 0.422),
#  ('mazzile01', 0.422),
#  ('mcphebi01', 0.422),
#  ('rodrial01', 0.422),
#  ('rosenal01', 0.422),
#  ('smithea02', 0.422),
#  ('vanhage01', 0.422),
#  ('wilsoar01', 0.422),
#  ('choosh01', 0.421),
#  ('cronijo01', 0.421),
#  ('cruzne02', 0.421),
#  ('elliobo01', 0.421),
#  ('eversjo01', 0.421),
#  ('fletcel01', 0.421),
#  ('goodmbi01', 0.421),
#  ('hollibu01', 0.421),
#  ('jonescl01', 0.421),
#  ('jonesfi01', 0.421),
#  ('kalinal01', 0.421),
#  ('matheed01', 0.421),
#  ('phelpba01', 0.421),
#  ('readyra01', 0.421),
#  ('robinfr02', 0.421),
#  ('schofdi01', 0.421),
#  ('stahlch01', 0.421),
#  ('westlwa01', 0.421),
#  ('wolfji01', 0.421),
#  ('allendi01', 0.42),
#  ('dykstle01', 0.42),
#  ('edmonji01', 0.42),
#  ('freembu01', 0.42),
#  ('harpege02', 0.42),
#  ('hoppjo01', 0.42),
#  ('huggimi01', 0.42),
#  ('mccosba01', 0.42),
#  ('northro01', 0.42),
#  ('palmera01', 0.42),
#  ('plantph01', 0.42),
#  ('torrejo01', 0.42),
#  ('vaughmo01', 0.42),
#  ('weintph01', 0.42),
#  ('abramca01', 0.419),
#  ('burksel01', 0.419),
#  ('caminke01', 0.419),
#  ('cruiswa01', 0.419),
#  ('fioremi01', 0.419),
#  ('haneyfr01', 0.419),
#  ('hollima01', 0.419),
#  ('holmedu01', 0.419),
#  ('longmto01', 0.419),
#  ('lopesda01', 0.419),
#  ('newsowa01', 0.419),
#  ('selbaki01', 0.419),
#  ('suhrgu01', 0.419),
#  ('tettlmi01', 0.419),
#  ('wistete01', 0.419),
#  ('woodjo02', 0.419),
#  ('zarilal01', 0.419),
#  ('doyleja01', 0.418),
#  ('glavito01', 0.418),
#  ('hahned01', 0.418),
#  ('hickmji02', 0.418),
#  ('holmeto01', 0.418),
#  ('leede02', 0.418),
#  ('mcfarhe01', 0.418),
#  ('porteda02', 0.418),
#  ('riosar01', 0.418),
#  ('stonejo01', 0.418),
#  ('bressru01', 0.417),
#  ('combsea01', 0.417),
#  ('dunnad01', 0.417),
#  ('edwarha01', 0.417),
#  ('evansdw01', 0.417),
#  ('ferguch01', 0.417),
#  ('hartnga01', 0.417),
#  ('henrito01', 0.417),
#  ('kurowwh01', 0.417),
#  ('lazzeto01', 0.417),
#  ('maybejo01', 0.417),
#  ('murphda05', 0.417),
#  ('odeake01', 0.417),
#  ('schomot01', 0.417),
#  ('smithlo01', 0.417),
#  ('sweenmi01', 0.417),
#  ('yorkru01', 0.417),
#  ('zimmech01', 0.417),
#  ('aloumo01', 0.416),
#  ('downibr01', 0.416),
#  ('fribebe01', 0.416),
#  ('greenmi01', 0.416),
#  ('howarfr01', 0.416),
#  ('lindsfr01', 0.416),
#  ('michaja01', 0.416),
#  ('ryanji01', 0.416),
#  ('severha01', 0.416),
#  ('wrighda03', 0.416),
#  ('alomaro01', 0.415),
#  ('beltrca01', 0.415),
#  ('biggicr01', 0.415),
#  ('bollija01', 0.415),
#  ('fennefr01', 0.415),
#  ('fieldpr01', 0.415),
#  ('gowdyha01', 0.415),
#  ('jamiech01', 0.415),
#  ('mackre01', 0.415),
#  ('morame01', 0.415),
#  ('niarhgu01', 0.415),
#  ('oneilst01', 0.415),
#  ('pearsal02', 0.415),
#  ('sefcike01', 0.415),
#  ('stiveja01', 0.415),
#  ('stransa01', 0.415),
#  ('torgeea01', 0.415),
#  ('wagneha01', 0.415),
#  ('batesjo02', 0.414),
#  ('bottoji01', 0.414),
#  ('burnsoy01', 0.414),
#  ('delanbi02', 0.414),
#  ('donlimi01', 0.414),
#  ('epstemi01', 0.414),
#  ('floydcl01', 0.414),
#  ('fonsele01', 0.414),
#  ('germaes01', 0.414),
#  ('hillgl01', 0.414),
#  ('hoilech01', 0.414),
#  ('irvinmo01', 0.414),
#  ('jahajo01', 0.414),
#  ('medwijo01', 0.414),
#  ('merceor01', 0.414),
#  ('meyerbe01', 0.414),
#  ('murraed02', 0.414),
#  ('napolmi01', 0.414),
#  ('neunjo01', 0.414),
#  ('orrda01', 0.414),
#  ('owensp01', 0.414),
#  ('runnepe01', 0.414),
#  ('scheifr01', 0.414),
#  ('scheiri01', 0.414),
#  ('slaugen01', 0.414),
#  ('summech01', 0.414),
#  ('turneju01', 0.414),
#  ('wardtu01', 0.414),
#  ('beaumgi01', 0.413),
#  ('careyma01', 0.413),
#  ('chriscu01', 0.413),
#  ('eisenji01', 0.413),
#  ('francti01', 0.413),
#  ('kellge01', 0.413),
#  ('kreutch01', 0.413),
#  ('lakeed01', 0.413),
#  ('morriha02', 0.413),
#  ('paskedo01', 0.413),
#  ('suzukic01', 0.413),
#  ('tebeage01', 0.413),
#  ('whitejo01', 0.413),
#  ('williji01', 0.413),
#  ('youklke01', 0.413),
#  ('zaungr01', 0.413),
#  ('bufordo01', 0.412),
#  ('castilu01', 0.412),
#  ('evansst01', 0.412),
#  ('forceda01', 0.412),
#  ('grubbjo01', 0.412),
#  ('hartsto01', 0.412),
#  ('huntro01', 0.412),
#  ('lewisbu01', 0.412),
#  ('maxwech01', 0.412),
#  ('michaca01', 0.412),
#  ('naehrti01', 0.412),
#  ('powelbo01', 0.412),
#  ('siebeno01', 0.412),
#  ('woltery01', 0.412),
#  ('clemero01', 0.411),
#  ('crossla01', 0.411),
#  ('darlide01', 0.411),
#  ('flemile01', 0.411),
#  ('grichbo01', 0.411),
#  ('johnsch04', 0.411),
#  ('lankfra01', 0.411),
#  ('lemahdj01', 0.411),
#  ('lowenjo01', 0.411),
#  ('paschbe01', 0.411),
#  ('pinknge01', 0.411),
#  ('reisepe01', 0.411),
#  ('robinwi01', 0.411),
#  ('rossco01', 0.411),
#  ('santoro01', 0.411),
#  ('treadge01', 0.411),
#  ('aaronha01', 0.41),
#  ('bannoji01', 0.41),
#  ('dickech01', 0.41),
#  ('dimagdo01', 0.41),
#  ('douthta01', 0.41),
#  ('gonzaad01', 0.41),
#  ('hamiljo03', 0.41),
#  ('hargrbu01', 0.41),
#  ('leyriji01', 0.41),
#  ('lezcasi01', 0.41),
#  ('matthga01', 0.41),
#  ('mccarti01', 0.41),
#  ('mccutan01', 0.41),
#  ('orourji01', 0.41),
#  ('penaca01', 0.41),
#  ('ramirha01', 0.41),
#  ('titusjo01', 0.41),
#  ('watkige01', 0.41),
#  ('altuvjo01', 0.409),
#  ('atkinga01', 0.409),
#  ('bryankr01', 0.409),
#  ('elberki01', 0.409),
#  ('heathje01', 0.409),
#  ('jacksre01', 0.409),
#  ('johnscl01', 0.409),
#  ('johnssp01', 0.409),
#  ('loftoke01', 0.409),
#  ('martivi01', 0.409),
#  ('phamth01', 0.409),
#  ('portedi01', 0.409),
#  ('shirear01', 0.409),
#  ('sutclsy01', 0.409),
#  ('tartada01', 0.409),
#  ('travice01', 0.409),
#  ('utleych01', 0.409),
#  ('walkene01', 0.409),
#  ('bakerfl01', 0.408),
#  ('bakerfr01', 0.408),
#  ('barneau01', 0.408),
#  ('barrebi02', 0.408),
#  ('brownga01', 0.408),
#  ('creebi01', 0.408),
#  ('crookja01', 0.408),
#  ('custja01', 0.408),
#  ('davanje01', 0.408),
#  ('erstada01', 0.408),
#  ('evansjo01', 0.408),
#  ('ferrewe01', 0.408),
#  ('francju01', 0.408),
#  ('frankch01', 0.408),
#  ('gracejo01', 0.408),
#  ('gracema01', 0.408),
#  ('greerru01', 0.408),
#  ('griffke02', 0.408),
#  ('holbrsa01', 0.408),
#  ('hollato01', 0.408),
#  ('jeffegr01', 0.408),
#  ('leibeha01', 0.408),
#  ('milledo01', 0.408),
#  ('millijo01', 0.408),
#  ('millira01', 0.408),
#  ('poseybu01', 0.408),
#  ('reesepe01', 0.408),
#  ('rolensc01', 0.408),
#  ('russere01', 0.408),
#  ('sheelea01', 0.408),
#  ('shumpte01', 0.408),
#  ('simmote01', 0.408),
#  ('smithal01', 0.408),
#  ('bannial01', 0.407),
#  ('braunst01', 0.407),
#  ('crousbu01', 0.407),
#  ('fothebo01', 0.407),
#  ('hamilda02', 0.407),
#  ('hastisc01', 0.407),
#  ('hoopeha01', 0.407),
#  ('kearnau01', 0.407),
#  ('kluszte01', 0.407),
#  ('koenele01', 0.407),
#  ('leslisa01', 0.407),
#  ('lewisma01', 0.407),
#  ('mannle01', 0.407),
#  ('marrle01', 0.407),
#  ('mcdonte01', 0.407),
#  ('mctamji01', 0.407),
#  ('mostijo01', 0.407),
#  ('nilssda01', 0.407),
#  ('perkicy01', 0.407),
#  ('rizzuph01', 0.407),
#  ('soderer01', 0.407),
#  ('southbi01', 0.407),
#  ('spilbry01', 0.407),
#  ('stargwi01', 0.407),
#  ('verasqu01', 0.407),
#  ('alexaga01', 0.406),
#  ('bailebo01', 0.406),
#  ('bonnefr01', 0.406),
#  ('burnije01', 0.406),
#  ('davisle01', 0.406),
#  ('ewingbu01', 0.406),
#  ('judgejo01', 0.406),
#  ('judniwa01', 0.406),
#  ('markani01', 0.406),
#  ('mcraeha01', 0.406),
#  ('moseswa01', 0.406),
#  ('radfopa01', 0.406),
#  ('roeniro01', 0.406),
#  ('seguida01', 0.406),
#  ('shottbu01', 0.406),
#  ('smithal04', 0.406),
#  ('stonege01', 0.406),
#  ('traynpi01', 0.406),
#  ('vosmijo01', 0.406),
#  ('whittpo01', 0.406),
#  ('butlebr01', 0.405),
#  ('colavro01', 0.405),
#  ('colbrgr01', 0.405),
#  ('connafr01', 0.405),
#  ('doughpa01', 0.405),
#  ('gordojo01', 0.405),
#  ('kieltbo01', 0.405),
#  ('lawtoma02', 0.405),
#  ('lynchje01', 0.405),
#  ('maulal01', 0.405),
#  ('mayca01', 0.405),
#  ('mcgrifr01', 0.405),
#  ('mokanjo01', 0.405),
#  ('murphed02', 0.405),
#  ('twombba01', 0.405),
#  ('whitalo01', 0.405),
#  ('whitede01', 0.405),
#  ('zimmehe01', 0.405),
#  ('allisbo01', 0.404),
#  ('bradlph01', 0.404),
#  ('doranbi02', 0.404),
#  ('dwyerji01', 0.404),
#  ('ettenni01', 0.404),
#  ('gladdda01', 0.404),
#  ('glaustr01', 0.404),
#  ('grothjo01', 0.404),
#  ('halech01', 0.404),
#  ('hayesvo01', 0.404),
#  ('jenseja01', 0.404),
#  ('mancugu01', 0.404),
#  ('mckeaed01', 0.404),
#  ('ochoaal01', 0.404),
#  ('rolfere01', 0.404),
#  ('schoere01', 0.404),
#  ('stockke01', 0.404),
#  ('sullima01', 0.404),
#  ('tatisfe01', 0.404),
#  ('troskha01', 0.404),
#  ('werdepe01', 0.404),
#  ('wrighge01', 0.404),
#  ('zobribe01', 0.404),
#  ('anderbr01', 0.403),
#  ('bandosa01', 0.403),
#  ('bardjo01', 0.403),
#  ('donaljo02', 0.403),
#  ('freemfr01', 0.403),
#  ('galaran01', 0.403),
#  ('gordosi01', 0.403),
#  ('hafeych01', 0.403),
#  ('hanigry01', 0.403),
#  ('hurstdo01', 0.403),
#  ('johnsda02', 0.403),
#  ('johnser01', 0.403),
#  ('joycema01', 0.403),
#  ('jurgebi01', 0.403),
#  ('lennoed01', 0.403),
#  ('lombaer01', 0.403),
#  ('merribi01', 0.403),
#  ('rendoan01', 0.403),
#  ('rhodedu01', 0.403),
#  ('robined01', 0.403),
#  ('sauerha01', 0.403),
#  ('silvech01', 0.403),
#  ('stoveha01', 0.403),
#  ('tennefr02', 0.403),
#  ('webbea01', 0.403),
#  ('bayja01', 0.402),
#  ('berbelo01', 0.402),
#  ('booneik01', 0.402),
#  ('dykesji01', 0.402),
#  ('eversho01', 0.402),
#  ('ferreri01', 0.402),
#  ('heckegu01', 0.402),
#  ('henlibu01', 0.402),
#  ('hermabi01', 0.402),
#  ('higgibo02', 0.402),
#  ('manushe01', 0.402),
#  ('mccreto01', 0.402),
#  ('offerjo01', 0.402),
#  ('pagemi02', 0.402),
#  ('richaha01', 0.402),
#  ('seitzke01', 0.402),
#  ('sullijo01', 0.402),
#  ('swansev01', 0.402),
#  ('watsobo01', 0.402),
#  ('beckehe02', 0.401),
#  ('blausje01', 0.401),
#  ('boonera01', 0.401),
#  ('bushra01', 0.401),
#  ('byrdsa01', 0.401),
#  ('cookedu01', 0.401),
#  ('davissp01', 0.401),
#  ('eayrsed01', 0.401),
#  ('evansda01', 0.401),
#  ('flagsir01', 0.401),
#  ('garagjo01', 0.401),
#  ('griffke01', 0.401),
#  ('larocad01', 0.401),
#  ('lucasre01', 0.401),
#  ('macksh01', 0.401),
#  ('minchdo01', 0.401),
#  ('oquenjo01', 0.401),
#  ('perezed02', 0.401),
#  ('perezto01', 0.401),
#  ('petrori01', 0.401),
#  ('quinlro01', 0.401),
#  ('saenzol01', 0.401),
#  ('santaca01', 0.401),
#  ('trammal01', 0.401),
#  ('vernomi01', 0.401),
#  ('walkecu01', 0.401),
#  ('werthja01', 0.401),
#  ('woodbo01', 0.401),
#  ('wynegbu01', 0.401),
#  ('younger01', 0.401)]

# %% [markdown]
# - How about only those players who played more than 1,000 games?
#     - Sum the games in the GROUP BY to produce the aggregated/grouped table.
#     - Apply HAVING to get SELECT only players with 1,000 or more games.

# %%
# %sql select distinct playerid, total_g, temp.obp as career_max_obp from \
    (select playerID, max(round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3)) as obp, sum(g) as total_g\
        from batting  \
             where \
            ab > 100 AND \
            (round((H+BB+HBP)/(AB + BB + HBP + SH + SF), 3) > 0.400) \
       group by playerid having total_g > 1000) as temp \
    order by temp.obp desc;
# Out:
# 39 rows affected.
# [('bondsba01', 2304.0, 0.609),
#  ('willite01', 2146.0, 0.553),
#  ('ruthba01', 2211.0, 0.542),
#  ('hamilbi01', 1457.0, 0.516),
#  ('mantlmi01', 1221.0, 0.512),
#  ('hornsro01', 1396.0, 0.497),
#  ('delahed01', 1168.0, 0.495),
#  ('ramirma02', 1321.0, 0.489),
#  ('thomafr04', 1444.0, 0.487),
#  ('cobbty01', 2277.0, 0.48),
#  ('martied01', 1547.0, 0.479),
#  ('burkeje01', 1216.0, 0.477),
#  ('giambja01', 1053.0, 0.477),
#  ('boggswa01', 1550.0, 0.476),
#  ('gehrilo01', 2007.0, 0.476),
#  ('vottojo01', 1193.0, 0.474),
#  ('broutda01', 1217.0, 0.471),
#  ('jonesch06', 1424.0, 0.47),
#  ('applilu01', 1179.0, 0.469),
#  ('foxxji01', 1727.0, 0.469),
#  ('heltoto01', 1383.0, 0.469),
#  ('henderi01', 1633.0, 0.469),
#  ('speaktr01', 1851.0, 0.469),
#  ('sheffga01', 1175.0, 0.467),
#  ('morgajo02', 1017.0, 0.466),
#  ('heilmha01', 1263.0, 0.463),
#  ('pujolal01', 1401.0, 0.462),
#  ('collied01', 1801.0, 0.455),
#  ('bagweje01', 1060.0, 0.454),
#  ('fainfe01', 1086.0, 0.454),
#  ('berkmla01', 1215.0, 0.45),
#  ('musiast01', 2091.0, 0.45),
#  ('thomeji01', 1388.0, 0.45),
#  ('carewro01', 1042.0, 0.448),
#  ('abreubo01', 1249.0, 0.446),
#  ('ottme01', 1891.0, 0.444),
#  ('wanerpa01', 1278.0, 0.443),
#  ('bishoma01', 1058.0, 0.44),
#  ('wagneho01', 1243.0, 0.431)]
