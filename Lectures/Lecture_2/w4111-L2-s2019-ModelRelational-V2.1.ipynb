# %% [markdown]
# <b><center>
# <span style="font-size: 24pt; line-height: 1.2">
# COMS W4111: Introduction to Databases
# </span>
# </center></b>
# </span><br>
# <p>
# <i><center>
# <span style="font-size: 20pt; line-height: 1.2">
# Lecture 2: Begin Working with Data Modeling, the Relational Model and SQL<br>(V 2.1)
# </span>
# </center></i>

# %% [markdown]
# # Introduction

# %% [markdown]
# ## Questions?

# %% [markdown]
# ## Today's Topics
#
# 1. Environment: Spend some time configuring environments and discussing what is happening:
#     - Jupyter (iPython) Notebook
#     - URLs, database connections, database management system servers
#     - PyCharm environments
# <br><br>
# 2. Core database concepts and examples.
# <br><br>
# 3. The relational model and SQL:
#     1. Overview and concepts.
#     2. SQL operations: ```SELECT, INSERT, UPDATE, DELETE.```
#     3. Introduction to keys.
#     4. Discussion of HW1.

# %% [markdown]
# # Set Up Environment
#
# ## Setup

# %%
# %load_ext sql
# %sql mysql+pymysql://dbuser:dbuserdbuser@localhost/lahman2019raw
# %sql select * from people where playerid='willite01'

import pymysql
default_cnx = pymysql.connect(host='localhost',
                             user='dbuser',
                             password='dbuserdbuser',
                             db='lahman2019raw',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 1 rows affected.

# %% [markdown]
# - To run the examples that use %sql, you will have to install an extension to your iPython/Jupyter notebooks.
#
#
# - The extension and installation instruction are at: https://pypi.org/project/ipython-sql/
#
#
# - You can come to office hours (CAs, mine) if you need help.
#
# | <img src="../../images/install_wizard.jpg"> |
# | :---: |
# | __Installation Wizard__ |

# %% [markdown]
# ## Explanation
#
# - Three interesting and illuminating program statements.
#
# ```
# %load_ext sql
# %sql mysql+pymysql://dbuser:dbuser@localhost/lahman2017
# %sql select * from people where playerid='willite01'
# ```
# <br><br>
#
# | <img src="../../images/what-is-this-sorcery.jpg" > |
# | :---: |
# | __Some Sorcery__ |

# %% [markdown]
# ### iPython/Jupyter Notebook Architecture
#
# | <img src="../../images/notebook_components.png" > |
# | :---: |
# | [iPython Notebook Architecture](https://jupyter.readthedocs.io/en/latest/architecture/how_jupyter_ipython_work.html) |
#
#
# - There are several good explanations of interactive Python, iPython notebooks, etc:
#     - https://jupyter.readthedocs.io/en/latest/architecture/how_jupyter_ipython_work.html
#     - https://ipython-books.github.io/chapter-3-mastering-the-jupyter-notebook/
#
#
# - You do not need to understand this material for the course.
#
#
# - In lectures, I am using Jupyter notebooks.
#     - There is an ecosystem of plug-ins and extensions that add features to the base notebook capabilities.
#     - The ```%sql magic function``` is one of the extensions.
#
#
# - "IPython will treat any line whose first character is a % as a special call to a ‘magic’ function. These allow you to control the behavior of IPython itself, plus a lot of system-type features. They are all prefixed with a % character, but parameters are given without parentheses or quote." (https://ipython.readthedocs.io/en/stable/interactive/reference.html#magic)

# %%
# %magic

# %% [markdown]
# - ```%load_ext sql``` is calling the magic function ```load_extension.``` This
#     - Loads the extension module
#     - The ```%sql``` magic function.
#
#
# - This is all FYI. The [iPython](https://ipython.readthedocs.io/en/stable/config/custommagics.html?highlight=magic) documentation explains how to implement Magics.

# %% [markdown]
# ### Databases and Connections
#
# - What about ```%sql mysql+pymysql://dbuser:dbuser@localhost/lahman2017```?
#
# | <img src="../../images/db-connection.jpg"> |
# | :---: |
# | __Database Server and Connection__ |
#
#
# - There are typically two processes (running programs) in a database application.
#     - The database server, which processes database commands.
#     - The client application that sends commands to and receives responses from the database server.
#
#
# - The magic statement defines a database connection.
#
#
# "A Database connection is facility in computer science that allows client software to talk to database server software, whether on the same machine or not. A connection is required to send commands and receive answers, usually in the form of a result set.
#
# Connections are a key concept in data-centric programming. Since some DBMS engines require considerable time to connect connection pooling was invented to improve performance. No command can be performed against a database without an "open and available" connection to it.
#
# Connections are built by supplying an underlying driver or provider with a connection string, which is a way of addressing a specific database or server and instance as well as user authentication credentials (for example, Server=sql_box;Database=Common;User ID=uid;Pwd=password;). Once a connection has been built it can be opened and closed at will, and properties (such as the command time-out length, or transaction, if one exists) can be set. The Connection String is composed of a set of key/value pairs as dictated by the data access interface and data provider being used." (https://en.wikipedia.org/wiki/Database_connection)

# %% [markdown]
# - Modifying the diagram above to add the DB server
#
# | <img src="../../images/notebook_and_db.jpeg"> |
# | :---: |
# | __Notebook and DB__

# %% [markdown]
# - Again, this is just FYI.
#     - Understanding that there are connections, how to create them, ... is important and you will write code that uses connections.
#     - We will not cover the details of connections.

# %% [markdown]
# ### URLs
#
# - A little more about ```mysql+pymysql://dbuser:dbuser@localhost/lahman2017```
#
#
# - The connection specification above is a URL.
#
#
# - "A Uniform Resource Locator (URL), colloquially termed a web address, is a reference to a web resource that specifies its location on a computer network and a mechanism for retrieving it. A URL is a specific type of Uniform Resource Identifier (URI), although many people use the two terms interchangeably. URLs occur most commonly to reference web pages (http), but are also used for file transfer (ftp), email (mailto), database access (JDBC), and many other applications." (https://en.wikipedia.org/wiki/URL)
#
#
# - A URL has the format
#
#
# ```URI = scheme:[//authority]path[?query][#fragment]```
#
#
# - The components are:
#     1. Scheme: Information about the protocol, connector library, ...
#     2. Authority: Usually ```userid:password```.
#     3. Path: File system like folder path to the resource.
#     4. We will cover query string later.
#     5. Fragment: A location or subset of the resource, e.g. a section with heading.
#
#
# - We have seen how we connect to MySQL from Python using ```PyMySQL``` library.
#
# ```default_cnx = pymysql.connect(host='localhost',
#                              user='dbuser',
#                              password='dbuser',
#                              db='lahman2017',
#                              charset='utf8mb4',
#                              cursorclass=pymysql.cursors.DictCursor)```
#
#
#
# - Some connector libraries support a single connection string of the form:
#
#
# ```jdbc:mysql://someuserid:somepassword@www.myurl.com:3306```
#
#
# - Other databases have similar concepts, for example CouchDB.

# %% [markdown]
# ### The Command
#
# - And, ```%sql select * from people where playerid='willite01'``` simply runs a [Structured Query Language (SQL)](https://en.wikipedia.org/wiki/SQL) statement.
#
#
# - The optional (recommended) text book _Ramakrishnan and Gehrke,_ chapter 5 discusses SQL.
#
#
# - SQL is the main topic in this and the next few lectures.

# %% [markdown]
# ### URL, Connection Summary
#
# - A database management system:
#     - Is a software program executing on a "server" in the network.The data in a database.
#     - Stores the data in the database on the file system, usually in special files on a "disk."
#
#
# - Applications, including tools like MySQL Workbench, connect to the database management system:
#     - Over a network.
#     - Specifying some form of URL that defines:
#         - The network address of the server (host, port).
#         - The protocol to use.
#         - The specific database among the many that the DBMS controls.
#         - Authentication and authorization information.
#     - Send commands in a DBMS specific language to the server.
#
# | <img src="../../images/two-three-tier.jpeg"> |
# | :---: |
# | __Database Architectures__ |

# %% [markdown]
# - We have seen an example of (a) using Jupyter Notebooks.

# %%
import json
cool_cnx = pymysql.connect(host='localhost',
                             user='dbuser',
                             password='dbuserdbuser',
                             db='lahman2019raw',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)

sql = "select playerID, nameLast, nameFirst, birthCity, birthState, birthYear from People where birthCity='San Diego' " + \
    "and nameLast='Williams'"
cur = cool_cnx.cursor()
res = cur.execute(sql)
people_info = cur.fetchall()
print("The relevant people are: \n", json.dumps(people_info, indent=2))
# Out:
# The relevant people are:
#  [
#   {
#     "playerID": "willite01",
#     "nameLast": "Williams",
#     "nameFirst": "Ted",
#     "birthCity": "San Diego",
#     "birthState": "CA",
#     "birthYear": "1918"
#   },
#   {
#     "playerID": "willitr01",
#     "nameLast": "Williams",
#     "nameFirst": "Trevor",
#     "birthCity": "San Diego",
#     "birthState": "CA",
#     "birthYear": "1992"
#   }
# ]

# %% [markdown]
# - Other database have similar concepts, for example [CouchDB](http://couchdb.apache.org/)

# %% [markdown]
# | <img src="../../images/couchdb_arch.png" width="800px"> |
# | :---: |
# | [CouchDB Architecture](https://www.researchgate.net/figure/Simple-Architecture-of-Apache-CouchDB-database-Storage-Engine-It-is-B-tree-based-and-the_fig1_265062016) |

# %%
import requests
body = {
    "selector": {
        "last_name": {"$eq": "Ferguson"}
    },
    "fields": ["_id", "_rev", "last_name", "email"]
}
url = "http://127.0.0.1:5984/w4111f19/_find"
headers = {"content-type": "application/json"}
result = requests.post(url, json=body, headers=headers)
print("Result = ", json.dumps(result.json(), indent=2))
# Out:
# Result =  {
#   "docs": [
#     {
#       "_id": "2570e0b648805195a380643653006e66",
#       "_rev": "1-b2d6f5b544ea86d95522f3af40d0e2c5",
#       "last_name": "Ferguson",
#       "email": "dff9@columbia.edu"
#     }
#   ],
#   "bookmark": "g1AAAABweJzLYWBgYMpgSmHgKy5JLCrJTq2MT8lPzkzJBYorGJmaG6QaJJmZWFgYmBpamiYaWxiYmRibmRobGJilmpmB9HHA9BGlIwsAJ70bdw",
#   "warning": "no matching index found, create an index to optimize query time"
# }

# %% [markdown]
# - We will do a Web simple application, specifically a REST API, the implements the three-tier model. This will be homework 2.
#
#
# - There is a very basic HTML UI to give a feel for how the application works end-to-end. The primary focus is an application that accesses data.

# %%
from IPython.display import IFrame  
IFrame('http://127.0.0.1:5000/static/W4111/index.html', width=900, height=650)
# Out:
#         <iframe
#             width="900"
#             height="650"
#             src="http://127.0.0.1:5000/static/W4111/index.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# %rest http://127.0.0.1:5000/api/lahman2019raw/people/willite01
# Out:
# {
#   "data": {
#     "playerID": {
#       "value": "aardsda01",
#       "link": {
#         "rel": "people",
#         "href": "/api/people/aardsda01"
#       }
#     },
#     "birthYear": "1981",
#     "birthMonth": "12",
#     "birthDay": "27",
#     "birthCountry": "USA",
#     "birthState": "CO",
#     "birthCity": "Denver",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "David",
#     "nameLast": "Aardsma",
#     "nameGiven": "David Allan",
#     "weight": "215",
#     "height": "75",
#     "bats": "R",
#     "throws": "R",
#     "debut": "2004-04-06",
#     "finalGame": "2015-08-23",
#     "retroID": "aardd001",
#     "bbrefID": "aardsda01"
#   },
#   "links": [
#     {
#       "rel": "current",
#       "href": "http://127.0.0.1:5000/api/lahman2019raw/people/willite01"
#     }
#   ]
# }
# <Response [200]>

# %% [markdown]
# ## PyCharm (Python) Environment
#
# ### Concept
#
# - A core concept in Python, and by extension PyCharm and any Python tool, is a virtual environment.
#
#
# "'What Is a Virtual Environment?'"<br><br>
# At its core, the main purpose of Python virtual environments is to create an isolated environment for Python projects. This means that each project can have its own dependencies, regardless of what dependencies every other project has." (https://realpython.com/python-virtual-environments-a-primer/)
#
# - [From the Python documentation:](https://docs.python.org/3/tutorial/venv.html)
#
# "Python applications will often use packages and modules that don’t come as part of the standard library. Applications will sometimes need a specific version of a library, because the application may require that a particular bug has been fixed or the application may be written using an obsolete version of the library’s interface.
#
# This means it may not be possible for one Python installation to meet the requirements of every application. If application A needs version 1.0 of a particular module but application B needs version 2.0, then the requirements are in conflict and installing either version 1.0 or 2.0 will leave one application unable to run.
#
# The solution for this problem is to create a virtual environment, a self-contained directory tree that contains a Python installation for a particular version of Python, plus a number of additional packages.
#
# Different applications can then use different virtual environments. To resolve the earlier example of conflicting requirements, application A can have its own virtual environment with version 1.0 installed while application B has another virtual environment with version 2.0. If application B requires a library be upgraded to version 3.0, this will not affect application A’s environment."
#
#
# - Other programming languages have similar concepts:
#     - Java Classpath (https://en.wikipedia.org/wiki/Classpath_(Java))
#     - JavaScript/NodeJS has the [Node Module Path](https://nodejs.org/api/modules.html)
#
#
# - There are two applications with environments that I will use in this course.
#     - Ananconda
#     - PyCharm
#
# ### PyCharm Demo
#
# - Demo environments, creating environments, installing packages.
#
#
# ### Anaconda
#
# - Demonstrate terminal environment in Jupyter.
#
#
# - Demonstrate Conda command prompt.

# %% [markdown]
# # Common Database Concepts
#
# ## The Concepts
#
# - Almost all database engines and models have the concepts of
#     - Objects that are some form of array of (name, value) pairs.
#     - Sets of similar or related objects.
#     - Four basic (CRUD) operations on a set
#         - CREATE a new object and add to a set.
#         - RETRIEVE an object in a set based on a criteria.
#         - UPDATE an object in a set, e.g. change the data in the object.
#         - DELETE an object from a set, specifying the object(s) by some criteria.
#
#
# - In the file systems/CSV model:
#     - A set is a file, e.g. People.csv.
#     - Each object is a row in the file.
#     - The header row gives the names of each column.
#     - The CRUD processing involves writing a program that reads the file, changes the two-dimensional array and writing the file.
#         - CREATE: Append a row and save the file.
#         - RETRIEVE: Scan the table and apply some kind of IF statement.
#         - UPDATE: Change a row in the two dimensional array.
#         - DELETE: Remove a row from the array.
#
#
# - In the "pure" relational model
#     - A set is a _relation_.
#     - An object is a _row_ or _tuple_.
#     - The operation for _retrieve_ is $\sigma$.
#     - There is no support for CREATE, UPDATE or DELETE.
#     - There is an _algebra_ and language for producing a new relation from existing relations that you can use to "sort of" implement INSERT, DELETE, UPDATE.
#
#
# - In SQL,
#     - A set is a _table_.
#     - An object is a _row_ or _tuple_.
#     - INSERT is the create operation.
#     - UPDATE is the delete operation.
#     - DELETE is the delete operation.
#     - SELECT is the statement that realizes the relational _algebra_.
#
#
# - In [Representational state transfer](https://en.wikipedia.org/wiki/Representational_state_transfer) REST.
#     - A set is a _resource_ that is a collection of _resources._
#     - An object is a resource.
#     - CREATE is HTTP POST
#     - RETRIEVE is HTTP GET
#     - UPDATE is HTTP PUT (or PATCH)
#     - DELETE is HTTP DELETE.
#
#
# - [Redis](https://redis.io/): I am tempted to say, "Don't ask!"
#     - The basic concept is that Redis stores pairs of (key, value).
#     - Key is just a string
#     - Value can be:
#         - String
#         - List
#         - Hash
#         - Set
#         - Sorted Set
#     - The CRUD commands depend on the data type for a value.
#
#
# - In [CouchDB](http://couchdb.apache.org/): I am tempted to say, "No. Seriously, do not ask! Please!"
#     - CouchDB is basically a REST/HTTP accessible document database.
#     - The CRUD operations are the same as for basic REST, but ...
#     - There is much more powerful support for running commands, e.g. ```_find.```

# %% [markdown]
# ## Examples
#
# ### SQL
#
# - ```RETRIEVE``` is ```SELECT```
#
#
# - The basic syntax is:
# ```
# SELECT column1, column2, ...
# FROM table_name
# WHERE condition;
# ```
#
# - ```table_name``` is the table/relation representing a set of entities.
#
#
# - ```column1, column2, ...``` is the list of fields/properties you want from each entity.
#
#
# - ```WHERE condition``` is like an ```IF``` statement in a programming language. The operation only returns the entities for which the condition is true.

# %%
# %%sql
#     select playerID, nameLast, nameFirst, birthYear, birthState
#     from lahman2019raw.people where nameLast='Williams' and birthState='CA'
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 11 rows affected.
# [('willibe01', 'Williams', 'Bernie', '1948', 'CA'),
#  ('willido02', 'Williams', 'Don', '1935', 'CA'),
#  ('williji03', 'Williams', 'Jimy', '1943', 'CA'),
#  ('willike02', 'Williams', 'Ken', '1964', 'CA'),
#  ('willima04', 'Williams', 'Matt', '1965', 'CA'),
#  ('willimi02', 'Williams', 'Mitch', '1964', 'CA'),
#  ('williri02', 'Williams', 'Rinaldo', '1893', 'CA'),
#  ('williri03', 'Williams', 'Rick', '1952', 'CA'),
#  ('willish01', 'Williams', 'Shad', '1971', 'CA'),
#  ('willite01', 'Williams', 'Ted', '1918', 'CA'),
#  ('willitr01', 'Williams', 'Trevor', '1992', 'CA')]

# %% [markdown]
# - Remember, we set up a connection. So, the "location" in the "web" of the entity is ```localhost:3038``` which resolve to my laptop.

# %% [markdown]
# ### REST
#
# - SQL is very powerful and there is a widely implement [standard.](https://en.wikipedia.org/wiki/ISO/IEC_9075)
#
#
# - REST is less a standard and more a set of conventions or informal agreements.
#
#
# - Different endpoints interpret the conventions differently. You typically have to read documentation for each endpoint to figure it all out.
#
#
# - For HW2, we will implement a REST endpoint on top of the Lahman 2019 database.
#
#
# - A sample query would be:
# ```
# http://127.0.0.1:5000/api/lahman2019raw/people?nameLast=Williams&birthState=CA&fields=playerID,nameLast,nameFirst,birthYear,birthState
# ```
#
# - A sample of using my solution to HW2 is:

# %%
 # %load_ext restmagic

# %%
# %rest GET http://127.0.0.1:5000/api/lahman2019raw/people?nameLast=Williams&birthState=CA&fields=playerID,nameLast,nameFirst,birthYear,birthState
# Out:
# {
#   "data": [
#     {
#       "playerID": {
#         "value": "willibe01",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/willibe01"
#         }
#       },
#       "nameLast": "Williams",
#       "nameFirst": "Bernie",
#       "birthYear": "1948",
#       "birthState": "CA"
#     },
#     {
#       "playerID": {
#         "value": "willido02",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/willido02"
#         }
#       },
#       "nameLast": "Williams",
#       "nameFirst": "Don",
#       "birthYear": "1935",
#       "birthState": "CA"
#     },
#     {
#       "playerID": {
#         "value": "williji03",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/williji03"
#         }
#       },
#       "nameLast": "Williams",
#       "nameFirst": "Jimy",
#       "birthYear": "1943",
#       "birthState": "CA"
#     },
#     {
#       "playerID": {
#         "value": "willike02",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/willike02"
#         }
#       },
#       "nameLast": "Williams",
#       "nameFirst": "Ken",
#       "birthYear": "1964",
#       "birthState": "CA"
#     },
#     {
#       "playerID": {
#         "value": "willima04",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/willima04"
#         }
#       },
#       "nameLast": "Williams",
#       "nameFirst": "Matt",
#       "birthYear": "1965",
#       "birthState": "CA"
#     },
#     {
#       "playerID": {
#         "value": "willimi02",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/willimi02"
#         }
#       },
#       "nameLast": "Williams",
#       "nameFirst": "Mitch",
#       "birthYear": "1964",
#       "birthState": "CA"
#     },
#     {
#       "playerID": {
#         "value": "williri02",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/williri02"
#         }
#       },
#       "nameLast": "Williams",
#       "nameFirst": "Rinaldo",
#       "birthYear": "1893",
#       "birthState": "CA"
#     },
#     {
#       "playerID": {
#         "value": "williri03",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/williri03"
#         }
#       },
#       "nameLast": "Williams",
#       "nameFirst": "Rick",
#       "birthYear": "1952",
#       "birthState": "CA"
#     },
#     {
#       "playerID": {
#         "value": "willish01",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/willish01"
#         }
#       },
#       "nameLast": "Williams",
#       "nameFirst": "Shad",
#       "birthYear": "1971",
#       "birthState": "CA"
#     },
#     {
#       "playerID": {
#         "value": "willite01",
#         "link": {
#           "rel": "people",
#           "href": "/api/people/willite01"
#         }
#       },
#       "nameLast": "Williams",
#       "nameFirst": "Ted",
#       "birthYear": "1918",
#       "birthState": "CA"
#     }
#   ],
#   "links": [
#     {
#       "rel": "current",
#       "href": "http://127.0.0.1:5000/api/lahman2019raw/people?nameLast=Williams&birthState=CA&fields=playerID,nameLast,nameFirst,birthYear,birthState"
#     },
#     {
#       "rel": "next",
#       "href": "http://127.0.0.1:5000/api/lahman2019raw/people?nameLast=Williams&birthState=CA&fields=playerID,nameLast,nameFirst,birthYear,birthState&offset=10&limit=10"
#     }
#   ]
# }
# <Response [200]>

# %% [markdown]
# - Comments:
#     - 127.0.0.1 is just another way to say ```localhost.```
#     - ```/api``` is a convention or pattern that means "I am calling an API, not asking for a web page.
#     - ```/lahman2019/people``` is a convention for identifying the database and table.
#     - ```fields=...``` is a convention for identifying the properties that you want.
#     - ```?x=y&z=m``` is a simplified query expressions similar to ```WHERE ...```
#
#
# - We will understand more when we move onto HW2. The important point is thinking about the web as a kind of database.
#
#
# - __Note:__ Demo the UI
#
#
# <hr style="height:1px;">
#
# | <img src="../../images/hw2_intro.jpeg"> |
# | :---: |
# | __HW2 Concept__ |
#
# <hr style="height:1px;">

# %% [markdown]
# ### Files/CSVs
#
# - There is not standard. HW1 defines a convention, and then maps to RDB or CSV files.
#
#
# - To learn about database concepts, we are implementing a DB like think on top of CSV files.
#
#
# - We implement the same concept on top of RDB to compare implementations.
#
#
# - We could do the same pattern on top of all of our various databases, but there is not a lot of learning value.

# %%
# Load my solution implementation into the Notebook's path.
import sys
sys.path.append("C:\\Users\\dferguso\\ansys_one_drive\\Columbia\\Projects\\W4111\\HW1Impl")

# %%
from src.CSVDataTable import CSVDataTable

# %%
# Where is the "DB" holding my "tables"?
_default_directory = \
        "C:\\Users\\dferguso\\ansys_one_drive\\Columbia\Projects\\W4111\\HW1Impl\\Data" + \
            "\\baseballdatabank-2019.2\\core\\"

# %%
# I want to connect to a "table"
connect_info = {
    "directory": _default_directory,
    "file_name": 'People.csv'
}

# %%
# Create a data table to wrap the file.
t = CSVDataTable(table_name="People", key_columns=['playerID'],connect_info=connect_info)

# %%
# Load the file into memory.
t.load()

# %%
template = {"birthState": "CA", "nameLast": "Williams"}
field_list = ['playerID', 'nameLast', 'nameFirst', 'birthYear', 'birthState']

# %%
result = t.find_by_template(template, field_list, None, None, None)

# %%
print(result)
# Out:
# <class 'src.DerivedDataTable.DerivedDataTable'>: name = FBT:People
# connect_info = None
# Key columns = None
# No. of rows = 11
# {'playerID': 'willibe01', 'nameLast': 'Williams', 'nameFirst': 'Bernie', 'birthYear': '1948', 'birthState': 'CA'}
# {'playerID': 'willido02', 'nameLast': 'Williams', 'nameFirst': 'Don', 'birthYear': '1935', 'birthState': 'CA'}
# {'playerID': 'williji03', 'nameLast': 'Williams', 'nameFirst': 'Jimy', 'birthYear': '1943', 'birthState': 'CA'}
# {'playerID': 'willike02', 'nameLast': 'Williams', 'nameFirst': 'Ken', 'birthYear': '1964', 'birthState': 'CA'}
# {'playerID': 'willima04', 'nameLast': 'Williams', 'nameFirst': 'Matt', 'birthYear': '1965', 'birthState': 'CA'}

# %% [markdown]
# ### Redis, CouchDB
#
# __I said, 'Don't ask."__
#
#
# - These are complex discussions and I want to move onto the relational model.

# %% [markdown]
# # The Relational Model $-$ I
#
# ## Overview
#
# References: Ramakrishnan and Gehrke, section 3.1
#
# There are two perspectives on the relational model:
# 1. Formal language and algebra.
# 2. A standard implementation language, Structure Query Language [(SQL)](https://en.wikipedia.org/wiki/SQL)
#
#
# The relational model and SQL language (and most DB engines) have two sub-languages/models:
# 1. Data definition
# 2. Data manipulation
#
#
# MySQL and other database engines also have an API/language for administration and security.
#
# <hr style="height:1px;">
#
# | <img src="../../images/db_engine_apis.jpeg"> |
# | :---: |
# | __DB Engine Interfaces__ |
#
# <hr style="height:1px;">

# %% [markdown]
# <hr>
#
# | <img src="../../images/Slide03.jpg"> |
# | :---: |
# | __Relational Model__ |
#
# <hr>
#
# | <img src="../../images/Slide04.jpg"> |
# | :---: |
# | __Relational Model__ |

# %% [markdown]
# ## Defining Data
#
# ### Relational Model
#
# - _Relational Schema_ defines and provides metadata describing what is/can be in "the file" (called a _relation_), e.g.<br>
#
#
# \begin{equation}
# Employees(\overline{employeeNumber}:integer, \ lastName:string, \ firstName:string, \ extension:string, \ email:string, \ officeCode:integer, \ reportsTo:integer, \ jobTitle: string)
# \end{equation}
#
#
# - The formal relational model is imprecise about allowed types for fields/columns. The types must be elementary (atomic) types, e.g. integer, string, char, ...
#
#
# - The $\overline{overline}$ indicates the _key columns,_ which we will cover later.
#
#
# - A _Relational Instance_ is a "table" of data that conforms to a relation schema, e.g.<br><br>
#
#
# | <img src="../../images/employee_relation.jpeg" width="900px%"> |
# | :---: |
# | __Employee Relational Instance__ |

# %% [markdown]
# ### SQL
#
# - Structured Query Language (SQL) is a well-defined programming language that realizes a superset of the relation model.
#
#
# - There are two sub-languages
#     1. Data Definition Language (DDL) corresponds to relational schema.
#     2. Data Manipulation Language corresponds to relational algebra (covered later).
#
#
# - Data Definition Statements (DDL) statements are how you create/modify tables in SQL.
#
#
# - Defining a table in SQL uses the create statement. The statement for creating the ```People``` table to hold data from ```Lahman2019's``` CSV file ```people.csv``` is:
#
# ```
#
# CREATE TABLE `people` (
#   `playerID` text,
#   `birthYear` text,
#   `birthMonth` text,
#   `birthDay` text,
#   `birthCountry` text,
#   `birthState` text,
#   `birthCity` text,
#   `deathYear` text,
#   `deathMonth` text,
#   `deathDay` text,
#   `deathCountry` text,
#   `deathState` text,
#   `deathCity` text,
#   `nameFirst` text,
#   `nameLast` text,
#   `nameGiven` text,
#   `weight` text,
#   `height` text,
#   `bats` text,
#   `throws` text,
#   `debut` text,
#   `finalGame` text,
#   `retroID` text,
#   `bbrefID` text
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COLLATE=utf8mb4_0900_ai_ci;
#
#
#
# ```

# %% [markdown]
# - The back, single quotes are a sometimes useful/sometimes annoying aspect of MySQL's implementation of the SQL standard.
#     - Anything in between single back quotes is a _schema element._
#     - Allows attributes and table names of the form \`My Table\` \`My-Table\` and makes clear that \`My-Table\` is a schema element and not an attempt to subtract the variable `Table` from the variable `My`
#
#
# - SQL has a superset of the relational model's schema definition capability. An improved table definition could be
#
#
# - There are some design or best practice issues with this table, which we will discuss later.
#
#
# - The SQL DML
#     - Has many other operations/statements.
#         - DROP
#         - ALTER
#     - Operates on more than just a table's attributes, e.g.
#         - Constraints
#         - Triggers
#         - Indexes
#
#
# - We will go into DML and defining data in much more detail.

# %% [markdown]
# ## Manipulating and Processing Information
#
# ### Computer Languages
#
# - A [declarative language's](https://en.wikipedia.org/wiki/Declarative_programming) programs describe their desired results without explicitly listing commands or steps that must be performed
#
#
# - An [imperative language](https://en.wikipedia.org/wiki/Imperative_programming) program consists of commands for the computer to perform. Imperative programming focuses on describing how a program operates.
#
#
# - The most distinguishing feature is that declarative languages do not have control-flow constructs, e.g.
#     - ```if {...} else {...}```
#     - ```for (...) {...}```
#
#
# - The relation model, SQL and many DB languages are (primarily) [declarative languages.](https://en.wikipedia.org/wiki/Declarative_programming)

# %% [markdown]
# ### Algebraic Query Language
#
# Reference: Ramkrishan and Gherke, section 2.4.
#
# Both the abstract relational model/theory and SQL are __algebras__.
#
# #### Algebra
#
# "... abstract algebra (occasionally called modern algebra) is the study of algebraic structures." (https://en.wikipedia.org/wiki/Abstract_algebra)
#
# "In mathematics, and more specifically in abstract algebra, an algebraic structure is a set (called carrier set or underlying set) with one or more operations defined on it that satisfies a list of axioms." (https://en.wikipedia.org/wiki/Algebraic_structure)
#
# __Group is an Example__ (http://mathworld.wolfram.com/Group.html)
#
# "A group G is a finite or infinite set of elements together with a binary operation (called the group operation) that together satisfy the four fundamental properties of closure, associativity, the identity property, and the inverse property. The operation with respect to which a group is defined is often called the "group operation," and a set is said to be a group "under" this operation. Elements A, B, C, ... with binary operation between A and B denoted AB form a group if
#
# 1. Closure: If A and B are two elements in G, then the product AB is also in G.
# <br><br>
# 2. Associativity: The defined multiplication is associative, i.e., for all A,B,C in G, (AB)C=A(BC).
# <br><br>
# 3. Identity: There is an identity element I (a.k.a. 1, E, or e) such that IA=AI=A for every element A in G.
# <br><br>
# 4. Inverse: There must be an inverse (a.k.a. reciprocal) of each element. Therefore, for each element A of G, the set contains an element B=A<sup>-1</sup> such that <br>AA<sup>-1</sup>=A<sup>-1</sup>A=I.

# %% [markdown]
# #### Why a Special Query Language? Why a Formal Language? Why an Algebra
#
# - Computing has a formal mathemetical model.
#
#
# - Programming languages derive from the model and have their own formal definition.
#
#
# - Almost every time someone publishes a new language, my reaction is, "What? Why another language? Can't we just pick one, use it and get it right?"
#
#
# - Relational algebra is less powerful and expressive than Java, C, ... and other programming languages.
#
#
# - __The simplicity and constrained capabilities is actually one of the core of the value,__ enabling
#     - Vastly simplified programming and supporting tools that yields increased productivity.
#     - Development of algorithms that process the data definitions and query statements to automatically produce optimal execution plans, which are better than what a programmer can directly code.
#
#
# - We will see these benefits in coming lectures.
#
#
# _Simple Tool Example_ that enables "citizen programmers" to maniuplate data.
#
# | <img src="../../images/ss_1.jpeg"> |
# | :---: |
# | __Data Processing and Cleansing Tools__ |
#
# <br><br>
# _Simple Tool Example_ for enabling business professionals to analyze and report on data.
#
# | <img src="../../images/quicksight.jpeg" width="85%"> |
# | :---: |
# | [QuickSight](https://aws.amazon.com/quicksight/) Analysis Tool |

# %% [markdown]
# ### Relational Algebra
#
# - There are two notations or representations of the algebra:
#     - The original, formal theory.
#     - SQL
#
# #### Original, Formal Relational Notation
#
# Ramakrishnan and Gehrke, section 4.2
#
#
# - The "set" in the relational algebra is the set of _relations_.
#
#
# - The operations are:
#     - Common set operations:
#         - Union: $\cup$
#         - Intersection: $\cap$
#         - Difference: $-$
#     - Projection: $\pi$
#     - Selection: $\sigma$
#     - Cartesian Product: $\times$
#     - Join: $\bowtie$
#     - Rename/Alias
#
#
# - The formal notation does not support create, update or delete of tuples/rows in a relation. You could emulate the operations by
#     - Defining new relations containing the created, updated or delete tuples.
#     - Using $\cup$, $\cap$, $-$ on the original relation and created/deleted/updated tuple relation.
#
#
# - This is an algebra $\Rightarrow$ that $R_1\ OP\ R_2 \rightarrow R_3 ,$ where $R_1 , R_2 , $ and $R_3$ are relations ( aka tables). Relationa algebra is closed. Algebra statements operate on relations and produce relations.
#
#
# #### SQL Notation
#
# Ramakrishnan and Gehrke, sections 5.1, 5.2
#
# - The "set" in the relational algebra is the catalog of _tables_.
#
#
# - The operations are:
#     - Common set operations:
#         - Union: UNION
#         - Intersection: INTERSECT
#         - Difference: EXCEPT
#     - Selection, Projection, Cartesian Product, Rename/Alias and Join are clauses within a SELECT statement.
#
#     ```SELECT <project clause> FROM <table> [JOIN <table> [ON <join condition]] WHERE <select condition>```
#
#
# - SQL supports additional operations, e.g
#     - GROUP BY
#     - ORDER BY

# %% [markdown]
# ### Selection and Projection
#
# #### Relational Model

# %% [markdown]
# - <span style="color: red;">Projection</span> produces a new relation that
#     - Has the same rows as the original table
#     - But only containing the requested columns/fields
#
#
# - <span style="color: red;">Selection</span> produces a new relation that
#     - Has the same columns as the original relation
#     - But only contains rows with column values matching a predicate.

# %% [markdown]
# ##### Selection
#
# - The selection operator is $\sigma$
#
#
# - The selection predicate operators are: $\lt, \gt, =, \ne, \ge, \le$
#
#
# - $\sigma(Players)$ selects all of the rows/tuples in the player relation.
#
#
# - The predicate/condition is a "subscript," e.g.
#     - $\sigma$<sub>playerID=napolmi01</sub>$(Players)$ selects all players with _playerID=napolmi01_
#     - $\sigma$<sub>((nameLast=Williams)$\land(throws=L))\lor(birthYear\ne1914)$</sub>$(Players)$ selects all players with
#         - Last name williams who threw lefthanded
#         - Birth year not equal to 1914
#
#
# - This notation is a little clunky. You can think of the selection predicate being similar to what goes in an _if()_ statement if you were looping through an array testing for a match.

# %% [markdown]
# ###### Projection
#
# - The projection operator is $\pi$
#
#
# - The requested columns are subscripts on the operator, e.g. $\pi$<sub>$nameLast,nameFirst,throws$</sub>$(Players)$ returns a table
#     - Containing the $nameLast, nameFirst, throws$ column values, in that order
#     - For all tuples in the $Players$ table.

# %% [markdown]
# ##### An Algebra
#
# - Because the relational model is an algebra, composition is possible.
#
#
# - Like algebras, there are instances where composition supports _commutativity,_ _associativity,_ _distribution_ and other algebra rules.
#
#
# - For example, $\pi$ and $\sigma$ are commutative.
# \begin{equation}
# \pi_{nameLast,nameFirst,birthYear}(\sigma_{birthYear=1960}(Players)) = \sigma_{birthYear=1960}(\pi_{nameLast,nameFirst,birthYear}(Players))
# \end{equation}
#
#
# - The fact that some algebra rules apply will become important in query optimization later in the course.

# %% [markdown]
# #### SQL
#
# - The core syntax of the SQL SELECT statement is
# ```
# SELECT [DISTINCT] column-list
#     FROM table-list
#     WHERE qualification
# ```
#
# - All RDB products implement the core syntax but with extensions.
#
#
# - The MYSQL syntax is
#
# ```
# SELECT
#     [ALL | DISTINCT | DISTINCTROW ]
#       [HIGH_PRIORITY]
#       [STRAIGHT_JOIN]
#       [SQL_SMALL_RESULT] [SQL_BIG_RESULT] [SQL_BUFFER_RESULT]
#       SQL_NO_CACHE [SQL_CALC_FOUND_ROWS]
#     select_expr [, select_expr ...]
#     [FROM table_references
#       [PARTITION partition_list]
#     [WHERE where_condition]
#     [GROUP BY {col_name | expr | position}, ... [WITH ROLLUP]]
#     [HAVING where_condition]
#     [WINDOW window_name AS (window_spec)
#         [, window_name AS (window_spec)] ...]
#     [ORDER BY {col_name | expr | position}
#       [ASC | DESC], ... [WITH ROLLUP]]
#     [LIMIT {[offset,] row_count | row_count OFFSET offset}]
#     [INTO OUTFILE 'file_name'
#         [CHARACTER SET charset_name]
#         export_options
#       | INTO DUMPFILE 'file_name'
#       | INTO var_name [, var_name]]
#     [FOR {UPDATE | SHARE} [OF tbl_name [, tbl_name] ...] [NOWAIT | SKIP LOCKED]
#       | LOCK IN SHARE MODE]]
# ```
#
#
# - __Examples are the easiest way to master the syntax and behavior.__
#
#
# - A reminder of the ```Lahman2017.People``` table.
#
# ```
# CREATE TABLE `people` (
#   `playerID` varchar(12) NOT NULL,
#   `birthYear` char(4) DEFAULT NULL,
#   `birthMonth` char(2) DEFAULT NULL,
#   `birthDay` char(2) DEFAULT NULL,
#   `birthCountry` varchar(64) DEFAULT NULL,
#   `birthState` varchar(32) DEFAULT NULL,
#   `birthCity` varchar(64) DEFAULT NULL,
#   `deathYear` char(4) DEFAULT NULL,
#   `deathMonth` char(2) DEFAULT NULL,
#   `deathDay` char(2) DEFAULT NULL,
#   `deathCountry` varchar(64) DEFAULT NULL,
#   `deathState` varchar(32) DEFAULT NULL,
#   `deathCity` varchar(64) DEFAULT NULL,
#   `nameFirst` varchar(64) NOT NULL,
#   `nameLast` varchar(64) NOT NULL,
#   `nameGiven` varchar(128) DEFAULT NULL,
#   `weight` char(3) DEFAULT NULL,
#   `height` char(3) DEFAULT NULL,
#   `bats` char(1) DEFAULT NULL,
#   `throws` char(1) DEFAULT NULL,
#   `debut` varchar(16) DEFAULT NULL,
#   `finalGame` varchar(16) DEFAULT NULL,
#   `retroID` varchar(12) DEFAULT NULL,
#   `bbrefID` varchar(12) DEFAULT NULL,
#   PRIMARY KEY (`playerID`)
# ) ENGINE=InnoDB DEFAULT CHARSET=utf8;
# ```
#
# - __NOTE:__ All of the single back quotes are:
#     - MySQL specific
#     - Optional in most cases, and only required if a table or column name has a space or some other icky character, e.g. ``` `First Name` ```, ```First-Name```

# %% [markdown]
# <u>Select all People with last name 'Williams'</u>

# %%
# %sql select * from People where nameLast='Williams';
# Out:
# 80 rows affected.
# [('williac01', 1917, 3, 18, 'USA', 'NJ', 'Montclair', 1999, 9, 16, 'USA', 'FL', 'Fort Myers', 'Ace', 'Williams', 'Robert Fulton', '174', '74', 'R', 'L', '1940-07-15', '1946-04-22', 'willa103', 'williac01', datetime.date(1999, 9, 16), datetime.date(1917, 3, 18)),
#  ('willial02', 1914, 5, 11, 'USA', 'AL', 'Valhermosa Springs', 1969, 7, 19, 'USA', 'TX', 'Groves', 'Al', 'Williams', 'Almon Edward', '200', '75', 'R', 'R', '1937-04-19', '1938-09-04', 'willa101', 'willial02', datetime.date(1969, 7, 19), datetime.date(1914, 5, 11)),
#  ('willial03', 1954, 5, 6, 'Nicaragua', 'Atlantico Sur', 'Pearl Lagoon', None, None, None, '', '', '', 'Albert', 'Williams', 'Albert Hamilton', '190', '76', 'R', 'R', '1980-05-07', '1984-09-26', 'willa001', 'willial03', None, datetime.date(1954, 5, 6)),
#  ('williar01', 1877, 8, 24, 'USA', 'MA', 'Somerville', 1941, 5, 16, 'USA', 'VA', 'Arlington', 'Art', 'Williams', 'Arthur Frank', '', '', 'L', 'R', '1902-05-07', '1902-09-01', 'willa104', 'williar01', datetime.date(1941, 5, 16), datetime.date(1877, 8, 24)),
#  ('willibe01', 1948, 10, 8, 'USA', 'CA', 'Alameda', None, None, None, '', '', '', 'Bernie', 'Williams', 'Bernard', '175', '73', 'R', 'R', '1970-09-07', '1974-05-12', 'willb105', 'willibe01', None, datetime.date(1948, 10, 8)),
#  ('willibe02', 1968, 9, 13, 'P.R.', '', 'San Juan', None, None, None, '', '', '', 'Bernie', 'Williams', 'Bernabe', '180', '74', 'B', 'R', '1991-07-07', '2006-10-01', 'willb002', 'willibe02', None, datetime.date(1968, 9, 13)),
#  ('willibi01', 1938, 6, 15, 'USA', 'AL', 'Whistler', None, None, None, '', '', '', 'Billy', 'Williams', 'Billy Leo', '175', '73', 'L', 'R', '1959-08-06', '1976-10-02', 'willb104', 'willibi01', None, datetime.date(1938, 6, 15)),
#  ('willibi02', 1932, 6, 13, 'USA', 'SC', 'Newberry', 2013, 6, 11, 'USA', 'CA', 'Berkeley', 'Billy', 'Williams', 'William', '195', '75', 'L', 'R', '1969-08-15', '1969-08-20', 'willb102', 'willibi02', datetime.date(2013, 6, 11), datetime.date(1932, 6, 13)),
#  ('willibo01', 1884, 4, 27, 'USA', 'OH', 'Monday', 1962, 8, 6, 'USA', 'OH', 'Nelsonville', 'Bob', 'Williams', 'Robert Elias', '190', '72', 'R', 'R', '1911-07-03', '1913-09-30', 'willb103', 'willibo01', datetime.date(1962, 8, 6), datetime.date(1884, 4, 27)),
#  ('willibr01', 1969, 2, 15, 'USA', 'SC', 'Lancaster', None, None, None, '', '', '', 'Brian', 'Williams', "Brian O'Neal", '205', '75', 'R', 'R', '1991-09-16', '2000-07-05', 'willb001', 'willibr01', None, datetime.date(1969, 2, 15)),
#  ('willich01', 1947, 10, 11, 'USA', 'NY', 'Flushing', 2015, 1, 27, 'USA', 'FL', 'Port Orange', 'Charlie', 'Williams', 'Charles Prosek', '200', '74', 'R', 'R', '1971-04-23', '1978-09-11', 'willc101', 'willich01', datetime.date(2015, 1, 27), datetime.date(1947, 10, 11)),
#  ('willicy01', 1887, 12, 21, 'USA', 'IN', 'Wadena', 1974, 4, 23, 'USA', 'WI', 'Eagle River', 'Cy', 'Williams', 'Fred', '180', '74', 'L', 'L', '1912-07-18', '1930-09-22', 'willc103', 'willicy01', datetime.date(1974, 4, 23), datetime.date(1887, 12, 21)),
#  ('willida01', 1855, 10, 6, 'USA', 'KY', 'Ludlow', 1939, 10, 22, 'USA', 'KY', 'Covington', 'Dale', 'Williams', 'Elisha Alphonso', '175', '69', 'R', 'R', '1876-08-12', '1876-09-09', 'willd106', 'willida01', datetime.date(1939, 10, 22), datetime.date(1855, 10, 6)),
#  ('willida02', 1881, 2, 7, 'USA', 'PA', 'Scranton', 1918, 4, 25, 'USA', 'AR', 'Hot Springs', 'Dave', 'Williams', 'David Owen', '167', '71', 'R', 'L', '1902-07-02', '1902-08-03', 'willd103', 'willida02', datetime.date(1918, 4, 25), datetime.date(1881, 2, 7)),
#  ('willida03', 1927, 11, 2, 'USA', 'TX', 'Dallas', 2009, 8, 17, 'USA', 'TX', 'Farmers Branch', 'Davey', 'Williams', 'David Carlous', '160', '70', 'R', 'R', '1949-09-16', '1955-07-31', 'willd102', 'willida03', datetime.date(2009, 8, 17), datetime.date(1927, 11, 2)),
#  ('willida05', 1958, 2, 28, 'USA', 'NY', 'Brooklyn', None, None, None, '', '', '', 'Dallas', 'Williams', 'Dallas McKinley', '165', '71', 'L', 'L', '1981-09-19', '1983-10-02', 'willd101', 'willida05', None, datetime.date(1958, 2, 28)),
#  ('willida06', 1963, 3, 20, 'USA', 'WV', 'Weirton', None, None, None, '', '', '', 'Dana', 'Williams', 'Dana Lamont', '170', '70', 'R', 'R', '1989-06-19', '1989-07-02', 'willd001', 'willida06', None, datetime.date(1963, 3, 20)),
#  ('willida07', 1979, 3, 12, 'USA', 'AK', 'Anchorage', None, None, None, '', '', '', 'David', 'Williams', 'David Aaron', '215', '75', 'L', 'L', '2001-06-06', '2007-09-24', 'willd002', 'willida07', None, datetime.date(1979, 3, 12)),
#  ('willide01', 1896, 12, 13, 'USA', 'OR', 'Portland', 1929, 3, 23, 'USA', 'CA', 'San Clemente', 'Denny', 'Williams', 'Evon Daniel', '150', '68', 'L', 'R', '1921-04-15', '1928-07-18', 'willd105', 'willide01', datetime.date(1929, 3, 23), datetime.date(1896, 12, 13)),
#  ('willide02', 1916, 2, 5, 'USA', 'NC', 'Durham', 2000, 3, 19, 'USA', 'ND', 'Williston', 'Dewey', 'Williams', 'Dewey Edgar', '160', '72', 'R', 'R', '1944-06-28', '1948-09-26', 'willd109', 'willide02', datetime.date(2000, 3, 19), datetime.date(1916, 2, 5)),
#  ('willidi01', 1910, 1, 19, 'USA', 'AR', 'Greenbrier', 1992, 4, 2, 'USA', 'AR', 'Searcy', 'Dib', 'Williams', 'Edwin Dibrell', '175', '71', 'R', 'R', '1930-04-27', '1935-09-29', 'willd107', 'willidi01', datetime.date(1992, 4, 2), datetime.date(1910, 1, 19)),
#  ('willidi02', 1929, 5, 7, 'USA', 'MO', 'St. Louis', 2011, 7, 7, 'USA', 'NV', 'Las Vegas', 'Dick', 'Williams', 'Richard Hirschfeld', '190', '72', 'R', 'R', '1951-06-10', '1964-10-01', 'willd104', 'willidi02', datetime.date(2011, 7, 7), datetime.date(1929, 5, 7)),
#  ('willido01', 1931, 9, 14, 'USA', 'VA', 'Floyd', 2011, 10, 16, 'USA', 'VA', 'Floyd', 'Don', 'Williams', 'Don Fred', '180', '74', 'R', 'R', '1958-09-12', '1962-08-23', 'willd108', 'willido01', datetime.date(2011, 10, 16), datetime.date(1931, 9, 14)),
#  ('willido02', 1935, 9, 2, 'USA', 'CA', 'Los Angeles', 1991, 12, 20, 'USA', 'CA', 'La Jolla', 'Don', 'Williams', 'Donald Reid', '218', '77', 'R', 'R', '1963-08-04', '1963-08-17', 'willd110', 'willido02', datetime.date(1991, 12, 20), datetime.date(1935, 9, 2)),
#  ('williea01', 1903, 1, 27, 'USA', 'TN', 'Cumberland Gap', 1958, 3, 10, 'USA', 'TN', 'Knoxville', 'Earl', 'Williams', 'Earl Baxter', '185', '72', 'R', 'R', '1928-05-27', '1928-06-02', 'wille102', 'williea01', datetime.date(1958, 3, 10), datetime.date(1903, 1, 27)),
#  ('williea02', 1948, 7, 14, 'USA', 'NJ', 'Newark', 2013, 1, 28, 'USA', 'NJ', 'Somerset', 'Earl', 'Williams', 'Earl Craig', '215', '75', 'R', 'R', '1970-09-13', '1977-09-25', 'wille101', 'williea02', datetime.date(2013, 1, 28), datetime.date(1948, 7, 14)),
#  ('willied01', 1964, 11, 1, 'USA', 'LA', 'Shreveport', None, None, None, '', '', '', 'Eddie', 'Williams', 'Edward Laquan', '175', '72', 'R', 'R', '1986-04-18', '1998-05-27', 'wille001', 'willied01', None, datetime.date(1964, 11, 1)),
#  ('willifr01', 1958, 2, 13, 'USA', 'WA', 'Seattle', 2009, 1, 9, 'CAN', 'BC', 'Victoria', 'Frank', 'Williams', 'Frank Lee', '180', '73', 'R', 'R', '1984-04-05', '1989-09-27', 'willf001', 'willifr01', datetime.date(2009, 1, 9), datetime.date(1958, 2, 13)),
#  ('willige01', 1939, 10, 23, 'USA', 'MI', 'Detroit', 2009, 5, 14, 'USA', 'MI', 'Detroit', 'George', 'Williams', 'George', '165', '71', 'R', 'R', '1961-07-16', '1964-07-05', 'willg101', 'willige01', datetime.date(2009, 5, 14), datetime.date(1939, 10, 23)),
#  ('willige02', 1966, 8, 10, 'USA', 'LA', 'New Orleans', None, None, None, '', '', '', 'Gerald', 'Williams', 'Gerald Floyd', '190', '74', 'R', 'R', '1992-09-15', '2005-10-02', 'willg001', 'willige02', None, datetime.date(1966, 8, 10)),
#  ('willige03', 1969, 4, 22, 'USA', 'WI', 'La Crosse', None, None, None, '', '', '', 'George', 'Williams', 'George Erik', '190', '70', 'B', 'R', '1995-07-14', '2000-09-13', 'willg002', 'willige03', None, datetime.date(1969, 4, 22)),
#  ('willigl01', 1977, 7, 18, 'Australia', 'New South Wales', 'Gosford', None, None, None, '', '', '', 'Glenn', 'Williams', 'Glenn David', '195', '74', 'B', 'R', '2005-06-07', '2005-06-28', 'willg003', 'willigl01', None, datetime.date(1977, 7, 18)),
#  ('willigu01', 1870, None, None, 'USA', 'NY', 'New York', 1890, 10, 14, 'USA', 'NY', 'New York', 'Gus', 'Williams', 'Augustine H.', '170', '71', '', '', '1890-04-18', '1890-04-22', 'willg102', 'willigu01', datetime.date(1890, 10, 14), None),
#  ('willigu02', 1888, 5, 7, 'USA', 'NE', 'Omaha', 1964, 4, 16, 'USA', 'IL', 'Sterling', 'Gus', 'Williams', 'August Joseph', '185', '72', 'L', 'L', '1911-04-12', '1915-06-18', 'willg103', 'willigu02', datetime.date(1964, 4, 16), datetime.date(1888, 5, 7)),
#  ('williha01', 1890, 6, 23, 'USA', 'NE', 'Omaha', 1963, 12, 21, 'USA', 'CA', 'Huntington Park', 'Harry', 'Williams', 'Harry Peter', '200', '73', 'R', 'R', '1913-08-07', '1914-06-30', 'willh103', 'williha01', datetime.date(1963, 12, 21), datetime.date(1890, 6, 23)),
#  ('willija01', 1986, 5, 14, 'USA', 'OK', 'Tulsa', None, None, None, '', '', '', 'Jackson', 'Williams', 'Jackson Thomas', '200', '70', 'R', 'R', '2014-08-27', '2015-10-04', 'willj005', 'willija01', None, datetime.date(1986, 5, 14)),
#  ('willije01', 1972, 6, 6, 'Australia', 'Capital Territory', 'Canberra', None, None, None, '', '', '', 'Jeff', 'Williams', 'Jeffrey F.', '185', '72', 'R', 'L', '1999-09-12', '2002-09-28', 'willj002', 'willije02', None, datetime.date(1972, 6, 6)),
#  ('willije02', 1981, 12, 4, 'USA', 'HI', 'Honolulu', None, None, None, '', '', '', 'Jerome', 'Williams', 'Jerome Lee', '260', '75', 'R', 'R', '2003-04-26', '2016-09-26', 'willj003', 'willije01', None, datetime.date(1981, 12, 4)),
#  ('williji01', 1876, 12, 20, 'USA', 'MO', 'St. Louis', 1965, 1, 16, 'USA', 'FL', 'St. Petersburg', 'Jimmy', 'Williams', 'James Thomas', '175', '69', 'R', 'R', '1899-04-15', '1909-10-03', 'willj106', 'williji01', datetime.date(1965, 1, 16), datetime.date(1876, 12, 20)),
#  ('williji03', 1943, 10, 4, 'USA', 'CA', 'Santa Maria', None, None, None, '', '', '', 'Jimy', 'Williams', 'James Francis', '170', '70', 'R', 'R', '1966-04-26', '1967-09-21', 'willj107', 'williji03', None, datetime.date(1943, 10, 4)),
#  ('williji04', 1947, 4, 29, 'USA', 'LA', 'Zachary', None, None, None, '', '', '', 'Jim', 'Williams', 'James Alfred', '190', '74', 'R', 'R', '1969-09-08', '1970-09-30', 'willj108', 'williji04', None, datetime.date(1947, 4, 29)),
#  ('williji99', 1847, 1, 4, 'USA', 'OH', 'Catawba', 1918, 10, 23, 'USA', 'NY', 'Westbury', 'Jimmy', 'Williams', 'James Andrew', '', '', '', '', '', '', 'willj801', 'williji99', datetime.date(1918, 10, 23), datetime.date(1847, 1, 4)),
#  ('willijo02', 1889, 7, 16, 'USA', 'HI', 'Honolulu', 1963, 9, 8, 'USA', 'CA', 'Long Beach', 'Johnnie', 'Williams', 'John Brodie', '180', '72', 'R', 'R', '1914-04-21', '1914-08-19', 'willj101', 'willijo02', datetime.date(1963, 9, 8), datetime.date(1889, 7, 16)),
#  ('willijo99', 1885, 4, 6, 'USA', 'TX', 'Seguin', 1951, 2, 25, 'USA', 'NY', 'New York', 'Smokey Joe', 'Williams', 'Joseph', '190', '76', 'R', 'R', '', '', '', 'willijo99', datetime.date(1951, 2, 25), datetime.date(1885, 4, 6)),
#  ('willike01', 1890, 6, 28, 'USA', 'OR', 'Grants Pass', 1959, 1, 22, 'USA', 'OR', 'Grants Pass', 'Ken', 'Williams', 'Kenneth Roy', '170', '72', 'L', 'R', '1915-07-14', '1929-08-10', 'willk101', 'willike01', datetime.date(1959, 1, 22), datetime.date(1890, 6, 28)),
#  ('willike02', 1964, 4, 6, 'USA', 'CA', 'Berkeley', None, None, None, '', '', '', 'Ken', 'Williams', 'Kenneth Royal', '187', '74', 'R', 'R', '1986-09-02', '1991-10-04', 'willk001', 'willike02', None, datetime.date(1964, 4, 6)),
#  ('willike03', 1972, 4, 21, 'USA', 'PA', 'Bedford', None, None, None, '', '', '', 'Keith', 'Williams', 'David Keith', '190', '72', 'R', 'R', '1996-06-07', '1996-06-23', 'willk002', 'willike03', None, datetime.date(1972, 4, 21)),
#  ('willile01', 1893, 3, 9, 'USA', 'MO', 'Aurora', 1959, 11, 4, 'USA', 'CA', 'Laguna Beach', 'Lefty', 'Williams', 'Claude Preston', '160', '69', 'R', 'L', '1913-09-17', '1920-09-25', 'willl104', 'willile01', datetime.date(1959, 11, 4), datetime.date(1893, 3, 9)),
#  ('willile03', 1905, 12, 2, 'USA', 'GA', 'Macon', 1984, 11, 20, 'USA', 'GA', 'Atlanta', 'Leon', 'Williams', 'Leon Theo', '154', '70', 'L', 'L', '1926-05-26', '1926-09-06', 'willl101', 'willile03', datetime.date(1984, 11, 20), datetime.date(1905, 12, 2)),
#  ('willima01', 1893, 2, 21, 'USA', 'NC', 'Faison', 1935, 2, 22, 'USA', 'AZ', 'Tucson', 'Marsh', 'Williams', 'Marshall McDiarmid', '180', '72', 'R', 'R', '1916-07-07', '1916-08-25', 'willm104', 'willima01', datetime.date(1935, 2, 22), datetime.date(1893, 2, 21)),
#  ('willima02', 1953, 7, 28, 'USA', 'NY', 'Elmira', None, None, None, '', '', '', 'Mark', 'Williams', 'Mark Westley', '180', '72', 'L', 'L', '1977-05-20', '1977-05-22', 'willm105', 'willima02', None, datetime.date(1953, 7, 28)),
#  ('willima03', 1959, 7, 25, 'USA', 'TX', 'Houston', None, None, None, '', '', '', 'Matt', 'Williams', 'Matthew Evan', '200', '73', 'R', 'R', '1983-08-02', '1985-10-05', 'willm001', 'willima03', None, datetime.date(1959, 7, 25)),
#  ('willima04', 1965, 11, 28, 'USA', 'CA', 'Bishop', None, None, None, '', '', '', 'Matt', 'Williams', 'Matthew Derrick', '205', '74', 'R', 'R', '1987-04-11', '2003-05-31', 'willm003', 'willima04', None, datetime.date(1965, 11, 28)),
#  ('willima06', 1971, 4, 12, 'USA', 'VA', 'Virginia Beach', None, None, None, '', '', '', 'Matt', 'Williams', 'Matt Taylor', '185', '72', 'B', 'L', '2000-04-05', '2000-04-29', 'willm006', 'willima09', None, datetime.date(1971, 4, 12)),
#  ('willima07', 1991, 8, 21, 'USA', 'RI', 'Pawtucket', None, None, None, '', '', '', 'Mason', 'Williams', 'Mason', '195', '73', 'L', 'R', '2015-06-12', '2017-06-25', 'willm007', 'willima10', None, datetime.date(1991, 8, 21)),
#  ('willimi02', 1964, 11, 17, 'USA', 'CA', 'Santa Ana', None, None, None, '', '', '', 'Mitch', 'Williams', 'Mitchell Steven', '180', '75', 'L', 'L', '1986-04-09', '1997-05-10', 'willm002', 'willimi02', None, datetime.date(1964, 11, 17)),
#  ('willimi03', 1968, 7, 29, 'USA', 'VA', 'Radford', None, None, None, '', '', '', 'Mike', 'Williams', 'Michael Darren', '190', '74', 'R', 'R', '1992-06-30', '2003-09-28', 'willm005', 'willimi03', None, datetime.date(1968, 7, 29)),
#  ('willimu01', 1892, 7, 31, 'USA', 'AR', 'Ozark', 1962, 3, 30, 'USA', 'AR', 'Fayetteville', 'Mutt', 'Williams', 'David Carter', '195', '75', 'R', 'R', '1913-10-04', '1914-10-01', 'willm103', 'willimu01', datetime.date(1962, 3, 30), datetime.date(1892, 7, 31)),
#  ('willini01', 1993, 9, 8, 'USA', 'TX', 'Galveston', None, None, None, '', '', '', 'Nick', 'Williams', 'Billy Nicholas', '195', '75', 'L', 'L', '2017-06-30', '2017-10-01', 'willn001', 'willini01', None, datetime.date(1993, 9, 8)),
#  ('williot01', 1877, 11, 2, 'USA', 'NJ', 'Newark', 1937, 3, 19, 'USA', 'NE', 'Omaha', 'Otto', 'Williams', 'Otto George', '165', '68', 'R', 'R', '1902-10-05', '1906-06-09', 'willo101', 'williot01', datetime.date(1937, 3, 19), datetime.date(1877, 11, 2)),
#  ('willipa01', 1913, 7, 17, 'USA', 'MS', 'Meridian', 1993, 11, 2, 'USA', 'MS', 'Meridian', 'Papa', 'Williams', 'Fred', '200', '73', 'R', 'R', '1945-04-19', '1945-07-08', 'willp102', 'willipa01', datetime.date(1993, 11, 2), datetime.date(1913, 7, 17)),
#  ('willipo01', 1874, 5, 19, 'USA', 'ME', 'Bowdoinham', 1959, 8, 4, 'USA', 'ME', 'Topsham', 'Pop', 'Williams', 'Walter Merrill', '190', '71', 'R', 'L', '1898-09-14', '1903-09-15', 'willp101', 'willipo01', datetime.date(1959, 8, 4), datetime.date(1874, 5, 19)),
#  ('willira01', 1975, 9, 18, 'USA', 'TX', 'Harlingen', None, None, None, '', '', '', 'Randy', 'Williams', 'Randall Duane', '200', '75', 'L', 'L', '2004-09-11', '2011-08-05', 'willr003', 'willira01', None, datetime.date(1975, 9, 18)),
#  ('willire01', 1960, 8, 29, 'USA', 'TN', 'Memphis', None, None, None, '', '', '', 'Reggie', 'Williams', 'Reginald Dewayne', '185', '71', 'R', 'R', '1985-09-02', '1988-10-02', 'willr001', 'willire01', None, datetime.date(1960, 8, 29)),
#  ('willire02', 1966, 5, 5, 'USA', 'SC', 'Laurens', None, None, None, '', '', '', 'Reggie', 'Williams', 'Reginald Bernard', '180', '73', 'B', 'R', '1992-09-08', '1999-07-25', 'willr002', 'willire02', None, datetime.date(1966, 5, 5)),
#  ('williri01', 1882, 1, 31, 'USA', 'IL', 'Carthage', 1933, 7, 23, 'USA', 'IA', 'Keokuk', 'Rip', 'Williams', 'Alva Mitchell', '187', '71', 'R', 'R', '1911-04-12', '1918-06-09', 'willr104', 'williri01', datetime.date(1933, 7, 23), datetime.date(1882, 1, 31)),
#  ('williri02', 1893, 12, 18, 'USA', 'CA', 'Santa Cruz', 1966, 4, 24, 'USA', 'AZ', 'Cottonwood', 'Rinaldo', 'Williams', 'Rinaldo Louis', '', '', 'L', 'R', '1914-10-08', '1914-10-10', 'willr103', 'williri02', datetime.date(1966, 4, 24), datetime.date(1893, 12, 18)),
#  ('williri03', 1952, 11, 9, 'USA', 'CA', 'Merced', None, None, None, '', '', '', 'Rick', 'Williams', 'Richard Allen', '180', '73', 'R', 'R', '1978-06-12', '1979-09-26', 'willr101', 'williri03', None, datetime.date(1952, 11, 9)),
#  ('willish01', 1971, 3, 10, 'USA', 'CA', 'Fresno', None, None, None, '', '', '', 'Shad', 'Williams', 'Shad Clayton', '185', '72', 'R', 'R', '1996-05-18', '1997-07-22', 'wills001', 'willish01', None, datetime.date(1971, 3, 10)),
#  ('willist01', 1892, 1, 31, 'USA', 'MT', 'Cascade', 1979, 6, 29, 'USA', 'MN', 'Deer River', 'Steamboat', 'Williams', 'Rees Gephardt', '170', '71', 'L', 'R', '1914-07-12', '1916-10-01', 'wills101', 'willist01', datetime.date(1979, 6, 29), datetime.date(1892, 1, 31)),
#  ('willist02', 1936, 9, 14, 'USA', 'NH', 'Enfield', None, None, None, '', '', '', 'Stan', 'Williams', 'Stanley Wilson', '230', '77', 'R', 'R', '1958-05-17', '1972-08-01', 'wills102', 'willist02', None, datetime.date(1936, 9, 14)),
#  ('willita01', 1991, 7, 21, 'USA', 'WA', 'Vancouver', None, None, None, '', '', '', 'Taylor', 'Williams', 'Taylor Grant', '195', '71', 'B', 'R', '2017-09-06', '2017-10-01', 'willt003', 'willita01', None, datetime.date(1991, 7, 21)),
#  ('willite01', 1918, 8, 30, 'USA', 'CA', 'San Diego', 2002, 7, 5, 'USA', 'FL', 'Inverness', 'Ted', 'Williams', 'Theodore Samuel', '205', '75', 'L', 'R', '1939-04-20', '1960-09-28', 'willt103', 'willite01', datetime.date(2002, 7, 5), datetime.date(1918, 8, 30)),
#  ('willito01', 1870, 8, 19, 'USA', 'OH', 'Minersville', 1940, 7, 27, 'USA', 'OH', 'Columbus', 'Tom', 'Williams', 'Thomas C.', '', '', '', '', '1892-05-01', '1893-09-14', 'willt101', 'willito01', datetime.date(1940, 7, 27), datetime.date(1870, 8, 19)),
#  ('willito02', 1971, 2, 13, 'USA', 'NY', 'Syracuse', None, None, None, '', '', '', 'Todd', 'Williams', 'Todd Michael', '185', '75', 'R', 'R', '1995-04-29', '2007-06-15', 'willt001', 'willito02', None, datetime.date(1971, 2, 13)),
#  ('willitr01', 1992, 4, 25, 'USA', 'CA', 'San Diego', None, None, None, '', '', '', 'Trevor', 'Williams', 'Trevor Anthony', '230', '75', 'R', 'R', '2016-09-07', '2017-09-26', 'willt002', 'willitr01', None, datetime.date(1992, 4, 25)),
#  ('williwa01', None, None, None, 'USA', 'PA', 'Philadelphia', None, None, None, '', '', '', 'Wash', 'Williams', 'Washington J.', '180', '71', '', '', '1884-08-05', '1885-06-08', 'willw102', 'williwa01', None, None),
#  ('williwa02', 1943, 12, 19, 'USA', 'TX', 'Brownwood', 2016, 1, 23, 'USA', 'TX', 'Abilene', 'Walt', 'Williams', 'Walter Allen', '165', '66', 'R', 'R', '1964-04-21', '1975-09-22', 'willw103', 'williwa02', datetime.date(2016, 1, 23), datetime.date(1943, 12, 19)),
#  ('williwo01', 1912, 8, 21, 'USA', 'VA', 'Pamplin', 1995, 2, 24, 'USA', 'VA', 'Appomattox', 'Woody', 'Williams', 'Woodrow Wilson', '175', '71', 'R', 'R', '1938-09-05', '1945-09-30', 'willw101', 'williwo01', datetime.date(1995, 2, 24), datetime.date(1912, 8, 21)),
#  ('williwo02', 1966, 8, 19, 'USA', 'TX', 'Houston', None, None, None, '', '', '', 'Woody', 'Williams', 'Gregory Scott', '180', '72', 'R', 'R', '1993-05-14', '2007-09-22', 'willw001', 'williwo02', None, datetime.date(1966, 8, 19))]

# %% [markdown]
# - I am using a special plug-in [ipython-sql](https://pypi.org/project/ipython-sql/) for running SQL directly from a code cell in the Jupyter notebook.
#
#
# - I can use the SQL command from many database clients.

# %% [markdown]
# | <img src="../../images/sql_query_1.jpeg"> |
# | :---: |
# | __Query MySQL Workbench__ |

# %% [markdown]
# | <img src="../../images/sql_select_terminal_1.jpeg"> |
# | :---: |
# | __Query MySQL Terminal Client__ |

# %% [markdown]
# - From Python code

# %%
import pymysql.cursors
import pandas as pd
import json

# The database server is running somewhere in the network.
# I must specify the IP address (HW server) and port number
# (connection that SW server is listening on)
# Also, I do not want to allow anyone to access the database
# and different people have different permissions. So, the
# client must log on.


# Connect to the database over the network. Use the connection
# to send commands to the DB.
default_cnx = pymysql.connect(host='localhost',
                             user='dbuser',
                             password='dbuser',
                             db='lahman2017',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)


def run_q(q, args=None, fields= None, fetch=True, cnx=None):
    """

    :param q: An SQL query string that may have %s slots for argument insertion.
    :param args: A tuple of values to insert in the %s slots.
    :param fetch: If true, return the result.
    :param cnx: A database connection. May be None
    :return: A result set or None.
    """

    try:
        if cnx is None:
            cnx = default_cnx

        if fields:
            q = q.format(",".join(fields))

        cursor=cnx.cursor()             # Just ignore this for now.

        print("Query = ", cursor.mogrify(q, args))
        cursor.execute(q, args)         # Execute the query.

        if fetch:
            r = cursor.fetchall()       # Return all elements of the result.
        else:
            r = None
    except Exception as e:
        print("Exception e = ", e)
        
    cnx.commit()

    return r

# %%
result = run_q("select * from people where nameLast='Williams';")
print("Result = ")
print(result)
# Out:
# Query =  select * from people where nameLast='Williams';
# Result =
# [{'playerID': 'williac01', 'birthYear': 1917, 'birthMonth': 3, 'birthDay': 18, 'birthCountry': 'USA', 'birthState': 'NJ', 'birthCity': 'Montclair', 'deathYear': 1999, 'deathMonth': 9, 'deathDay': 16, 'deathCountry': 'USA', 'deathState': 'FL', 'deathCity': 'Fort Myers', 'nameFirst': 'Ace', 'nameLast': 'Williams', 'nameGiven': 'Robert Fulton', 'weight': '174', 'height': '74', 'bats': 'R', 'throws': 'L', 'debut': '1940-07-15', 'finalGame': '1946-04-22', 'retroID': 'willa103', 'bbrefID': 'williac01', 'DOD': datetime.date(1999, 9, 16), 'DOB': datetime.date(1917, 3, 18)}, {'playerID': 'willial02', 'birthYear': 1914, 'birthMonth': 5, 'birthDay': 11, 'birthCountry': 'USA', 'birthState': 'AL', 'birthCity': 'Valhermosa Springs', 'deathYear': 1969, 'deathMonth': 7, 'deathDay': 19, 'deathCountry': 'USA', 'deathState': 'TX', 'deathCity': 'Groves', 'nameFirst': 'Al', 'nameLast': 'Williams', 'nameGiven': 'Almon Edward', 'weight': '200', 'height': '75', 'bats': 'R', 'throws': 'R', 'debut': '1937-04-19', 'finalGame': '1938-09-04', 'retroID': 'willa101', 'bbrefID': 'willial02', 'DOD': datetime.date(1969, 7, 19), 'DOB': datetime.date(1914, 5, 11)}, {'playerID': 'willial03', 'birthYear': 1954, 'birthMonth': 5, 'birthDay': 6, 'birthCountry': 'Nicaragua', 'birthState': 'Atlantico Sur', 'birthCity': 'Pearl Lagoon', 'deathYear': None, 'deathMonth': None, 'deathDay': None, 'deathCountry': '', 'deathState': '', 'deathCity': '', 'nameFirst': 'Albert', 'nameLast': 'Williams', 'nameGiven': 'Albert Hamilton', 'weight': '190', 'height': '76', 'bats': 'R', 'throws': 'R', 'debut': '1980-05-07', 'finalGame': '1984-09-26', 'retroID': 'willa001', 'bbrefID': 'willial03', 'DOD': None, 'DOB': datetime.date(1954, 5, 6)}, {'playerID': 'williar01', 'birthYear': 1877, 'birthMonth': 8, 'birthDay': 24, 'birthCountry': 'USA', 'birthState': 'MA', 'birthCity': 'Somerville', 'deathYear': 1941, 'deathMonth': 5, 'deathDay': 16, 'deathCountry': 'USA', 'deathState': 'VA', 'deathCity': 'Arlington', 'nameFirst': 'Art', 'nameLast': 'Williams', 'nameGiven': 'Arthur Frank', 'weight': '', 'height': '', 'bats': 'L', 'throws': 'R', 'debut': '1902-05-07', 'finalGame': '1902-09-01', 'retroID': 'willa104', 'bbrefID': 'williar01', 'DOD': datetime.date(1941, 5, 16), 'DOB': datetime.date(1877, 8, 24)}, {'playerID': 'willibe01', 'birthYear': 1948, 'birthMonth': 10, 'birthDay': 8, 'birthCountry': 'USA', 'birthState': 'CA', 'birthCity': 'Alameda', 'deathYear': None, 'deathMonth': None, 'deathDay': None, 'deathCountry': '', 'deathState': '', 'deathCity': '', 'nameFirst': 'Bernie', 'nameLast': 'Williams', 'nameGiven': 'Bernard', 'weight': '175', 'height': '73', 'bats': 'R', 'throws': 'R', 'debut': '1970-09-07', 'finalGame': '1974-05-12', 'retroID': 'willb105', 'bbrefID': 'willibe01', 'DOD': None, 'DOB': datetime.date(1948, 10, 8)}, {'playerID': 'willibe02', 'birthYear': 1968, 'birthMonth': 9, 'birthDay': 13, 'birthCountry': 'P.R.', 'birthState': '', 'birthCity': 'San Juan', 'deathYear': None, 'deathMonth': None, 'deathDay': None, 'deathCountry': '', 'deathState': '', 'deathCity': '', 'nameFirst': 'Bernie', 'nameLast': 'Williams', 'nameGiven': 'Bernabe', 'weight': '180', 'height': '74', 'bats': 'B', 'throws': 'R', 'debut': '1991-07-07', 'finalGame': '2006-10-01', 'retroID': 'willb002', 'bbrefID': 'willibe02', 'DOD': None, 'DOB': datetime.date(1968, 9, 13)}, {'playerID': 'willibi01', 'birthYear': 1938, 'birthMonth': 6, 'birthDay': 15, 'birthCountry': 'USA', 'birthState': 'AL', 'birthCity': 'Whistler', 'deathYear': None, 'deathMonth': None, 'deathDay': None, 'deathCountry': '', 'deathState': '', 'deathCity': '', 'nameFirst': 'Billy', 'nameLast': 'Williams', 'nameGiven': 'Billy Leo', 'weight': '175', 'height': '73', 'bats': 'L', 'throws': 'R', 'debut': '1959-08-06', 'finalGame': '1976-10-02', 'retroID': 'willb104', 'bbrefID': 'willibi01', 'DOD': None, 'DOB': datetime.date(1938, 6, 15)}, {'playerID': 'willibi02', 'birthYear': 1932, 'birthMonth': 6, 'birthDay': 13, 'birthCountry': 'USA', 'birthState': ' ...

# %% [markdown]
# - OK. That output is kind of icky.
#
#
# - The Python function json.dumps() makes the output a little cleaner.

# %% [markdown]
# <u>A more complex example that includes PROJECT</u>

# %%
q ='''SELECT nameLast as last_name, nameFirst as firstName, birthYear as birth_year  
    from people where 
    nameLast='Williams' and birthYear > '1920';'''
result = run_q(q)
print("Result = ")
print(json.dumps(result, indent=2))
# Out:
# Query =  SELECT nameLast as last_name, nameFirst as firstName, birthYear as birth_year
#     from people where
#     nameLast='Williams' and birthYear > '1920';
# Result =
# [
#   {
#     "last_name": "Williams",
#     "firstName": "Albert",
#     "birth_year": 1954
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Bernie",
#     "birth_year": 1948
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Bernie",
#     "birth_year": 1968
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Billy",
#     "birth_year": 1938
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Billy",
#     "birth_year": 1932
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Brian",
#     "birth_year": 1969
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Charlie",
#     "birth_year": 1947
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Davey",
#     "birth_year": 1927
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Dallas",
#     "birth_year": 1958
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Dana",
#     "birth_year": 1963
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "David",
#     "birth_year": 1979
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Dick",
#     "birth_year": 1929
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Don",
#     "birth_year": 1931
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Don",
#     "birth_year": 1935
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Earl",
#     "birth_year": 1948
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Eddie",
#     "birth_year": 1964
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Frank",
#     "birth_year": 1958
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "George",
#     "birth_year": 1939
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Gerald",
#     "birth_year": 1966
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "George",
#     "birth_year": 1969
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Glenn",
#     "birth_year": 1977
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Jackson",
#     "birth_year": 1986
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Jeff",
#     "birth_year": 1972
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Jerome",
#     "birth_year": 1981
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Jimy",
#     "birth_year": 1943
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Jim",
#     "birth_year": 1947
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Ken",
#     "birth_year": 1964
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Keith",
#     "birth_year": 1972
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Mark",
#     "birth_year": 1953
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Matt",
#     "birth_year": 1959
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Matt",
#     "birth_year": 1965
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Matt",
#     "birth_year": 1971
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Mason",
#     "birth_year": 1991
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Mitch",
#     "birth_year": 1964
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Mike",
#     "birth_year": 1968
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Nick",
#     "birth_year": 1993
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Randy",
#     "birth_year": 1975
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Reggie",
#     "birth_year": 1960
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Reggie",
#     "birth_year": 1966
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Rick",
#     "birth_year": 1952
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Shad",
#     "birth_year": 1971
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Stan",
#     "birth_year": 1936
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Taylor",
#     "birth_year": 1991
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Todd",
#     "birth_year": 1971
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Trevor",
#     "birth_year": 1992
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Walt",
#     "birth_year": 1943
#   },
#   {
#     "last_name": "Williams",
#     "firstName": "Woody",
#     "birth_year": 1966
#   }
# ]

# %% [markdown]
# <u>Using Arguments</u>
#
# - If you want to pass parameters into a query string, there are two options:
#     1. String concatentation functions.
#     2. %s templates and arguments
#
#
# - You cannot insert schema terms, like table name or columns using %s substitution. So, you using string formatting or concatenation.

# %%
q = "select {} from {} where nameLast=%s and throws=%s"
q2 = q.format(",".join(['playerId', 'nameLast', 'nameFirst', 'throws']), "People")
print("q2 = ", q2)
# Out:
# q2 =  select playerId,nameLast,nameFirst,throws from People where nameLast=%s and throws=%s

# %%
cur = default_cnx.cursor()
cur.execute(q2, ('Williams', 'R'))
result = cur.fetchall()
print("Result = ", json.dumps(result, indent=2))
# Out:
# Result =  [
#   {
#     "playerId": "willial02",
#     "nameLast": "Williams",
#     "nameFirst": "Al",
#     "throws": "R"
#   },
#   {
#     "playerId": "willial03",
#     "nameLast": "Williams",
#     "nameFirst": "Albert",
#     "throws": "R"
#   },
#   {
#     "playerId": "williar01",
#     "nameLast": "Williams",
#     "nameFirst": "Art",
#     "throws": "R"
#   },
#   {
#     "playerId": "willibe01",
#     "nameLast": "Williams",
#     "nameFirst": "Bernie",
#     "throws": "R"
#   },
#   {
#     "playerId": "willibe02",
#     "nameLast": "Williams",
#     "nameFirst": "Bernie",
#     "throws": "R"
#   },
#   {
#     "playerId": "willibi01",
#     "nameLast": "Williams",
#     "nameFirst": "Billy",
#     "throws": "R"
#   },
#   {
#     "playerId": "willibi02",
#     "nameLast": "Williams",
#     "nameFirst": "Billy",
#     "throws": "R"
#   },
#   {
#     "playerId": "willibo01",
#     "nameLast": "Williams",
#     "nameFirst": "Bob",
#     "throws": "R"
#   },
#   {
#     "playerId": "willibr01",
#     "nameLast": "Williams",
#     "nameFirst": "Brian",
#     "throws": "R"
#   },
#   {
#     "playerId": "willich01",
#     "nameLast": "Williams",
#     "nameFirst": "Charlie",
#     "throws": "R"
#   },
#   {
#     "playerId": "willida01",
#     "nameLast": "Williams",
#     "nameFirst": "Dale",
#     "throws": "R"
#   },
#   {
#     "playerId": "willida03",
#     "nameLast": "Williams",
#     "nameFirst": "Davey",
#     "throws": "R"
#   },
#   {
#     "playerId": "willida06",
#     "nameLast": "Williams",
#     "nameFirst": "Dana",
#     "throws": "R"
#   },
#   {
#     "playerId": "willide01",
#     "nameLast": "Williams",
#     "nameFirst": "Denny",
#     "throws": "R"
#   },
#   {
#     "playerId": "willide02",
#     "nameLast": "Williams",
#     "nameFirst": "Dewey",
#     "throws": "R"
#   },
#   {
#     "playerId": "willidi01",
#     "nameLast": "Williams",
#     "nameFirst": "Dib",
#     "throws": "R"
#   },
#   {
#     "playerId": "willidi02",
#     "nameLast": "Williams",
#     "nameFirst": "Dick",
#     "throws": "R"
#   },
#   {
#     "playerId": "willido01",
#     "nameLast": "Williams",
#     "nameFirst": "Don",
#     "throws": "R"
#   },
#   {
#     "playerId": "willido02",
#     "nameLast": "Williams",
#     "nameFirst": "Don",
#     "throws": "R"
#   },
#   {
#     "playerId": "williea01",
#     "nameLast": "Williams",
#     "nameFirst": "Earl",
#     "throws": "R"
#   },
#   {
#     "playerId": "williea02",
#     "nameLast": "Williams",
#     "nameFirst": "Earl",
#     "throws": "R"
#   },
#   {
#     "playerId": "willied01",
#     "nameLast": "Williams",
#     "nameFirst": "Eddie",
#     "throws": "R"
#   },
#   {
#     "playerId": "willifr01",
#     "nameLast": "Williams",
#     "nameFirst": "Frank",
#     "throws": "R"
#   },
#   {
#     "playerId": "willige01",
#     "nameLast": "Williams",
#     "nameFirst": "George",
#     "throws": "R"
#   },
#   {
#     "playerId": "willige02",
#     "nameLast": "Williams",
#     "nameFirst": "Gerald",
#     "throws": "R"
#   },
#   {
#     "playerId": "willige03",
#     "nameLast": "Williams",
#     "nameFirst": "George",
#     "throws": "R"
#   },
#   {
#     "playerId": "willigl01",
#     "nameLast": "Williams",
#     "nameFirst": "Glenn",
#     "throws": "R"
#   },
#   {
#     "playerId": "williha01",
#     "nameLast": "Williams",
#     "nameFirst": "Harry",
#     "throws": "R"
#   },
#   {
#     "playerId": "willija01",
#     "nameLast": "Williams",
#     "nameFirst": "Jackson",
#     "throws": "R"
#   },
#   {
#     "playerId": "willije02",
#     "nameLast": "Williams",
#     "nameFirst": "Jerome",
#     "throws": "R"
#   },
#   {
#     "playerId": "williji01",
#     "nameLast": "Williams",
#     "nameFirst": "Jimmy",
#     "throws": "R"
#   },
#   {
#     "playerId": "williji03",
#     "nameLast": "Williams",
#     "nameFirst": "Jimy",
#     "throws": "R"
#   },
#   {
#     "playerId": "williji04",
#     "nameLast": "Williams",
#     "nameFirst": "Jim",
#     "throws": "R"
#   },
#   {
#     "playerId": "willijo02",
#     "nameLast": "Williams",
#     "nameFirst": "Johnnie",
#     "throws": "R"
#   },
#   {
#     "playerId": "willijo99",
#     "nameLast": "Williams",
#     "nameFirst": "Smokey Joe",
#     "throws": "R"
#   },
#   {
#     "playerId": "willike01",
#     "nameLast": "Williams",
#     "nameFirst": "Ken",
#     "throws": "R"
#   },
#   {
#     "playerId": "willike02",
#     "nameLast": "Williams",
#     "nameFirst": "Ken",
#     "throws": "R"
#   },
#   {
#     "playerId": "willike03",
#     "nameLast": "Williams",
#     "nameFirst": "Keith",
#     "throws": "R"
#   },
#   {
#     "playerId": "willima01",
#     "nameLast": "Williams",
#     "nameFirst": "Marsh",
#     "throws": "R"
#   },
#   {
#     "playerId": "willima03",
#     "nameLast": "Williams",
#     "nameFirst": "Matt",
#     "throws": "R"
#   },
#   {
#     "playerId": "willima04",
#     "nameLast": "Williams",
#     "nameFirst": "Matt",
#     "throws": "R"
#   },
#   {
#     "playerId": "willima07",
#     "nameLast": "Williams",
#     "nameFirst": "Mason",
#     "throws": "R"
#   },
#   {
#     "playerId": "willimi03",
#     "nameLast": "Williams",
#     "nameFirst": "Mike",
#     "throws": "R"
#   },
#   {
#     "playerId": "willimu01",
#     "nameLast": "Williams",
#     "nameFirst": "Mutt",
#     "throws": "R"
#   },
#   {
#     "playerId": "williot01",
#     "nameLast": "Williams",
#     "nameFirst": "Otto",
#     "throws": "R"
#   },
#   {
#     "playerId": "willipa01",
#     "nameLast": "Williams",
#     "nameFirst": "Papa",
#     "throws": "R"
#   },
#   {
#     "playerId": "willire01",
#     "nameLast": "Williams",
#     "nameFirst": "Reggie",
#     "throws": "R"
#   },
#   {
#     "playerId": "willire02",
#     "nameLast": "Williams",
#     "nameFirst": "Reggie",
#     "throws": "R"
#   },
#   {
#     "playerId": "williri01",
#     "nameLast": "Williams",
#     "nameFirst": "Rip",
#     "throws": "R"
#   },
#   {
#     "playerId": "williri02",
#     "nameLast": "Williams",
#     "nameFirst": "Rinaldo",
#     "throws": "R"
#   },
#   {
#     "playerId": "williri03",
#     "nameLast": "Williams",
#     "nameFirst": "Rick",
#     "throws": "R"
#   },
#   {
#     "playerId": "willish01",
#     "nameLast": "Williams",
#     "nameFirst": "Shad",
#     "throws": "R"
#   },
#   {
#     "playerId": "willist01",
#     "nameLast": "Williams",
#     "nameFirst": "Steamboat",
#     "throws": "R"
#   },
#   {
#     "playerId": "willist02",
#     "nameLast": "Williams",
#     "nameFirst": "Stan",
#     "throws": "R"
#   },
#   {
#     "playerId": "willita01",
#     "nameLast": "Williams",
#     "nameFirst": "Taylor",
#     "throws": "R"
#   },
#   {
#     "playerId": "willite01",
#     "nameLast": "Williams",
#     "nameFirst": "Ted",
#     "throws": "R"
#   },
#   {
#     "playerId": "willito02",
#     "nameLast": "Williams",
#     "nameFirst": "Todd",
#     "throws": "R"
#   },
#   {
#     "playerId": "willitr01",
#     "nameLast": "Williams",
#     "nameFirst": "Trevor",
#     "throws": "R"
#   },
#   {
#     "playerId": "williwa02",
#     "nameLast": "Williams",
#     "nameFirst": "Walt",
#     "throws": "R"
#   },
#   {
#     "playerId": "williwo01",
#     "nameLast": "Williams",
#     "nameFirst": "Woody",
#     "throws": "R"
#   },
#   {
#     "playerId": "williwo02",
#     "nameLast": "Williams",
#     "nameFirst": "Woody",
#     "throws": "R"
#   }
# ]

# %% [markdown]
# ## A Digression on the Power of SQL
#
# - CourseWorks (Canvass) has a basic REST API for querying and updating information about courses, students, ...
#
#
# - More complex understanding of the data requires:
#     - Making GET calls to retrieve the information using query parameters.
#     - Writing a program to process the data to answer complex questions.
#
#
# - SQL provides simpler (once you understand it), more compact ways to analyze data than writing Python, Java, etc. programs.
#
#
# - To show with an example,
#     - I wrote a Python program to query and download information from CourseWorks/Canvass.
#     - Create and load the data into MySQL tables.
#
#
# - What does the data look like?
#
# <hr style="height:1px;">
#
# | <img src="../../images/cw_er_model.jpg"> |
# | :---: |
# | __My CourseWorks Data Model__ |
#
# <hr style="height:1px;">

# %% [markdown]
# - The notation in the diagram is an example of [Crow's Foot Notation.](https://www.vertabelo.com/blog/technical-articles/crow-s-foot-notation).
#
#
# - We will go through the meanings, patterns, etc. later.
#
#
# - The CourseWorks REST API allows me to query what classes I have taken/taught, which students have been in which classes, etc.
#
#
# - I cannot ask interesting questions about complex combinations of the data.
#
#
# - <u>Question 1: "Who is the bravest person in the world?"</u> The answer is the person who has taken the most courses with me.

# %%
# %%sql
# select last_name, first_name, count(*) as number_of_courses from w4111f19.student_course_view
#     group by student_id
#     having number_of_courses > 2
#     order by count(*) desc
#     limit 5;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 3 rows affected.
# [('Gupta', ' Abhi', 4), ('Liu', ' Sen', 3), ('Ontiveros', ' Bryan', 3)]

# %% [markdown]
# - I will not bore you with more Python code, but doing this on the REST APIs alone would be tedious.
#
#
# - The RDB query engine executes the diagram below to produce the result. You can think of each rectangle as being a block of code that you would have to write.
#
#
# <hr style="height:1px;">
#
# | <img src="../../images/query_execution.jpg" width="700px;"> |
# | :---: |
# | __Query Execution Plan__ |
#
# <hr style="height:1px;">

# %% [markdown]
# - <u>Question 1: "Who is in this class and has previously taken a class with me? Maybe they can help you."</u>

# %%
# %%sql
# use w4111f19;
#
# SELECT
# 	first_name, count(*) as count, group_concat(course_code_full separator ", ") as course_codes_full
# FROM
# 	student_course_view
# where
# 	student_id in ( select student_id from student_course_view where course_id='85777' or course_id='91884')
#     and
#     student_id in (select student_id from student_course_view where year < 2019 or (semester < 3 and year = 2019))
# group by
# 	user_id, last_name, first_name
# having count > 1
# order by count desc;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 0 rows affected.
# 9 rows affected.
# [(' Samantha', 2, 'ENGIE1006_001_2018_1 - INTRO TO COMP FOR ENG/APP SCI, COMSW4111_002_2019_3 - INTRODUCTION TO DATABASES'),
#  (' Sharon', 2, 'ENGIE1006_001_2018_1 - INTRO TO COMP FOR ENG/APP SCI, COMSW4111_002_2019_3 - INTRODUCTION TO DATABASES'),
#  (' Ahmed', 2, 'ENGIE1102_001_2018_3 - THE ART OF ENGINEERING, COMSW4111_002_2019_3 - INTRODUCTION TO DATABASES'),
#  (' Joshua', 2, 'ENGIE1006_001_2018_1 - INTRO TO COMP FOR ENG/APP SCI, COMSW4111_002_2019_3 - INTRODUCTION TO DATABASES'),
#  (' Bradley', 2, 'ENGIE1006_001_2018_1 - INTRO TO COMP FOR ENG/APP SCI, COMSW4111_002_2019_3 - INTRODUCTION TO DATABASES'),
#  (' Derek', 2, 'ENGIE1006_001_2018_1 - INTRO TO COMP FOR ENG/APP SCI, COMSW4111_002_2019_3 - INTRODUCTION TO DATABASES'),
#  (' Jetasri', 2, 'ENGIE1006_001_2018_1 - INTRO TO COMP FOR ENG/APP SCI, COMSW4111_002_2019_3 - INTRODUCTION TO DATABASES'),
#  (' Jillian', 2, 'ENGIE1006_001_2018_1 - INTRO TO COMP FOR ENG/APP SCI, COMSW4111_002_2019_3 - INTRODUCTION TO DATABASES'),
#  (' Lara', 2, 'ENGIE1006_001_2018_1 - INTRO TO COMP FOR ENG/APP SCI, COMSW4111_002_2019_3 - INTRODUCTION TO DATABASES')]

# %% [markdown]
# - That SQL statement may seem complex until you realize the equivalent code algorithm is something like ...
#
# <hr style="height:1px;">
#
# | <img src="../../images/explain_2.png" width="900px;"> |
# | :---: |
# | __Query Execution Plan__ |
#
# <hr style="height:1px;">

# %% [markdown]
# ## Connections, Cursors and Fetch...
#
# - We previously, briefly discussed connections.
#
#
# - Section 6.1.2 in Ramakrishnan and Gherke discuss cursors (p. 189, 191)
#
#
# "SQL is a set-based language, meaning operations are completed on all or rows of the result.  However, there are times, when you want to do operation on a row by row basis.  This is where cursors come in to play.
#
# ... ...
#
# A database cursor can be thought of as a pointer to a specific row within a query result.  The pointer can be moved from one row to the next.  Depending on the type of cursor, you may be even able to move it to the previous row." (https://www.essentialsql.com/database-cursor/)
#
#
# - Cursors are fundamental to relational database APIs, and many other types of databases.
#
#
# - The details are often hidden and not explicit, and programmers use them in advanced scenarios. But, they are always (logically) created.
#
#
# | <img src="../../images/cursor.png"> |
# | :---: |
# | [Cursor Concept](https://codeandwork.github.io/courses/java/sp_cursors_triggers_indexes.html) |

# %% [markdown]
# - Concept is similar to an iterator in programming languages/libraries.
#
#
# - ```cursor.execute(...)``` sends the command to the database and produces the result set. The common operations on the result set are:
#     - ```fetchall()```
#     - ```fetchone()```
#     - ```fetchmany(size=...)```
#
#
# - ```cursor.mogrify(q, args)``` returns the actual query string that will be sent to the database.
#
#
# - The details are PyMySQL library specific but the concepts apply in general to all connection libraries.
#
#
# - A simple example:

# %%
import pymysql
default_cnx = pymysql.connect(host='localhost',
                             user='dbuser',
                             password='dbuserdbuser',
                             db='lahman2019raw',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)

# %%
cur = default_cnx.cursor()
how_many = cur.execute("select * from people where nameLast='Smith'")
print("The query produced", how_many, "rows.")
# Out:
# The query produced 162 rows.

# %%
import json
all_result = cur.fetchall()
print("Fetch all returns a list of size: ", len(all_result))
print("The result set is = \n", json.dumps(all_result, indent=2))
# Out:
# Fetch all returns a list of size:  162
# The result set is =
#  [
#   {
#     "playerID": "smith01",
#     "birthYear": "",
#     "birthMonth": "",
#     "birthDay": "",
#     "birthCountry": "",
#     "birthState": "",
#     "birthCity": "",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "",
#     "nameLast": "Smith",
#     "nameGiven": "",
#     "weight": "",
#     "height": "",
#     "bats": "",
#     "throws": "",
#     "debut": "1884-06-05",
#     "finalGame": "1884-06-05",
#     "retroID": "smitu101",
#     "bbrefID": "smith01"
#   },
#   {
#     "playerID": "smithal01",
#     "birthYear": "1871",
#     "birthMonth": "",
#     "birthDay": "",
#     "birthCountry": "USA",
#     "birthState": "NY",
#     "birthCity": "New York",
#     "deathYear": "1919",
#     "deathMonth": "7",
#     "deathDay": "9",
#     "deathCountry": "USA",
#     "deathState": "NY",
#     "deathCity": "New York",
#     "nameFirst": "Aleck",
#     "nameLast": "Smith",
#     "nameGiven": "Alexander Benjamin",
#     "weight": "",
#     "height": "",
#     "bats": "",
#     "throws": "R",
#     "debut": "1897-04-23",
#     "finalGame": "1906-10-05",
#     "retroID": "smita105",
#     "bbrefID": "smithal01"
#   },
#   {
#     "playerID": "smithal02",
#     "birthYear": "1903",
#     "birthMonth": "12",
#     "birthDay": "13",
#     "birthCountry": "USA",
#     "birthState": "PA",
#     "birthCity": "Norristown",
#     "deathYear": "1995",
#     "deathMonth": "8",
#     "deathDay": "11",
#     "deathCountry": "USA",
#     "deathState": "CA",
#     "deathCity": "San Diego",
#     "nameFirst": "Al",
#     "nameLast": "Smith",
#     "nameGiven": "Alfred Kendricks",
#     "weight": "170",
#     "height": "72",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1926-06-18",
#     "finalGame": "1926-06-18",
#     "retroID": "smita103",
#     "bbrefID": "smithal02"
#   },
#   {
#     "playerID": "smithal03",
#     "birthYear": "1907",
#     "birthMonth": "10",
#     "birthDay": "12",
#     "birthCountry": "USA",
#     "birthState": "IL",
#     "birthCity": "Belleville",
#     "deathYear": "1977",
#     "deathMonth": "4",
#     "deathDay": "28",
#     "deathCountry": "USA",
#     "deathState": "TX",
#     "deathCity": "Brownsville",
#     "nameFirst": "Al",
#     "nameLast": "Smith",
#     "nameGiven": "Alfred John",
#     "weight": "180",
#     "height": "71",
#     "bats": "L",
#     "throws": "L",
#     "debut": "1934-05-05",
#     "finalGame": "1945-09-15",
#     "retroID": "smita104",
#     "bbrefID": "smithal03"
#   },
#   {
#     "playerID": "smithal04",
#     "birthYear": "1928",
#     "birthMonth": "2",
#     "birthDay": "7",
#     "birthCountry": "USA",
#     "birthState": "MO",
#     "birthCity": "Kirkwood",
#     "deathYear": "2002",
#     "deathMonth": "1",
#     "deathDay": "3",
#     "deathCountry": "USA",
#     "deathState": "IN",
#     "deathCity": "Hammond",
#     "nameFirst": "Al",
#     "nameLast": "Smith",
#     "nameGiven": "Alphonse Eugene",
#     "weight": "189",
#     "height": "72",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1953-07-10",
#     "finalGame": "1964-10-04",
#     "retroID": "smita102",
#     "bbrefID": "smithal04"
#   },
#   {
#     "playerID": "smithar01",
#     "birthYear": "1906",
#     "birthMonth": "6",
#     "birthDay": "21",
#     "birthCountry": "USA",
#     "birthState": "MA",
#     "birthCity": "Boston",
#     "deathYear": "1995",
#     "deathMonth": "11",
#     "deathDay": "22",
#     "deathCountry": "USA",
#     "deathState": "CT",
#     "deathCity": "Norwalk",
#     "nameFirst": "Art",
#     "nameLast": "Smith",
#     "nameGiven": "Arthur Laird",
#     "weight": "175",
#     "height": "72",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1932-06-09",
#     "finalGame": "1932-06-20",
#     "retroID": "smita101",
#     "bbrefID": "smithar01"
#   },
#   {
#     "playerID": "smithbe01",
#     "birthYear": "1941",
#     "birthMonth": "9",
#     "birthDay": "4",
#     "birthCountry": "USA",
#     "birthState": "LA",
#     "birthCity": "Ponchatoula",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Bernie",
#     "nameLast": "Smith",
#     "nameGiven": "Calvin Bernard",
#     "weight": "164",
#     "height": "69",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1970-07-31",
#     "finalGame": "1971-04-28",
#     "retroID": "smitb105",
#     "bbrefID": "smithbe01"
#   },
#   {
#     "playerID": "smithbi01",
#     "birthYear": "",
#     "birthMonth": "",
#     "birthDay": "",
#     "birthCountry": "USA",
#     "birthState": "MD",
#     "birthCity": "Baltimore",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Bill",
#     "nameLast": "Smith",
#     "nameGiven": "William J.",
#     "weight": "",
#     "height": "",
#     "bats": "",
#     "throws": "",
#     "debut": "1873-04-14",
#     "finalGame": "1873-07-11",
#     "retroID": "smitb113",
#     "bbrefID": "smithbi01"
#   },
#   {
#     "playerID": "smithbi02",
#     "birthYear": "1865",
#     "birthMonth": "",
#     "birthDay": "",
#     "birthCountry": "USA",
#     "birthState": "OH",
#     "birthCity": "Cleveland",
#     "deathYear": "1886",
#     "deathMonth": "8",
#     "deathDay": "9",
#     "deathCountry": "CAN",
#     "deathState": "ON",
#     "deathCity": "Toronto",
#     "nameFirst": "Bill",
#     "nameLast": "Smith",
#     "nameGiven": "William E.",
#     "weight": "178",
#     "height": "71",
#     "bats": "",
#     "throws": "",
#     "debut": "1884-09-17",
#     "finalGame": "1884-09-17",
#     "retroID": "smitb107",
#     "bbrefID": "smithbi02"
#   },
#   {
#     "playerID": "smithbi03",
#     "birthYear": "1861",
#     "birthMonth": "4",
#     "birthDay": "",
#     "birthCountry": "USA",
#     "birthState": "LA",
#     "birthCity": "New Orleans",
#     "deathYear": "1928",
#     "deathMonth": "5",
#     "deathDay": "24",
#     "deathCountry": "USA",
#     "deathState": "LA",
#     "deathCity": "New Orleans",
#     "nameFirst": "Billy",
#     "nameLast": "Smith",
#     "nameGiven": "Frederick William",
#     "weight": "152",
#     "height": "68",
#     "bats": "",
#     "throws": "R",
#     "debut": "1886-07-06",
#     "finalGame": "1886-09-13",
#     "retroID": "schmb104",
#     "bbrefID": "smithbi03"
#   },
#   {
#     "playerID": "smithbi04",
#     "birthYear": "1934",
#     "birthMonth": "6",
#     "birthDay": "8",
#     "birthCountry": "USA",
#     "birthState": "DC",
#     "birthCity": "Washington",
#     "deathYear": "1997",
#     "deathMonth": "3",
#     "deathDay": "30",
#     "deathCountry": "USA",
#     "deathState": "MD",
#     "deathCity": "Clinton",
#     "nameFirst": "Bill",
#     "nameLast": "Smith",
#     "nameGiven": "William Garland",
#     "weight": "190",
#     "height": "72",
#     "bats": "L",
#     "throws": "L",
#     "debut": "1958-09-13",
#     "finalGame": "1962-09-28",
#     "retroID": "smitb112",
#     "bbrefID": "smithbi04"
#   },
#   {
#     "playerID": "smithbi05",
#     "birthYear": "1953",
#     "birthMonth": "7",
#     "birthDay": "14",
#     "birthCountry": "USA",
#     "birthState": "LA",
#     "birthCity": "Hodge",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Billy",
#     "nameLast": "Smith",
#     "nameGiven": "Billy Edward",
#     "weight": "185",
#     "height": "74",
#     "bats": "B",
#     "throws": "R",
#     "debut": "1975-04-13",
#     "finalGame": "1981-09-24",
#     "retroID": "smitb101",
#     "bbrefID": "smithbi05"
#   },
#   {
#     "playerID": "smithbi06",
#     "birthYear": "1954",
#     "birthMonth": "9",
#     "birthDay": "13",
#     "birthCountry": "USA",
#     "birthState": "TX",
#     "birthCity": "La Marque",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Billy",
#     "nameLast": "Smith",
#     "nameGiven": "Billy Lavern",
#     "weight": "200",
#     "height": "79",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1981-06-09",
#     "finalGame": "1981-10-03",
#     "retroID": "smitb102",
#     "bbrefID": "smithbi06"
#   },
#   {
#     "playerID": "smithbl01",
#     "birthYear": "1987",
#     "birthMonth": "12",
#     "birthDay": "9",
#     "birthCountry": "USA",
#     "birthState": "CA",
#     "birthCity": "Modesto",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Blake",
#     "nameLast": "Smith",
#     "nameGiven": "Blake Matthew",
#     "weight": "220",
#     "height": "74",
#     "bats": "L",
#     "throws": "R",
#     "debut": "2016-09-10",
#     "finalGame": "2016-09-21",
#     "retroID": "smitb006",
#     "bbrefID": "smithbl01"
#   },
#   {
#     "playerID": "smithbo01",
#     "birthYear": "1890",
#     "birthMonth": "7",
#     "birthDay": "19",
#     "birthCountry": "USA",
#     "birthState": "VT",
#     "birthCity": "Woodbury",
#     "deathYear": "1965",
#     "deathMonth": "12",
#     "deathDay": "27",
#     "deathCountry": "USA",
#     "deathState": "CA",
#     "deathCity": "West Los Angeles",
#     "nameFirst": "Bob",
#     "nameLast": "Smith",
#     "nameGiven": "Robert Ashley",
#     "weight": "160",
#     "height": "71",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1913-04-19",
#     "finalGame": "1915-04-19",
#     "retroID": "smitb103",
#     "bbrefID": "smithbo01"
#   },
#   {
#     "playerID": "smithbo02",
#     "birthYear": "1895",
#     "birthMonth": "4",
#     "birthDay": "22",
#     "birthCountry": "USA",
#     "birthState": "TN",
#     "birthCity": "Rogersville",
#     "deathYear": "1987",
#     "deathMonth": "7",
#     "deathDay": "19",
#     "deathCountry": "USA",
#     "deathState": "GA",
#     "deathCity": "Waycross",
#     "nameFirst": "Bob",
#     "nameLast": "Smith",
#     "nameGiven": "Robert Eldridge",
#     "weight": "175",
#     "height": "70",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1923-04-19",
#     "finalGame": "1937-08-06",
#     "retroID": "smitb110",
#     "bbrefID": "smithbo02"
#   },
#   {
#     "playerID": "smithbo03",
#     "birthYear": "1930",
#     "birthMonth": "2",
#     "birthDay": "1",
#     "birthCountry": "USA",
#     "birthState": "NH",
#     "birthCity": "Woodsville",
#     "deathYear": "2013",
#     "deathMonth": "4",
#     "deathDay": "1",
#     "deathCountry": "USA",
#     "deathState": "GA",
#     "deathCity": "Augusta",
#     "nameFirst": "Bob",
#     "nameLast": "Smith",
#     "nameGiven": "Robert Gilchrist",
#     "weight": "190",
#     "height": "73",
#     "bats": "R",
#     "throws": "L",
#     "debut": "1955-04-29",
#     "finalGame": "1959-09-23",
#     "retroID": "smitb109",
#     "bbrefID": "smithbo03"
#   },
#   {
#     "playerID": "smithbo04",
#     "birthYear": "1934",
#     "birthMonth": "5",
#     "birthDay": "28",
#     "birthCountry": "USA",
#     "birthState": "OR",
#     "birthCity": "Hood River",
#     "deathYear": "2015",
#     "deathMonth": "11",
#     "deathDay": "24",
#     "deathCountry": "USA",
#     "deathState": "OR",
#     "deathCity": "Hood River",
#     "nameFirst": "Bobby",
#     "nameLast": "Smith",
#     "nameGiven": "Bobby Gene",
#     "weight": "180",
#     "height": "71",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1957-04-16",
#     "finalGame": "1965-07-17",
#     "retroID": "smitb104",
#     "bbrefID": "smithbo04"
#   },
#   {
#     "playerID": "smithbo05",
#     "birthYear": "1928",
#     "birthMonth": "5",
#     "birthDay": "13",
#     "birthCountry": "USA",
#     "birthState": "MO",
#     "birthCity": "Clarence",
#     "deathYear": "2003",
#     "deathMonth": "6",
#     "deathDay": "23",
#     "deathCountry": "USA",
#     "deathState": "MO",
#     "deathCity": "Clarence",
#     "nameFirst": "Bob",
#     "nameLast": "Smith",
#     "nameGiven": "Robert Walkup",
#     "weight": "185",
#     "height": "72",
#     "bats": "R",
#     "throws": "L",
#     "debut": "1958-04-22",
#     "finalGame": "1959-09-27",
#     "retroID": "smitb108",
#     "bbrefID": "smithbo05"
#   },
#   {
#     "playerID": "smithbo06",
#     "birthYear": "1974",
#     "birthMonth": "5",
#     "birthDay": "10",
#     "birthCountry": "USA",
#     "birthState": "CA",
#     "birthCity": "Oakland",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Bob",
#     "nameLast": "Smith",
#     "nameGiven": "Robert Eugene",
#     "weight": "190",
#     "height": "75",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1998-03-31",
#     "finalGame": "2002-05-06",
#     "retroID": "smitr003",
#     "bbrefID": "smithbo06"
#   },
#   {
#     "playerID": "smithbr01",
#     "birthYear": "1955",
#     "birthMonth": "8",
#     "birthDay": "11",
#     "birthCountry": "USA",
#     "birthState": "GA",
#     "birthCity": "Marietta",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Bryn",
#     "nameLast": "Smith",
#     "nameGiven": "Bryn Nelson",
#     "weight": "200",
#     "height": "74",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1981-09-08",
#     "finalGame": "1993-06-01",
#     "retroID": "smitb001",
#     "bbrefID": "smithbr01"
#   },
#   {
#     "playerID": "smithbr02",
#     "birthYear": "1959",
#     "birthMonth": "5",
#     "birthDay": "2",
#     "birthCountry": "USA",
#     "birthState": "NC",
#     "birthCity": "Charlotte",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Brick",
#     "nameLast": "Smith",
#     "nameGiven": "Brick Dudley",
#     "weight": "225",
#     "height": "76",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1987-09-13",
#     "finalGame": "1988-04-23",
#     "retroID": "smitb002",
#     "bbrefID": "smithbr02"
#   },
#   {
#     "playerID": "smithbr03",
#     "birthYear": "1972",
#     "birthMonth": "7",
#     "birthDay": "19",
#     "birthCountry": "USA",
#     "birthState": "NC",
#     "birthCity": "Salisbury",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Brian",
#     "nameLast": "Smith",
#     "nameGiven": "Randall Brian",
#     "weight": "185",
#     "height": "71",
#     "bats": "R",
#     "throws": "R",
#     "debut": "2000-09-11",
#     "finalGame": "2000-09-15",
#     "retroID": "smitb003",
#     "bbrefID": "smithbr03"
#   },
#   {
#     "playerID": "smithbu01",
#     "birthYear": "1880",
#     "birthMonth": "8",
#     "birthDay": "20",
#     "birthCountry": "USA",
#     "birthState": "WV",
#     "birthCity": "Plum",
#     "deathYear": "1928",
#     "deathMonth": "5",
#     "deathDay": "1",
#     "deathCountry": "USA",
#     "deathState": "WV",
#     "deathCity": "Charleston",
#     "nameFirst": "Bull",
#     "nameLast": "Smith",
#     "nameGiven": "Lewis Oscar",
#     "weight": "180",
#     "height": "72",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1904-08-30",
#     "finalGame": "1911-08-30",
#     "retroID": "smitb111",
#     "bbrefID": "smithbu01"
#   },
#   {
#     "playerID": "smithbu02",
#     "birthYear": "1979",
#     "birthMonth": "10",
#     "birthDay": "23",
#     "birthCountry": "USA",
#     "birthState": "CA",
#     "birthCity": "Torrance",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Bud",
#     "nameLast": "Smith",
#     "nameGiven": "Robert Allan",
#     "weight": "170",
#     "height": "72",
#     "bats": "L",
#     "throws": "L",
#     "debut": "2001-06-10",
#     "finalGame": "2002-07-19",
#     "retroID": "smitb004",
#     "bbrefID": "smithbu02"
#   },
#   {
#     "playerID": "smithbu03",
#     "birthYear": "1990",
#     "birthMonth": "4",
#     "birthDay": "12",
#     "birthCountry": "USA",
#     "birthState": "TX",
#     "birthCity": "San Antonio",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Burch",
#     "nameLast": "Smith",
#     "nameGiven": "Burch Taylor",
#     "weight": "225",
#     "height": "76",
#     "bats": "R",
#     "throws": "R",
#     "debut": "2013-05-11",
#     "finalGame": "2018-09-28",
#     "retroID": "smitb005",
#     "bbrefID": "smithbu03"
#   },
#   {
#     "playerID": "smithca01",
#     "birthYear": "1901",
#     "birthMonth": "4",
#     "birthDay": "8",
#     "birthCountry": "USA",
#     "birthState": "NC",
#     "birthCity": "Kernersville",
#     "deathYear": "1989",
#     "deathMonth": "4",
#     "deathDay": "14",
#     "deathCountry": "USA",
#     "deathState": "FL",
#     "deathCity": "Miami",
#     "nameFirst": "Carr",
#     "nameLast": "Smith",
#     "nameGiven": "Emanuel Carr",
#     "weight": "175",
#     "height": "73",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1923-09-23",
#     "finalGame": "1924-06-09",
#     "retroID": "smitc103",
#     "bbrefID": "smithca01"
#   },
#   {
#     "playerID": "smithca02",
#     "birthYear": "1989",
#     "birthMonth": "10",
#     "birthDay": "19",
#     "birthCountry": "USA",
#     "birthState": "TX",
#     "birthCity": "Midland",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Carson",
#     "nameLast": "Smith",
#     "nameGiven": "Carson Donald",
#     "weight": "215",
#     "height": "78",
#     "bats": "R",
#     "throws": "R",
#     "debut": "2014-09-01",
#     "finalGame": "2018-05-14",
#     "retroID": "smitc004",
#     "bbrefID": "smithca02"
#   },
#   {
#     "playerID": "smithca03",
#     "birthYear": "1991",
#     "birthMonth": "7",
#     "birthDay": "28",
#     "birthCountry": "USA",
#     "birthState": "TX",
#     "birthCity": "Huntsville",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Caleb",
#     "nameLast": "Smith",
#     "nameGiven": "Caleb Anthony",
#     "weight": "205",
#     "height": "74",
#     "bats": "R",
#     "throws": "L",
#     "debut": "2017-07-17",
#     "finalGame": "2018-06-24",
#     "retroID": "smitc006",
#     "bbrefID": "smithca03"
#   },
#   {
#     "playerID": "smithch01",
#     "birthYear": "1840",
#     "birthMonth": "12",
#     "birthDay": "11",
#     "birthCountry": "USA",
#     "birthState": "NY",
#     "birthCity": "Brooklyn",
#     "deathYear": "1897",
#     "deathMonth": "11",
#     "deathDay": "15",
#     "deathCountry": "USA",
#     "deathState": "NY",
#     "deathCity": "Great Neck",
#     "nameFirst": "Charlie",
#     "nameLast": "Smith",
#     "nameGiven": "Charles J.",
#     "weight": "150",
#     "height": "70",
#     "bats": "",
#     "throws": "",
#     "debut": "1871-05-18",
#     "finalGame": "1871-08-01",
#     "retroID": "smitc106",
#     "bbrefID": "smithch01"
#   },
#   {
#     "playerID": "smithch02",
#     "birthYear": "1880",
#     "birthMonth": "4",
#     "birthDay": "20",
#     "birthCountry": "USA",
#     "birthState": "OH",
#     "birthCity": "Cleveland",
#     "deathYear": "1929",
#     "deathMonth": "1",
#     "deathDay": "3",
#     "deathCountry": "USA",
#     "deathState": "OH",
#     "deathCity": "Wickliffe",
#     "nameFirst": "Charlie",
#     "nameLast": "Smith",
#     "nameGiven": "Charles Edwin",
#     "weight": "185",
#     "height": "73",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1902-08-06",
#     "finalGame": "1914-09-19",
#     "retroID": "smitc107",
#     "bbrefID": "smithch02"
#   },
#   {
#     "playerID": "smithch03",
#     "birthYear": "1892",
#     "birthMonth": "12",
#     "birthDay": "2",
#     "birthCountry": "USA",
#     "birthState": "KY",
#     "birthCity": "Dayton",
#     "deathYear": "1935",
#     "deathMonth": "10",
#     "deathDay": "11",
#     "deathCountry": "USA",
#     "deathState": "KY",
#     "deathCity": "Dayton",
#     "nameFirst": "Chick",
#     "nameLast": "Smith",
#     "nameGiven": "John William",
#     "weight": "165",
#     "height": "68",
#     "bats": "L",
#     "throws": "L",
#     "debut": "1913-04-12",
#     "finalGame": "1913-05-21",
#     "retroID": "smitc102",
#     "bbrefID": "smithch03"
#   },
#   {
#     "playerID": "smithch04",
#     "birthYear": "1937",
#     "birthMonth": "9",
#     "birthDay": "15",
#     "birthCountry": "USA",
#     "birthState": "SC",
#     "birthCity": "Charleston",
#     "deathYear": "1994",
#     "deathMonth": "11",
#     "deathDay": "29",
#     "deathCountry": "USA",
#     "deathState": "NV",
#     "deathCity": "Reno",
#     "nameFirst": "Charley",
#     "nameLast": "Smith",
#     "nameGiven": "Charles William",
#     "weight": "170",
#     "height": "73",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1960-09-08",
#     "finalGame": "1969-04-22",
#     "retroID": "smitc105",
#     "bbrefID": "smithch04"
#   },
#   {
#     "playerID": "smithch05",
#     "birthYear": "1957",
#     "birthMonth": "7",
#     "birthDay": "18",
#     "birthCountry": "USA",
#     "birthState": "CA",
#     "birthCity": "Torrance",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Chris",
#     "nameLast": "Smith",
#     "nameGiven": "Christopher William",
#     "weight": "185",
#     "height": "72",
#     "bats": "B",
#     "throws": "R",
#     "debut": "1981-05-14",
#     "finalGame": "1983-10-02",
#     "retroID": "smitc101",
#     "bbrefID": "smithch05"
#   },
#   {
#     "playerID": "smithch06",
#     "birthYear": "1969",
#     "birthMonth": "10",
#     "birthDay": "21",
#     "birthCountry": "USA",
#     "birthState": "TN",
#     "birthCity": "Memphis",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Chuck",
#     "nameLast": "Smith",
#     "nameGiven": "Charles Edward",
#     "weight": "185",
#     "height": "73",
#     "bats": "R",
#     "throws": "R",
#     "debut": "2000-06-13",
#     "finalGame": "2001-07-24",
#     "retroID": "smitc001",
#     "bbrefID": "smithch07"
#   },
#   {
#     "playerID": "smithch07",
#     "birthYear": "1981",
#     "birthMonth": "4",
#     "birthDay": "9",
#     "birthCountry": "USA",
#     "birthState": "CA",
#     "birthCity": "Apple Valley",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Chris",
#     "nameLast": "Smith",
#     "nameGiven": "Christopher Michael",
#     "weight": "190",
#     "height": "72",
#     "bats": "R",
#     "throws": "R",
#     "debut": "2008-06-21",
#     "finalGame": "2017-09-30",
#     "retroID": "smitc002",
#     "bbrefID": "smithch08"
#   },
#   {
#     "playerID": "smithch08",
#     "birthYear": "1989",
#     "birthMonth": "10",
#     "birthDay": "2",
#     "birthCountry": "USA",
#     "birthState": "CA",
#     "birthCity": "Thousand Oaks",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Chad",
#     "nameLast": "Smith",
#     "nameGiven": "Chad Dennis",
#     "weight": "220",
#     "height": "75",
#     "bats": "L",
#     "throws": "R",
#     "debut": "2014-06-22",
#     "finalGame": "2015-05-06",
#     "retroID": "smitc003",
#     "bbrefID": "smithch09"
#   },
#   {
#     "playerID": "smithch09",
#     "birthYear": "1988",
#     "birthMonth": "8",
#     "birthDay": "19",
#     "birthCountry": "USA",
#     "birthState": "KY",
#     "birthCity": "Louisville",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Chris",
#     "nameLast": "Smith",
#     "nameGiven": "Christopher Patrick",
#     "weight": "205",
#     "height": "74",
#     "bats": "R",
#     "throws": "R",
#     "debut": "2017-06-27",
#     "finalGame": "2017-07-28",
#     "retroID": "smitc005",
#     "bbrefID": "smithch10"
#   },
#   {
#     "playerID": "smithcl01",
#     "birthYear": "1914",
#     "birthMonth": "9",
#     "birthDay": "11",
#     "birthCountry": "USA",
#     "birthState": "KS",
#     "birthCity": "Cambridge",
#     "deathYear": "2002",
#     "deathMonth": "3",
#     "deathDay": "5",
#     "deathCountry": "USA",
#     "deathState": "KS",
#     "deathCity": "Winfield",
#     "nameFirst": "Clay",
#     "nameLast": "Smith",
#     "nameGiven": "Clay Jamieson",
#     "weight": "190",
#     "height": "74",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1938-09-13",
#     "finalGame": "1940-09-22",
#     "retroID": "smitc104",
#     "bbrefID": "smithcl01"
#   },
#   {
#     "playerID": "smithda01",
#     "birthYear": "1914",
#     "birthMonth": "12",
#     "birthDay": "17",
#     "birthCountry": "USA",
#     "birthState": "SC",
#     "birthCity": "Sellers",
#     "deathYear": "1998",
#     "deathMonth": "4",
#     "deathDay": "1",
#     "deathCountry": "USA",
#     "deathState": "NC",
#     "deathCity": "Whiteville",
#     "nameFirst": "Dave",
#     "nameLast": "Smith",
#     "nameGiven": "David Merwin",
#     "weight": "170",
#     "height": "70",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1938-06-16",
#     "finalGame": "1939-04-23",
#     "retroID": "smitd105",
#     "bbrefID": "smithda01"
#   },
#   {
#     "playerID": "smithda02",
#     "birthYear": "1955",
#     "birthMonth": "1",
#     "birthDay": "21",
#     "birthCountry": "USA",
#     "birthState": "CA",
#     "birthCity": "Richmond",
#     "deathYear": "2008",
#     "deathMonth": "12",
#     "deathDay": "17",
#     "deathCountry": "USA",
#     "deathState": "CA",
#     "deathCity": "San Diego",
#     "nameFirst": "Dave",
#     "nameLast": "Smith",
#     "nameGiven": "David Stanley",
#     "weight": "195",
#     "height": "73",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1980-04-11",
#     "finalGame": "1992-06-08",
#     "retroID": "smitd001",
#     "bbrefID": "smithda02"
#   },
#   {
#     "playerID": "smithda03",
#     "birthYear": "1957",
#     "birthMonth": "8",
#     "birthDay": "30",
#     "birthCountry": "USA",
#     "birthState": "TX",
#     "birthCity": "Tomball",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Dave",
#     "nameLast": "Smith",
#     "nameGiven": "David Wayne",
#     "weight": "190",
#     "height": "73",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1984-09-18",
#     "finalGame": "1985-09-14",
#     "retroID": "smitd002",
#     "bbrefID": "smithda03"
#   },
#   {
#     "playerID": "smithda04",
#     "birthYear": "1960",
#     "birthMonth": "7",
#     "birthDay": "29",
#     "birthCountry": "USA",
#     "birthState": "MD",
#     "birthCity": "Baltimore",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Dar",
#     "nameLast": "Smith",
#     "nameGiven": "Daryl Clinton",
#     "weight": "185",
#     "height": "76",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1990-09-18",
#     "finalGame": "1990-10-03",
#     "retroID": "smitd004",
#     "bbrefID": "smithda04"
#   },
#   {
#     "playerID": "smithda05",
#     "birthYear": "1969",
#     "birthMonth": "4",
#     "birthDay": "20",
#     "birthCountry": "USA",
#     "birthState": "MN",
#     "birthCity": "St. Paul",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Dan",
#     "nameLast": "Smith",
#     "nameGiven": "Daniel Scott",
#     "weight": "190",
#     "height": "77",
#     "bats": "L",
#     "throws": "L",
#     "debut": "1992-09-12",
#     "finalGame": "1994-07-08",
#     "retroID": "smitd005",
#     "bbrefID": "smithda05"
#   },
#   {
#     "playerID": "smithda06",
#     "birthYear": "1975",
#     "birthMonth": "9",
#     "birthDay": "15",
#     "birthCountry": "USA",
#     "birthState": "NJ",
#     "birthCity": "Flemington",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Dan",
#     "nameLast": "Smith",
#     "nameGiven": "Daniel Charles",
#     "weight": "210",
#     "height": "75",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1999-06-08",
#     "finalGame": "2003-06-25",
#     "retroID": "smitd006",
#     "bbrefID": "smithda07"
#   },
#   {
#     "playerID": "smithdi01",
#     "birthYear": "1927",
#     "birthMonth": "7",
#     "birthDay": "21",
#     "birthCountry": "USA",
#     "birthState": "PA",
#     "birthCity": "Blandburg",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Dick",
#     "nameLast": "Smith",
#     "nameGiven": "Richard Harrison",
#     "weight": "160",
#     "height": "68",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1951-09-14",
#     "finalGame": "1955-05-01",
#     "retroID": "smitd103",
#     "bbrefID": "smithdi01"
#   },
#   {
#     "playerID": "smithdi02",
#     "birthYear": "1939",
#     "birthMonth": "5",
#     "birthDay": "17",
#     "birthCountry": "USA",
#     "birthState": "OR",
#     "birthCity": "Lebanon",
#     "deathYear": "2012",
#     "deathMonth": "2",
#     "deathDay": "19",
#     "deathCountry": "USA",
#     "deathState": "OR",
#     "deathCity": "Medford",
#     "nameFirst": "Dick",
#     "nameLast": "Smith",
#     "nameGiven": "Richard Arthur",
#     "weight": "205",
#     "height": "74",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1963-07-20",
#     "finalGame": "1965-05-02",
#     "retroID": "smitd104",
#     "bbrefID": "smithdi02"
#   },
#   {
#     "playerID": "smithdi03",
#     "birthYear": "1944",
#     "birthMonth": "8",
#     "birthDay": "25",
#     "birthCountry": "USA",
#     "birthState": "NC",
#     "birthCity": "Lincolnton",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Dick",
#     "nameLast": "Smith",
#     "nameGiven": "Richard Kelly",
#     "weight": "200",
#     "height": "77",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1969-08-20",
#     "finalGame": "1969-09-27",
#     "retroID": "smitd102",
#     "bbrefID": "smithdi03"
#   },
#   {
#     "playerID": "smithdo01",
#     "birthYear": "1892",
#     "birthMonth": "5",
#     "birthDay": "25",
#     "birthCountry": "USA",
#     "birthState": "MA",
#     "birthCity": "Millers Falls",
#     "deathYear": "1973",
#     "deathMonth": "9",
#     "deathDay": "18",
#     "deathCountry": "USA",
#     "deathState": "MA",
#     "deathCity": "Greenfield",
#     "nameFirst": "Doug",
#     "nameLast": "Smith",
#     "nameGiven": "Douglass Weldon",
#     "weight": "168",
#     "height": "70",
#     "bats": "L",
#     "throws": "L",
#     "debut": "1912-07-10",
#     "finalGame": "1912-07-10",
#     "retroID": "smitd101",
#     "bbrefID": "smithdo01"
#   },
#   {
#     "playerID": "smithdo02",
#     "birthYear": "1995",
#     "birthMonth": "6",
#     "birthDay": "15",
#     "birthCountry": "USA",
#     "birthState": "CA",
#     "birthCity": "Los Angeles",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Dominic",
#     "nameLast": "Smith",
#     "nameGiven": "Dominic David Rene",
#     "weight": "239",
#     "height": "72",
#     "bats": "L",
#     "throws": "L",
#     "debut": "2017-08-11",
#     "finalGame": "2018-09-30",
#     "retroID": "smitd008",
#     "bbrefID": "smithdo02"
#   },
#   {
#     "playerID": "smithdr01",
#     "birthYear": "1993",
#     "birthMonth": "9",
#     "birthDay": "24",
#     "birthCountry": "USA",
#     "birthState": "TX",
#     "birthCity": "Fort Worth",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Drew",
#     "nameLast": "Smith",
#     "nameGiven": "Andrew David",
#     "weight": "190",
#     "height": "74",
#     "bats": "R",
#     "throws": "R",
#     "debut": "2018-06-23",
#     "finalGame": "2018-09-29",
#     "retroID": "smitd009",
#     "bbrefID": "smithdr01"
#   },
#   {
#     "playerID": "smithdw01",
#     "birthYear": "1963",
#     "birthMonth": "11",
#     "birthDay": "8",
#     "birthCountry": "USA",
#     "birthState": "FL",
#     "birthCity": "Tallahassee",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Dwight",
#     "nameLast": "Smith",
#     "nameGiven": "John Dwight",
#     "weight": "175",
#     "height": "71",
#     "bats": "L",
#     "throws": "R",
#     "debut": "1989-05-01",
#     "finalGame": "1996-09-29",
#     "retroID": "smitd003",
#     "bbrefID": "smithdw01"
#   },
#   {
#     "playerID": "smithdw02",
#     "birthYear": "1992",
#     "birthMonth": "10",
#     "birthDay": "26",
#     "birthCountry": "USA",
#     "birthState": "GA",
#     "birthCity": "Peachtree City",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Dwight",
#     "nameLast": "Smith",
#     "nameGiven": "John Dwight",
#     "weight": "195",
#     "height": "71",
#     "bats": "L",
#     "throws": "R",
#     "debut": "2017-05-18",
#     "finalGame": "2018-09-30",
#     "retroID": "smitd007",
#     "bbrefID": "smithdw02"
#   },
#   {
#     "playerID": "smithea01",
#     "birthYear": "1891",
#     "birthMonth": "1",
#     "birthDay": "20",
#     "birthCountry": "USA",
#     "birthState": "OH",
#     "birthCity": "Oak Hill",
#     "deathYear": "1943",
#     "deathMonth": "3",
#     "deathDay": "13",
#     "deathCountry": "USA",
#     "deathState": "OH",
#     "deathCity": "Portsmouth",
#     "nameFirst": "Earl",
#     "nameLast": "Smith",
#     "nameGiven": "Earl Leonard",
#     "weight": "170",
#     "height": "71",
#     "bats": "B",
#     "throws": "R",
#     "debut": "1916-09-10",
#     "finalGame": "1922-08-06",
#     "retroID": "smite107",
#     "bbrefID": "smithea01"
#   },
#   {
#     "playerID": "smithea02",
#     "birthYear": "1897",
#     "birthMonth": "2",
#     "birthDay": "14",
#     "birthCountry": "USA",
#     "birthState": "AR",
#     "birthCity": "Sheridan",
#     "deathYear": "1963",
#     "deathMonth": "6",
#     "deathDay": "8",
#     "deathCountry": "USA",
#     "deathState": "AR",
#     "deathCity": "Little Rock",
#     "nameFirst": "Earl",
#     "nameLast": "Smith",
#     "nameGiven": "Earl Sutton",
#     "weight": "180",
#     "height": "70",
#     "bats": "L",
#     "throws": "R",
#     "debut": "1919-04-24",
#     "finalGame": "1930-09-28",
#     "retroID": "smite106",
#     "bbrefID": "smithea02"
#   },
#   {
#     "playerID": "smithea03",
#     "birthYear": "1928",
#     "birthMonth": "3",
#     "birthDay": "14",
#     "birthCountry": "USA",
#     "birthState": "WA",
#     "birthCity": "Sunnyside",
#     "deathYear": "2014",
#     "deathMonth": "9",
#     "deathDay": "27",
#     "deathCountry": "USA",
#     "deathState": "CA",
#     "deathCity": "Fresno",
#     "nameFirst": "Earl",
#     "nameLast": "Smith",
#     "nameGiven": "Earl Calvin",
#     "weight": "185",
#     "height": "72",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1955-04-14",
#     "finalGame": "1955-04-29",
#     "retroID": "smite108",
#     "bbrefID": "smithea03"
#   },
#   {
#     "playerID": "smithed01",
#     "birthYear": "1862",
#     "birthMonth": "6",
#     "birthDay": "12",
#     "birthCountry": "USA",
#     "birthState": "RI",
#     "birthCity": "Providence",
#     "deathYear": "1892",
#     "deathMonth": "11",
#     "deathDay": "3",
#     "deathCountry": "USA",
#     "deathState": "RI",
#     "deathCity": "Providence",
#     "nameFirst": "Edgar",
#     "nameLast": "Smith",
#     "nameGiven": "Edgar Eugene",
#     "weight": "160",
#     "height": "70",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1883-05-25",
#     "finalGame": "1890-08-12",
#     "retroID": "smite101",
#     "bbrefID": "smithed01"
#   },
#   {
#     "playerID": "smithed02",
#     "birthYear": "1860",
#     "birthMonth": "10",
#     "birthDay": "15",
#     "birthCountry": "USA",
#     "birthState": "CT",
#     "birthCity": "North Haven",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Edgar",
#     "nameLast": "Smith",
#     "nameGiven": "Albert Edward",
#     "weight": "200",
#     "height": "72",
#     "bats": "",
#     "throws": "R",
#     "debut": "1883-06-20",
#     "finalGame": "1883-09-29",
#     "retroID": "smite109",
#     "bbrefID": "smithed02"
#   },
#   {
#     "playerID": "smithed03",
#     "birthYear": "1879",
#     "birthMonth": "2",
#     "birthDay": "21",
#     "birthCountry": "USA",
#     "birthState": "IN",
#     "birthCity": "Mentone",
#     "deathYear": "1956",
#     "deathMonth": "3",
#     "deathDay": "20",
#     "deathCountry": "USA",
#     "deathState": "FL",
#     "deathCity": "Tarpon Springs",
#     "nameFirst": "Ed",
#     "nameLast": "Smith",
#     "nameGiven": "Rhesa Edward",
#     "weight": "170",
#     "height": "71",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1906-04-27",
#     "finalGame": "1906-10-07",
#     "retroID": "smite102",
#     "bbrefID": "smithed03"
#   },
#   {
#     "playerID": "smithed04",
#     "birthYear": "1913",
#     "birthMonth": "12",
#     "birthDay": "14",
#     "birthCountry": "USA",
#     "birthState": "NJ",
#     "birthCity": "Mansfield",
#     "deathYear": "1994",
#     "deathMonth": "1",
#     "deathDay": "2",
#     "deathCountry": "USA",
#     "deathState": "NJ",
#     "deathCity": "Willingboro",
#     "nameFirst": "Eddie",
#     "nameLast": "Smith",
#     "nameGiven": "Edgar",
#     "weight": "174",
#     "height": "70",
#     "bats": "B",
#     "throws": "L",
#     "debut": "1936-09-20",
#     "finalGame": "1947-09-20",
#     "retroID": "smite105",
#     "bbrefID": "smithed04"
#   },
#   {
#     "playerID": "smithed05",
#     "birthYear": "1863",
#     "birthMonth": "11",
#     "birthDay": "2",
#     "birthCountry": "CAN",
#     "birthState": "ON",
#     "birthCity": "Sparta",
#     "deathYear": "1948",
#     "deathMonth": "7",
#     "deathDay": "5",
#     "deathCountry": "CAN",
#     "deathState": "ON",
#     "deathCity": "St. Thomas",
#     "nameFirst": "Ed",
#     "nameLast": "Smith",
#     "nameGiven": "Edgar Alexander",
#     "weight": "",
#     "height": "",
#     "bats": "",
#     "throws": "",
#     "debut": "1884-04-18",
#     "finalGame": "1884-05-22",
#     "retroID": "smite110",
#     "bbrefID": "smithed05"
#   },
#   {
#     "playerID": "smithel01",
#     "birthYear": "1868",
#     "birthMonth": "3",
#     "birthDay": "23",
#     "birthCountry": "USA",
#     "birthState": "PA",
#     "birthCity": "Pittsburgh",
#     "deathYear": "1945",
#     "deathMonth": "11",
#     "deathDay": "3",
#     "deathCountry": "USA",
#     "deathState": "PA",
#     "deathCity": "Pittsburgh",
#     "nameFirst": "Mike",
#     "nameLast": "Smith",
#     "nameGiven": "Elmer Ellsworth",
#     "weight": "178",
#     "height": "71",
#     "bats": "L",
#     "throws": "L",
#     "debut": "1886-09-10",
#     "finalGame": "1901-06-15",
#     "retroID": "smitm104",
#     "bbrefID": "smithel01"
#   },
#   {
#     "playerID": "smithel02",
#     "birthYear": "1892",
#     "birthMonth": "9",
#     "birthDay": "21",
#     "birthCountry": "USA",
#     "birthState": "OH",
#     "birthCity": "Erie County",
#     "deathYear": "1984",
#     "deathMonth": "8",
#     "deathDay": "3",
#     "deathCountry": "USA",
#     "deathState": "KY",
#     "deathCity": "Columbia",
#     "nameFirst": "Elmer",
#     "nameLast": "Smith",
#     "nameGiven": "Elmer John",
#     "weight": "165",
#     "height": "70",
#     "bats": "L",
#     "throws": "R",
#     "debut": "1914-09-20",
#     "finalGame": "1925-09-27",
#     "retroID": "smite104",
#     "bbrefID": "smithel02"
#   },
#   {
#     "playerID": "smither01",
#     "birthYear": "1899",
#     "birthMonth": "10",
#     "birthDay": "11",
#     "birthCountry": "USA",
#     "birthState": "NJ",
#     "birthCity": "Totowa",
#     "deathYear": "1973",
#     "deathMonth": "4",
#     "deathDay": "6",
#     "deathCountry": "USA",
#     "deathState": "NY",
#     "deathCity": "Brooklyn",
#     "nameFirst": "Ernie",
#     "nameLast": "Smith",
#     "nameGiven": "Ernest Henry",
#     "weight": "155",
#     "height": "68",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1930-04-17",
#     "finalGame": "1930-05-22",
#     "retroID": "smite103",
#     "bbrefID": "smither01"
#   },
#   {
#     "playerID": "smithfr01",
#     "birthYear": "1857",
#     "birthMonth": "11",
#     "birthDay": "24",
#     "birthCountry": "CAN",
#     "birthState": "ON",
#     "birthCity": "Fonthill",
#     "deathYear": "1928",
#     "deathMonth": "10",
#     "deathDay": "11",
#     "deathCountry": "USA",
#     "deathState": "NY",
#     "deathCity": "Canandaigua",
#     "nameFirst": "Frank",
#     "nameLast": "Smith",
#     "nameGiven": "Frank L.",
#     "weight": "175",
#     "height": "70",
#     "bats": "R",
#     "throws": "",
#     "debut": "1884-08-06",
#     "finalGame": "1884-10-03",
#     "retroID": "smitf105",
#     "bbrefID": "smithfr01"
#   },
#   {
#     "playerID": "smithfr02",
#     "birthYear": "1865",
#     "birthMonth": "10",
#     "birthDay": "",
#     "birthCountry": "USA",
#     "birthState": "MD",
#     "birthCity": "Baltimore",
#     "deathYear": "1926",
#     "deathMonth": "11",
#     "deathDay": "19",
#     "deathCountry": "USA",
#     "deathState": "IL",
#     "deathCity": "Chicago",
#     "nameFirst": "Fred",
#     "nameLast": "Smith",
#     "nameGiven": "Fred Christopher",
#     "weight": "156",
#     "height": "71",
#     "bats": "L",
#     "throws": "R",
#     "debut": "1890-04-18",
#     "finalGame": "1890-10-12",
#     "retroID": "smitf101",
#     "bbrefID": "smithfr02"
#   },
#   {
#     "playerID": "smithfr03",
#     "birthYear": "1879",
#     "birthMonth": "10",
#     "birthDay": "28",
#     "birthCountry": "USA",
#     "birthState": "PA",
#     "birthCity": "Pittsburgh",
#     "deathYear": "1952",
#     "deathMonth": "11",
#     "deathDay": "3",
#     "deathCountry": "USA",
#     "deathState": "PA",
#     "deathCity": "Pittsburgh",
#     "nameFirst": "Frank",
#     "nameLast": "Smith",
#     "nameGiven": "Frank Elmer",
#     "weight": "194",
#     "height": "70",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1904-04-22",
#     "finalGame": "1915-09-30",
#     "retroID": "smitf106",
#     "bbrefID": "smithfr03"
#   },
#   {
#     "playerID": "smithfr04",
#     "birthYear": "1878",
#     "birthMonth": "11",
#     "birthDay": "24",
#     "birthCountry": "USA",
#     "birthState": "WI",
#     "birthCity": "New Diggings",
#     "deathYear": "1964",
#     "deathMonth": "2",
#     "deathDay": "4",
#     "deathCountry": "USA",
#     "deathState": "CA",
#     "deathCity": "Los Angeles",
#     "nameFirst": "Fred",
#     "nameLast": "Smith",
#     "nameGiven": "Frederick",
#     "weight": "186",
#     "height": "72",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1907-06-14",
#     "finalGame": "1907-09-21",
#     "retroID": "smitf102",
#     "bbrefID": "smithfr04"
#   },
#   {
#     "playerID": "smithfr05",
#     "birthYear": "1891",
#     "birthMonth": "7",
#     "birthDay": "29",
#     "birthCountry": "USA",
#     "birthState": "OH",
#     "birthCity": "Cleveland",
#     "deathYear": "1961",
#     "deathMonth": "5",
#     "deathDay": "28",
#     "deathCountry": "USA",
#     "deathState": "OH",
#     "deathCity": "Cleveland",
#     "nameFirst": "Fred",
#     "nameLast": "Smith",
#     "nameGiven": "Fred Vincent",
#     "weight": "185",
#     "height": "71",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1913-04-17",
#     "finalGame": "1917-09-30",
#     "retroID": "smitf103",
#     "bbrefID": "smithfr05"
#   },
#   {
#     "playerID": "smithfr06",
#     "birthYear": "1928",
#     "birthMonth": "4",
#     "birthDay": "4",
#     "birthCountry": "USA",
#     "birthState": "NY",
#     "birthCity": "Pierrepont Manor",
#     "deathYear": "2005",
#     "deathMonth": "9",
#     "deathDay": "24",
#     "deathCountry": "USA",
#     "deathState": "FL",
#     "deathCity": "Malone",
#     "nameFirst": "Frank",
#     "nameLast": "Smith",
#     "nameGiven": "Frank Thomas",
#     "weight": "195",
#     "height": "75",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1950-04-18",
#     "finalGame": "1956-05-13",
#     "retroID": "smitf104",
#     "bbrefID": "smithfr06"
#   },
#   {
#     "playerID": "smithge01",
#     "birthYear": "1859",
#     "birthMonth": "4",
#     "birthDay": "20",
#     "birthCountry": "USA",
#     "birthState": "PA",
#     "birthCity": "Pittsburgh",
#     "deathYear": "1927",
#     "deathMonth": "12",
#     "deathDay": "1",
#     "deathCountry": "USA",
#     "deathState": "PA",
#     "deathCity": "Altoona",
#     "nameFirst": "Germany",
#     "nameLast": "Smith",
#     "nameGiven": "George J.",
#     "weight": "175",
#     "height": "72",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1884-04-17",
#     "finalGame": "1898-10-09",
#     "retroID": "smitg103",
#     "bbrefID": "smithge01"
#   },
#   {
#     "playerID": "smithge02",
#     "birthYear": "1892",
#     "birthMonth": "5",
#     "birthDay": "31",
#     "birthCountry": "USA",
#     "birthState": "CT",
#     "birthCity": "East Port Chester",
#     "deathYear": "1965",
#     "deathMonth": "1",
#     "deathDay": "7",
#     "deathCountry": "USA",
#     "deathState": "CT",
#     "deathCity": "Greenwich",
#     "nameFirst": "George",
#     "nameLast": "Smith",
#     "nameGiven": "George Allen",
#     "weight": "163",
#     "height": "74",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1916-08-09",
#     "finalGame": "1923-09-21",
#     "retroID": "smitg104",
#     "bbrefID": "smithge02"
#   },
#   {
#     "playerID": "smithge03",
#     "birthYear": "1901",
#     "birthMonth": "10",
#     "birthDay": "27",
#     "birthCountry": "USA",
#     "birthState": "KY",
#     "birthCity": "Louisville",
#     "deathYear": "1981",
#     "deathMonth": "5",
#     "deathDay": "26",
#     "deathCountry": "USA",
#     "deathState": "VA",
#     "deathCity": "Richmond",
#     "nameFirst": "George",
#     "nameLast": "Smith",
#     "nameGiven": "George Shelby",
#     "weight": "175",
#     "height": "73",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1926-04-21",
#     "finalGame": "1930-09-17",
#     "retroID": "smitg102",
#     "bbrefID": "smithge03"
#   },
#   {
#     "playerID": "smithge04",
#     "birthYear": "1937",
#     "birthMonth": "7",
#     "birthDay": "7",
#     "birthCountry": "USA",
#     "birthState": "FL",
#     "birthCity": "St. Petersburg",
#     "deathYear": "1987",
#     "deathMonth": "6",
#     "deathDay": "15",
#     "deathCountry": "USA",
#     "deathState": "FL",
#     "deathCity": "St. Petersburg",
#     "nameFirst": "George",
#     "nameLast": "Smith",
#     "nameGiven": "George Cornelius",
#     "weight": "170",
#     "height": "70",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1963-08-04",
#     "finalGame": "1966-09-17",
#     "retroID": "smitg101",
#     "bbrefID": "smithge04"
#   },
#   {
#     "playerID": "smithgr01",
#     "birthYear": "1967",
#     "birthMonth": "4",
#     "birthDay": "5",
#     "birthCountry": "USA",
#     "birthState": "MD",
#     "birthCity": "Baltimore",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Greg",
#     "nameLast": "Smith",
#     "nameGiven": "Gregory Alan",
#     "weight": "170",
#     "height": "71",
#     "bats": "B",
#     "throws": "R",
#     "debut": "1989-09-02",
#     "finalGame": "1991-05-24",
#     "retroID": "smitg001",
#     "bbrefID": "smithgr01"
#   },
#   {
#     "playerID": "smithgr02",
#     "birthYear": "1983",
#     "birthMonth": "12",
#     "birthDay": "22",
#     "birthCountry": "USA",
#     "birthState": "LA",
#     "birthCity": "Alexandria",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Greg",
#     "nameLast": "Smith",
#     "nameGiven": "Gregory Thomas",
#     "weight": "190",
#     "height": "73",
#     "bats": "L",
#     "throws": "L",
#     "debut": "2008-04-09",
#     "finalGame": "2010-05-19",
#     "retroID": "smitg002",
#     "bbrefID": "smithgr02"
#   },
#   {
#     "playerID": "smithha01",
#     "birthYear": "1856",
#     "birthMonth": "2",
#     "birthDay": "5",
#     "birthCountry": "USA",
#     "birthState": "IN",
#     "birthCity": "North Vernon",
#     "deathYear": "1898",
#     "deathMonth": "6",
#     "deathDay": "4",
#     "deathCountry": "USA",
#     "deathState": "IN",
#     "deathCity": "Queensville",
#     "nameFirst": "Harry",
#     "nameLast": "Smith",
#     "nameGiven": "Harry W.",
#     "weight": "175",
#     "height": "72",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1877-05-08",
#     "finalGame": "1889-08-19",
#     "retroID": "smith103",
#     "bbrefID": "smithha01"
#   },
#   {
#     "playerID": "smithha02",
#     "birthYear": "1871",
#     "birthMonth": "7",
#     "birthDay": "24",
#     "birthCountry": "USA",
#     "birthState": "PA",
#     "birthCity": "Union Deposit",
#     "deathYear": "1962",
#     "deathMonth": "11",
#     "deathDay": "12",
#     "deathCountry": "USA",
#     "deathState": "PA",
#     "deathCity": "Harrisburg",
#     "nameFirst": "Harvey",
#     "nameLast": "Smith",
#     "nameGiven": "Harvey Fetterhoff",
#     "weight": "160",
#     "height": "68",
#     "bats": "L",
#     "throws": "R",
#     "debut": "1896-08-19",
#     "finalGame": "1896-09-26",
#     "retroID": "smith102",
#     "bbrefID": "smithha02"
#   },
#   {
#     "playerID": "smithha03",
#     "birthYear": "1874",
#     "birthMonth": "10",
#     "birthDay": "31",
#     "birthCountry": "United Kingdom",
#     "birthState": "Yorkshire",
#     "birthCity": "",
#     "deathYear": "1933",
#     "deathMonth": "2",
#     "deathDay": "17",
#     "deathCountry": "USA",
#     "deathState": "NJ",
#     "deathCity": "Salem",
#     "nameFirst": "Harry",
#     "nameLast": "Smith",
#     "nameGiven": "Harry Thomas",
#     "weight": "165",
#     "height": "68",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1901-07-11",
#     "finalGame": "1910-09-15",
#     "retroID": "smith104",
#     "bbrefID": "smithha03"
#   },
#   {
#     "playerID": "smithha04",
#     "birthYear": "1883",
#     "birthMonth": "7",
#     "birthDay": "14",
#     "birthCountry": "USA",
#     "birthState": "OR",
#     "birthCity": "Coquille",
#     "deathYear": "1961",
# ...
#     "deathCity": "Louisville",
#     "nameFirst": "Rex",
#     "nameLast": "Smith",
#     "nameGiven": "Rex",
#     "weight": "190",
#     "height": "70",
#     "bats": "",
#     "throws": "R",
#     "debut": "1886-05-31",
#     "finalGame": "1886-07-11",
#     "retroID": "smitr106",
#     "bbrefID": "smithre01"
#   },
#   {
#     "playerID": "smithre02",
#     "birthYear": "1890",
#     "birthMonth": "4",
#     "birthDay": "6",
#     "birthCountry": "USA",
#     "birthState": "SC",
#     "birthCity": "Greenville",
#     "deathYear": "1966",
#     "deathMonth": "10",
#     "deathDay": "11",
#     "deathCountry": "USA",
#     "deathState": "GA",
#     "deathCity": "Atlanta",
#     "nameFirst": "Red",
#     "nameLast": "Smith",
#     "nameGiven": "James Carlisle",
#     "weight": "165",
#     "height": "71",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1911-09-05",
#     "finalGame": "1919-09-25",
#     "retroID": "smitr108",
#     "bbrefID": "smithre02"
#   },
#   {
#     "playerID": "smithre03",
#     "birthYear": "1892",
#     "birthMonth": "4",
#     "birthDay": "11",
#     "birthCountry": "USA",
#     "birthState": "IN",
#     "birthCity": "Logansport",
#     "deathYear": "1970",
#     "deathMonth": "8",
#     "deathDay": "23",
#     "deathCountry": "USA",
#     "deathState": "FL",
#     "deathCity": "Bradenton",
#     "nameFirst": "Red",
#     "nameLast": "Smith",
#     "nameGiven": "Willard Jehu",
#     "weight": "165",
#     "height": "68",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1917-09-17",
#     "finalGame": "1918-09-01",
#     "retroID": "smitr104",
#     "bbrefID": "smithre03"
#   },
#   {
#     "playerID": "smithre04",
#     "birthYear": "1899",
#     "birthMonth": "7",
#     "birthDay": "17",
#     "birthCountry": "USA",
#     "birthState": "IL",
#     "birthCity": "Ashley",
#     "deathYear": "1961",
#     "deathMonth": "2",
#     "deathDay": "19",
#     "deathCountry": "USA",
#     "deathState": "CA",
#     "deathCity": "Los Angeles",
#     "nameFirst": "Red",
#     "nameLast": "Smith",
#     "nameGiven": "Marvin Harold",
#     "weight": "165",
#     "height": "67",
#     "bats": "L",
#     "throws": "R",
#     "debut": "1925-04-14",
#     "finalGame": "1925-09-26",
#     "retroID": "smitr107",
#     "bbrefID": "smithre04"
#   },
#   {
#     "playerID": "smithre05",
#     "birthYear": "1904",
#     "birthMonth": "5",
#     "birthDay": "18",
#     "birthCountry": "USA",
#     "birthState": "WI",
#     "birthCity": "Brokaw",
#     "deathYear": "1978",
#     "deathMonth": "5",
#     "deathDay": "8",
#     "deathCountry": "USA",
#     "deathState": "OH",
#     "deathCity": "Sylvania",
#     "nameFirst": "Red",
#     "nameLast": "Smith",
#     "nameGiven": "Richard Paul",
#     "weight": "185",
#     "height": "70",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1927-05-31",
#     "finalGame": "1927-05-31",
#     "retroID": "smitr105",
#     "bbrefID": "smithre05"
#   },
#   {
#     "playerID": "smithre06",
#     "birthYear": "1945",
#     "birthMonth": "4",
#     "birthDay": "2",
#     "birthCountry": "USA",
#     "birthState": "LA",
#     "birthCity": "Shreveport",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Reggie",
#     "nameLast": "Smith",
#     "nameGiven": "Carl Reginald",
#     "weight": "180",
#     "height": "72",
#     "bats": "B",
#     "throws": "R",
#     "debut": "1966-09-18",
#     "finalGame": "1982-10-03",
#     "retroID": "smitr101",
#     "bbrefID": "smithre06"
#   },
#   {
#     "playerID": "smithro01",
#     "birthYear": "1961",
#     "birthMonth": "9",
#     "birthDay": "6",
#     "birthCountry": "USA",
#     "birthState": "NY",
#     "birthCity": "Mount Vernon",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Roy",
#     "nameLast": "Smith",
#     "nameGiven": "LeRoy Purdy",
#     "weight": "200",
#     "height": "75",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1984-06-23",
#     "finalGame": "1991-08-16",
#     "retroID": "smitr001",
#     "bbrefID": "smithro01"
#   },
#   {
#     "playerID": "smithro03",
#     "birthYear": "1976",
#     "birthMonth": "5",
#     "birthDay": "18",
#     "birthCountry": "USA",
#     "birthState": "FL",
#     "birthCity": "St. Petersburg",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Roy",
#     "nameLast": "Smith",
#     "nameGiven": "Walter Roy",
#     "weight": "235",
#     "height": "78",
#     "bats": "R",
#     "throws": "R",
#     "debut": "2001-05-26",
#     "finalGame": "2002-09-29",
#     "retroID": "smitr004",
#     "bbrefID": "smithro03"
#   },
#   {
#     "playerID": "smithru01",
#     "birthYear": "1905",
#     "birthMonth": "1",
#     "birthDay": "24",
#     "birthCountry": "USA",
#     "birthState": "NC",
#     "birthCity": "Guilford College",
#     "deathYear": "1984",
#     "deathMonth": "8",
#     "deathDay": "21",
#     "deathCountry": "USA",
#     "deathState": "SC",
#     "deathCity": "Aiken",
#     "nameFirst": "Rufus",
#     "nameLast": "Smith",
#     "nameGiven": "Rufus Frazier",
#     "weight": "165",
#     "height": "68",
#     "bats": "R",
#     "throws": "L",
#     "debut": "1927-10-02",
#     "finalGame": "1927-10-02",
#     "retroID": "smitr103",
#     "bbrefID": "smithru01"
#   },
#   {
#     "playerID": "smithse01",
#     "birthYear": "1982",
#     "birthMonth": "9",
#     "birthDay": "30",
#     "birthCountry": "USA",
#     "birthState": "MS",
#     "birthCity": "Jackson",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Seth",
#     "nameLast": "Smith",
#     "nameGiven": "Garry Seth",
#     "weight": "210",
#     "height": "75",
#     "bats": "L",
#     "throws": "L",
#     "debut": "2007-09-16",
#     "finalGame": "2017-09-30",
#     "retroID": "smits002",
#     "bbrefID": "smithse01"
#   },
#   {
#     "playerID": "smithsh01",
#     "birthYear": "1891",
#     "birthMonth": "2",
#     "birthDay": "18",
#     "birthCountry": "USA",
#     "birthState": "GA",
#     "birthCity": "Monticello",
#     "deathYear": "1949",
#     "deathMonth": "9",
#     "deathDay": "12",
#     "deathCountry": "USA",
#     "deathState": "GA",
#     "deathCity": "Reidsville",
#     "nameFirst": "Sherry",
#     "nameLast": "Smith",
#     "nameGiven": "Sherrod Malone",
#     "weight": "170",
#     "height": "73",
#     "bats": "R",
#     "throws": "L",
#     "debut": "1911-05-11",
#     "finalGame": "1927-07-18",
#     "retroID": "smits102",
#     "bbrefID": "smithsh01"
#   },
#   {
#     "playerID": "smithsk01",
#     "birthYear": "1868",
#     "birthMonth": "3",
#     "birthDay": "19",
#     "birthCountry": "USA",
#     "birthState": "MD",
#     "birthCity": "Baltimore",
#     "deathYear": "1916",
#     "deathMonth": "4",
#     "deathDay": "26",
#     "deathCountry": "USA",
#     "deathState": "MO",
#     "deathCity": "St. Louis",
#     "nameFirst": "Skyrocket",
#     "nameLast": "Smith",
#     "nameGiven": "Samuel J.",
#     "weight": "170",
#     "height": "74",
#     "bats": "R",
#     "throws": "",
#     "debut": "1888-04-18",
#     "finalGame": "1888-07-08",
#     "retroID": "smits103",
#     "bbrefID": "smithsk01"
#   },
#   {
#     "playerID": "smithst01",
#     "birthYear": "1873",
#     "birthMonth": "11",
#     "birthDay": "24",
#     "birthCountry": "USA",
#     "birthState": "IL",
#     "birthCity": "Elmwood",
#     "deathYear": "1947",
#     "deathMonth": "11",
#     "deathDay": "14",
#     "deathCountry": "USA",
#     "deathState": "MA",
#     "deathCity": "Fall River",
#     "nameFirst": "Stub",
#     "nameLast": "Smith",
#     "nameGiven": "James Abner",
#     "weight": "145",
#     "height": "66",
#     "bats": "L",
#     "throws": "R",
#     "debut": "1898-09-10",
#     "finalGame": "1898-10-15",
#     "retroID": "smits104",
#     "bbrefID": "smithst01"
#   },
#   {
#     "playerID": "smithsy01",
#     "birthYear": "1883",
#     "birthMonth": "8",
#     "birthDay": "31",
#     "birthCountry": "USA",
#     "birthState": "SC",
#     "birthCity": "Smithville",
#     "deathYear": "1961",
#     "deathMonth": "6",
#     "deathDay": "5",
#     "deathCountry": "USA",
#     "deathState": "SC",
#     "deathCity": "Orangeburg",
#     "nameFirst": "Syd",
#     "nameLast": "Smith",
#     "nameGiven": "Sydney A.",
#     "weight": "190",
#     "height": "70",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1908-04-14",
#     "finalGame": "1915-04-18",
#     "retroID": "smits101",
#     "bbrefID": "smithsy01"
#   },
#   {
#     "playerID": "smithto01",
#     "birthYear": "1851",
#     "birthMonth": "",
#     "birthDay": "",
#     "birthCountry": "CAN",
#     "birthState": "ON",
#     "birthCity": "Guelph",
#     "deathYear": "1889",
#     "deathMonth": "3",
#     "deathDay": "27",
#     "deathCountry": "USA",
#     "deathState": "MI",
#     "deathCity": "Detroit",
#     "nameFirst": "Tom",
#     "nameLast": "Smith",
#     "nameGiven": "Thomas N.",
#     "weight": "141",
#     "height": "68",
#     "bats": "R",
#     "throws": "",
#     "debut": "1875-09-15",
#     "finalGame": "1875-10-09",
#     "retroID": "smitt103",
#     "bbrefID": "smithto01"
#   },
#   {
#     "playerID": "smithto02",
#     "birthYear": "1871",
#     "birthMonth": "12",
#     "birthDay": "5",
#     "birthCountry": "USA",
#     "birthState": "MA",
#     "birthCity": "Boston",
#     "deathYear": "1929",
#     "deathMonth": "3",
#     "deathDay": "2",
#     "deathCountry": "USA",
#     "deathState": "MA",
#     "deathCity": "Dorchester",
#     "nameFirst": "Tom",
#     "nameLast": "Smith",
#     "nameGiven": "Thomas Edward",
#     "weight": "165",
#     "height": "67",
#     "bats": "R",
#     "throws": "L",
#     "debut": "1894-06-06",
#     "finalGame": "1898-05-12",
#     "retroID": "smitt104",
#     "bbrefID": "smithto02"
#   },
#   {
#     "playerID": "smithto03",
#     "birthYear": "1884",
#     "birthMonth": "5",
#     "birthDay": "14",
#     "birthCountry": "USA",
#     "birthState": "IL",
#     "birthCity": "Chicago",
#     "deathYear": "1964",
#     "deathMonth": "2",
#     "deathDay": "27",
#     "deathCountry": "USA",
#     "deathState": "TX",
#     "deathCity": "Galveston",
#     "nameFirst": "Tony",
#     "nameLast": "Smith",
#     "nameGiven": "Anthony",
#     "weight": "150",
#     "height": "69",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1907-08-12",
#     "finalGame": "1911-07-11",
#     "retroID": "smitt101",
#     "bbrefID": "smithto03"
#   },
#   {
#     "playerID": "smithto04",
#     "birthYear": "1948",
#     "birthMonth": "8",
#     "birthDay": "1",
#     "birthCountry": "USA",
#     "birthState": "NC",
#     "birthCity": "Albemarle",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Tommy",
#     "nameLast": "Smith",
#     "nameGiven": "Tommy Alexander",
#     "weight": "210",
#     "height": "76",
#     "bats": "L",
#     "throws": "R",
#     "debut": "1973-09-06",
#     "finalGame": "1977-09-10",
#     "retroID": "smitt102",
#     "bbrefID": "smithto04"
#   },
#   {
#     "playerID": "smithtr01",
#     "birthYear": "1972",
#     "birthMonth": "11",
#     "birthDay": "7",
#     "birthCountry": "USA",
#     "birthState": "OR",
#     "birthCity": "Springfield",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Travis",
#     "nameLast": "Smith",
#     "nameGiven": "Travis William",
#     "weight": "170",
#     "height": "70",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1998-06-21",
#     "finalGame": "2006-05-20",
#     "retroID": "smitt001",
#     "bbrefID": "smithtr01"
#   },
#   {
#     "playerID": "smithty01",
#     "birthYear": "1991",
#     "birthMonth": "7",
#     "birthDay": "1",
#     "birthCountry": "USA",
#     "birthState": "CA",
#     "birthCity": "Long Beach",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Tyler",
#     "nameLast": "Smith",
#     "nameGiven": "Tyler Douglas",
#     "weight": "195",
#     "height": "72",
#     "bats": "R",
#     "throws": "R",
#     "debut": "2017-06-02",
#     "finalGame": "2017-06-20",
#     "retroID": "smitt002",
#     "bbrefID": "smithty01"
#   },
#   {
#     "playerID": "smithvi01",
#     "birthYear": "1915",
#     "birthMonth": "12",
#     "birthDay": "7",
#     "birthCountry": "USA",
#     "birthState": "VA",
#     "birthCity": "Richmond",
#     "deathYear": "1979",
#     "deathMonth": "12",
#     "deathDay": "14",
#     "deathCountry": "USA",
#     "deathState": "VA",
#     "deathCity": "Virginia Beach",
#     "nameFirst": "Vinnie",
#     "nameLast": "Smith",
#     "nameGiven": "Vincent Ambrose",
#     "weight": "176",
#     "height": "73",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1941-09-10",
#     "finalGame": "1946-04-27",
#     "retroID": "smitv101",
#     "bbrefID": "smithvi01"
#   },
#   {
#     "playerID": "smithwa01",
#     "birthYear": "1888",
#     "birthMonth": "3",
#     "birthDay": "13",
#     "birthCountry": "USA",
#     "birthState": "PA",
#     "birthCity": "Philadelphia",
#     "deathYear": "1930",
#     "deathMonth": "6",
#     "deathDay": "10",
#     "deathCountry": "USA",
#     "deathState": "AZ",
#     "deathCity": "Florence",
#     "nameFirst": "Wally",
#     "nameLast": "Smith",
#     "nameGiven": "Wallace Henry",
#     "weight": "180",
#     "height": "71",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1911-04-17",
#     "finalGame": "1914-10-07",
#     "retroID": "smitw103",
#     "bbrefID": "smithwa01"
#   },
#   {
#     "playerID": "smithwi01",
#     "birthYear": "1886",
#     "birthMonth": "8",
#     "birthDay": "30",
#     "birthCountry": "USA",
#     "birthState": "MI",
#     "birthCity": "Evart",
#     "deathYear": "1959",
#     "deathMonth": "11",
#     "deathDay": "18",
#     "deathCountry": "USA",
#     "deathState": "ND",
#     "deathCity": "Fargo",
#     "nameFirst": "Wib",
#     "nameLast": "Smith",
#     "nameGiven": "Wilbur Floyd",
#     "weight": "165",
#     "height": "70",
#     "bats": "L",
#     "throws": "R",
#     "debut": "1909-05-31",
#     "finalGame": "1909-09-29",
#     "retroID": "smitw101",
#     "bbrefID": "smithwi01"
#   },
#   {
#     "playerID": "smithwi02",
#     "birthYear": "1939",
#     "birthMonth": "2",
#     "birthDay": "11",
#     "birthCountry": "USA",
#     "birthState": "AL",
#     "birthCity": "Anniston",
#     "deathYear": "2006",
#     "deathMonth": "1",
#     "deathDay": "16",
#     "deathCountry": "USA",
#     "deathState": "AL",
#     "deathCity": "Anniston",
#     "nameFirst": "Willie",
#     "nameLast": "Smith",
#     "nameGiven": "Willie",
#     "weight": "182",
#     "height": "72",
#     "bats": "L",
#     "throws": "L",
#     "debut": "1963-06-18",
#     "finalGame": "1971-09-30",
#     "retroID": "smitw102",
#     "bbrefID": "smithwi02"
#   },
#   {
#     "playerID": "smithwi03",
#     "birthYear": "1967",
#     "birthMonth": "8",
#     "birthDay": "27",
#     "birthCountry": "USA",
#     "birthState": "GA",
#     "birthCity": "Savannah",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Willie",
#     "nameLast": "Smith",
#     "nameGiven": "Willie Everett",
#     "weight": "250",
#     "height": "78",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1994-04-25",
#     "finalGame": "1994-05-10",
#     "retroID": "smitw001",
#     "bbrefID": "smithwi03"
#   },
#   {
#     "playerID": "smithwi04",
#     "birthYear": "1989",
#     "birthMonth": "7",
#     "birthDay": "10",
#     "birthCountry": "USA",
#     "birthState": "GA",
#     "birthCity": "Newnan",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Will",
#     "nameLast": "Smith",
#     "nameGiven": "William Michael",
#     "weight": "248",
#     "height": "77",
#     "bats": "R",
#     "throws": "L",
#     "debut": "2012-05-23",
#     "finalGame": "2018-09-29",
#     "retroID": "smitw002",
#     "bbrefID": "smithwi04"
#   },
#   {
#     "playerID": "smithza01",
#     "birthYear": "1960",
#     "birthMonth": "12",
#     "birthDay": "28",
#     "birthCountry": "USA",
#     "birthState": "WI",
#     "birthCity": "Madison",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Zane",
#     "nameLast": "Smith",
#     "nameGiven": "Zane William",
#     "weight": "185",
#     "height": "74",
#     "bats": "L",
#     "throws": "L",
#     "debut": "1984-09-10",
#     "finalGame": "1996-07-05",
#     "retroID": "smitz001",
#     "bbrefID": "smithza01"
#   }
# ]

# %%
cur = default_cnx.cursor()
how_many = cur.execute("select * from people where nameLast='Smith'")
print("The query produced", how_many, "rows.")
# Out:
# The query produced 162 rows.

# %%
result = cur.fetchmany(size=3)
while result is not None and len(result) > 0:
    print("The next 3 rows are:\n", json.dumps(result, indent=2))
    cont = input("Do you want to see more (Y/N)?")
    if cont == 'Y' or cont=='y':
        result = cur.fetchmany(size=3)
    else:
        result = None
# Out:
# The next 3 rows are:
#  [
#   {
#     "playerID": "smith01",
#     "birthYear": "",
#     "birthMonth": "",
#     "birthDay": "",
#     "birthCountry": "",
#     "birthState": "",
#     "birthCity": "",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "",
#     "nameLast": "Smith",
#     "nameGiven": "",
#     "weight": "",
#     "height": "",
#     "bats": "",
#     "throws": "",
#     "debut": "1884-06-05",
#     "finalGame": "1884-06-05",
#     "retroID": "smitu101",
#     "bbrefID": "smith01"
#   },
#   {
#     "playerID": "smithal01",
#     "birthYear": "1871",
#     "birthMonth": "",
#     "birthDay": "",
#     "birthCountry": "USA",
#     "birthState": "NY",
#     "birthCity": "New York",
#     "deathYear": "1919",
#     "deathMonth": "7",
#     "deathDay": "9",
#     "deathCountry": "USA",
#     "deathState": "NY",
#     "deathCity": "New York",
#     "nameFirst": "Aleck",
#     "nameLast": "Smith",
#     "nameGiven": "Alexander Benjamin",
#     "weight": "",
#     "height": "",
#     "bats": "",
#     "throws": "R",
#     "debut": "1897-04-23",
#     "finalGame": "1906-10-05",
#     "retroID": "smita105",
#     "bbrefID": "smithal01"
#   },
#   {
#     "playerID": "smithal02",
#     "birthYear": "1903",
#     "birthMonth": "12",
#     "birthDay": "13",
#     "birthCountry": "USA",
#     "birthState": "PA",
#     "birthCity": "Norristown",
#     "deathYear": "1995",
#     "deathMonth": "8",
#     "deathDay": "11",
#     "deathCountry": "USA",
#     "deathState": "CA",
#     "deathCity": "San Diego",
#     "nameFirst": "Al",
#     "nameLast": "Smith",
#     "nameGiven": "Alfred Kendricks",
#     "weight": "170",
#     "height": "72",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1926-06-18",
#     "finalGame": "1926-06-18",
#     "retroID": "smita103",
#     "bbrefID": "smithal02"
#   }
# ]
# Do you want to see more (Y/N)?Y
# The next 3 rows are:
#  [
#   {
#     "playerID": "smithal03",
#     "birthYear": "1907",
#     "birthMonth": "10",
#     "birthDay": "12",
#     "birthCountry": "USA",
#     "birthState": "IL",
#     "birthCity": "Belleville",
#     "deathYear": "1977",
#     "deathMonth": "4",
#     "deathDay": "28",
#     "deathCountry": "USA",
#     "deathState": "TX",
#     "deathCity": "Brownsville",
#     "nameFirst": "Al",
#     "nameLast": "Smith",
#     "nameGiven": "Alfred John",
#     "weight": "180",
#     "height": "71",
#     "bats": "L",
#     "throws": "L",
#     "debut": "1934-05-05",
#     "finalGame": "1945-09-15",
#     "retroID": "smita104",
#     "bbrefID": "smithal03"
#   },
#   {
#     "playerID": "smithal04",
#     "birthYear": "1928",
#     "birthMonth": "2",
#     "birthDay": "7",
#     "birthCountry": "USA",
#     "birthState": "MO",
#     "birthCity": "Kirkwood",
#     "deathYear": "2002",
#     "deathMonth": "1",
#     "deathDay": "3",
#     "deathCountry": "USA",
#     "deathState": "IN",
#     "deathCity": "Hammond",
#     "nameFirst": "Al",
#     "nameLast": "Smith",
#     "nameGiven": "Alphonse Eugene",
#     "weight": "189",
#     "height": "72",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1953-07-10",
#     "finalGame": "1964-10-04",
#     "retroID": "smita102",
#     "bbrefID": "smithal04"
#   },
#   {
#     "playerID": "smithar01",
#     "birthYear": "1906",
#     "birthMonth": "6",
#     "birthDay": "21",
#     "birthCountry": "USA",
#     "birthState": "MA",
#     "birthCity": "Boston",
#     "deathYear": "1995",
#     "deathMonth": "11",
#     "deathDay": "22",
#     "deathCountry": "USA",
#     "deathState": "CT",
#     "deathCity": "Norwalk",
#     "nameFirst": "Art",
#     "nameLast": "Smith",
#     "nameGiven": "Arthur Laird",
#     "weight": "175",
#     "height": "72",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1932-06-09",
#     "finalGame": "1932-06-20",
#     "retroID": "smita101",
#     "bbrefID": "smithar01"
#   }
# ]
# Do you want to see more (Y/N)?Y
# The next 3 rows are:
#  [
#   {
#     "playerID": "smithbe01",
#     "birthYear": "1941",
#     "birthMonth": "9",
#     "birthDay": "4",
#     "birthCountry": "USA",
#     "birthState": "LA",
#     "birthCity": "Ponchatoula",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Bernie",
#     "nameLast": "Smith",
#     "nameGiven": "Calvin Bernard",
#     "weight": "164",
#     "height": "69",
#     "bats": "R",
#     "throws": "R",
#     "debut": "1970-07-31",
#     "finalGame": "1971-04-28",
#     "retroID": "smitb105",
#     "bbrefID": "smithbe01"
#   },
#   {
#     "playerID": "smithbi01",
#     "birthYear": "",
#     "birthMonth": "",
#     "birthDay": "",
#     "birthCountry": "USA",
#     "birthState": "MD",
#     "birthCity": "Baltimore",
#     "deathYear": "",
#     "deathMonth": "",
#     "deathDay": "",
#     "deathCountry": "",
#     "deathState": "",
#     "deathCity": "",
#     "nameFirst": "Bill",
#     "nameLast": "Smith",
#     "nameGiven": "William J.",
#     "weight": "",
#     "height": "",
#     "bats": "",
#     "throws": "",
#     "debut": "1873-04-14",
#     "finalGame": "1873-07-11",
#     "retroID": "smitb113",
#     "bbrefID": "smithbi01"
#   },
#   {
#     "playerID": "smithbi02",
#     "birthYear": "1865",
#     "birthMonth": "",
#     "birthDay": "",
#     "birthCountry": "USA",
#     "birthState": "OH",
#     "birthCity": "Cleveland",
#     "deathYear": "1886",
#     "deathMonth": "8",
#     "deathDay": "9",
#     "deathCountry": "CAN",
#     "deathState": "ON",
#     "deathCity": "Toronto",
#     "nameFirst": "Bill",
#     "nameLast": "Smith",
#     "nameGiven": "William E.",
#     "weight": "178",
#     "height": "71",
#     "bats": "",
#     "throws": "",
#     "debut": "1884-09-17",
#     "finalGame": "1884-09-17",
#     "retroID": "smitb107",
#     "bbrefID": "smithbi02"
#   }
# ]
# Do you want to see more (Y/N)?N

# %% [markdown]
# - There are many implications for cursors. Two of the most important are:
#     1. Remember that the database application is a network connected client of the database. Returning all rows in a large result may swamp the client program or network.
#     2. DBMS use locking to implement transactions, which we will cover later. Cursors are fundamental to locking.

# %% [markdown]
# ## INSERT, UPDATE, DELETE
#
# ### Note on Examples
#
# I do not want to "mess up" the Lahman2017 stats with insert, update, delete. So, I am going to use the the [MySQL Tutorial Classic Cars](http://www.mysqltutorial.org/mysql-sample-database.aspx) database/schema.
#
# | <img src="http://www.mysqltutorial.org/wp-content/uploads/2009/12/MySQL-Sample-Database-Schema.png"> |
# | :---: |
# | __Classic Cars Schema__ |
#
# ### Overview
#
# - All databases support some form of Create-Retrieve-Update-Delete (CRUD)
#
#
# - ```SELECT``` is the SQL retrieve operation.
#
#
# - The verbs for the other operations are:
#     - ```INSERT``` for Create
#     - ```UPDATE```
#     - ```DELETE```
#
# ### INSERT
#
# #### Overview
#
# - The basic form is
#
# ```
# INSERT INTO table_name (column1, column2, column3, ...)
# VALUES (value1, value2, value3, ...);
# ```
#
# - If you are passing a value for every column, in the order in which the columns are defined in the table, you can skip the columns list because it is implied.
#
# ```
# INSERT INTO table_name
# VALUES (value1, value2, value3, ...);
# ```
#
# - For MySQL and most RDB engines, the ```INSERT``` statement has many more options. The MySQL version is
#
# ```
# INSERT [LOW_PRIORITY | DELAYED | HIGH_PRIORITY] [IGNORE]
#     [INTO] tbl_name
#     [PARTITION (partition_name [, partition_name] ...)]
#     [(col_name [, col_name] ...)]
#     {VALUES | VALUE} (value_list) [, (value_list)] ...
#     [ON DUPLICATE KEY UPDATE assignment_list]
#
# INSERT [LOW_PRIORITY | DELAYED | HIGH_PRIORITY] [IGNORE]
#     [INTO] tbl_name
#     [PARTITION (partition_name [, partition_name] ...)]
#     SET assignment_list
#     [ON DUPLICATE KEY UPDATE assignment_list]
#
# INSERT [LOW_PRIORITY | HIGH_PRIORITY] [IGNORE]
#     [INTO] tbl_name
#     [PARTITION (partition_name [, partition_name] ...)]
#     [(col_name [, col_name] ...)]
#     SELECT ...
#     [ON DUPLICATE KEY UPDATE assignment_list]
#
# value:
#     {expr | DEFAULT}
#
# value_list:
#     value [, value] ...
#
# assignment:
#     col_name = value
#
# assignment_list:
#     assignment [, assignment] ...
# ```
#
# - We will not cover most of the options in the course.
#
# #### Examples
#
# __Note:__ We will switch to a simpler table to demonstrate ```INSERT, UPDATE``` and ```DELETE.```

# %%
# %sql select * from classicmodels.offices
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 7 rows affected.
# [('1', 'San Francisco', '+1 650 219 4782', '100 Market Street', 'Suite 300', 'CA', 'USA', '94080', 'NA'),
#  ('2', 'Boston', '+1 215 837 0825', '1550 Court Place', 'Suite 102', 'MA', 'USA', '02107', 'NA'),
#  ('3', 'NYC', '+1 212 555 3000', '523 East 53rd Street', 'apt. 5A', 'NY', 'USA', '10022', 'NA'),
#  ('4', 'Paris', '+33 14 723 4404', "43 Rue Jouffroy D'abbans", None, None, 'France', '75017', 'EMEA'),
#  ('5', 'Tokyo', '+81 33 224 5000', '4-1 Kioicho', None, 'Chiyoda-Ku', 'Japan', '102-8578', 'Japan'),
#  ('6', 'Sydney', '+61 2 9264 2451', '5-11 Wentworth Avenue', 'Floor #2', None, 'Australia', 'NSW 2010', 'APAC'),
#  ('7', 'London', '+44 20 7877 2041', '25 Old Broad Street', 'Level 7', None, 'UK', 'EC2N 1HN', 'EMEA')]

# %%
# %%sql
#     INSERT INTO classicmodels.offices
#     values(8, 'New York', '+1 212 555-1212', 'W 116th Street', 'and Broadway', 'NY', 'USA', '10027', 'NA')
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 1 rows affected.
# []

# %%
# %sql select * from classicmodels.offices
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 8 rows affected.
# [('1', 'San Francisco', '+1 650 219 4782', '100 Market Street', 'Suite 300', 'CA', 'USA', '94080', 'NA'),
#  ('2', 'Boston', '+1 215 837 0825', '1550 Court Place', 'Suite 102', 'MA', 'USA', '02107', 'NA'),
#  ('3', 'NYC', '+1 212 555 3000', '523 East 53rd Street', 'apt. 5A', 'NY', 'USA', '10022', 'NA'),
#  ('4', 'Paris', '+33 14 723 4404', "43 Rue Jouffroy D'abbans", None, None, 'France', '75017', 'EMEA'),
#  ('5', 'Tokyo', '+81 33 224 5000', '4-1 Kioicho', None, 'Chiyoda-Ku', 'Japan', '102-8578', 'Japan'),
#  ('6', 'Sydney', '+61 2 9264 2451', '5-11 Wentworth Avenue', 'Floor #2', None, 'Australia', 'NSW 2010', 'APAC'),
#  ('7', 'London', '+44 20 7877 2041', '25 Old Broad Street', 'Level 7', None, 'UK', 'EC2N 1HN', 'EMEA'),
#  ('8', 'New York', '+1 212 555-1212', 'W 116th Street', 'and Broadway', 'NY', 'USA', '10027', 'NA')]

# %% [markdown]
# - Example insert with explicitly enumerated columns:

# %%
# %%sql
#     INSERT INTO classicmodels.offices
#     (city, officeCode, country, phone, territory, addressLine1, postalCode)
#     values('Boston', 9, 'USA', '+1 617 555 1212', 'NA', '1 Government Plaza', '02101')
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 1 rows affected.
# []

# %%
# %sql select * from classicmodels.offices
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 9 rows affected.
# [('1', 'San Francisco', '+1 650 219 4782', '100 Market Street', 'Suite 300', 'CA', 'USA', '94080', 'NA'),
#  ('2', 'Boston', '+1 215 837 0825', '1550 Court Place', 'Suite 102', 'MA', 'USA', '02107', 'NA'),
#  ('3', 'NYC', '+1 212 555 3000', '523 East 53rd Street', 'apt. 5A', 'NY', 'USA', '10022', 'NA'),
#  ('4', 'Paris', '+33 14 723 4404', "43 Rue Jouffroy D'abbans", None, None, 'France', '75017', 'EMEA'),
#  ('5', 'Tokyo', '+81 33 224 5000', '4-1 Kioicho', None, 'Chiyoda-Ku', 'Japan', '102-8578', 'Japan'),
#  ('6', 'Sydney', '+61 2 9264 2451', '5-11 Wentworth Avenue', 'Floor #2', None, 'Australia', 'NSW 2010', 'APAC'),
#  ('7', 'London', '+44 20 7877 2041', '25 Old Broad Street', 'Level 7', None, 'UK', 'EC2N 1HN', 'EMEA'),
#  ('8', 'New York', '+1 212 555-1212', 'W 116th Street', 'and Broadway', 'NY', 'USA', '10027', 'NA'),
#  ('9', 'Boston', '+1 617 555 1212', '1 Government Plaza', None, None, 'USA', '02101', 'NA')]

# %% [markdown]
# ### UPDATE
#
# #### Overview
#
# - The basic syntax is:
#
# ```
# UPDATE table_name
#     SET column1 = value1, column2 = value2, ...
#     WHERE condition;
# ```
#
# - The ```WHERE``` condition syntax and behavior is exactly the same as the ```WHERE``` clause in a ```SELECT.```
#
#
# - There ```WHERE``` clause determines the matching rows. The ```SET``` changes the values of the specified columns.
#
#
# - The full MySQL syntax is a little more complicated.
#
# ```
# UPDATE [LOW_PRIORITY] [IGNORE] table_reference
#     SET assignment_list
#     [WHERE where_condition]
#     [ORDER BY ...]
#     [LIMIT row_count]
#
# value:
#     {expr | DEFAULT}
#
# assignment:
#     col_name = value
#
# assignment_list:
#     assignment [, assignment] ...
# ```

# %% [markdown]
# #### Examples
#
# ##### Example 1: Simple
#
# - Change of the zip code for the office with officeCode=11.

# %%
# %sql select * from classicmodels.offices where officeCode=9
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 1 rows affected.
# [('9', 'Boston', '+1 617 555 1212', '1 Government Plaza', None, None, 'USA', '02101', 'NA')]

# %%
# %sql update classicmodels.offices set postalCode="02343",city="Pembroke" where officeCode=9
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 1 rows affected.
# []

# %%
# %sql select * from classicmodels.offices where officeCode=9
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 1 rows affected.
# [('9', 'Pembroke', '+1 617 555 1212', '1 Government Plaza', None, None, 'USA', '02343', 'NA')]

# %% [markdown]
# ##### Example 2: More Complex
#
# - Increase the MSRP for products from ```productLine``` Motorcycles and ```productScale``` 1:10 by 5%.
#
#
# - First, let's get a feel for the ```products``` table.

# %%
# %sql select count(*) as productCount from classicmodels.products;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 1 rows affected.
# [(110,)]

# %% [markdown]
# - There are 110 products. Let's just look at the first 10 to understand structure.

# %%
# %sql select * from classicmodels.products limit 10;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 10 rows affected.
# [('S10_1678', '1969 Harley Davidson Ultimate Chopper', 'Motorcycles', '1:10', 'Min Lin Diecast', 'This replica features working kickstand, front suspension, gear-shift lever, footbrake lever, drive chain, wheels and steering. All parts are particularly delicate due to their precise scale and require special care and attention.', 7933, Decimal('48.81'), Decimal('95.70')),
#  ('S10_1949', '1952 Alpine Renault 1300', 'Classic Cars', '1:10', 'Classic Metal Creations', 'Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.', 7305, Decimal('98.58'), Decimal('214.30')),
#  ('S10_2016', '1996 Moto Guzzi 1100i', 'Motorcycles', '1:10', 'Highway 66 Mini Classics', 'Official Moto Guzzi logos and insignias, saddle bags located on side of motorcycle, detailed engine, working steering, working suspension, two leathe ... (93 characters truncated) ... paint with chrome accents, superior die-cast detail , rotating wheels , working kick stand, diecast metal with plastic parts and baked enamel finish.', 6625, Decimal('68.99'), Decimal('118.94')),
#  ('S10_4698', '2003 Harley-Davidson Eagle Drag Bike', 'Motorcycles', '1:10', 'Red Start Diecast', 'Model features, official Harley Davidson logos and insignias, detachable rear wheelie bar, heavy diecast metal with resin parts, authentic multi-colo ... (199 characters truncated) ... t replica, baked enamel finish, 1:10 scale model, removable fender, seat and tank cover piece for displaying the superior detail of the v-twin engine', 5582, Decimal('91.02'), Decimal('193.66')),
#  ('S10_4757', '1972 Alfa Romeo GTA', 'Classic Cars', '1:10', 'Motor City Art Classics', 'Features include: Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.', 3252, Decimal('85.68'), Decimal('136.00')),
#  ('S10_4962', '1962 LanciaA Delta 16V', 'Classic Cars', '1:10', 'Second Gear Diecast', 'Features include: Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.', 6791, Decimal('103.42'), Decimal('147.74')),
#  ('S12_1099', '1968 Ford Mustang', 'Classic Cars', '1:12', 'Autoart Studio Design', 'Hood, doors and trunk all open to reveal highly detailed interior features. Steering wheel actually turns the front wheels. Color dark green.', 68, Decimal('95.34'), Decimal('194.57')),
#  ('S12_1108', '2001 Ferrari Enzo', 'Classic Cars', '1:12', 'Second Gear Diecast', 'Turnable front wheels; steering function; detailed interior; detailed engine; opening hood; opening trunk; opening doors; and detailed chassis.', 3619, Decimal('95.59'), Decimal('207.80')),
#  ('S12_1666', '1958 Setra Bus', 'Trucks and Buses', '1:12', 'Welly Diecast Productions', 'Model features 30 windows, skylights & glare resistant glass, working steering system, original logos', 1579, Decimal('77.90'), Decimal('136.67')),
#  ('S12_2823', '2002 Suzuki XREO', 'Motorcycles', '1:12', 'Unimax Art Galleries', 'Official logos and insignias, saddle bags located on side of motorcycle, detailed engine, working steering, working suspension, two leather seats, lu ... (82 characters truncated) ... paint with chrome accents, superior die-cast detail , rotating wheels , working kick stand, diecast metal with plastic parts and baked enamel finish.', 9997, Decimal('66.27'), Decimal('150.62'))]

# %% [markdown]
# - Just for verification, let's find the set of rows we plan to update.

# %%
# %sql SELECT * FROM classicmodels.products where productLine='Motorcycles' and productScale='1:10';
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 3 rows affected.
# [('S10_1678', '1969 Harley Davidson Ultimate Chopper', 'Motorcycles', '1:10', 'Min Lin Diecast', 'This replica features working kickstand, front suspension, gear-shift lever, footbrake lever, drive chain, wheels and steering. All parts are particularly delicate due to their precise scale and require special care and attention.', 7933, Decimal('48.81'), Decimal('95.70')),
#  ('S10_2016', '1996 Moto Guzzi 1100i', 'Motorcycles', '1:10', 'Highway 66 Mini Classics', 'Official Moto Guzzi logos and insignias, saddle bags located on side of motorcycle, detailed engine, working steering, working suspension, two leathe ... (93 characters truncated) ... paint with chrome accents, superior die-cast detail , rotating wheels , working kick stand, diecast metal with plastic parts and baked enamel finish.', 6625, Decimal('68.99'), Decimal('118.94')),
#  ('S10_4698', '2003 Harley-Davidson Eagle Drag Bike', 'Motorcycles', '1:10', 'Red Start Diecast', 'Model features, official Harley Davidson logos and insignias, detachable rear wheelie bar, heavy diecast metal with resin parts, authentic multi-colo ... (199 characters truncated) ... t replica, baked enamel finish, 1:10 scale model, removable fender, seat and tank cover piece for displaying the superior detail of the v-twin engine', 5582, Decimal('91.02'), Decimal('193.66'))]

# %% [markdown]
# - Now perform the update:

# %%
# %%sql
# update classicmodels.products set MSRP=(1.05*MSRP) where productLine='Motorcycles' and productScale='1:10';
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 3 rows affected.
# C:\Users\dferguso\Anaconda\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'MSRP' at row 1")
#   result = self._query(query)
# C:\Users\dferguso\Anaconda\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'MSRP' at row 2")
#   result = self._query(query)
# C:\Users\dferguso\Anaconda\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'MSRP' at row 3")
#   result = self._query(query)
# []

# %%
# %sql SELECT * FROM classicmodels.products where productLine='Motorcycles' and productScale='1:10';
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 3 rows affected.
# [('S10_1678', '1969 Harley Davidson Ultimate Chopper', 'Motorcycles', '1:10', 'Min Lin Diecast', 'This replica features working kickstand, front suspension, gear-shift lever, footbrake lever, drive chain, wheels and steering. All parts are particularly delicate due to their precise scale and require special care and attention.', 7933, Decimal('48.81'), Decimal('100.49')),
#  ('S10_2016', '1996 Moto Guzzi 1100i', 'Motorcycles', '1:10', 'Highway 66 Mini Classics', 'Official Moto Guzzi logos and insignias, saddle bags located on side of motorcycle, detailed engine, working steering, working suspension, two leathe ... (93 characters truncated) ... paint with chrome accents, superior die-cast detail , rotating wheels , working kick stand, diecast metal with plastic parts and baked enamel finish.', 6625, Decimal('68.99'), Decimal('124.89')),
#  ('S10_4698', '2003 Harley-Davidson Eagle Drag Bike', 'Motorcycles', '1:10', 'Red Start Diecast', 'Model features, official Harley Davidson logos and insignias, detachable rear wheelie bar, heavy diecast metal with resin parts, authentic multi-colo ... (199 characters truncated) ... t replica, baked enamel finish, 1:10 scale model, removable fender, seat and tank cover piece for displaying the superior detail of the v-twin engine', 5582, Decimal('91.02'), Decimal('203.34'))]

# %% [markdown]
# - The truncated warning is due to the fact that:
#     - The MSRP columns is of type DECIMAL(10,2).
#     - Multiplying by 1.05 produces real numbers with more than two digits after the decimal.
#     - The value is truncated to DECIMAL(10,2)
#
#
# - We can fix several ways. The easiest way is to round the result to two decimal places.

# %%
# %%sql
# update classicmodels.products set MSRP=round((1.05*MSRP),2) where productLine='Motorcycles' and productScale='1:10';
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 3 rows affected.
# []

# %%
# %sql SELECT * FROM classicmodels.products where productLine='Motorcycles' and productScale='1:10';
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 3 rows affected.
# [('S10_1678', '1969 Harley Davidson Ultimate Chopper', 'Motorcycles', '1:10', 'Min Lin Diecast', 'This replica features working kickstand, front suspension, gear-shift lever, footbrake lever, drive chain, wheels and steering. All parts are particularly delicate due to their precise scale and require special care and attention.', 7933, Decimal('48.81'), Decimal('105.51')),
#  ('S10_2016', '1996 Moto Guzzi 1100i', 'Motorcycles', '1:10', 'Highway 66 Mini Classics', 'Official Moto Guzzi logos and insignias, saddle bags located on side of motorcycle, detailed engine, working steering, working suspension, two leathe ... (93 characters truncated) ... paint with chrome accents, superior die-cast detail , rotating wheels , working kick stand, diecast metal with plastic parts and baked enamel finish.', 6625, Decimal('68.99'), Decimal('131.13')),
#  ('S10_4698', '2003 Harley-Davidson Eagle Drag Bike', 'Motorcycles', '1:10', 'Red Start Diecast', 'Model features, official Harley Davidson logos and insignias, detachable rear wheelie bar, heavy diecast metal with resin parts, authentic multi-colo ... (199 characters truncated) ... t replica, baked enamel finish, 1:10 scale model, removable fender, seat and tank cover piece for displaying the superior detail of the v-twin engine', 5582, Decimal('91.02'), Decimal('213.51'))]

# %% [markdown]
# ### DELETE
#
# #### Overview
#
# - Very similar to ```SELECT``` and ```UPDATE.```
#
# ```
# DELETE FROM table_name WHERE condition;
# ```
#
# - The more complex, full MySQL syntax is:
#
# ```
# DELETE [LOW_PRIORITY] [QUICK] [IGNORE] FROM tbl_name
#     [PARTITION (partition_name [, partition_name] ...)]
#     [WHERE where_condition]
#     [ORDER BY ...]
#     [LIMIT row_count]
# ```

# %% [markdown]
# #### Example
#
# - I do not want to delete, or try to delete, too much of the various databases I have installed.
#
#
# - I am going to delete a couple of the rows that I previously inserted.

# %%
# %sql select * from classicmodels.offices
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 9 rows affected.
# [('1', 'San Francisco', '+1 650 219 4782', '100 Market Street', 'Suite 300', 'CA', 'USA', '94080', 'NA'),
#  ('2', 'Boston', '+1 215 837 0825', '1550 Court Place', 'Suite 102', 'MA', 'USA', '02107', 'NA'),
#  ('3', 'NYC', '+1 212 555 3000', '523 East 53rd Street', 'apt. 5A', 'NY', 'USA', '10022', 'NA'),
#  ('4', 'Paris', '+33 14 723 4404', "43 Rue Jouffroy D'abbans", None, None, 'France', '75017', 'EMEA'),
#  ('5', 'Tokyo', '+81 33 224 5000', '4-1 Kioicho', None, 'Chiyoda-Ku', 'Japan', '102-8578', 'Japan'),
#  ('6', 'Sydney', '+61 2 9264 2451', '5-11 Wentworth Avenue', 'Floor #2', None, 'Australia', 'NSW 2010', 'APAC'),
#  ('7', 'London', '+44 20 7877 2041', '25 Old Broad Street', 'Level 7', None, 'UK', 'EC2N 1HN', 'EMEA'),
#  ('8', 'New York', '+1 212 555-1212', 'W 116th Street', 'and Broadway', 'NY', 'USA', '10027', 'NA'),
#  ('9', 'Boston', '+1 617 555 1212', '1 Government Plaza', None, None, 'USA', '02101', 'NA')]

# %% [markdown]
# - Just to show a slightly more complex example of ```DELETE```

# %%
# %%sql
# delete from classicmodels.offices where city='Boston' and addressLine1='1 Government Plaza'
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 1 rows affected.
# []

# %%
# %sql select * from classicmodels.offices where officeCode=9
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 0 rows affected.
# []

# %% [markdown]
# ## HW1 Checkpoint
#
# ### Core Concept
#
# - ```RDBDataTable``` and ```CSVDataTable``` have four core methods:
#     - ```find_by_template(self, template, field_list=None, limit=None, offset=None, order_by=None)```
#     - ```delete_by_template(self, template)```
#     - ```update_by_template(self, template, new_values)```
#     - ```insert(self, new_record)```
#
#
# - ```by_template``` is core to three of the methods: ```find_by_template, udate_by_template, delete_by_template.```
#
#
# - How do you handle templates?
#
#
# ### CSV Files
#
# ```1.``` The first step is to load the CSV file into a data structure, e.g. _list_

# %%
import csv

_default_directory = \
        "C:\\Users\\dferguso\\ansys_one_drive\\Columbia\Projects\\W4111\\HW1Impl\\Data" + \
            "\\baseballdatabank-2019.2\\core\\"

def load_csv_file(fn):
    
    # Open the file in read model
    with open(fn, "r") as in_file:
        
        # Wrap with class that helps reading CSV files.
        csv_rdr = csv.DictReader(in_file)
        
        # Place to hold the result
        result = []
        
        # Build the result
        for r in csv_rdr:
            result.append(r)
            
    return result

# %%
import os
fn = os.path.join(_default_directory, "People.csv")
the_people = load_csv_file(fn)

# %%
print("Load got", len(the_people), "rows.")
# Out:
# Load got 19617 rows.

# %%
import json
print("A typical row looks like: \n", json.dumps(the_people[0], indent=2))
# Out:
# A typical row looks like:
#  {
#   "playerID": "aardsda01",
#   "birthYear": "1981",
#   "birthMonth": "12",
#   "birthDay": "27",
#   "birthCountry": "USA",
#   "birthState": "CO",
#   "birthCity": "Denver",
#   "deathYear": "",
#   "deathMonth": "",
#   "deathDay": "",
#   "deathCountry": "",
#   "deathState": "",
#   "deathCity": "",
#   "nameFirst": "David",
#   "nameLast": "Aardsma",
#   "nameGiven": "David Allan",
#   "weight": "215",
#   "height": "75",
#   "bats": "R",
#   "throws": "R",
#   "debut": "2004-04-06",
#   "finalGame": "2015-08-23",
#   "retroID": "aardd001",
#   "bbrefID": "aardsda01"
# }

# %% [markdown]
# ```2.``` How do you check if a specific row matches a template?

# %%
template = {"nameLast": "Aardsma", "throws": "R"}


def matches_template(row, template):
    
    result = True
    
    # Look at every attribute in the template and see if there is a match.
    for k,v in template.items():
        
        # Get the corresponding value in the row, or None if not there.
        row_v = row.get(k, None)
       
        if v != row_v:
            result = False
            break
            
    return result

# %%
match = matches_template(the_people[0], template)
match
# Out:
# True

# %%
template2 = {"nameLast": "Aardsma", "throws": "L"}
match = matches_template(the_people[0], template2)
match
# Out:
# False

# %% [markdown]
# ```3.``` Apply the matcher to all the rows. This is a simple loop.
#
#
# ```4.``` You also need to get the subset of fields requested.

# %%
def get_fields(row, field_list):
    
    result = {}
    for f in field_list:
        
        # A good program would catch an exception if field is not in the row.
        # Do not worry about it. This is not a robust programming course.
        result[f] = row[f]
        
    return result

# %%
field_list = ['nameFirst', 'nameLast', 'birthState']
requested_fields = get_fields(the_people[0], field_list)
print("Requested fields = ", json.dumps(requested_fields, indent=2))
# Out:
# Requested fields =  {
#   "nameFirst": "David",
#   "nameLast": "Aardsma",
#   "birthState": "CO"
# }

# %% [markdown]
# ### How do You do this for SQL
#
# ```1.``` You have to make a ```WHERE``` clause.

# %%
def template_to_where_clause(template):
    
    if template is None or template == {}:
        w_clause = None
        args = None
    else:
        terms = []
        args = []
        for k,v in template.items():
            terms.append(k + "=%s")
            args.append(v)
            
        w_clause = "where " + (" and ".join(terms))
        
    return w_clause, args

# %%
template = {"nameLast": "Aardsma", "nameFirst": "David"}
w_clause, args = template_to_where_clause(template)

# %%
w_clause
# Out:
# 'where nameLast=%s and nameFirst=%s'

# %%
args
# Out:
# ['Aardsma', 'David']

# %% [markdown]
# ```2.``` You also have to pick some fields.

# %%
def get_select_fields(fields):
    
    if fields is None or fields == []:
        field_list = " * "
    else:
        field_list = ",".join(fields)
        
    return field_list

# %%
fields = ['nameLast', 'nameFirst', 'birthCity', 'throws']
field_list = get_select_fields(fields)
field_list
# Out:
# 'nameLast,nameFirst,birthCity,throws'

# %% [markdown]
# ```3.``` Now, we can put the pieces together.

# %%
fields = ['nameLast', 'nameFirst', 'birthCity', 'throws']
template = {"nameLast": "Aardsma", "nameFirst": "David"}
w_clause, arhs = template_to_where_clause(template)
field_list = get_select_fields(fields)
table_name = "lahman2019raw.people"

# %%
sql = "select " + field_list + " from " + table_name + " " + w_clause
sql
# Out:
# 'select nameLast,nameFirst,birthCity,throws from lahman2019raw.people where nameLast=%s and nameFirst=%s'

# %% [markdown]
# ```4.``` Now run the query.

# %%
cur = default_cnx.cursor()
res = cur.execute(sql, args)
result = cur.fetchall()
print("Result = ", json.dumps(result, indent=2))
# Out:
# Result =  [
#   {
#     "nameLast": "Aardsma",
#     "nameFirst": "David",
#     "birthCity": "Denver",
#     "throws": "R"
#   }
# ]

# %% [markdown]
# ### Summary
#
# 1. This HW may seem overwhelming. It is actually very simple.<br><br>
# 2. The homework only requires programming knowledge that you learn in 1004, 1007 or 1007.<br><br>
# 3. Solving the HW requires:
#     - Writing several "helper" functions each of which does a simple task.
#     - Putting the smaller pieces together into the larger methods in the class.<br><br>
# 4. The complexity stems for the fact that we do not sufficiently teach you how to write larger programs through decomposition and assembly. All of your past programming assignments have not taught you do develop and test this way.

# %% [markdown]
# ## Primary Key
#
# ### Conept
#
# - Briefly discussed the concept in lecture 1, and will cover in more detail now.
#
#
# - There are several types of keys:
#     - Super key: A set of attributes within a table whose values can be used to uniquely identify a tuple.
#     - Candidate key: A minimal super key. That is, no subset of the columns is a super key.
#     - Primary key: Candidate key arbitrarily chosen to be the "primary" key.
#     - Alternate key: Alternate key is the key that can work as a primary key. Basically it is a candidate key that currently is not primary key.
#     - Composite/Compound key: Composite Key is a combination of more than one fields/columns of a table. It can be a Candidate key, Primary key.
#     - Unique Key: Unique key is a set of one or more fields/columns of a table that uniquely identify a record in database table but can be NULL.
#     - Foreign key: Foreign key is a a set of columns in database table that is primary key in another table. It can accept multiple null, duplicate values.
#     - Natural key: A natural key (also known as business key) is a type of unique key, found in relational model database design, that is formed of attributes that already exist in the real world. It is used in business-related columns. In other words, a natural key is a candidate key that has a logical relationship to the attributes within that row. A natural key is sometimes called domain key. (https://en.wikipedia.org/wiki/Candidate_key)
#     - Surrogate key: A surrogate key (or synthetic key, entity identifier, system-generated key, database sequence number, factless key, technical key, or arbitrary unique identifier) in a database is a unique identifier for either an entity in the modeled world or an object in the database. The surrogate key is not derived from application data, unlike a natural (or business) key which is derived from application data. (https://en.wikipedia.org/wiki/Surrogate_key)
#
#
# - "In the relational model of databases, a primary key is a specific choice of a minimal set of attributes (columns) that uniquely specify a tuple (row) in a relation (table). Informally, a primary key is 'which attributes identify a record', and in simple cases are simply a single attribute: a unique id. More formally, a primary key is a choice of candidate key (a minimal superkey); any other candidate key is an alternate key.<br><br>
# A primary key may consist of real-world observables, in which case it is called a natural key, while an attribute created to function as a key is called a surrogate key. For example, for a database of people (of a given nationality), time and location of birth is a natural key, while national identification numbers are surrogate keys." (https://en.wikipedia.org/wiki/Primary_key)
#
#
# - __Note:__
#     - Time and location of birth is a terrible natural key.
#     - A better example is ```Appearances``` in Lahman database, the columns: ```playerID, teamID, yearID``` uniquely identify a tuple.
#     - The RDB engine will enforce any defined primary key. Your code just needs to handle any exceptions.
#     - You will need to implement primary key definition on ```CSVDataTable``` instance creation.

# %% [markdown]
# ### Relational Model $-$ Keys
#
# - "_Data integrity_ is the maintenance of, and the assurance of the accuracy and consistency of, data over its entire life-cycle, and is a critical aspect to the design, implementation and usage of any system which stores, processes, or retrieves data." (https://en.wikipedia.org/wiki/Data_integrity)
#
#
# - _Relational (integrity) constraints_ are central to the value of relational databases.
#     - The database designer _declares (defines)_ integrity constraints.
#     - The database management system _rejects_ any _create, update_ or _delete_ operation that would result in a constraint violation.
#
#
# - _Key(s)_ is a core  _(integrity) constraint_ enforcing _data integrity._
#     - A _super key_ is a combination of columns with the property that no two rows have the same values for the fields of a super key.
#     - A _candidate key_ is a minimal _super key_, that is removing a column from the key definition means that the key no longer uniquely identifies a row.,
#     - The _primary key_ is a candidate key subjectively chosen as the "best key" for uniquely identifying the tuples.
#
#
# - You will some times here the term _functionally determines._
#     - Assume we have a relation $R(a,b,c,d,e)$.
#     - If $(a,b)$ is a key $k$, then
#     - The we can say that $k(a,b)$ _functionally determines_ $(c,d,e).$
#     - Given values $(x,y)$ for $(a,b)$ we can functionally return $(c,d,e).$ The function is
#
#     $\pi$<sub>$c,d,e$</sub>$(\sigma$<sub>$(a=x)\land(b=y)$</sub>$(R))$

# %% [markdown]
# - One common notation for identifying a key in the relational notation is an ```overline.```<br>
# \begin{equation}
# R = (\overline{a,b},c,d)
# \end{equation}

# %% [markdown]
# ### Keys and Indexes $-$ SQL
#
# #### Overview
#
# - Relational database engines support additional key semantics and also support _indexes._
#
#
# - MySQL supports the following keys/index:
#     - PRIMARY KEY: Key is unique and NOT NULL. $\Rightarrow$ Indexed
#     - UNIQUE: Key is unique or NULL. Multiple rows may have NULL for a value if column definition allows NULL. $\Rightarrow$ Indexed
#     - INDEX: Non-unique but indexed for performance.
#     - FULLTEXT (INDEX) -- Will cover later.
#
#
# - In database engines, keys represent/implement
#     - Integrity constraints. We will cover the concept in detail in future lectures.
#     - Performance optimization.
#
#
# - For now, just think:
#     - Every table should have a primary key.
#     - Put indexes on other columns or sets of columns that will frequently be in WHERE clauses.
#
#
# - For a table with 1,000,000 rows:
#     - SELECT without a index examines O(1,000,000) rows.
#     - SELECT with an index examines O(log(1,000,000)) = 20 rows.
#
#
# - RDB query engine compute a "cost" in terms of CPU and disk input/output for relational operations. This is critical to _query optimization,_ which we will cover later. For comparison of the benefits of indexes, the cost of ```select * from people where playerid='willite01'```
#     - Without index = 4,071.
#     - With index = 1
#
#
# - We will cover query optimization and cost in Module II: Database Management System Implementation/Architecture.

# %% [markdown]
# #### An Example
#
# - A course directory entry for a database course/section.
#
# <hr style="height: 1px;">
#
# | <img src="../../images/course_directory_entry.jpeg"> |
# | :---: |
# | __Student SSOL for W4111__ |
#
# <hr style="height: 1px;">

# %% [markdown]
# - I pulled down some course data for me.
#
#
# - How do I figure out the keys?
#
#
# - You can use ```SELECT COUNT(*) GROUP BY A,B,C``` for various sets of columns.
#
#
# - We will cover _Aggregation_ in the next lecture, but you can use now.
#
#
# - Let's look at the data.

# %%
# %sql select * from w4111f19.course_catalog
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 15 rows affected.
# [('11912', 'TOPICS IN COMPUTER SCIENCE', 'COMSE6998', '010', '2016', '3'),
#  ('34758', 'TOPICS IN COMPUTER SCIENCE', 'COMSE6998', '006', '2017', '1'),
#  ('47421', 'TOPICS IN COMPUTER SCIENCE', 'COMSE6998', '014', '2017', '3'),
#  ('47468', 'INTRODUCTION TO DATABASES', 'COMSW4111', '003', '2017', '3'),
#  ('53309', 'INTRODUCTION TO DATABASES', 'COMSW4111', '002', '2018', '1'),
#  ('53496', 'INTRO TO COMP FOR ENG/APP SCI', 'ENGIE1006', '001', '2018', '1'),
#  ('59651', 'FIELDWORK', 'COMSW3999', '063', '2018', '3'),
#  ('59653', 'INTRODUCTION TO DATABASES', 'COMSW4111', '001', '2018', '3'),
#  ('61720', 'THE ART OF ENGINEERING', 'ENGIE1102', '001', '2018', '3'),
#  ('69174', 'TOPICS IN SOFTWARE ENGINEERING: Cloud and Microservice Applications', 'COMSE6156', '001', '2018', '3'),
#  ('79571', 'INTRODUCTION TO DATABASES', 'COMSW4111', '003', '2019', '1'),
#  ('82004', 'FIELDWORK', 'COMSW3999', '063', '2019', '2'),
#  ('85777', 'INTRODUCTION TO DATABASES', 'COMSW4111', '002', '2019', '3'),
#  ('87722', 'TOPICS IN SOFTWARE ENGINEERING', 'COMSE6156', '001', '2019', '3'),
#  ('91884', 'INTRODUCTION TO DATABASES', 'COMSW4111', 'H02', '2019', '3')]

# %%
# %sql select count(*) as no_of_rows from w4111f19.course_catalog
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 1 rows affected.
# [(15,)]

# %% [markdown]
# - Is ```course_no``` a key?

# %%
# %sql select course_no, count(*) as no_of_occurences  from w4111f19.course_catalog group by course_no;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 6 rows affected.
# [('COMSE6998', 3),
#  ('COMSW4111', 6),
#  ('ENGIE1006', 1),
#  ('COMSW3999', 2),
#  ('ENGIE1102', 1),
#  ('COMSE6156', 2)]

# %% [markdown]
# - Clearly not.

# %% [markdown]
# - How about ```course_no``` and ```year?```

# %%
# %sql select course_no, year, count(*) as no_of_occurences  from w4111f19.course_catalog group by course_no, year;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 11 rows affected.
# [('COMSE6998', '2016', 1),
#  ('COMSE6998', '2017', 2),
#  ('COMSW4111', '2017', 1),
#  ('COMSW4111', '2018', 2),
#  ('ENGIE1006', '2018', 1),
#  ('COMSW3999', '2018', 1),
#  ('ENGIE1102', '2018', 1),
#  ('COMSE6156', '2018', 1),
#  ('COMSW4111', '2019', 3),
#  ('COMSW3999', '2019', 1),
#  ('COMSE6156', '2019', 1)]

# %% [markdown]
# - How about ```course_no, year, section?```

# %%
# %sql select course_no, year, section, count(*) as no_of_occurences  from w4111f19.course_catalog \
    group by course_no, year, section;
# Out:
#  * mysql+pymysql://dbuser:***@localhost/lahman2019raw
# 15 rows affected.
# [('COMSE6998', '2016', '010', 1),
#  ('COMSE6998', '2017', '006', 1),
#  ('COMSE6998', '2017', '014', 1),
#  ('COMSW4111', '2017', '003', 1),
#  ('COMSW4111', '2018', '002', 1),
#  ('ENGIE1006', '2018', '001', 1),
#  ('COMSW3999', '2018', '063', 1),
#  ('COMSW4111', '2018', '001', 1),
#  ('ENGIE1102', '2018', '001', 1),
#  ('COMSE6156', '2018', '001', 1),
#  ('COMSW4111', '2019', '003', 1),
#  ('COMSW3999', '2019', '063', 1),
#  ('COMSW4111', '2019', '002', 1),
#  ('COMSE6156', '2019', '001', 1),
#  ('COMSW4111', '2019', 'H02', 1)]

# %% [markdown]
# - That looks promising, but ...
#     - This is due to the fact that these are the courses that I teach.
#     - There are three or four database sections each semester.
#     - It is possible that I could teach ```section 003``` in different semesters. This has not happened, __but it could.__
#
#
# - A key is a statement about the __all possible values for the relation/table,__ not just the rows currently in the table.
#
#
# - In this simple case, the actual answer is:
#     - Course number.
#     - Section number.
#     - Semester.
#     - Year.

# %% [markdown]
# # Data Modeling and Some Examples
#
# ## Setup Scenario
#
# - Let's assume we we are going to build a course/section database for Columbia courses.
#
#
# - We would conduct interviews and look at forms/documentation to determine what the data model underlying the information is.
#
#
# - There already are databases, but let's pretend we are trying to build the database from existing information (docs, forms).

# %% [markdown]
# ## Course and Section Information Table
#
# - Let's look at some of the information that we would find in interviews, looking at forms, ...
#
# | <img src="../../images/course_info_1.jpg" width="900px"> |
# | :---: |
# | __Course/Section Information: Course Works__ |

# %% [markdown]
# | <img src="../../images/course_info_2.jpg" width="900px"> |
# | :---: |
# | __Course/Section Information: Section Information__ |

# %% [markdown]
# | <img src="../../images/course_info_3.jpg" width="900px"> |
# | :---: |
# | __Course/Section Information: Scheduled Classes__ |
#
#
# | <img src="../../images/course_info_4.jpg" width="900px"> |
# | :---: |
# | __Course/Section Information: Standard Times__ |
